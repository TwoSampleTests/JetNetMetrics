# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [3]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more.deformations import deformed_distribution, deform_mean, deform_cov_diag, deform_cov_off_diag, deform_power_abs, deform_random
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection_dataset # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-07-02 11:13:49.452887: Importing os...
# 2024-07-02 11:13:49.453113: Importing sys...
# Visible devices: [3]
# 2024-07-02 11:13:49.453370: Importing timer from timeit...
# 2024-07-02 11:13:49.453446: Setting env variables for tf import (only device(s) [3] will be available)...
# 2024-07-02 11:13:49.453582: Importing numpy...
# 2024-07-02 11:13:49.595018: Importing matplotlib...
# 2024-07-02 11:13:50.032602: Importing h5py...
# 2024-07-02 11:13:50.061451: Importing importlib.util...
# 2024-07-02 11:13:50.061566: Importing json...
# 2024-07-02 11:13:50.061629: Importing pandas...
# 2024-07-02 11:13:50.590550: Importing random...
# 2024-07-02 11:13:50.590702: Importing scipy utils...
# 2024-07-02 11:13:51.054064: Importing subprocess...
# 2024-07-02 11:13:51.054213: Importing textwrap...
# 2024-07-02 11:13:51.054278: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-07-02 11:13:54.955623: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-07-02 11:13:56.014861: Importing timeit...
# 2024-07-02 11:13:56.014976: Importing tqdm...
# 2024-07-02 11:13:56.024552: Importing typing...
# 2024-07-02 11:13:56.024699: Setting tf configs...
# 2024-07-02 11:13:56.129081: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-07-02 11:14:01.521847: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #3, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-07-02 11:14:01.551593: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 60,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 60, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 60, 4)

# %% [markdown]
# # Particle level

# %% [markdown]
# ## Init data

# %%
results_dir = "results_leo/particle_features_60/"
figures_dir = os.path.join(results_dir, "figures/")
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocess_data=(data-means)/stds
    return preprocess_data

def postprocess_data(data,means,stds):
    postprocess_data=data*stds+means
    return postprocess_data

def get_reduced_particle_features(particle_features):
    tmp = particle_features[:, :, :3]
    shape = tmp.shape
    particle_features_reshaped = tf.reshape(tmp, [-1, shape[1] * shape[2]])
    return particle_features_reshaped

particle_features_reduced = get_reduced_particle_features(particle_features)
particle_features_reduced.shape
# Out:
# TensorShape([177252, 180])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests/")
model_dir = os.path.join(tests_dir, '10K/')
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    
dataset = get_reduced_particle_features(particle_features)

# %% [markdown]
# ## 10K

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(model_dir, 'null_hypotheses/')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(model_dir, "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 10_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 10_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 8, nbootstrap: 125
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputsNull.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0      8            10000            1000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  is_symb_1  ndims_1  \
# 0     0    True            False     None     True      False      180
#
#    nsamples_1  is_symb_2  ndims_2  nsamples_2    dtype  ndims  nsamples  \
# 0       80000      False      180       80000  float64    180     80000
#
#    small_sample
# 0         False

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 10_000, 
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {"verbose": True}, 
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 360,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values())[3:]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng sks with max_vectorize = 800
#
# ===========================================================
# Testing from 0 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 8.466021046042442 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3231294569559395 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1818344799103215 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.15107615001034 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f911ff3f9c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SKS metric calculation completed in 3.0583172329934314 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7f8f4448e520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SKS metric calculation completed in 3.427351817023009 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.874028217047453 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4282854419434443 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1019260090542957 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.443391044042073 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.057541832095012 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.27782501897309 seconds.
#
# ===========================================================
# Testing from 96 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.094857599004172 seconds.
#
# ===========================================================
# Testing from 104 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.421834795968607 seconds.
#
# ===========================================================
# Testing from 112 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3429193740012124 seconds.
#
# ===========================================================
# Testing from 120 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.177362743997946 seconds.
#
# ===========================================================
# Testing from 128 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.388276546029374 seconds.
#
# ===========================================================
# Testing from 136 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3435167249990627 seconds.
#
# ===========================================================
# Testing from 144 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4536170050268993 seconds.
#
# ===========================================================
# Testing from 152 to 160 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2497236790368333 seconds.
#
# ===========================================================
# Testing from 160 to 168 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.486370514030568 seconds.
#
# ===========================================================
# Testing from 168 to 176 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4057290019700304 seconds.
#
# ===========================================================
# Testing from 176 to 184 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5574191389605403 seconds.
#
# ===========================================================
# Testing from 184 to 192 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1363034709356725 seconds.
#
# ===========================================================
# Testing from 192 to 200 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.199124107020907 seconds.
#
# ===========================================================
# Testing from 200 to 208 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.9516036090208218 seconds.
#
# ===========================================================
# Testing from 208 to 216 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.402169194072485 seconds.
#
# ===========================================================
# Testing from 216 to 224 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1489940600004047 seconds.
#
# ===========================================================
# Testing from 224 to 232 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.189584926934913 seconds.
#
# ===========================================================
# Testing from 232 to 240 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.161764962016605 seconds.
#
# ===========================================================
# Testing from 240 to 248 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.050818418967538 seconds.
#
# ===========================================================
# Testing from 248 to 256 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.378183731925674 seconds.
#
# ===========================================================
# Testing from 256 to 264 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.105698077008128 seconds.
#
# ===========================================================
# Testing from 264 to 272 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2073582159355283 seconds.
#
# ===========================================================
# Testing from 272 to 280 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.018787396955304 seconds.
#
# ===========================================================
# Testing from 280 to 288 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.347371896961704 seconds.
#
# ===========================================================
# Testing from 288 to 296 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1195846900809556 seconds.
#
# ===========================================================
# Testing from 296 to 304 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.323504065978341 seconds.
#
# ===========================================================
# Testing from 304 to 312 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.220548570039682 seconds.
#
# ===========================================================
# Testing from 312 to 320 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.213643944938667 seconds.
#
# ===========================================================
# Testing from 320 to 328 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3734175759600475 seconds.
#
# ===========================================================
# Testing from 328 to 336 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2113540819846094 seconds.
#
# ===========================================================
# Testing from 336 to 344 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.258141294005327 seconds.
#
# ===========================================================
# Testing from 344 to 352 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.006240436108783 seconds.
#
# ===========================================================
# Testing from 352 to 360 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.441089599044062 seconds.
#
# ===========================================================
# Testing from 360 to 368 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2544511519372463 seconds.
#
# ===========================================================
# Testing from 368 to 376 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3920643619494513 seconds.
#
# ===========================================================
# Testing from 376 to 384 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.120995822013356 seconds.
#
# ===========================================================
# Testing from 384 to 392 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.261807191069238 seconds.
#
# ===========================================================
# Testing from 392 to 400 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.079362265067175 seconds.
#
# ===========================================================
# Testing from 400 to 408 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4744763009948656 seconds.
#
# ===========================================================
# Testing from 408 to 416 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1960619759047404 seconds.
#
# ===========================================================
# Testing from 416 to 424 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2217318420298398 seconds.
#
# ===========================================================
# Testing from 424 to 432 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.205337337916717 seconds.
#
# ===========================================================
# Testing from 432 to 440 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.257740692002699 seconds.
#
# ===========================================================
# Testing from 440 to 448 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4121167899575084 seconds.
#
# ===========================================================
# Testing from 448 to 456 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.199203714961186 seconds.
#
# ===========================================================
# Testing from 456 to 464 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.257937308982946 seconds.
#
# ===========================================================
# Testing from 464 to 472 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 2.990698765963316 seconds.
#
# ===========================================================
# Testing from 472 to 480 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.459539759089239 seconds.
#
# ===========================================================
# Testing from 480 to 488 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.119108142098412 seconds.
#
# ===========================================================
# Testing from 488 to 496 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.394877983024344 seconds.
#
# ===========================================================
# Testing from 496 to 504 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1588143260451034 seconds.
#
# ===========================================================
# Testing from 504 to 512 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.144283203058876 seconds.
#
# ===========================================================
# Testing from 512 to 520 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.222400557948276 seconds.
#
# ===========================================================
# Testing from 520 to 528 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.403064651065506 seconds.
#
# ===========================================================
# Testing from 528 to 536 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3391354830237105 seconds.
#
# ===========================================================
# Testing from 536 to 544 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1506827489938587 seconds.
#
# ===========================================================
# Testing from 544 to 552 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2320287860929966 seconds.
#
# ===========================================================
# Testing from 552 to 560 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.009196581901051 seconds.
#
# ===========================================================
# Testing from 560 to 568 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.577570660971105 seconds.
#
# ===========================================================
# Testing from 568 to 576 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.207488479092717 seconds.
#
# ===========================================================
# Testing from 576 to 584 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3566039920551702 seconds.
#
# ===========================================================
# Testing from 584 to 592 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1108854360645637 seconds.
#
# ===========================================================
# Testing from 592 to 600 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2025610400596634 seconds.
#
# ===========================================================
# Testing from 600 to 608 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.13377053802833 seconds.
#
# ===========================================================
# Testing from 608 to 616 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.430246287956834 seconds.
#
# ===========================================================
# Testing from 616 to 624 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.280441729002632 seconds.
#
# ===========================================================
# Testing from 624 to 632 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1484151770127937 seconds.
#
# ===========================================================
# Testing from 632 to 640 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.221660449053161 seconds.
#
# ===========================================================
# Testing from 640 to 648 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.3325815229909495 seconds.
#
# ===========================================================
# Testing from 648 to 656 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.572696250048466 seconds.
#
# ===========================================================
# Testing from 656 to 664 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.396261199028231 seconds.
#
# ===========================================================
# Testing from 664 to 672 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5493362329434603 seconds.
#
# ===========================================================
# Testing from 672 to 680 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1265044449828565 seconds.
#
# ===========================================================
# Testing from 680 to 688 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.712206204072572 seconds.
#
# ===========================================================
# Testing from 688 to 696 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3759865920292214 seconds.
#
# ===========================================================
# Testing from 696 to 704 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.553765225922689 seconds.
#
# ===========================================================
# Testing from 704 to 712 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1836141259409487 seconds.
#
# ===========================================================
# Testing from 712 to 720 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5215445059584454 seconds.
#
# ===========================================================
# Testing from 720 to 728 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.285004619974643 seconds.
#
# ===========================================================
# Testing from 728 to 736 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6389583299169317 seconds.
#
# ===========================================================
# Testing from 736 to 744 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.205357968923636 seconds.
#
# ===========================================================
# Testing from 744 to 752 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.569506661966443 seconds.
#
# ===========================================================
# Testing from 752 to 760 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.1682802670402452 seconds.
#
# ===========================================================
# Testing from 760 to 768 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4933353330707178 seconds.
#
# ===========================================================
# Testing from 768 to 776 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.435400178073905 seconds.
#
# ===========================================================
# Testing from 776 to 784 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.479191279038787 seconds.
#
# ===========================================================
# Testing from 784 to 792 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.380059689981863 seconds.
#
# ===========================================================
# Testing from 792 to 800 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.255058628041297 seconds.
#
# ===========================================================
# Testing from 800 to 808 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2627582480199635 seconds.
#
# ===========================================================
# Testing from 808 to 816 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.3380364530021325 seconds.
#
# ===========================================================
# Testing from 816 to 824 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.587575334007852 seconds.
#
# ===========================================================
# Testing from 824 to 832 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4937037780182436 seconds.
#
# ===========================================================
# Testing from 832 to 840 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5825243371073157 seconds.
#
# ===========================================================
# Testing from 840 to 848 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3951509500620887 seconds.
#
# ===========================================================
# Testing from 848 to 856 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.817536709015258 seconds.
#
# ===========================================================
# Testing from 856 to 864 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5870618049521 seconds.
#
# ===========================================================
# Testing from 864 to 872 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.586548065999523 seconds.
#
# ===========================================================
# Testing from 872 to 880 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4130675720516592 seconds.
#
# ===========================================================
# Testing from 880 to 888 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5172933940775692 seconds.
#
# ===========================================================
# Testing from 888 to 896 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3101812649983913 seconds.
#
# ===========================================================
# Testing from 896 to 904 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.014971447060816 seconds.
#
# ===========================================================
# Testing from 904 to 912 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5408465270884335 seconds.
#
# ===========================================================
# Testing from 912 to 920 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5827006039908156 seconds.
#
# ===========================================================
# Testing from 920 to 928 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4938545710174367 seconds.
#
# ===========================================================
# Testing from 928 to 936 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5160086000105366 seconds.
#
# ===========================================================
# Testing from 936 to 944 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.574777886969969 seconds.
#
# ===========================================================
# Testing from 944 to 952 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6834103730507195 seconds.
#
# ===========================================================
# Testing from 952 to 960 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.47761957696639 seconds.
#
# ===========================================================
# Testing from 960 to 968 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6129955749493092 seconds.
#
# ===========================================================
# Testing from 968 to 976 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.315495755057782 seconds.
#
# ===========================================================
# Testing from 976 to 984 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.542728752014227 seconds.
#
# ===========================================================
# Testing from 984 to 992 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.761483252979815 seconds.
#
# ===========================================================
# Testing from 992 to 1000 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.645057510002516 seconds.
# All done in: 462.52 s.
# Saving sks to results_leo/particle_features_60/tests/10K/null_hypotheses/SKS.json
# Computing and savng swd with max_vectorize = 800
#
# ===========================================================
# Testing from 0 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.6638908699387684 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.221015571965836 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2196133100660518 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2199492899235338 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# WARNING:tensorflow:5 out of the last 5 calls to <function SWDMetric.Test_tf.<locals>.batched_test_sub at 0x7f8e90174fe0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SWD metric calculation completed in 1.2220647830981761 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# WARNING:tensorflow:6 out of the last 6 calls to <function SWDMetric.Test_tf.<locals>.batched_test_sub at 0x7f8e4462c680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SWD metric calculation completed in 1.1347389820730314 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.079627956962213 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.0633588240016252 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1532549320254475 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1956754149869084 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1702446739654988 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 2.519891517003998 seconds.
#
# ===========================================================
# Testing from 96 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1245679929852486 seconds.
#
# ===========================================================
# Testing from 104 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2546596340835094 seconds.
#
# ===========================================================
# Testing from 112 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2560815330361947 seconds.
#
# ===========================================================
# Testing from 120 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2763546640053391 seconds.
#
# ===========================================================
# Testing from 128 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2402396460529417 seconds.
#
# ===========================================================
# Testing from 136 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.157943982980214 seconds.
#
# ===========================================================
# Testing from 144 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.093399992911145 seconds.
#
# ===========================================================
# Testing from 152 to 160 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1866017429856583 seconds.
#
# ===========================================================
# Testing from 160 to 168 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2210470479913056 seconds.
#
# ===========================================================
# Testing from 168 to 176 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2071354821091518 seconds.
#
# ===========================================================
# Testing from 176 to 184 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.216788909980096 seconds.
#
# ===========================================================
# Testing from 184 to 192 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# ...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2449452059809119 seconds.
#
# ===========================================================
# Testing from 584 to 592 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 2.112824188079685 seconds.
#
# ===========================================================
# Testing from 592 to 600 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2571670239558443 seconds.
#
# ===========================================================
# Testing from 600 to 608 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3044287300435826 seconds.
#
# ===========================================================
# Testing from 608 to 616 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2921799769392237 seconds.
#
# ===========================================================
# Testing from 616 to 624 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2907576439902186 seconds.
#
# ===========================================================
# Testing from 624 to 632 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2680440740659833 seconds.
#
# ===========================================================
# Testing from 632 to 640 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1137516100425273 seconds.
#
# ===========================================================
# Testing from 640 to 648 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.237408145912923 seconds.
#
# ===========================================================
# Testing from 648 to 656 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2470905269728974 seconds.
#
# ===========================================================
# Testing from 656 to 664 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2466817640233785 seconds.
#
# ===========================================================
# Testing from 664 to 672 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2266157829435542 seconds.
#
# ===========================================================
# Testing from 672 to 680 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1859289150452241 seconds.
#
# ===========================================================
# Testing from 680 to 688 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.0787980280583724 seconds.
#
# ===========================================================
# Testing from 688 to 696 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2325544649502262 seconds.
#
# ===========================================================
# Testing from 696 to 704 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.232404710026458 seconds.
#
# ===========================================================
# Testing from 704 to 712 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2503275469643995 seconds.
#
# ===========================================================
# Testing from 712 to 720 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 2.4883772040484473 seconds.
#
# ===========================================================
# Testing from 720 to 728 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.151500090956688 seconds.
#
# ===========================================================
# Testing from 728 to 736 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3201659939950332 seconds.
#
# ===========================================================
# Testing from 736 to 744 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3018537079915404 seconds.
#
# ===========================================================
# Testing from 744 to 752 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2674350639572367 seconds.
#
# ===========================================================
# Testing from 752 to 760 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2836048599565402 seconds.
#
# ===========================================================
# Testing from 760 to 768 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.121060331002809 seconds.
#
# ===========================================================
# Testing from 768 to 776 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1871012999908999 seconds.
#
# ===========================================================
# Testing from 776 to 784 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2792984619736671 seconds.
#
# ===========================================================
# Testing from 784 to 792 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2243898889282718 seconds.
#
# ===========================================================
# Testing from 792 to 800 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.251109607052058 seconds.
#
# ===========================================================
# Testing from 800 to 808 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2362555479630828 seconds.
#
# ===========================================================
# Testing from 808 to 816 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.0933604090241715 seconds.
#
# ===========================================================
# Testing from 816 to 824 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.194229206070304 seconds.
#
# ===========================================================
# Testing from 824 to 832 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2304375170497224 seconds.
#
# ===========================================================
# Testing from 832 to 840 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2419184850296006 seconds.
#
# ===========================================================
# Testing from 840 to 848 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 2.544943247921765 seconds.
#
# ===========================================================
# Testing from 848 to 856 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1120239889714867 seconds.
#
# ===========================================================
# Testing from 856 to 864 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2410598490387201 seconds.
#
# ===========================================================
# Testing from 864 to 872 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2998243970796466 seconds.
#
# ===========================================================
# Testing from 872 to 880 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2767186609562486 seconds.
#
# ===========================================================
# Testing from 880 to 888 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2688649840420112 seconds.
#
# ===========================================================
# Testing from 888 to 896 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.198461047024466 seconds.
#
# ===========================================================
# Testing from 896 to 904 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1022349059348926 seconds.
#
# ===========================================================
# Testing from 904 to 912 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2419357870239764 seconds.
#
# ===========================================================
# Testing from 912 to 920 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2315686580259353 seconds.
#
# ===========================================================
# Testing from 920 to 928 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2455417029559612 seconds.
#
# ===========================================================
# Testing from 928 to 936 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.219518780009821 seconds.
#
# ===========================================================
# Testing from 936 to 944 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.137833197019063 seconds.
#
# ===========================================================
# Testing from 944 to 952 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.083491622004658 seconds.
#
# ===========================================================
# Testing from 952 to 960 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.242971429019235 seconds.
#
# ===========================================================
# Testing from 960 to 968 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 2.5778335640206933 seconds.
#
# ===========================================================
# Testing from 968 to 976 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.320956996991299 seconds.
#
# ===========================================================
# Testing from 976 to 984 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1634483089437708 seconds.
#
# ===========================================================
# Testing from 984 to 992 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1347272999119014 seconds.
#
# ===========================================================
# Testing from 992 to 1000 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2960136740002781 seconds.
# All done in: 639.69 s.
# Saving swd to results_leo/particle_features_60/tests/10K/null_hypotheses/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []
ndims = 180

for metric in list(metrics_config[unique_key].values())[3:]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    print(len(dist_null))

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# 1000
# ThresholdS for metric sks: [[0.68, [680, 319], 0.8878439104706318], [0.95, [950, 50], 1.0933288947519717], [0.99, [990, 10], 1.2588624862031303]]
# Computing time for metric sks: 445.69244032981806
# 1000
# ThresholdS for metric swd: [[0.68, [680, 319], 0.616830476901352], [0.95, [950, 50], 0.8232286331379893], [0.99, [990, 10], 1.0129123500991009]]
# Computing time for metric swd: 161.86231001699343
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f911ff3c900>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f911ff3d1c0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f911ff3f2e0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f911ff3f380>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f911ff3f420>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 8, 'batch_size_test': 10000, 'batch_...              8
# 1  {'niter': 8, 'batch_size_test': 10000, 'batch_...              8
# 2  {'niter': 8, 'batch_size_test': 10000, 'batch_...            360
# 3  {'niter': 8, 'batch_size_test': 10000, 'batch_...            800
# 4  {'niter': 8, 'batch_size_test': 10000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/10K/nul...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/10K/nul...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/10K/nul...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/10K/nul...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/10K/nul...
#
#                                           thresholds
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[0.68, [680, 319], 0.8878439104706318], [0.95...
# 4  [[0.68, [680, 319], 0.616830476901352], [0.95,...

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[3:]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Frequency', fontsize=16)
    ax[0].set_title('PDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.8562641765849257 +/- 0.0004981124443928219
# sigma = 0.12550577098903798 +/- 0.004180611626864655
# 68%CL = 0.8878439104706318, 95%CL = 1.0933288947519717, 99%CL = 1.2588624862031303
# mu = 0.8562641765849257 +/- 0.0004981124443928219
# sigma = 0.12550577098903798 +/- 0.004180611626864655
# /tmp/ipykernel_1267236/3538746891.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1267236/3538746891.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1267236/3538746891.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1267236/3538746891.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.7384969589766115 seconds.
# mu = 0.5865783311165488 +/- 0.000553939443984983
# sigma = 0.13235219411856403 +/- 0.005221107499553514
# 68%CL = 0.616830476901352, 95%CL = 0.8232286331379893, 99%CL = 1.0129123500991009
# mu = 0.5865783311165488 +/- 0.000553939443984983
# sigma = 0.13235219411856403 +/- 0.005221107499553514
# /tmp/ipykernel_1267236/3538746891.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1267236/3538746891.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1267236/3538746891.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1267236/3538746891.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.968846998992376 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f911ff3c900>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f911ff3d1c0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f911ff3f2e0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f911ff3f380>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f911ff3f420>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 8, 'batch_size_test': 10000, 'batch_...              8
# 1  {'niter': 8, 'batch_size_test': 10000, 'batch_...              8
# 2  {'niter': 8, 'batch_size_test': 10000, 'batch_...            360
# 3  {'niter': 8, 'batch_size_test': 10000, 'batch_...            800
# 4  {'niter': 8, 'batch_size_test': 10000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/10K/nul...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/10K/nul...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/10K/nul...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/10K/nul...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/10K/nul...
#
#                                           thresholds  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[0.68, [680, 319], 0.8878439104706318], [0.95...
# 4  [[0.68, [680, 319], 0.616830476901352], [0.95,...
#
#                                          null_figure
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  results_leo/particle_features_60/tests/10K/nul...
# 4  results_leo/particle_features_60/tests/10K/nul...

# %% [markdown]
# ### Alternative hypothesis

# %% [markdown]
# #### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100, # this will be adapted to the boostrap size
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}

# %%
file_path = os.path.join(model_dir, "exclusion_limits.json")
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}
    
# Sort the dictionary by keys
existing_data = dict(sorted(existing_data.items()))

# Save the sorted dictionary back to a JSON file
with open(file_path, 'w') as f:
    json.dump(existing_data, f, cls=GMetrics.utils.CustomEncoder, indent=4) # type: ignore

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[3:]:
    for deformation in deformations:
        eps_max = 2.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection_dataset(dataset = dataset,
                                                             metric_config = metric_config,
                                                             test_kwargs = test_kwargs,
                                                             model_dir = model_dir,
                                                             deformation = deformation,
                                                             seed_dist = 0,
                                                             x_tol = 0.1,
                                                             fn_tol = 0.15,
                                                             bound = bound,
                                                             eps_min = 0.,
                                                             eps_max = eps_max,
                                                             smear = 0.,
                                                             max_iterations = 50,
                                                             save = True,
                                                             filename = "exclusion_limits.json",
                                                             verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Computing upper bounds for sks with mean deformation.
#
# ======================================================
# =============== sks - mean ===============
# ======================================================
# niter: 8, nbootstrap: 12
#
# ------------ 1 - 0.95 CL -  upper bound -----------
# eps = 1.0 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2390067219967023 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6725804730085656 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.555772230029106 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.8097117830766365 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.260919871972874 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.691386488964781 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2474127280293033 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5915777339832857 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.731123996083625 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.8186063829343766 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2236464499728754 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.7109898049384356 seconds.
# statistic = 15.989509223997008 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7439936181208653
#
# ------------ 2 - 0.95 CL -  upper bound -----------
# eps = 0.5 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.204804852954112 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.620187358930707 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.885367802926339 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.791252853930928 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.256304371985607 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.705160481040366 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2098484500311315 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.124934282968752 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3134109099628404 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.751052572974004 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2808990930207074 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6353230229578912 seconds.
# statistic = 8.570420971337983 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5474514924735554
#
# ------------ 3 - 0.95 CL -  upper bound -----------
# eps = 0.25 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2908847799990326 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.419805061072111 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5202528019435704 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.7704462710535154 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2190600089961663 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6812263960018754 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.230391544988379 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.610267420997843 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.163117778953165 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.8538180419709533 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.390843253931962 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.7647377139655873 seconds.
# statistic = 4.488981433862467 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.216576055152174
#
# ------------ 4 - 0.95 CL -  upper bound -----------
# eps = 0.125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2370020740199834 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6291796300793067 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 4.860457511036657 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.918345900019631 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.34454448800534 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.7572292449185625 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2698411269811913 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5951725180493668 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.174696997040883 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.8859821390360594 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5213536110240966 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.7657079360214993 seconds.
# statistic = 2.3983185140310685 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7474922101220586
#
# ------------ 5 - 0.95 CL -  upper bound -----------
# eps = 0.0625 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4159491409081966 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.65204362408258 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.114180900040083 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.89454556198325 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.714562800945714 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.660660562920384 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.362399233970791 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.358227827004157 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.072694199043326 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.662980522029102 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6298214859561995 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.611948129022494 seconds.
# statistic = 1.4229899211687804 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.2620184885405164
#
# ------------ 6 - 0.95 CL -  upper bound -----------
# eps = 0.03125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3672178119886667 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.365216057980433 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.286424070945941 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.7072672159411013 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.7063262140145525 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.570329598034732 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.39662016404327 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4162021490046754 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.177810241933912 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.273895985097624 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.8213758249767125 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5711636210326105 seconds.
# statistic = 0.9844590456272289 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 0.10479399462187068
#
# ------------ 7 - 0.95 CL -  upper bound -----------
# eps = 0.046875 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.561168057960458 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5281191510148346 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2918854570016265 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.02875900210347 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.8636989800725132 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.46916426892858 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.583705428056419 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5264808339998126 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.288125579012558 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.37178155395668 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.19102688296698 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6882092559244484 seconds.
# statistic = 1.2055574062920271 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 0.4
# relative_error_metric = 0.09763728766323833
#
# ------------ 8 - 0.95 CL -  upper bound -----------
# eps = 0.0390625 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.681766032939777 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.593277973937802 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4021727649960667 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4152694470249116 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.410704233916476 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.512412876007147 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.814037545933388 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4266991841141135 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5083964690566063 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.397313950001262 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.22999175300356 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.173871880979277 seconds.
# statistic = 1.0894186394598016 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 0.18181818181818182
# relative_error_metric = 0.0035828745476807595
#
# ------------ 9 - 0.95 CL -  upper bound -----------
# eps = 0.04296875 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.8125951149268076 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6162189309252426 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.587744242977351 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.5332215450471267 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2794772260822356 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.149843754014 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.9188302269903943 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4643078800290823 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6489255799679086 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.47811978997197 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3483505450421944 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.36818680097349 seconds.
# statistic = 1.1421820672492 - next threshold = 1.0933288947519717 at 0.95 CL
# relative_error_eps = 0.09523809523809523
# relative_error_metric = 0.04370649334995541
# =======> statistic within required accuracy at 0.95 CL in 424.6912403870374 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
#
# ------------ 1 - 0.99 CL -  upper bound -----------
# eps = 0.041015625 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.61534911300987 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.458720915019512 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.8240706640062854 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3870800010627136 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.56454949604813 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3817610549740493 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3215990009484813 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.125388918910176 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.9206426800228655 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.471049214946106 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6693836050108075 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.471289218054153 seconds.
# statistic = 1.1038164688707106 - next threshold = 1.2588624862031303 at 0.99 CL
# relative_error_eps = 1.9196172248803827
# relative_error_metric = 0.13124594604735373
#
# ------------ 2 - 0.99 CL -  upper bound -----------
# eps = 1.0205078125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.3488428209675476 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.376583883073181 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.5849728810135275 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.548136724042706 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.878458482096903 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.4227432989282534 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.73442419199273 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.395730340969749 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.6506263540359214 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 5.525716701056808 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.9455635090125725 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.606182605959475 seconds.
# statistic = 16.280950844688903 - next threshold = 1.2588624862031303 at 0.99 CL
# relative_error_eps = 1.845446182152714
# relative_error_metric = 1.7129131393922064
#
# ------------ 3 - 0.99 CL -  upper bound -----------
# eps = 0.53076171875 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.76468131900765 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.410610081977211 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.661560306092724 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.2174196399282664 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 6.049576157005504 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.7905639510136098 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.817657068022527 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 8
# batch_size = 10000
# SKS metric calculation completed in 3.543151621008292 seconds.
#
# ===========================================================
# ...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2522595669142902 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2479211100144312 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1333251500036567 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 11.274940519942902 seconds.
# statistic = 0.9694461353169345 - next threshold = 0.8232286331379893 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.16312775161661647
#
# ------------ 48 - 0.95 CL -  central bound -----------
# eps = 1.3810194578623564e-16 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 2.204486354952678 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.9052939841058105 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.6691757400985807 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 2.193240404012613 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.971889812964946 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.4734175900230184 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3493915930157527 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.5520435959333554 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.498966568033211 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.4629813339561224 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2893405960639939 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.279528914950788 seconds.
# statistic = 0.954111284948966 - next threshold = 0.8232286331379893 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.14727925759058244
#
# ------------ 49 - 0.95 CL -  central bound -----------
# eps = 6.905097289311782e-17 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.4485528910299763 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.4252463759621605 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.4067514430498704 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2410819780780002 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2149966850411147 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3787140540080145 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.396493933047168 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3727405440295115 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3343018130399287 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1823250419693068 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3674245899310336 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3737767949933186 seconds.
# statistic = 0.9476591251238308 - next threshold = 0.8232286331379893 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.14052894250957354
#
# ------------ 50 - 0.95 CL -  central bound -----------
# eps = 3.452548644655891e-17 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3667795830406249 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3444187329150736 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.1531104459427297 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3026155580300838 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3531387649709359 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.347499925061129 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3556669930694625 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.2198913630563766 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.239164620055817 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3491513420594856 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.3477928779320791 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 8
# batch_size = 10000
# SWD metric calculation completed in 1.345572368009016 seconds.
# statistic = 0.9396975060007229 - next threshold = 0.8232286331379893 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.13213131313559748
# Time elapsed: 958.1369321090169 seconds.
# Saving results in the file results_leo/particle_features_60/tests/10K/exclusion_limits.json
# Computing lower bounds for swd with mean deformation.
#
# ======================================================
# =============== swd - mean ===============
# ======================================================
# niter: 8, nbootstrap: 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 15
#      13 if result == {}:
#      14     print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
# ---> 15     result = compute_exclusion_bisection_dataset(dataset = dataset,
#      16                                                  metric_config = metric_config,
#      17                                                  test_kwargs = test_kwargs,
#      18                                                  model_dir = model_dir,
#      19                                                  deformation = deformation,
#      20                                                  seed_dist = 0,
#      21                                                  x_tol = 0.1,
#      22                                                  fn_tol = 0.15,
#      23                                                  bound = bound,
#      24                                                  eps_min = 0.,
#      25                                                  eps_max = eps_max,
#      26                                                  smear = 0.,
#      27                                                  max_iterations = 50,
#      28                                                  save = True,
#      29                                                  filename = "exclusion_limits.json",
#      30                                                  verbose = True)
#      31     eps_max = list(result.values())[0]["exclusion_list"][-1][3]
#      32 else:
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics/GMetrics/more/optimizers_deformations.py:299, in compute_exclusion_bisection_dataset(dataset, metric_config, test_kwargs, model_dir, deformation, seed_dist, x_tol, fn_tol, bound, eps_min, eps_max, smear, max_iterations, save, filename, verbose)
#     297 eps_min_start = eps_min
#     298 eps_max_start = eps_max
# --> 299 eps = (eps_max + eps_min) / 2.
#     300 eps_min, eps_max = eps_min_start, eps_max_start # Initialize the bounds
#     301 sigma_factor = smear
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'float'

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_366541/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#   Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 2       sks        mean  450      8                10000
# 9       swd        mean  450      8                10000
#
#   $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 2      $0.01907_{-0.0061}^{+0.0053}$      $0.02864_{-0.0029}^{+0.0043}$
# 9      $0.02298_{-0.0092}^{+0.0073}$      $0.03031_{-0.0052}^{+0.0094}$
#
#    $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 2           2334  [0.01298, 0.01907, 0.02441]   [0.0257, 0.02864, 0.03299]
# 9            894  [0.01374, 0.02298, 0.03027]  [0.02513, 0.03031, 0.03974]
#
#                time
# 2  [1166, 586, 582]
# 9   [438, 237, 219]
#   Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 2       sks      $0.01907_{-0.0061}^{+0.0053}$
# 9       swd      $0.02298_{-0.0092}^{+0.0073}$
#
#   $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 2      $0.02864_{-0.0029}^{+0.0043}$           2334
# 9      $0.03031_{-0.0052}^{+0.0094}$            894

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_366541/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#   Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 7       swd    cov_diag  450      8                10000
# 0       sks    cov_diag  450      8                10000
#
#   $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7                $0.04013_{-0.017}^{+0.017}$
# 0                 $0.0436_{-0.014}^{+0.021}$
#
#   $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 7                $0.05138_{-0.016}^{+0.014}$                    884
# 0                  $0.06547_{-0.02}^{+0.01}$                   2300
#
#                          95%CL                        99%CL              time
# 7  [0.02328, 0.04013, 0.05664]  [0.03558, 0.05138, 0.06585]   [429, 220, 235]
# 0   [0.02967, 0.0436, 0.06445]  [0.04533, 0.06547, 0.07542]  [1064, 615, 621]
#   Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7       swd                $0.04013_{-0.017}^{+0.017}$
# 0       sks                 $0.0436_{-0.014}^{+0.021}$
#
#   $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 7                $0.05138_{-0.016}^{+0.014}$                    884
# 0                  $0.06547_{-0.02}^{+0.01}$                   2300

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_366541/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#   Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 8       swd  cov_off_diag  450      8                10000
# 1       sks  cov_off_diag  450      8                10000
#
#   $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 8                     $0.02913_{-0.012}^{+0.012}$
# 1                     $0.03352_{-0.011}^{+0.011}$
#
#   $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)  \
# 8                    $0.03843_{-0.0066}^{+0.012}$                         914
# 1                   $0.05034_{-0.0086}^{+0.0076}$                        2563
#
#                          95%CL                        99%CL              time
# 8  [0.01741, 0.02913, 0.04102]  [0.03186, 0.03843, 0.05038]   [435, 249, 230]
# 1  [0.02281, 0.03352, 0.04492]  [0.04173, 0.05034, 0.05798]  [1240, 658, 665]
#   Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 8       swd                     $0.02913_{-0.012}^{+0.012}$
# 1       sks                     $0.03352_{-0.011}^{+0.011}$
#
#   $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 8                    $0.03843_{-0.0066}^{+0.012}$                         914
# 1                   $0.05034_{-0.0086}^{+0.0076}$                        2563

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_366541/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 11       swd  power_abs_up  450      8                10000
# 4        sks  power_abs_up  450      8                10000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11                 $0.03145_{-0.013}^{+0.017}$
# 4                  $0.04783_{-0.015}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 11                 $0.04149_{-0.013}^{+0.013}$                     874
# 4                  $0.07182_{-0.022}^{+0.011}$                    2513
#
#                           95%CL                        99%CL              time
# 11   [0.0188, 0.03145, 0.04883]   [0.02873, 0.04149, 0.0544]   [426, 218, 230]
# 4   [0.03254, 0.04783, 0.06445]  [0.04973, 0.07182, 0.08273]  [1167, 669, 677]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11       swd                 $0.03145_{-0.013}^{+0.017}$
# 4        sks                 $0.04783_{-0.015}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 11                 $0.04149_{-0.013}^{+0.013}$                     874
# 4                  $0.07182_{-0.022}^{+0.011}$                    2513

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_366541/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 10       swd  power_abs_down  450      8                10000
# 3        sks  power_abs_down  450      8                10000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10                 $0.03807_{-0.017}^{+0.019}$
# 3                  $0.04783_{-0.017}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 10                 $0.04675_{-0.014}^{+0.019}$                     863
# 3                  $0.06746_{-0.012}^{+0.015}$                    2641
#
#                           95%CL                        99%CL              time
# 10  [0.02119, 0.03807, 0.05664]  [0.03237, 0.04675, 0.06585]   [416, 230, 217]
# 3   [0.03057, 0.04783, 0.06445]  [0.05593, 0.06746, 0.08273]  [1225, 704, 712]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10       swd                 $0.03807_{-0.017}^{+0.019}$
# 3        sks                 $0.04783_{-0.017}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 10                 $0.04675_{-0.014}^{+0.019}$                     863
# 3                  $0.06746_{-0.012}^{+0.015}$                    2641

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_366541/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        sks  random_normal  450      8                10000
# 12       swd  random_normal  450      8                10000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                   $0.132_{-0.014}^{+0.032}$
# 12                 $0.14348_{-0.03}^{+0.021}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 5                 $0.16428_{-0.029}^{+0.019}$                   2195
# 12                $0.15855_{-0.017}^{+0.025}$                    676
#
#                           95%CL                        99%CL              time
# 5     [0.11808, 0.132, 0.16406]  [0.13541, 0.16428, 0.18365]  [1041, 567, 587]
# 12  [0.11395, 0.14348, 0.16406]  [0.14182, 0.15855, 0.18365]   [325, 174, 177]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        sks                  $0.132_{-0.014}^{+0.032}$
# 12       swd                 $0.14348_{-0.03}^{+0.021}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                 $0.16428_{-0.029}^{+0.019}$                   2195
# 12                $0.15855_{-0.017}^{+0.025}$                    676

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_366541/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        sks  random_uniform  450      8                10000
# 13       swd  random_uniform  450      8                10000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                 $0.22101_{-0.023}^{+0.052}$
# 13                $0.25187_{-0.052}^{+0.037}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                 $0.27506_{-0.048}^{+0.032}$                   2180
# 13                $0.27831_{-0.049}^{+0.044}$                    661
#
#                           95%CL                        99%CL             time
# 6    [0.1977, 0.22101, 0.27344]   [0.22671, 0.27506, 0.3075]  [989, 595, 596]
# 13  [0.20004, 0.25187, 0.28906]  [0.22939, 0.27831, 0.32239]  [300, 175, 186]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        sks                $0.22101_{-0.023}^{+0.052}$
# 13       swd                $0.25187_{-0.052}^{+0.037}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                 $0.27506_{-0.048}^{+0.032}$                   2180
# 13                $0.27831_{-0.049}^{+0.044}$                    661
