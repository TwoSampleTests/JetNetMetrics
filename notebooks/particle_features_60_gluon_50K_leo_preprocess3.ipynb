# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [3]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more.deformations import deformed_distribution, deform_mean, deform_cov_diag, deform_cov_off_diag, deform_power_abs, deform_random
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection_dataset # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-07-02 14:36:29.625912: Importing os...
# 2024-07-02 14:36:29.626158: Importing sys...
# Visible devices: [3]
# 2024-07-02 14:36:29.626400: Importing timer from timeit...
# 2024-07-02 14:36:29.626469: Setting env variables for tf import (only device(s) [3] will be available)...
# 2024-07-02 14:36:29.626595: Importing numpy...
# 2024-07-02 14:36:29.754239: Importing matplotlib...
# 2024-07-02 14:36:30.140242: Importing h5py...
# 2024-07-02 14:36:30.166485: Importing importlib.util...
# 2024-07-02 14:36:30.166590: Importing json...
# 2024-07-02 14:36:30.166654: Importing pandas...
# 2024-07-02 14:36:30.602549: Importing random...
# 2024-07-02 14:36:30.602698: Importing scipy utils...
# 2024-07-02 14:36:31.007212: Importing subprocess...
# 2024-07-02 14:36:31.007366: Importing textwrap...
# 2024-07-02 14:36:31.007429: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-07-02 14:36:35.078864: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-07-02 14:36:36.261052: Importing timeit...
# 2024-07-02 14:36:36.261151: Importing tqdm...
# 2024-07-02 14:36:36.271267: Importing typing...
# 2024-07-02 14:36:36.271394: Setting tf configs...
# 2024-07-02 14:36:36.391119: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-07-02 14:36:41.553746: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #3, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-07-02 14:36:41.583442: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 60,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 60, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 60, 4)

# %% [markdown]
# # Particle level

# %% [markdown]
# ## Init data

# %%
results_dir = "results_leo/particle_features_60/"
figures_dir = os.path.join(results_dir, "figures/")
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocess_data=(data-means)/stds
    return preprocess_data

def postprocess_data(data,means,stds):
    postprocess_data=data*stds+means
    return postprocess_data

def get_reduced_particle_features(particle_features):
    tmp = particle_features[:, :, :3]
    shape = tmp.shape
    particle_features_reshaped = tf.reshape(tmp, [-1, shape[1] * shape[2]])
    return particle_features_reshaped

particle_features_reduced = get_reduced_particle_features(particle_features)
particle_features_reduced.shape
# Out:
# TensorShape([177252, 180])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests/")
model_dir = os.path.join(tests_dir, '50K_preprocessed/')
if not os.path.exists(model_dir):
    os.makedirs(model_dir, exist_ok = True)

particle_features_reduced = get_reduced_particle_features(particle_features)

mean = tf.reduce_mean(particle_features_reduced, axis=0)
std = tf.math.reduce_std(particle_features_reduced, axis=0)
    
dataset = preprocess_data(particle_features_reduced, mean, std)

# %% [markdown]
# ## 50K

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(model_dir, 'null_hypotheses/')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(model_dir, "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 50_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 25_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 1, nbootstrap: 1000
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputsNull.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0      1            50000            1000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  is_symb_1  ndims_1  \
# 0     0    True            False     None     True      False      180
#
#    nsamples_1  is_symb_2  ndims_2  nsamples_2    dtype  ndims  nsamples  \
# 0       50000      False      180       50000  float64    180     50000
#
#    small_sample
# 0          True

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 25_000, 
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {"verbose": True}, 
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 360,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values())[3:]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng sks with max_vectorize = 800
#
# ===========================================================
# Testing from 0 to 1 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.04621822014451 seconds.
#
# ===========================================================
# Testing from 1 to 2 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1279325615614653 seconds.
#
# ===========================================================
# Testing from 2 to 3 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.928330386057496 seconds.
#
# ===========================================================
# Testing from 3 to 4 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.8555374639108777 seconds.
#
# ===========================================================
# Testing from 4 to 5 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fe5dd110220> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SKS metric calculation completed in 2.8240634575486183 seconds.
#
# ===========================================================
# Testing from 5 to 6 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fe5dd4e91c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SKS metric calculation completed in 2.8160895695909858 seconds.
#
# ===========================================================
# Testing from 6 to 7 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7157421307638288 seconds.
#
# ===========================================================
# Testing from 7 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.812982148490846 seconds.
#
# ===========================================================
# Testing from 8 to 9 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.8145808586850762 seconds.
#
# ===========================================================
# Testing from 9 to 10 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.7302737394347787 seconds.
#
# ===========================================================
# Testing from 10 to 11 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0242559406906366 seconds.
#
# ===========================================================
# Testing from 11 to 12 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.5220705466344953 seconds.
#
# ===========================================================
# Testing from 12 to 13 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.847585347481072 seconds.
#
# ===========================================================
# Testing from 13 to 14 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.722415995784104 seconds.
#
# ===========================================================
# Testing from 14 to 15 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.039373714476824 seconds.
#
# ===========================================================
# Testing from 15 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.531676659360528 seconds.
#
# ===========================================================
# Testing from 16 to 17 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.8861162485554814 seconds.
#
# ===========================================================
# Testing from 17 to 18 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.831755314953625 seconds.
#
# ===========================================================
# Testing from 18 to 19 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9633261933922768 seconds.
#
# ===========================================================
# Testing from 19 to 20 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.8231277959421277 seconds.
#
# ===========================================================
# Testing from 20 to 21 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.664165735244751 seconds.
#
# ===========================================================
# Testing from 21 to 22 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.041791096329689 seconds.
#
# ===========================================================
# Testing from 22 to 23 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9359231386333704 seconds.
#
# ===========================================================
# Testing from 23 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.826135575771332 seconds.
#
# ===========================================================
# Testing from 24 to 25 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.8563669687137008 seconds.
#
# ===========================================================
# Testing from 25 to 26 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9205971248447895 seconds.
#
# ===========================================================
# Testing from 26 to 27 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9218853833153844 seconds.
#
# ===========================================================
# Testing from 27 to 28 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.872761817649007 seconds.
#
# ===========================================================
# Testing from 28 to 29 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.7664836160838604 seconds.
#
# ===========================================================
# Testing from 29 to 30 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0262281065806746 seconds.
#
# ===========================================================
# Testing from 30 to 31 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7425049170851707 seconds.
#
# ===========================================================
# Testing from 31 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9393014051020145 seconds.
#
# ===========================================================
# Testing from 32 to 33 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9328154614195228 seconds.
#
# ===========================================================
# Testing from 33 to 34 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0046836026012897 seconds.
#
# ===========================================================
# Testing from 34 to 35 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.842202997766435 seconds.
#
# ===========================================================
# Testing from 35 to 36 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8012709505856037 seconds.
#
# ===========================================================
# Testing from 36 to 37 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1296759340912104 seconds.
#
# ===========================================================
# Testing from 37 to 38 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.954119423404336 seconds.
#
# ===========================================================
# Testing from 38 to 39 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.854106809012592 seconds.
#
# ===========================================================
# Testing from 39 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.567308713681996 seconds.
#
# ===========================================================
# Testing from 40 to 41 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1530078668147326 seconds.
#
# ===========================================================
# Testing from 41 to 42 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9403512943536043 seconds.
#
# ===========================================================
# Testing from 42 to 43 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.879263390786946 seconds.
#
# ===========================================================
# Testing from 43 to 44 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.756515015847981 seconds.
#
# ===========================================================
# Testing from 44 to 45 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.140851977281272 seconds.
#
# ===========================================================
# Testing from 45 to 46 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9810898238793015 seconds.
#
# ===========================================================
# Testing from 46 to 47 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9583321111276746 seconds.
#
# ===========================================================
# Testing from 47 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9501376263797283 seconds.
#
# ===========================================================
# Testing from 48 to 49 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9753860235214233 seconds.
#
# ===========================================================
# Testing from 49 to 50 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.858290650881827 seconds.
#
# ===========================================================
# Testing from 50 to 51 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9517140686511993 seconds.
#
# ===========================================================
# Testing from 51 to 52 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1911593824625015 seconds.
#
# ===========================================================
# Testing from 52 to 53 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9285818999633193 seconds.
#
# ===========================================================
# Testing from 53 to 54 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.867488327436149 seconds.
#
# ===========================================================
# Testing from 54 to 55 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.784064737148583 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1767355874180794 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9596090810373425 seconds.
#
# ===========================================================
# Testing from 57 to 58 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.926550933159888 seconds.
#
# ===========================================================
# Testing from 58 to 59 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.877185996621847 seconds.
#
# ===========================================================
# Testing from 59 to 60 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.042965264990926 seconds.
#
# ===========================================================
# Testing from 60 to 61 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.00452050473541 seconds.
#
# ===========================================================
# Testing from 61 to 62 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9472975581884384 seconds.
#
# ===========================================================
# Testing from 62 to 63 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1339484956115484 seconds.
#
# ===========================================================
# Testing from 63 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.881585992872715 seconds.
#
# ===========================================================
# Testing from 64 to 65 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9237094204872847 seconds.
#
# ===========================================================
# Testing from 65 to 66 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9686676673591137 seconds.
#
# ===========================================================
# Testing from 66 to 67 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.119649968110025 seconds.
#
# ===========================================================
# Testing from 67 to 68 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.940407518297434 seconds.
#
# ===========================================================
# Testing from 68 to 69 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.887648729607463 seconds.
#
# ===========================================================
# Testing from 69 to 70 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.941340070217848 seconds.
#
# ===========================================================
# Testing from 70 to 71 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.3133639972656965 seconds.
#
# ===========================================================
# Testing from 71 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.018381186760962 seconds.
#
# ===========================================================
# Testing from 72 to 73 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.86555936280638 seconds.
#
# ===========================================================
# Testing from 73 to 74 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.201742008328438 seconds.
#
# ===========================================================
# Testing from 74 to 75 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.893938980065286 seconds.
#
# ===========================================================
# Testing from 75 to 76 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.025129733607173 seconds.
#
# ===========================================================
# Testing from 76 to 77 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1741641936823726 seconds.
#
# ===========================================================
# Testing from 77 to 78 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.118027758784592 seconds.
#
# ===========================================================
# Testing from 78 to 79 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.978260723873973 seconds.
#
# ===========================================================
# Testing from 79 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9146559173241258 seconds.
#
# ===========================================================
# Testing from 80 to 81 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.222360226325691 seconds.
#
# ===========================================================
# Testing from 81 to 82 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0905281715095043 seconds.
#
# ===========================================================
# Testing from 82 to 83 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9984375024214387 seconds.
#
# ===========================================================
# Testing from 83 to 84 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.8367143403738737 seconds.
#
# ===========================================================
# Testing from 84 to 85 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.103633638471365 seconds.
#
# ===========================================================
# Testing from 85 to 86 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.069455374032259 seconds.
#
# ===========================================================
# Testing from 86 to 87 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.072595065459609 seconds.
#
# ===========================================================
# Testing from 87 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1832048296928406 seconds.
#
# ===========================================================
# Testing from 88 to 89 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0505210580304265 seconds.
#
# ===========================================================
# Testing from 89 to 90 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.913198422640562 seconds.
#
# ===========================================================
# Testing from 90 to 91 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8722291216254234 seconds.
#
# ===========================================================
# Testing from 91 to 92 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.304930767044425 seconds.
#
# ===========================================================
# Testing from 92 to 93 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.02825534529984 seconds.
#
# ===========================================================
# Testing from 93 to 94 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9894684115424752 seconds.
#
# ===========================================================
# Testing from 94 to 95 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.898945678025484 seconds.
#
# ===========================================================
# Testing from 95 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.044307217001915 seconds.
#
# ===========================================================
# Testing from 96 to 97 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.183312124572694 seconds.
#
# ===========================================================
# Testing from 97 to 98 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0288276690989733 seconds.
#
# ===========================================================
# Testing from 98 to 99 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.231823792681098 seconds.
#
# ===========================================================
# Testing from 99 to 100 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.988205535337329 seconds.
#
# ===========================================================
# Testing from 100 to 101 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9313554652035236 seconds.
#
# ===========================================================
# Testing from 101 to 102 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.263468286022544 seconds.
#
# ===========================================================
# Testing from 102 to 103 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.212364156730473 seconds.
#
# ===========================================================
# Testing from 103 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0458274874836206 seconds.
#
# ===========================================================
# Testing from 104 to 105 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.013422377407551 seconds.
#
# ===========================================================
# Testing from 105 to 106 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.096327854320407 seconds.
#
# ===========================================================
# Testing from 106 to 107 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.197998533025384 seconds.
#
# ===========================================================
# Testing from 107 to 108 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1103160912171006 seconds.
#
# ===========================================================
# Testing from 108 to 109 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0459620831534266 seconds.
#
# ===========================================================
# Testing from 109 to 110 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.131938800215721 seconds.
#
# ===========================================================
# Testing from 110 to 111 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9326536962762475 seconds.
#
# ===========================================================
# Testing from 111 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.890066146850586 seconds.
#
# ===========================================================
# Testing from 112 to 113 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.384894957765937 seconds.
#
# ===========================================================
# Testing from 113 to 114 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1171271093189716 seconds.
#
# ===========================================================
# Testing from 114 to 115 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0372796589508653 seconds.
#
# ===========================================================
# Testing from 115 to 116 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.8663075054064393 seconds.
#
# ===========================================================
# Testing from 116 to 117 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1236792225390673 seconds.
#
# ===========================================================
# Testing from 117 to 118 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.209568700753152 seconds.
#
# ===========================================================
# Testing from 118 to 119 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1437158938497305 seconds.
#
# ===========================================================
# Testing from 119 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.227684237062931 seconds.
#
# ===========================================================
# Testing from 120 to 121 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.998914794996381 seconds.
#
# ===========================================================
# Testing from 121 to 122 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9314151452854276 seconds.
#
# ===========================================================
# Testing from 122 to 123 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.852909592911601 seconds.
#
# ===========================================================
# Testing from 123 to 124 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.636739711277187 seconds.
#
# ===========================================================
# Testing from 124 to 125 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1414085384458303 seconds.
#
# ===========================================================
# Testing from 125 to 126 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.085481339134276 seconds.
#
# ===========================================================
# Testing from 126 to 127 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.1638056989759207 seconds.
#
# ===========================================================
# Testing from 127 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.055511837825179 seconds.
#
# ===========================================================
# Testing from 128 to 129 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9032885739579797 seconds.
#
# ===========================================================
# Testing from 129 to 130 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.166901637800038 seconds.
#
# ===========================================================
# Testing from 130 to 131 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.32147772051394 seconds.
#
# ===========================================================
# Testing from 131 to 132 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.0568046513944864 seconds.
#
# ===========================================================
# Testing from 132 to 133 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.031317228451371 seconds.
#
# ===========================================================
# Testing from 133 to 134 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9926602598279715 seconds.
#
# ===========================================================
# Testing from 134 to 135 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.396413535811007 seconds.
#
# ===========================================================
# Testing from 135 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.164069164544344 seconds.
#
# ===========================================================
# Testing from 136 to 137 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.928618671372533 seconds.
#
# ===========================================================
# Testing from 137 to 138 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.2449547983705997 seconds.
#
# ===========================================================
# Testing from 138 to 139 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9664417412132025 seconds.
#
# ===========================================================
# Testing from 139 to 140 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9273587092757225 seconds.
#
# ===========================================================
# Testing from 140 to 141 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.457388292066753 seconds.
#
# ===========================================================
# Testing from 141 to 142 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.223785306327045 seconds.
#
# ===========================================================
# Testing from 142 to 143 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.106470739468932 seconds.
#
# ===========================================================
# Testing from 143 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9158863620832562 seconds.
#
# ===========================================================
# Testing from 144 to 145 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.2303525106981397 seconds.
#
# ===========================================================
# Testing from 145 to 146 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.9215297624468803 seconds.
#
# ===========================================================
# Testing from 146 to 147 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.444114177487791 seconds.
#
# ===========================================================
# Testing from 147 to 148 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.393474549986422 seconds.
#
# ===========================================================
# Testing from 148 to 149 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.11849807202816 seconds.
#
# ===========================================================
# Testing from 149 to 150 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.034342276863754 seconds.
#
# ===========================================================
# Testing from 150 to 151 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 2.8918809816241264 seconds.
#
# ===========================================================
# Testing from 151 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.166403753682971 seconds.
#
# ===========================================================
# Testing from 152 to 153 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.5212277714163065 seconds.
#
# ===========================================================
# Testing from 153 to 154 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.2042234241962433 seconds.
#
# ===========================================================
# ...
#
# ===========================================================
# Testing from 948 to 949 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1776424404233694 seconds.
#
# ===========================================================
# Testing from 949 to 950 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.17187168169766665 seconds.
#
# ===========================================================
# Testing from 950 to 951 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.17137414403259754 seconds.
#
# ===========================================================
# Testing from 951 to 952 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.16251156758517027 seconds.
#
# ===========================================================
# Testing from 952 to 953 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.16979245748370886 seconds.
#
# ===========================================================
# Testing from 953 to 954 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14684456773102283 seconds.
#
# ===========================================================
# Testing from 954 to 955 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15069538354873657 seconds.
#
# ===========================================================
# Testing from 955 to 956 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1489769211038947 seconds.
#
# ===========================================================
# Testing from 956 to 957 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.16425531916320324 seconds.
#
# ===========================================================
# Testing from 957 to 958 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.150904705747962 seconds.
#
# ===========================================================
# Testing from 958 to 959 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15023580379784107 seconds.
#
# ===========================================================
# Testing from 959 to 960 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14950559567660093 seconds.
#
# ===========================================================
# Testing from 960 to 961 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15271931886672974 seconds.
#
# ===========================================================
# Testing from 961 to 962 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14902305975556374 seconds.
#
# ===========================================================
# Testing from 962 to 963 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1489355694502592 seconds.
#
# ===========================================================
# Testing from 963 to 964 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14697469305247068 seconds.
#
# ===========================================================
# Testing from 964 to 965 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1643500281497836 seconds.
#
# ===========================================================
# Testing from 965 to 966 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15008738730102777 seconds.
#
# ===========================================================
# Testing from 966 to 967 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14886357635259628 seconds.
#
# ===========================================================
# Testing from 967 to 968 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14940126612782478 seconds.
#
# ===========================================================
# Testing from 968 to 969 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15153923071920872 seconds.
#
# ===========================================================
# Testing from 969 to 970 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1538838166743517 seconds.
#
# ===========================================================
# Testing from 970 to 971 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14710759464651346 seconds.
#
# ===========================================================
# Testing from 971 to 972 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14793108589947224 seconds.
#
# ===========================================================
# Testing from 972 to 973 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1605298174545169 seconds.
#
# ===========================================================
# Testing from 973 to 974 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14933352917432785 seconds.
#
# ===========================================================
# Testing from 974 to 975 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1479836953803897 seconds.
#
# ===========================================================
# Testing from 975 to 976 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14607694186270237 seconds.
#
# ===========================================================
# Testing from 976 to 977 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14768528006970882 seconds.
#
# ===========================================================
# Testing from 977 to 978 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1463254289701581 seconds.
#
# ===========================================================
# Testing from 978 to 979 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1498443242162466 seconds.
#
# ===========================================================
# Testing from 979 to 980 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14712275844067335 seconds.
#
# ===========================================================
# Testing from 980 to 981 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1631281040608883 seconds.
#
# ===========================================================
# Testing from 981 to 982 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15048151928931475 seconds.
#
# ===========================================================
# Testing from 982 to 983 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1468703830614686 seconds.
#
# ===========================================================
# Testing from 983 to 984 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14842833299189806 seconds.
#
# ===========================================================
# Testing from 984 to 985 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1472627567127347 seconds.
#
# ===========================================================
# Testing from 985 to 986 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1430198922753334 seconds.
#
# ===========================================================
# Testing from 986 to 987 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.13775576744228601 seconds.
#
# ===========================================================
# Testing from 987 to 988 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.13856158684939146 seconds.
#
# ===========================================================
# Testing from 988 to 989 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15642117708921432 seconds.
#
# ===========================================================
# Testing from 989 to 990 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14065370429307222 seconds.
#
# ===========================================================
# Testing from 990 to 991 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.13846201729029417 seconds.
#
# ===========================================================
# Testing from 991 to 992 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1755739888176322 seconds.
#
# ===========================================================
# Testing from 992 to 993 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.1691209515556693 seconds.
#
# ===========================================================
# Testing from 993 to 994 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.17295300774276257 seconds.
#
# ===========================================================
# Testing from 994 to 995 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.16924056131392717 seconds.
#
# ===========================================================
# Testing from 995 to 996 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15583364758640528 seconds.
#
# ===========================================================
# Testing from 996 to 997 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.196569730527699 seconds.
#
# ===========================================================
# Testing from 997 to 998 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.17227783054113388 seconds.
#
# ===========================================================
# Testing from 998 to 999 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.15373392309993505 seconds.
#
# ===========================================================
# Testing from 999 to 1000 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 1
# batch_size = 50000
# SWD metric calculation completed in 0.14752243272960186 seconds.
# All done in: 4021.21 s.
# Saving swd to results_leo/particle_features_60/tests/50K_preprocessed/null_hypotheses/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []
ndims = 180

for metric in list(metrics_config[unique_key].values())[3:]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    print(len(dist_null))

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# 1000
# ThresholdS for metric sks: [[0.68, [680, 319], 0.8915101425178019], [0.95, [950, 50], 0.9961503757477772], [0.99, [990, 10], 1.0853261803836232]]
# Computing time for metric sks: 3631.1152971116826
# 1000
# ThresholdS for metric swd: [[0.68, [680, 319], 0.09693896635258573], [0.95, [950, 50], 0.11346000009189822], [0.99, [990, 10], 0.12744171058314918]]
# Computing time for metric swd: 156.19230466056615
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 25000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fe7cc9a56c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fe7cc9a4900>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fe7cc9a5760>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fe7cc9a74c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fe7cc9a7560>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 1, 'batch_size_test': 50000, 'batch_...              8
# 1  {'niter': 1, 'batch_size_test': 50000, 'batch_...              1
# 2  {'niter': 1, 'batch_size_test': 50000, 'batch_...            360
# 3  {'niter': 1, 'batch_size_test': 50000, 'batch_...            800
# 4  {'niter': 1, 'batch_size_test': 50000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/50K_pre...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/50K_pre...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/50K_pre...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/50K_pre...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/50K_pre...
#
#                                           thresholds
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[0.68, [680, 319], 0.8915101425178019], [0.95...
# 4  [[0.68, [680, 319], 0.09693896635258573], [0.9...

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[3:]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Frequency', fontsize=16)
    ax[0].set_title('PDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.8668018852320508 +/- 0.00016300526560084354
# sigma = 0.07179609389788283 +/- 0.0021375346132839904
# 68%CL = 0.8915101425178019, 95%CL = 0.9961503757477772, 99%CL = 1.0853261803836232
# mu = 0.8668018852320508 +/- 0.00016300526560084354
# sigma = 0.07179609389788283 +/- 0.0021375346132839904
# /tmp/ipykernel_1591727/3538746891.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1591727/3538746891.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1591727/3538746891.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1591727/3538746891.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5993553530424833 seconds.
# mu = 0.09378516583400197 +/- 3.643548194018741e-06
# sigma = 0.01073401651651995 +/- 0.00036301492582382477
# 68%CL = 0.09693896635258573, 95%CL = 0.11346000009189822, 99%CL = 0.12744171058314918
# mu = 0.09378516583400197 +/- 3.643548194018741e-06
# sigma = 0.01073401651651995 +/- 0.00036301492582382477
# /tmp/ipykernel_1591727/3538746891.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1591727/3538746891.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1591727/3538746891.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1591727/3538746891.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.013363760896027 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 25000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fe7cc9a56c0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fe7cc9a4900>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fe7cc9a5760>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fe7cc9a74c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fe7cc9a7560>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 1, 'batch_size_test': 50000, 'batch_...              8
# 1  {'niter': 1, 'batch_size_test': 50000, 'batch_...              1
# 2  {'niter': 1, 'batch_size_test': 50000, 'batch_...            360
# 3  {'niter': 1, 'batch_size_test': 50000, 'batch_...            800
# 4  {'niter': 1, 'batch_size_test': 50000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/50K_pre...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/50K_pre...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/50K_pre...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/50K_pre...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/50K_pre...
#
#                                           thresholds  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[0.68, [680, 319], 0.8915101425178019], [0.95...
# 4  [[0.68, [680, 319], 0.09693896635258573], [0.9...
#
#                                          null_figure
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  results_leo/particle_features_60/tests/50K_pre...
# 4  results_leo/particle_features_60/tests/50K_pre...

# %% [markdown]
# ### Alternative hypothesis

# %% [markdown]
# #### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100, # this will be adapted to the boostrap size
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}

# %%
file_path = os.path.join(model_dir, "exclusion_limits.json")
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}
    
# Sort the dictionary by keys
existing_data = dict(sorted(existing_data.items()))

# Save the sorted dictionary back to a JSON file
with open(file_path, 'w') as f:
    json.dump(existing_data, f, cls=GMetrics.utils.CustomEncoder, indent=4) # type: ignore

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[3:]:
    for deformation in deformations:
        eps_max = 2.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection_dataset(dataset = dataset,
                                                             metric_config = metric_config,
                                                             test_kwargs = test_kwargs,
                                                             model_dir = model_dir,
                                                             deformation = deformation,
                                                             seed_dist = 0,
                                                             x_tol = 0.1,
                                                             fn_tol = 0.15,
                                                             bound = bound,
                                                             eps_min = 0.,
                                                             eps_max = eps_max,
                                                             smear = 0.,
                                                             max_iterations = 50,
                                                             save = True,
                                                             filename = "exclusion_limits.json",
                                                             verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Computing upper bounds for sks with mean deformation.
#
# ======================================================
# =============== sks - mean ===============
# ======================================================
# niter: 1, nbootstrap: 100
#
# ------------ 1 - 0.95 CL -  upper bound -----------
# eps = 1.0 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.614427430555224 seconds.
#
# ===========================================================
# Testing from 1 to 2 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.163001728244126 seconds.
#
# ===========================================================
# Testing from 2 to 3 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9111908739432693 seconds.
#
# ===========================================================
# Testing from 3 to 4 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.271333417855203 seconds.
#
# ===========================================================
# Testing from 4 to 5 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7974037937819958 seconds.
#
# ===========================================================
# Testing from 5 to 6 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7613420579582453 seconds.
#
# ===========================================================
# Testing from 6 to 7 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.039275011047721 seconds.
#
# ===========================================================
# Testing from 7 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.708886867389083 seconds.
#
# ===========================================================
# Testing from 8 to 9 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6453325795009732 seconds.
#
# ===========================================================
# Testing from 9 to 10 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.814106105826795 seconds.
#
# ===========================================================
# Testing from 10 to 11 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6151765175163746 seconds.
#
# ===========================================================
# Testing from 11 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.5882935160771012 seconds.
#
# ===========================================================
# Testing from 12 to 13 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.659390247426927 seconds.
#
# ===========================================================
# Testing from 13 to 14 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.628432952798903 seconds.
#
# ===========================================================
# Testing from 14 to 15 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.78997088316828 seconds.
#
# ===========================================================
# Testing from 15 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.140838123857975 seconds.
#
# ===========================================================
# Testing from 16 to 17 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.94167257938534 seconds.
#
# ===========================================================
# Testing from 17 to 18 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.147072868421674 seconds.
#
# ===========================================================
# Testing from 18 to 19 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.885738253593445 seconds.
#
# ===========================================================
# Testing from 19 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7889974219724536 seconds.
#
# ===========================================================
# Testing from 20 to 21 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.979209017008543 seconds.
#
# ===========================================================
# Testing from 21 to 22 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.767465591430664 seconds.
#
# ===========================================================
# Testing from 22 to 23 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.655227441340685 seconds.
#
# ===========================================================
# Testing from 23 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.726761242374778 seconds.
#
# ===========================================================
# Testing from 24 to 25 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6536725014448166 seconds.
#
# ===========================================================
# Testing from 25 to 26 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.5887278290465474 seconds.
#
# ===========================================================
# Testing from 26 to 27 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.5117940939962864 seconds.
#
# ===========================================================
# Testing from 27 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.010232745669782 seconds.
#
# ===========================================================
# Testing from 28 to 29 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.4804978761821985 seconds.
#
# ===========================================================
# Testing from 29 to 30 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.051236365921795 seconds.
#
# ===========================================================
# Testing from 30 to 31 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.969706137664616 seconds.
#
# ===========================================================
# Testing from 31 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.221611182205379 seconds.
#
# ===========================================================
# Testing from 32 to 33 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8288445258513093 seconds.
#
# ===========================================================
# Testing from 33 to 34 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.775732303969562 seconds.
#
# ===========================================================
# Testing from 34 to 35 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.983760121278465 seconds.
#
# ===========================================================
# Testing from 35 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7375111132860184 seconds.
#
# ===========================================================
# Testing from 36 to 37 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.645622123964131 seconds.
#
# ===========================================================
# Testing from 37 to 38 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.769278572872281 seconds.
#
# ===========================================================
# Testing from 38 to 39 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.642256344668567 seconds.
#
# ===========================================================
# Testing from 39 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.593848140910268 seconds.
#
# ===========================================================
# Testing from 40 to 41 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.465845385566354 seconds.
#
# ===========================================================
# Testing from 41 to 42 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.324437975883484 seconds.
#
# ===========================================================
# Testing from 42 to 43 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.410834243521094 seconds.
#
# ===========================================================
# Testing from 43 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9331492902711034 seconds.
#
# ===========================================================
# Testing from 44 to 45 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.88268103916198 seconds.
#
# ===========================================================
# Testing from 45 to 46 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.06437056325376 seconds.
#
# ===========================================================
# Testing from 46 to 47 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8055219873785973 seconds.
#
# ===========================================================
# Testing from 47 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7225632490590215 seconds.
#
# ===========================================================
# Testing from 48 to 49 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.972197560593486 seconds.
#
# ===========================================================
# Testing from 49 to 50 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.698996227234602 seconds.
#
# ===========================================================
# Testing from 50 to 51 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6368103623390198 seconds.
#
# ===========================================================
# Testing from 51 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8570949658751488 seconds.
#
# ===========================================================
# Testing from 52 to 53 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.5905910367146134 seconds.
#
# ===========================================================
# Testing from 53 to 54 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.5986906345933676 seconds.
#
# ===========================================================
# Testing from 54 to 55 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.758205284364522 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.1680276822298765 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.254650107584894 seconds.
#
# ===========================================================
# Testing from 57 to 58 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9005700862035155 seconds.
#
# ===========================================================
# Testing from 58 to 59 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7872211020439863 seconds.
#
# ===========================================================
# Testing from 59 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.009571051225066 seconds.
#
# ===========================================================
# Testing from 60 to 61 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7898020073771477 seconds.
#
# ===========================================================
# Testing from 61 to 62 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.692693941295147 seconds.
#
# ===========================================================
# Testing from 62 to 63 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9558184687048197 seconds.
#
# ===========================================================
# Testing from 63 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7288056956604123 seconds.
#
# ===========================================================
# Testing from 64 to 65 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.583416295237839 seconds.
#
# ===========================================================
# Testing from 65 to 66 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7561202039942145 seconds.
#
# ===========================================================
# Testing from 66 to 67 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.5832855235785246 seconds.
#
# ===========================================================
# Testing from 67 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.560663841664791 seconds.
#
# ===========================================================
# Testing from 68 to 69 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.619844993576407 seconds.
#
# ===========================================================
# Testing from 69 to 70 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.081943861208856 seconds.
#
# ===========================================================
# Testing from 70 to 71 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.211798885837197 seconds.
#
# ===========================================================
# Testing from 71 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9508001608774066 seconds.
#
# ===========================================================
# Testing from 72 to 73 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.802532594650984 seconds.
#
# ===========================================================
# Testing from 73 to 74 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.104944213293493 seconds.
#
# ===========================================================
# Testing from 74 to 75 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.785576706752181 seconds.
#
# ===========================================================
# Testing from 75 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6921474020928144 seconds.
#
# ===========================================================
# Testing from 76 to 77 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9984834752976894 seconds.
#
# ===========================================================
# Testing from 77 to 78 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.711320608854294 seconds.
#
# ===========================================================
# Testing from 78 to 79 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.652473564259708 seconds.
#
# ===========================================================
# Testing from 79 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.862771537154913 seconds.
#
# ===========================================================
# Testing from 80 to 81 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.572788245975971 seconds.
#
# ===========================================================
# Testing from 81 to 82 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.589738141745329 seconds.
#
# ===========================================================
# Testing from 82 to 83 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.592654056847095 seconds.
#
# ===========================================================
# Testing from 83 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.1431383062154055 seconds.
#
# ===========================================================
# Testing from 84 to 85 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.290491800755262 seconds.
#
# ===========================================================
# Testing from 85 to 86 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.022111996077001 seconds.
#
# ===========================================================
# Testing from 86 to 87 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.159642540849745 seconds.
#
# ===========================================================
# Testing from 87 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9646810414269567 seconds.
#
# ===========================================================
# Testing from 88 to 89 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8046552538871765 seconds.
#
# ===========================================================
# Testing from 89 to 90 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.079405249096453 seconds.
#
# ===========================================================
# Testing from 90 to 91 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8416996095329523 seconds.
#
# ===========================================================
# Testing from 91 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6919489689171314 seconds.
#
# ===========================================================
# Testing from 92 to 93 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.860857881605625 seconds.
#
# ===========================================================
# Testing from 93 to 94 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7110156062990427 seconds.
#
# ===========================================================
# Testing from 94 to 95 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.579842008650303 seconds.
#
# ===========================================================
# Testing from 95 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.669973202981055 seconds.
#
# ===========================================================
# Testing from 96 to 97 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.29270342271775 seconds.
#
# ===========================================================
# Testing from 97 to 98 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.83808777667582 seconds.
#
# ===========================================================
# Testing from 98 to 99 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.121682851575315 seconds.
#
# ===========================================================
# Testing from 99 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.0443010199815035 seconds.
# statistic = 31.76105896813073 - next threshold = 0.9961503757477772 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8783595555664838
#
# ------------ 2 - 0.95 CL -  upper bound -----------
# eps = 0.5 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.220659145154059 seconds.
#
# ===========================================================
# Testing from 1 to 2 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.948704265989363 seconds.
#
# ===========================================================
# Testing from 2 to 3 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8204337544739246 seconds.
#
# ===========================================================
# Testing from 3 to 4 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.993513056077063 seconds.
#
# ===========================================================
# Testing from 4 to 5 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.746386030688882 seconds.
#
# ===========================================================
# Testing from 5 to 6 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6602638885378838 seconds.
#
# ===========================================================
# Testing from 6 to 7 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8826501863077283 seconds.
#
# ===========================================================
# Testing from 7 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6656829537823796 seconds.
#
# ===========================================================
# Testing from 8 to 9 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.594154976308346 seconds.
#
# ===========================================================
# Testing from 9 to 10 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8202234217897058 seconds.
#
# ===========================================================
# Testing from 10 to 11 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.179203850217164 seconds.
#
# ===========================================================
# Testing from 11 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.493843396194279 seconds.
#
# ===========================================================
# Testing from 12 to 13 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.037961299531162 seconds.
#
# ===========================================================
# Testing from 13 to 14 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.890182726085186 seconds.
#
# ===========================================================
# Testing from 14 to 15 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.158487018197775 seconds.
#
# ===========================================================
# Testing from 15 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9354396164417267 seconds.
#
# ===========================================================
# Testing from 16 to 17 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.768368221819401 seconds.
#
# ===========================================================
# Testing from 17 to 18 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.978389821946621 seconds.
#
# ===========================================================
# Testing from 18 to 19 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7910364801064134 seconds.
#
# ===========================================================
# Testing from 19 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6401926521211863 seconds.
#
# ===========================================================
# Testing from 20 to 21 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.899328495375812 seconds.
#
# ===========================================================
# Testing from 21 to 22 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6887828977778554 seconds.
#
# ===========================================================
# Testing from 22 to 23 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.5745592322200537 seconds.
#
# ===========================================================
# Testing from 23 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.865569980815053 seconds.
#
# ===========================================================
# Testing from 24 to 25 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.048912787809968 seconds.
#
# ===========================================================
# Testing from 25 to 26 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.503088762052357 seconds.
#
# ===========================================================
# Testing from 26 to 27 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.0835736487060785 seconds.
#
# ===========================================================
# Testing from 27 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.116819052025676 seconds.
#
# ===========================================================
# Testing from 28 to 29 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.039538003504276 seconds.
#
# ===========================================================
# Testing from 29 to 30 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8891020007431507 seconds.
#
# ===========================================================
# Testing from 30 to 31 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.12573669757694 seconds.
#
# ===========================================================
# Testing from 31 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.886897317133844 seconds.
#
# ===========================================================
# Testing from 32 to 33 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7600303906947374 seconds.
#
# ===========================================================
# Testing from 33 to 34 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9512814804911613 seconds.
#
# ===========================================================
# Testing from 34 to 35 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7113815285265446 seconds.
#
# ===========================================================
# Testing from 35 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6960252160206437 seconds.
#
# ===========================================================
# Testing from 36 to 37 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8168417327106 seconds.
#
# ===========================================================
# Testing from 37 to 38 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6744195092469454 seconds.
#
# ===========================================================
# Testing from 38 to 39 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.771064658649266 seconds.
#
# ===========================================================
# Testing from 39 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.434425516985357 seconds.
#
# ===========================================================
# Testing from 40 to 41 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.088466196320951 seconds.
#
# ===========================================================
# Testing from 41 to 42 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.38300756085664 seconds.
#
# ===========================================================
# Testing from 42 to 43 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.9743535360321403 seconds.
#
# ===========================================================
# Testing from 43 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8854261450469494 seconds.
#
# ===========================================================
# Testing from 44 to 45 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.071435010991991 seconds.
#
# ===========================================================
# Testing from 45 to 46 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.8138242503628135 seconds.
#
# ===========================================================
# Testing from 46 to 47 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7239515827968717 seconds.
#
# ===========================================================
# Testing from 47 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.946436893194914 seconds.
#
# ===========================================================
# Testing from 48 to 49 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.7483971156179905 seconds.
#
# ===========================================================
# Testing from 49 to 50 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.651897550560534 seconds.
#
# ===========================================================
# Testing from 50 to 51 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.807327347807586 seconds.
#
# ===========================================================
# Testing from 51 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.6404928537085652 seconds.
#
# ===========================================================
# Testing from 52 to 53 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 3.638595218770206 seconds.
#
# ===========================================================
# Testing from 53 to 54 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.881287027150393 seconds.
#
# ===========================================================
# Testing from 54 to 55 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.161976511590183 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 4.318239597603679 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 100 samples.
#
# ------------------------------------------
# ...
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.1628642026335 seconds.
#
# ===========================================================
# Testing from 36 to 37 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.19948388915509 seconds.
#
# ===========================================================
# Testing from 37 to 38 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.383953434415162 seconds.
#
# ===========================================================
# Testing from 38 to 39 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.03834279999137 seconds.
#
# ===========================================================
# Testing from 39 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.265912427566946 seconds.
#
# ===========================================================
# Testing from 40 to 41 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.156133002601564 seconds.
#
# ===========================================================
# Testing from 41 to 42 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.272694044746459 seconds.
#
# ===========================================================
# Testing from 42 to 43 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.070495220832527 seconds.
#
# ===========================================================
# Testing from 43 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.008383150212467 seconds.
#
# ===========================================================
# Testing from 44 to 45 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.21178584266454 seconds.
#
# ===========================================================
# Testing from 45 to 46 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.933561024256051 seconds.
#
# ===========================================================
# Testing from 46 to 47 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.935162036679685 seconds.
#
# ===========================================================
# Testing from 47 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.048124426975846 seconds.
#
# ===========================================================
# Testing from 48 to 49 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.7987450351938605 seconds.
#
# ===========================================================
# Testing from 49 to 50 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.938976749777794 seconds.
#
# ===========================================================
# Testing from 50 to 51 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.008551375940442 seconds.
#
# ===========================================================
# Testing from 51 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.774852253496647 seconds.
#
# ===========================================================
# Testing from 52 to 53 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.750293666496873 seconds.
#
# ===========================================================
# Testing from 53 to 54 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.910935373045504 seconds.
#
# ===========================================================
# Testing from 54 to 55 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.710064286366105 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.800467943772674 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.933022757060826 seconds.
#
# ===========================================================
# Testing from 57 to 58 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.744960899464786 seconds.
#
# ===========================================================
# Testing from 58 to 59 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.850801385939121 seconds.
#
# ===========================================================
# Testing from 59 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.913706633262336 seconds.
#
# ===========================================================
# Testing from 60 to 61 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.752129711210728 seconds.
#
# ===========================================================
# Testing from 61 to 62 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.814015785232186 seconds.
#
# ===========================================================
# Testing from 62 to 63 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.8807784942910075 seconds.
#
# ===========================================================
# Testing from 63 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.671816886402667 seconds.
#
# ===========================================================
# Testing from 64 to 65 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.828450629487634 seconds.
#
# ===========================================================
# Testing from 65 to 66 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.861966403201222 seconds.
#
# ===========================================================
# Testing from 66 to 67 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.689561674371362 seconds.
#
# ===========================================================
# Testing from 67 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.858796015381813 seconds.
#
# ===========================================================
# Testing from 68 to 69 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 38.42620069067925 seconds.
#
# ===========================================================
# Testing from 69 to 70 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.28789282310754 seconds.
#
# ===========================================================
# Testing from 70 to 71 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.259454810991883 seconds.
#
# ===========================================================
# Testing from 71 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.010862267576158 seconds.
#
# ===========================================================
# Testing from 72 to 73 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.606328100897372 seconds.
#
# ===========================================================
# Testing from 73 to 74 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.154300226829946 seconds.
#
# ===========================================================
# Testing from 74 to 75 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.838975617662072 seconds.
#
# ===========================================================
# Testing from 75 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.75593722704798 seconds.
#
# ===========================================================
# Testing from 76 to 77 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.681800108402967 seconds.
#
# ===========================================================
# Testing from 77 to 78 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.985406657680869 seconds.
#
# ===========================================================
# Testing from 78 to 79 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.65067258104682 seconds.
#
# ===========================================================
# Testing from 79 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.575865374878049 seconds.
#
# ===========================================================
# Testing from 80 to 81 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.79537581000477 seconds.
#
# ===========================================================
# Testing from 81 to 82 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.762692182324827 seconds.
#
# ===========================================================
# Testing from 82 to 83 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.609640263020992 seconds.
#
# ===========================================================
# Testing from 83 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.623029145412147 seconds.
#
# ===========================================================
# Testing from 84 to 85 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.759468326345086 seconds.
#
# ===========================================================
# Testing from 85 to 86 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.490622067824006 seconds.
#
# ===========================================================
# Testing from 86 to 87 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.60386305116117 seconds.
#
# ===========================================================
# Testing from 87 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.63683611061424 seconds.
#
# ===========================================================
# Testing from 88 to 89 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_366541/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#   Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 2       sks        mean  450      8                10000
# 9       swd        mean  450      8                10000
#
#   $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 2      $0.01907_{-0.0061}^{+0.0053}$      $0.02864_{-0.0029}^{+0.0043}$
# 9      $0.02298_{-0.0092}^{+0.0073}$      $0.03031_{-0.0052}^{+0.0094}$
#
#    $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 2           2334  [0.01298, 0.01907, 0.02441]   [0.0257, 0.02864, 0.03299]
# 9            894  [0.01374, 0.02298, 0.03027]  [0.02513, 0.03031, 0.03974]
#
#                time
# 2  [1166, 586, 582]
# 9   [438, 237, 219]
#   Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 2       sks      $0.01907_{-0.0061}^{+0.0053}$
# 9       swd      $0.02298_{-0.0092}^{+0.0073}$
#
#   $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 2      $0.02864_{-0.0029}^{+0.0043}$           2334
# 9      $0.03031_{-0.0052}^{+0.0094}$            894

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_366541/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#   Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 7       swd    cov_diag  450      8                10000
# 0       sks    cov_diag  450      8                10000
#
#   $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7                $0.04013_{-0.017}^{+0.017}$
# 0                 $0.0436_{-0.014}^{+0.021}$
#
#   $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 7                $0.05138_{-0.016}^{+0.014}$                    884
# 0                  $0.06547_{-0.02}^{+0.01}$                   2300
#
#                          95%CL                        99%CL              time
# 7  [0.02328, 0.04013, 0.05664]  [0.03558, 0.05138, 0.06585]   [429, 220, 235]
# 0   [0.02967, 0.0436, 0.06445]  [0.04533, 0.06547, 0.07542]  [1064, 615, 621]
#   Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7       swd                $0.04013_{-0.017}^{+0.017}$
# 0       sks                 $0.0436_{-0.014}^{+0.021}$
#
#   $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 7                $0.05138_{-0.016}^{+0.014}$                    884
# 0                  $0.06547_{-0.02}^{+0.01}$                   2300

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_366541/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#   Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 8       swd  cov_off_diag  450      8                10000
# 1       sks  cov_off_diag  450      8                10000
#
#   $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 8                     $0.02913_{-0.012}^{+0.012}$
# 1                     $0.03352_{-0.011}^{+0.011}$
#
#   $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)  \
# 8                    $0.03843_{-0.0066}^{+0.012}$                         914
# 1                   $0.05034_{-0.0086}^{+0.0076}$                        2563
#
#                          95%CL                        99%CL              time
# 8  [0.01741, 0.02913, 0.04102]  [0.03186, 0.03843, 0.05038]   [435, 249, 230]
# 1  [0.02281, 0.03352, 0.04492]  [0.04173, 0.05034, 0.05798]  [1240, 658, 665]
#   Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 8       swd                     $0.02913_{-0.012}^{+0.012}$
# 1       sks                     $0.03352_{-0.011}^{+0.011}$
#
#   $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 8                    $0.03843_{-0.0066}^{+0.012}$                         914
# 1                   $0.05034_{-0.0086}^{+0.0076}$                        2563

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_366541/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 11       swd  power_abs_up  450      8                10000
# 4        sks  power_abs_up  450      8                10000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11                 $0.03145_{-0.013}^{+0.017}$
# 4                  $0.04783_{-0.015}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 11                 $0.04149_{-0.013}^{+0.013}$                     874
# 4                  $0.07182_{-0.022}^{+0.011}$                    2513
#
#                           95%CL                        99%CL              time
# 11   [0.0188, 0.03145, 0.04883]   [0.02873, 0.04149, 0.0544]   [426, 218, 230]
# 4   [0.03254, 0.04783, 0.06445]  [0.04973, 0.07182, 0.08273]  [1167, 669, 677]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11       swd                 $0.03145_{-0.013}^{+0.017}$
# 4        sks                 $0.04783_{-0.015}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 11                 $0.04149_{-0.013}^{+0.013}$                     874
# 4                  $0.07182_{-0.022}^{+0.011}$                    2513

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_366541/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 10       swd  power_abs_down  450      8                10000
# 3        sks  power_abs_down  450      8                10000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10                 $0.03807_{-0.017}^{+0.019}$
# 3                  $0.04783_{-0.017}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 10                 $0.04675_{-0.014}^{+0.019}$                     863
# 3                  $0.06746_{-0.012}^{+0.015}$                    2641
#
#                           95%CL                        99%CL              time
# 10  [0.02119, 0.03807, 0.05664]  [0.03237, 0.04675, 0.06585]   [416, 230, 217]
# 3   [0.03057, 0.04783, 0.06445]  [0.05593, 0.06746, 0.08273]  [1225, 704, 712]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10       swd                 $0.03807_{-0.017}^{+0.019}$
# 3        sks                 $0.04783_{-0.017}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 10                 $0.04675_{-0.014}^{+0.019}$                     863
# 3                  $0.06746_{-0.012}^{+0.015}$                    2641

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_366541/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        sks  random_normal  450      8                10000
# 12       swd  random_normal  450      8                10000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                   $0.132_{-0.014}^{+0.032}$
# 12                 $0.14348_{-0.03}^{+0.021}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 5                 $0.16428_{-0.029}^{+0.019}$                   2195
# 12                $0.15855_{-0.017}^{+0.025}$                    676
#
#                           95%CL                        99%CL              time
# 5     [0.11808, 0.132, 0.16406]  [0.13541, 0.16428, 0.18365]  [1041, 567, 587]
# 12  [0.11395, 0.14348, 0.16406]  [0.14182, 0.15855, 0.18365]   [325, 174, 177]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        sks                  $0.132_{-0.014}^{+0.032}$
# 12       swd                 $0.14348_{-0.03}^{+0.021}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                 $0.16428_{-0.029}^{+0.019}$                   2195
# 12                $0.15855_{-0.017}^{+0.025}$                    676

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_366541/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        sks  random_uniform  450      8                10000
# 13       swd  random_uniform  450      8                10000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                 $0.22101_{-0.023}^{+0.052}$
# 13                $0.25187_{-0.052}^{+0.037}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                 $0.27506_{-0.048}^{+0.032}$                   2180
# 13                $0.27831_{-0.049}^{+0.044}$                    661
#
#                           95%CL                        99%CL             time
# 6    [0.1977, 0.22101, 0.27344]   [0.22671, 0.27506, 0.3075]  [989, 595, 596]
# 13  [0.20004, 0.25187, 0.28906]  [0.22939, 0.27831, 0.32239]  [300, 175, 186]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        sks                $0.22101_{-0.023}^{+0.052}$
# 13       swd                $0.25187_{-0.052}^{+0.037}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                 $0.27506_{-0.048}^{+0.032}$                   2180
# 13                $0.27831_{-0.049}^{+0.044}$                    661
