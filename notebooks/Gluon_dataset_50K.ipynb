# %% [markdown]
# # Initialize

# %%
# %cd "/local_data/scratch/rtorre/projects/JetNetDataMetrics"
# Out:
# /local_data/scratch/rtorre/projects/JetNetDataMetrics

# %%
visible_devices = [3]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more import deformations
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-06-15 11:50:44.754542: Importing os...
# 2024-06-15 11:50:44.754810: Importing sys...
# Visible devices: [3]
# 2024-06-15 11:50:44.755356: Importing timer from timeit...
# 2024-06-15 11:50:44.755500: Setting env variables for tf import (only device(s) [3] will be available)...
# 2024-06-15 11:50:44.755766: Importing numpy...
# 2024-06-15 11:50:44.895632: Importing matplotlib...
# 2024-06-15 11:50:45.246310: Importing h5py...
# 2024-06-15 11:50:45.273185: Importing importlib.util...
# 2024-06-15 11:50:45.273313: Importing json...
# 2024-06-15 11:50:45.273382: Importing pandas...
# 2024-06-15 11:50:45.614193: Importing random...
# 2024-06-15 11:50:45.614383: Importing scipy utils...
# 2024-06-15 11:50:45.955879: Importing subprocess...
# 2024-06-15 11:50:45.956024: Importing textwrap...
# 2024-06-15 11:50:45.956084: Importing tensorflow...
# Tensorflow version: 2.12.0
# 2024-06-15 11:50:48.133634: Importing tensorflow_probability...
# Tensorflow probability version: 0.20.1
# 2024-06-15 11:50:48.422311: Importing timeit...
# 2024-06-15 11:50:48.422412: Importing tqdm...
# 2024-06-15 11:50:48.426537: Importing typing...
# 2024-06-15 11:50:48.426665: Setting tf configs...
# 2024-06-15 11:50:48.577342: Importing GMetrics module...
# 2024-06-15 11:50:51.437372: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #3, model: NVIDIA A40
# Loaded 1 GPUs: ['NVIDIA A40']
# 2024-06-15 11:50:51.486395: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 30,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 30, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 30, 4)

# %% [markdown]
# # Jet level

# %% [markdown]
# ## Init data

# %%
results_dir = "results/jet_features/"
figures_dir = results_dir + "figures/"
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocess_data=(data-means)/stds
    return preprocess_data

def postprocess_data(data,means,stds):
    postprocess_data=data*stds+means
    return postprocess_data

def get_reduced_jet_features(jet_features):
    p_T_jet = jet_features[:,1]
    eta_jet = jet_features[:,2]
    m_jet = jet_features[:,3]
    m_jet_over_p_T_jet = m_jet / p_T_jet
    return tf.stack([p_T_jet, eta_jet, m_jet, m_jet_over_p_T_jet], axis=1)

jet_features_reduced = get_reduced_jet_features(jet_features)
jet_features_reduced.shape
# Out:
# TensorShape([177252, 4])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests")
model_dir = os.path.join(tests_dir, '50K')
if not os.path.exists(model_dir):
    os.makedirs(tests_dir)
    
dataset = get_reduced_jet_features(jet_features)

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(model_dir, 'null_hypotheses')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(model_dir, "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 50_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 20_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 1, nbootstrap: 1000
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "max_vectorize": 3200, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "max_vectorize": 3200,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "max_vectorize": 3200,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "max_vectorize": 3200,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values()):
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 3200
#
# ===========================================================
# Testing from 0 to 1 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 6.530948712490499 seconds.
#
# ===========================================================
# Testing from 1 to 2 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.811073080636561 seconds.
#
# ===========================================================
# Testing from 2 to 3 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.762451854534447 seconds.
#
# ===========================================================
# Testing from 3 to 4 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.8182153897359967 seconds.
#
# ===========================================================
# Testing from 4 to 5 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# WARNING:tensorflow:5 out of the last 5 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f4839914af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# FGD metric calculation completed in 3.968047857284546 seconds.
#
# ===========================================================
# Testing from 5 to 6 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# WARNING:tensorflow:6 out of the last 6 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f4839915480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# FGD metric calculation completed in 4.236884513869882 seconds.
#
# ===========================================================
# Testing from 6 to 7 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.960590268485248 seconds.
#
# ===========================================================
# Testing from 7 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.298646979033947 seconds.
#
# ===========================================================
# Testing from 8 to 9 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.278077310882509 seconds.
#
# ===========================================================
# Testing from 9 to 10 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.468706406652927 seconds.
#
# ===========================================================
# Testing from 10 to 11 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.167479786090553 seconds.
#
# ===========================================================
# Testing from 11 to 12 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.1759565295651555 seconds.
#
# ===========================================================
# Testing from 12 to 13 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.104323743842542 seconds.
#
# ===========================================================
# Testing from 13 to 14 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.443718681111932 seconds.
#
# ===========================================================
# Testing from 14 to 15 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.724516603164375 seconds.
#
# ===========================================================
# Testing from 15 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.8743643602356315 seconds.
#
# ===========================================================
# Testing from 16 to 17 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.6265065940096974 seconds.
#
# ===========================================================
# Testing from 17 to 18 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.3813926791772246 seconds.
#
# ===========================================================
# Testing from 18 to 19 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.1656181132420897 seconds.
#
# ===========================================================
# Testing from 19 to 20 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.5145997563377023 seconds.
#
# ===========================================================
# Testing from 20 to 21 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.5911145638674498 seconds.
#
# ===========================================================
# Testing from 21 to 22 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.4899812983348966 seconds.
#
# ===========================================================
# Testing from 22 to 23 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.6349046612158418 seconds.
#
# ===========================================================
# Testing from 23 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.6105673518031836 seconds.
#
# ===========================================================
# Testing from 24 to 25 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.553356730379164 seconds.
#
# ===========================================================
# Testing from 25 to 26 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.558954552747309 seconds.
#
# ===========================================================
# Testing from 26 to 27 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.1361027723178267 seconds.
#
# ===========================================================
# Testing from 27 to 28 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.1744871605187654 seconds.
#
# ===========================================================
# Testing from 28 to 29 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.5634429743513465 seconds.
#
# ===========================================================
# Testing from 29 to 30 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.079364350065589 seconds.
#
# ===========================================================
# Testing from 30 to 31 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.506781072355807 seconds.
#
# ===========================================================
# Testing from 31 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.0597092313691974 seconds.
#
# ===========================================================
# Testing from 32 to 33 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.3358957953751087 seconds.
#
# ===========================================================
# Testing from 33 to 34 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.268490497022867 seconds.
#
# ===========================================================
# Testing from 34 to 35 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.161024769768119 seconds.
#
# ===========================================================
# Testing from 35 to 36 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.1115831499919295 seconds.
#
# ===========================================================
# Testing from 36 to 37 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.3493377175182104 seconds.
#
# ===========================================================
# Testing from 37 to 38 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.157918487675488 seconds.
#
# ===========================================================
# Testing from 38 to 39 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.729090590029955 seconds.
#
# ===========================================================
# Testing from 39 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.4769403552636504 seconds.
#
# ===========================================================
# Testing from 40 to 41 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.1588684413582087 seconds.
#
# ===========================================================
# Testing from 41 to 42 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.0741488486528397 seconds.
#
# ===========================================================
# Testing from 42 to 43 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.2416294533759356 seconds.
#
# ===========================================================
# Testing from 43 to 44 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.10157333035022 seconds.
#
# ===========================================================
# Testing from 44 to 45 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.469475220888853 seconds.
#
# ===========================================================
# Testing from 45 to 46 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.747188551351428 seconds.
#
# ===========================================================
# Testing from 46 to 47 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.579054935835302 seconds.
#
# ===========================================================
# Testing from 47 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.362248259596527 seconds.
#
# ===========================================================
# Testing from 48 to 49 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.6636315723881125 seconds.
#
# ===========================================================
# Testing from 49 to 50 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.54335346724838 seconds.
#
# ===========================================================
# Testing from 50 to 51 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.500786822289228 seconds.
#
# ===========================================================
# Testing from 51 to 52 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.501510680653155 seconds.
#
# ===========================================================
# Testing from 52 to 53 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.716021153144538 seconds.
#
# ===========================================================
# Testing from 53 to 54 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.600351417437196 seconds.
#
# ===========================================================
# Testing from 54 to 55 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.545984062366188 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.614554740488529 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.6694162413477898 seconds.
#
# ===========================================================
# Testing from 57 to 58 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.298421022482216 seconds.
#
# ===========================================================
# Testing from 58 to 59 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.235987480729818 seconds.
#
# ===========================================================
# Testing from 59 to 60 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.360304152593017 seconds.
#
# ===========================================================
# Testing from 60 to 61 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.31346707418561 seconds.
#
# ===========================================================
# Testing from 61 to 62 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.447985699400306 seconds.
#
# ===========================================================
# Testing from 62 to 63 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.49215164873749 seconds.
#
# ===========================================================
# Testing from 63 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.184988872148097 seconds.
#
# ===========================================================
# Testing from 64 to 65 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.6490291599184275 seconds.
#
# ===========================================================
# Testing from 65 to 66 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.253316937014461 seconds.
#
# ===========================================================
# Testing from 66 to 67 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.648232853040099 seconds.
#
# ===========================================================
# Testing from 67 to 68 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.711727005429566 seconds.
#
# ===========================================================
# Testing from 68 to 69 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.675754940137267 seconds.
#
# ===========================================================
# Testing from 69 to 70 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.7448320193216205 seconds.
#
# ===========================================================
# Testing from 70 to 71 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.417292880825698 seconds.
#
# ===========================================================
# Testing from 71 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.314206554554403 seconds.
#
# ===========================================================
# Testing from 72 to 73 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.373092331923544 seconds.
#
# ===========================================================
# Testing from 73 to 74 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.097280794754624 seconds.
#
# ===========================================================
# Testing from 74 to 75 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.2250323705375195 seconds.
#
# ===========================================================
# Testing from 75 to 76 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.48571202903986 seconds.
#
# ===========================================================
# Testing from 76 to 77 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.5127478847280145 seconds.
#
# ===========================================================
# Testing from 77 to 78 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.593750906176865 seconds.
#
# ===========================================================
# Testing from 78 to 79 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.524308634921908 seconds.
#
# ===========================================================
# Testing from 79 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.650858156383038 seconds.
#
# ===========================================================
# Testing from 80 to 81 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.6718975799158216 seconds.
#
# ===========================================================
# Testing from 81 to 82 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.223360884934664 seconds.
#
# ===========================================================
# Testing from 82 to 83 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.4083607560023665 seconds.
#
# ===========================================================
# Testing from 83 to 84 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.701418182812631 seconds.
#
# ===========================================================
# Testing from 84 to 85 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.427794566377997 seconds.
#
# ===========================================================
# Testing from 85 to 86 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.540426413528621 seconds.
#
# ===========================================================
# Testing from 86 to 87 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.168124665506184 seconds.
#
# ===========================================================
# Testing from 87 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.741979451850057 seconds.
#
# ===========================================================
# Testing from 88 to 89 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.421214107424021 seconds.
#
# ===========================================================
# Testing from 89 to 90 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.596116928383708 seconds.
#
# ===========================================================
# Testing from 90 to 91 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.573165426962078 seconds.
#
# ===========================================================
# Testing from 91 to 92 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.500851536169648 seconds.
#
# ===========================================================
# Testing from 92 to 93 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.662438095547259 seconds.
#
# ===========================================================
# Testing from 93 to 94 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.581066983751953 seconds.
#
# ===========================================================
# Testing from 94 to 95 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.5850371113047 seconds.
#
# ===========================================================
# Testing from 95 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.638098261319101 seconds.
#
# ===========================================================
# Testing from 96 to 97 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.1491652224212885 seconds.
#
# ===========================================================
# Testing from 97 to 98 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.419459075666964 seconds.
#
# ===========================================================
# Testing from 98 to 99 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.979542135260999 seconds.
#
# ===========================================================
# Testing from 99 to 100 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.535869801416993 seconds.
#
# ===========================================================
# Testing from 100 to 101 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.7550706416368484 seconds.
#
# ===========================================================
# Testing from 101 to 102 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.752271958626807 seconds.
#
# ===========================================================
# Testing from 102 to 103 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.734901873394847 seconds.
#
# ===========================================================
# Testing from 103 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.581771248951554 seconds.
#
# ===========================================================
# Testing from 104 to 105 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.18279380351305 seconds.
#
# ===========================================================
# Testing from 105 to 106 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.545962476171553 seconds.
#
# ===========================================================
# Testing from 106 to 107 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.544071360491216 seconds.
#
# ===========================================================
# Testing from 107 to 108 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.51491657923907 seconds.
#
# ===========================================================
# Testing from 108 to 109 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.492860463447869 seconds.
#
# ===========================================================
# Testing from 109 to 110 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.411209196783602 seconds.
#
# ===========================================================
# Testing from 110 to 111 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.533915549516678 seconds.
#
# ===========================================================
# Testing from 111 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.639180927537382 seconds.
#
# ===========================================================
# Testing from 112 to 113 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.359156214632094 seconds.
#
# ===========================================================
# Testing from 113 to 114 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.530863678082824 seconds.
#
# ===========================================================
# Testing from 114 to 115 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.555862095206976 seconds.
#
# ===========================================================
# Testing from 115 to 116 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.9488227730616927 seconds.
#
# ===========================================================
# Testing from 116 to 117 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.157668490894139 seconds.
#
# ===========================================================
# Testing from 117 to 118 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.352613365277648 seconds.
#
# ===========================================================
# Testing from 118 to 119 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.0207807049155235 seconds.
#
# ===========================================================
# Testing from 119 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.108194240368903 seconds.
#
# ===========================================================
# Testing from 120 to 121 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.029573458246887 seconds.
#
# ===========================================================
# Testing from 121 to 122 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.9766681576147676 seconds.
#
# ===========================================================
# Testing from 122 to 123 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.9217647705227137 seconds.
#
# ===========================================================
# Testing from 123 to 124 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.564980769529939 seconds.
#
# ===========================================================
# Testing from 124 to 125 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.2446473287418485 seconds.
#
# ===========================================================
# Testing from 125 to 126 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.46000393666327 seconds.
#
# ===========================================================
# Testing from 126 to 127 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.331358042545617 seconds.
#
# ===========================================================
# Testing from 127 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.563957813195884 seconds.
#
# ===========================================================
# Testing from 128 to 129 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.01781231444329 seconds.
#
# ===========================================================
# Testing from 129 to 130 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.570988499559462 seconds.
#
# ===========================================================
# Testing from 130 to 131 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.120851472951472 seconds.
#
# ===========================================================
# Testing from 131 to 132 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.418335915543139 seconds.
#
# ===========================================================
# Testing from 132 to 133 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.379318960011005 seconds.
#
# ===========================================================
# Testing from 133 to 134 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.5754433162510395 seconds.
#
# ===========================================================
# Testing from 134 to 135 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.626107291318476 seconds.
#
# ===========================================================
# Testing from 135 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.529239002615213 seconds.
#
# ===========================================================
# Testing from 136 to 137 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.535004615783691 seconds.
#
# ===========================================================
# Testing from 137 to 138 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 5.135300434194505 seconds.
#
# ===========================================================
# Testing from 138 to 139 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.46282758936286 seconds.
#
# ===========================================================
# Testing from 139 to 140 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.625050878152251 seconds.
#
# ===========================================================
# Testing from 140 to 141 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.557546394877136 seconds.
#
# ===========================================================
# Testing from 141 to 142 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.049978948198259 seconds.
#
# ===========================================================
# Testing from 142 to 143 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.28876237384975 seconds.
#
# ===========================================================
# Testing from 143 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.7800916070118546 seconds.
#
# ===========================================================
# Testing from 144 to 145 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.7533525554463267 seconds.
#
# ===========================================================
# Testing from 145 to 146 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.867081210948527 seconds.
#
# ===========================================================
# Testing from 146 to 147 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.044555254280567 seconds.
#
# ===========================================================
# Testing from 147 to 148 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.369614223949611 seconds.
#
# ===========================================================
# Testing from 148 to 149 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.363217837177217 seconds.
#
# ===========================================================
# Testing from 149 to 150 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 3.4270168859511614 seconds.
#
# ===========================================================
# Testing from 150 to 151 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.488811117596924 seconds.
#
# ===========================================================
# Testing from 151 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.620248667895794 seconds.
#
# ===========================================================
# Testing from 152 to 153 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.639828206039965 seconds.
#
# ===========================================================
# Testing from 153 to 154 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 1
# batch_size = 50000
# FGD metric calculation completed in 4.607248038984835 seconds.
#
# ===========================================================
# Testing from 154 to 155 of 1000 samples.
# ...
# ===========================================================
# Testing from 558 to 559 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.756357105448842 seconds.
#
# ===========================================================
# Testing from 559 to 560 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.662792882882059 seconds.
#
# ===========================================================
# Testing from 560 to 561 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.791734116151929 seconds.
#
# ===========================================================
# Testing from 561 to 562 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.590991397388279 seconds.
#
# ===========================================================
# Testing from 562 to 563 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.752203983254731 seconds.
#
# ===========================================================
# Testing from 563 to 564 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.582919014617801 seconds.
#
# ===========================================================
# Testing from 564 to 565 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.096068633720279 seconds.
#
# ===========================================================
# Testing from 565 to 566 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 6.703148867934942 seconds.
#
# ===========================================================
# Testing from 566 to 567 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.422455602325499 seconds.
#
# ===========================================================
# Testing from 567 to 568 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.819224778562784 seconds.
#
# ===========================================================
# Testing from 568 to 569 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.878062376752496 seconds.
#
# ===========================================================
# Testing from 569 to 570 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.8627540823072195 seconds.
#
# ===========================================================
# Testing from 570 to 571 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.232727807015181 seconds.
#
# ===========================================================
# Testing from 571 to 572 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.646360266953707 seconds.
#
# ===========================================================
# Testing from 572 to 573 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 6.380360027775168 seconds.
#
# ===========================================================
# Testing from 573 to 574 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.428918002173305 seconds.
#
# ===========================================================
# Testing from 574 to 575 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 6.740550206974149 seconds.
#
# ===========================================================
# Testing from 575 to 576 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.971536696888506 seconds.
#
# ===========================================================
# Testing from 576 to 577 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.906059894710779 seconds.
#
# ===========================================================
# Testing from 577 to 578 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.837416551075876 seconds.
#
# ===========================================================
# Testing from 578 to 579 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.870461798273027 seconds.
#
# ===========================================================
# Testing from 579 to 580 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 6.518231270834804 seconds.
#
# ===========================================================
# Testing from 580 to 581 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.176612821407616 seconds.
#
# ===========================================================
# Testing from 581 to 582 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 6.382202062755823 seconds.
#
# ===========================================================
# Testing from 582 to 583 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.356236976571381 seconds.
#
# ===========================================================
# Testing from 583 to 584 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.704663377255201 seconds.
#
# ===========================================================
# Testing from 584 to 585 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.03544822987169 seconds.
#
# ===========================================================
# Testing from 585 to 586 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 15.325771181844175 seconds.
#
# ===========================================================
# Testing from 586 to 587 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.87665602657944 seconds.
#
# ===========================================================
# Testing from 587 to 588 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.422217913903296 seconds.
#
# ===========================================================
# Testing from 588 to 589 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.725402601994574 seconds.
#
# ===========================================================
# Testing from 589 to 590 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.744124555960298 seconds.
#
# ===========================================================
# Testing from 590 to 591 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.41360838059336 seconds.
#
# ===========================================================
# Testing from 591 to 592 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.193235445767641 seconds.
#
# ===========================================================
# Testing from 592 to 593 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.794302065856755 seconds.
#
# ===========================================================
# Testing from 593 to 594 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.764482384547591 seconds.
#
# ===========================================================
# Testing from 594 to 595 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.607539666816592 seconds.
#
# ===========================================================
# Testing from 595 to 596 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.563230047002435 seconds.
#
# ===========================================================
# Testing from 596 to 597 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.202010498382151 seconds.
#
# ===========================================================
# Testing from 597 to 598 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.261463891714811 seconds.
#
# ===========================================================
# Testing from 598 to 599 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.02349453791976 seconds.
#
# ===========================================================
# Testing from 599 to 600 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 6.301452326588333 seconds.
#
# ===========================================================
# Testing from 600 to 601 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 9.314544470980763 seconds.
#
# ===========================================================
# Testing from 601 to 602 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.33313069306314 seconds.
#
# ===========================================================
# Testing from 602 to 603 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 7.8230781108140945 seconds.
#
# ===========================================================
# Testing from 603 to 604 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 5.819246108643711 seconds.
#
# ===========================================================
# Testing from 604 to 605 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 17.90281500760466 seconds.
#
# ===========================================================
# Testing from 605 to 606 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 8.493873217143118 seconds.
#
# ===========================================================
# Testing from 606 to 607 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.735445501282811 seconds.
#
# ===========================================================
# Testing from 607 to 608 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.255043905228376 seconds.
#
# ===========================================================
# Testing from 608 to 609 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 10.236300223506987 seconds.
#
# ===========================================================
# Testing from 609 to 610 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000
# SKS metric calculation completed in 6.624752792529762 seconds.
#
# ===========================================================
# Testing from 610 to 611 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 1
# batch_size = 50000

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []

for metric in list(metrics_config[unique_key].values()):
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [408, 191], 4.4577638779739245e-05], [0.95, [570, 30], 7.448543633039335e-05], [0.99, [594, 6], 0.00011959992550350216]]
# Computing time for metric fgd: 148.91037395969033
# ThresholdS for metric mmd: [[0.68, [408, 191], 2746.20703125], [0.95, [570, 30], 72365.234375], [0.99, [594, 6], 129499.375]]
# Computing time for metric mmd: 129.76520181261003
# ThresholdS for metric ks: [[0.68, [408, 191], 0.896965621184943], [0.95, [570, 30], 0.9819947807132462], [0.99, [594, 6], 1.0392703985478076]]
# Computing time for metric ks: 19.073471484705806
# ThresholdS for metric sks: [[0.68, [408, 191], 0.9108953390102558], [0.95, [570, 30], 1.0818030487732582], [0.99, [594, 6], 1.2206786268323748]]
# Computing time for metric sks: 70.2185449115932
# ThresholdS for metric swd: [[0.68, [408, 191], 0.015897704081644884], [0.95, [570, 30], 0.020952556527507812], [0.99, [594, 6], 0.024422429300298917]]
# Computing time for metric swd: 48.65299752075225
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...      metric_list
# 2                                                 {}  statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}     metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f4be45dc790>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f4be45ddfc0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f4be45dd5a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f4be45dc280>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f4be45dd3f0>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#    max_vectorize               latex  \
# 0            120  $d_{\mathrm{FGD}}$
# 1              5  $d_{\mathrm{MMD}}$
# 2           6000      $\overline{D}$
# 3            100     $\widetilde{D}$
# 4            100     $\widetilde{W}$
#
#                                            null_file  \
# 0  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 1  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 2  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 3  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 4  results/EW_MsplineN/run_2/tests/10K/null_hypot...
#
#                                           thresholds
# 0  [[0.68, [408, 191], 4.4577638779739245e-05], [...
# 1  [[0.68, [408, 191], 2746.20703125], [0.95, [57...
# 2  [[0.68, [408, 191], 0.896965621184943], [0.95,...
# 3  [[0.68, [408, 191], 0.9108953390102558], [0.95...
# 4  [[0.68, [408, 191], 0.015897704081644884], [0....

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values()):
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Frequency', fontsize=16)
    ax[0].set_title('PDF for jet_features null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for jet_features null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 2.719135545983529e-05 +/- 3.934048563106961e-11
# sigma = 3.104257013029269e-05 +/- 2.5509261768487453e-06
# 68%CL = 4.4577638779739245e-05, 95%CL = 7.448543633039335e-05, 99%CL = 0.00011959992550350216
# mu = 2.719135545983529e-05 +/- 3.934048563106961e-11
# sigma = 3.104257013029269e-05 +/- 2.5509261768487453e-06
# /tmp/ipykernel_21054/2595869255.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_21054/2595869255.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_21054/2595869255.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 12.109236990101635 seconds.
# mu = 419.73290364583335 +/- 59393415.31390173
# sigma = 38142.307428925116 +/- 2919.7577919602127
# 68%CL = 2746.20703125, 95%CL = 72365.234375, 99%CL = 129499.375
# mu = 419.73290364583335 +/- 59393415.31390173
# sigma = 38142.307428925116 +/- 2919.7577919602127
# /tmp/ipykernel_21054/2595869255.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_21054/2595869255.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_21054/2595869255.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 9.705525293014944 seconds.
# mu = 0.8662105691797153 +/- 0.0001782817776784653
# sigma = 0.0660832343146544 +/- 0.0020118671175824625
# 68%CL = 0.896965621184943, 95%CL = 0.9819947807132462, 99%CL = 1.0392703985478076
# mu = 0.8662105691797153 +/- 0.0001782817776784653
# sigma = 0.0660832343146544 +/- 0.0020118671175824625
# /tmp/ipykernel_21054/2595869255.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_21054/2595869255.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_21054/2595869255.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_21054/2595869255.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 5.729966350831091 seconds.
# mu = 0.8661222671363001 +/- 0.000555686989504452
# sigma = 0.11666831536407898 +/- 0.003962134142497756
# 68%CL = 0.9108953390102558, 95%CL = 1.0818030487732582, 99%CL = 1.2206786268323748
# mu = 0.8661222671363001 +/- 0.000555686989504452
# sigma = 0.11666831536407898 +/- 0.003962134142497756
# /tmp/ipykernel_21054/2595869255.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_21054/2595869255.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_21054/2595869255.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_21054/2595869255.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 8.08307727612555 seconds.
# mu = 0.015085520877520322 +/- 3.3786594368341095e-07
# sigma = 0.002876802328086297 +/- 0.00012172428400288111
# 68%CL = 0.015897704081644884, 95%CL = 0.020952556527507812, 99%CL = 0.024422429300298917
# mu = 0.015085520877520322 +/- 3.3786594368341095e-07
# sigma = 0.002876802328086297 +/- 0.00012172428400288111
# /tmp/ipykernel_21054/2595869255.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_21054/2595869255.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_21054/2595869255.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_21054/2595869255.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 6.963683793321252 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...      metric_list
# 2                                                 {}  statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}     metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f4be45dc790>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f4be45ddfc0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f4be45dd5a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f4be45dc280>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f4be45dd3f0>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#    max_vectorize               latex  \
# 0            120  $d_{\mathrm{FGD}}$
# 1              5  $d_{\mathrm{MMD}}$
# 2           6000      $\overline{D}$
# 3            100     $\widetilde{D}$
# 4            100     $\widetilde{W}$
#
#                                            null_file  \
# 0  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 1  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 2  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 3  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 4  results/EW_MsplineN/run_2/tests/10K/null_hypot...
#
#                                           thresholds  \
# 0  [[0.68, [408, 191], 4.4577638779739245e-05], [...
# 1  [[0.68, [408, 191], 2746.20703125], [0.95, [57...
# 2  [[0.68, [408, 191], 0.896965621184943], [0.95,...
# 3  [[0.68, [408, 191], 0.9108953390102558], [0.95...
# 4  [[0.68, [408, 191], 0.015897704081644884], [0....
#
#                                          null_figure
# 0  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 1  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 2  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 3  results/EW_MsplineN/run_2/tests/10K/null_hypot...
# 4  results/EW_MsplineN/run_2/tests/10K/null_hypot...
