# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [0]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more.deformations import deformed_distribution, deform_mean, deform_cov_diag, deform_cov_off_diag, deform_power_abs, deform_random
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection_dataset # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-07-03 11:16:44.911513: Importing os...
# 2024-07-03 11:16:44.911721: Importing sys...
# Visible devices: [0]
# 2024-07-03 11:16:44.911954: Importing timer from timeit...
# 2024-07-03 11:16:44.912029: Setting env variables for tf import (only device(s) [0] will be available)...
# 2024-07-03 11:16:44.912156: Importing numpy...
# 2024-07-03 11:16:45.212037: Importing matplotlib...
# 2024-07-03 11:16:45.679406: Importing h5py...
# 2024-07-03 11:16:45.902798: Importing importlib.util...
# 2024-07-03 11:16:45.902933: Importing json...
# 2024-07-03 11:16:45.903003: Importing pandas...
# 2024-07-03 11:16:46.914491: Importing random...
# 2024-07-03 11:16:46.914642: Importing scipy utils...
# 2024-07-03 11:16:47.775874: Importing subprocess...
# 2024-07-03 11:16:47.776023: Importing textwrap...
# 2024-07-03 11:16:47.776085: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-07-03 11:16:56.837015: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-07-03 11:16:58.224254: Importing timeit...
# 2024-07-03 11:16:58.224347: Importing tqdm...
# 2024-07-03 11:16:58.235344: Importing typing...
# 2024-07-03 11:16:58.235448: Setting tf configs...
# 2024-07-03 11:16:59.382428: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-07-03 11:17:07.954246: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #0, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-07-03 11:17:07.968356: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 60,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 60, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 60, 4)

# %% [markdown]
# # Particle level

# %% [markdown]
# ## Init data

# %%
results_dir = "results_leo/particle_features_60/"
figures_dir = os.path.join(results_dir, "figures/")
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocess_data=(data-means)/stds
    return preprocess_data

def postprocess_data(data,means,stds):
    postprocess_data=data*stds+means
    return postprocess_data

def get_reduced_particle_features(particle_features):
    tmp = particle_features[:, :, :3]
    shape = tmp.shape
    particle_features_reshaped = tf.reshape(tmp, [-1, shape[1] * shape[2]])
    return particle_features_reshaped

particle_features_reduced = get_reduced_particle_features(particle_features)
particle_features_reduced.shape
# Out:
# TensorShape([177252, 180])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests/")
model_dir = os.path.join(tests_dir, '20K/')
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    
dataset = get_reduced_particle_features(particle_features)

# %% [markdown]
# ## 20K

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(model_dir, 'null_hypotheses/')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(model_dir, "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 20_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 20_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 4, nbootstrap: 250
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputsNull.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0      4            20000            1000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  is_symb_1  ndims_1  \
# 0     0    True            False     None     True      False      180
#
#    nsamples_1  is_symb_2  ndims_2  nsamples_2    dtype  ndims  nsamples  \
# 0       80000      False      180       80000  float64    180     80000
#
#    small_sample
# 0         False

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {"verbose": True}, 
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 360,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values())[1:2]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng mmd with max_vectorize = 2
#
# ===========================================================
# Testing from 0 to 4 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.623636940028518 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4805707069463097 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.874421184998937 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5172339089913294 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# WARNING:tensorflow:5 out of the last 9 calls to <function MMDMetric.Test_tf.<locals>.batched_test at 0x7fc5a2b95080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5121122199925594 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# WARNING:tensorflow:6 out of the last 11 calls to <function MMDMetric.Test_tf.<locals>.batched_test at 0x7fc5a57d0360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.518989488016814 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.971489901014138 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4841339149861597 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4861916980007663 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.929968237003777 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4782144550117664 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4639432880212553 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4641816719667986 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.9595968929934315 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.486303785990458 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4666284730192274 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4875286300084554 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.045041884994134 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.530091733962763 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5372016290202737 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.002405525010545 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5405262620188296 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4866178339580074 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.468992075009737 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.9937327530351467 seconds.
#
# ===========================================================
# Testing from 100 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.517401221964974 seconds.
#
# ===========================================================
# Testing from 104 to 108 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4825469269999303 seconds.
#
# ===========================================================
# Testing from 108 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.480047265999019 seconds.
#
# ===========================================================
# Testing from 112 to 116 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.010120512044523 seconds.
#
# ===========================================================
# Testing from 116 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.515756495005917 seconds.
#
# ===========================================================
# Testing from 120 to 124 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.48671024403302 seconds.
#
# ===========================================================
# Testing from 124 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.998100128956139 seconds.
#
# ===========================================================
# Testing from 128 to 132 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5109697489533573 seconds.
#
# ===========================================================
# Testing from 132 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.4955548730213195 seconds.
#
# ===========================================================
# Testing from 136 to 140 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5126772760413587 seconds.
#
# ===========================================================
# Testing from 140 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.119547645968851 seconds.
#
# ===========================================================
# Testing from 144 to 148 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5696634619962424 seconds.
#
# ===========================================================
# Testing from 148 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.554263942001853 seconds.
#
# ===========================================================
# Testing from 152 to 156 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5087451220024377 seconds.
#
# ===========================================================
# Testing from 156 to 160 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.085489310033154 seconds.
#
# ===========================================================
# Testing from 160 to 164 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5337642920203507 seconds.
#
# ===========================================================
# Testing from 164 to 168 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5558953500003554 seconds.
#
# ===========================================================
# Testing from 168 to 172 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.546446942957118 seconds.
#
# ===========================================================
# Testing from 172 to 176 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.067428246024065 seconds.
#
# ===========================================================
# Testing from 176 to 180 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.521223433956038 seconds.
#
# ===========================================================
# Testing from 180 to 184 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5248840249842033 seconds.
#
# ===========================================================
# Testing from 184 to 188 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5075912400498055 seconds.
#
# ===========================================================
# Testing from 188 to 192 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.132795782992616 seconds.
#
# ===========================================================
# Testing from 192 to 196 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5721106190467253 seconds.
#
# ===========================================================
# Testing from 196 to 200 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.56730403797701 seconds.
#
# ===========================================================
# Testing from 200 to 204 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.490374953020364 seconds.
#
# ===========================================================
# Testing from 204 to 208 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.1138634299859405 seconds.
#
# ===========================================================
# Testing from 208 to 212 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5328179229982197 seconds.
#
# ===========================================================
# Testing from 212 to 216 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.536344547988847 seconds.
#
# ===========================================================
# Testing from 216 to 220 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5262680809828453 seconds.
#
# ===========================================================
# Testing from 220 to 224 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.1262409670162015 seconds.
#
# ===========================================================
# Testing from 224 to 228 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.524369532999117 seconds.
#
# ===========================================================
# Testing from 228 to 232 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5185549440211616 seconds.
#
# ===========================================================
# Testing from 232 to 236 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.058734119986184 seconds.
#
# ===========================================================
# Testing from 236 to 240 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5376500450074673 seconds.
#
# ===========================================================
# Testing from 240 to 244 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5282838969724253 seconds.
#
# ===========================================================
# Testing from 244 to 248 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.561640019004699 seconds.
#
# ===========================================================
# Testing from 248 to 252 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.1572755969827995 seconds.
#
# ===========================================================
# Testing from 252 to 256 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5588864070014097 seconds.
#
# ===========================================================
# Testing from 256 to 260 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5595440680044703 seconds.
#
# ===========================================================
# Testing from 260 to 264 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.543843600025866 seconds.
#
# ===========================================================
# Testing from 264 to 268 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.14008936600294 seconds.
#
# ===========================================================
# Testing from 268 to 272 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5989344699773937 seconds.
#
# ===========================================================
# Testing from 272 to 276 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5773870359989814 seconds.
#
# ===========================================================
# Testing from 276 to 280 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.505592379020527 seconds.
#
# ===========================================================
# Testing from 280 to 284 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.129806959012058 seconds.
#
# ===========================================================
# Testing from 284 to 288 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.54110790300183 seconds.
#
# ===========================================================
# Testing from 288 to 292 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.539794825948775 seconds.
#
# ===========================================================
# Testing from 292 to 296 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5225951310130768 seconds.
#
# ===========================================================
# Testing from 296 to 300 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.1826175269670784 seconds.
#
# ===========================================================
# Testing from 300 to 304 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.581896865973249 seconds.
#
# ===========================================================
# Testing from 304 to 308 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6016276910086162 seconds.
#
# ===========================================================
# Testing from 308 to 312 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5735381690319628 seconds.
#
# ===========================================================
# Testing from 312 to 316 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.560913490015082 seconds.
#
# ===========================================================
# Testing from 316 to 320 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.285598323971499 seconds.
#
# ===========================================================
# Testing from 320 to 324 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5706793679855764 seconds.
#
# ===========================================================
# Testing from 324 to 328 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.604189023026265 seconds.
#
# ===========================================================
# Testing from 328 to 332 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.510703222011216 seconds.
#
# ===========================================================
# Testing from 332 to 336 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.2056905049830675 seconds.
#
# ===========================================================
# Testing from 336 to 340 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6043548139859922 seconds.
#
# ===========================================================
# Testing from 340 to 344 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5815158930490725 seconds.
#
# ===========================================================
# Testing from 344 to 348 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5165283780079335 seconds.
#
# ===========================================================
# Testing from 348 to 352 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.179712423007004 seconds.
#
# ===========================================================
# Testing from 352 to 356 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5493251910083927 seconds.
#
# ===========================================================
# Testing from 356 to 360 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5614754629787058 seconds.
#
# ===========================================================
# Testing from 360 to 364 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5797976499889046 seconds.
#
# ===========================================================
# Testing from 364 to 368 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.213628741970751 seconds.
#
# ===========================================================
# Testing from 368 to 372 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.61600089201238 seconds.
#
# ===========================================================
# Testing from 372 to 376 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6010862559778616 seconds.
#
# ===========================================================
# Testing from 376 to 380 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.54509411304025 seconds.
#
# ===========================================================
# Testing from 380 to 384 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.253281171026174 seconds.
#
# ===========================================================
# Testing from 384 to 388 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.561923264001962 seconds.
#
# ===========================================================
# Testing from 388 to 392 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5644041339983232 seconds.
#
# ===========================================================
# Testing from 392 to 396 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.533553365035914 seconds.
#
# ===========================================================
# Testing from 396 to 400 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.2125630639493465 seconds.
#
# ===========================================================
# Testing from 400 to 404 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.565468926972244 seconds.
#
# ===========================================================
# Testing from 404 to 408 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6265767180011608 seconds.
#
# ===========================================================
# Testing from 408 to 412 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.561741907033138 seconds.
#
# ===========================================================
# Testing from 412 to 416 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.288816173968371 seconds.
#
# ===========================================================
# Testing from 416 to 420 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.60086126497481 seconds.
#
# ===========================================================
# Testing from 420 to 424 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.617267529014498 seconds.
#
# ===========================================================
# Testing from 424 to 428 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5761479230131954 seconds.
#
# ===========================================================
# Testing from 428 to 432 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.588474021991715 seconds.
#
# ===========================================================
# Testing from 432 to 436 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.363539905985817 seconds.
#
# ===========================================================
# Testing from 436 to 440 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5639636269770563 seconds.
#
# ===========================================================
# Testing from 440 to 444 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5581329760025255 seconds.
#
# ===========================================================
# Testing from 444 to 448 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5493324249982834 seconds.
#
# ===========================================================
# Testing from 448 to 452 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.294118552003056 seconds.
#
# ===========================================================
# Testing from 452 to 456 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.573776967008598 seconds.
#
# ===========================================================
# Testing from 456 to 460 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.592457519029267 seconds.
#
# ===========================================================
# Testing from 460 to 464 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.552891322004143 seconds.
#
# ===========================================================
# Testing from 464 to 468 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.265897904988378 seconds.
#
# ===========================================================
# Testing from 468 to 472 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.5827035780530423 seconds.
#
# ===========================================================
# Testing from 472 to 476 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6421301449881867 seconds.
#
# ===========================================================
# Testing from 476 to 480 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.602692311978899 seconds.
#
# ===========================================================
# Testing from 480 to 484 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.614714241004549 seconds.
#
# ===========================================================
# Testing from 484 to 488 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.361774388002232 seconds.
#
# ===========================================================
# Testing from 488 to 492 of 1000 samples.
#
# ...
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6379811619990505 seconds.
#
# ===========================================================
# Testing from 836 to 840 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.543518657970708 seconds.
#
# ===========================================================
# Testing from 840 to 844 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.666986804048065 seconds.
#
# ===========================================================
# Testing from 844 to 848 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7024093929794617 seconds.
#
# ===========================================================
# Testing from 848 to 852 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6714459719951265 seconds.
#
# ===========================================================
# Testing from 852 to 856 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.602869438007474 seconds.
#
# ===========================================================
# Testing from 856 to 860 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.579998951987363 seconds.
#
# ===========================================================
# Testing from 860 to 864 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6613329630345106 seconds.
#
# ===========================================================
# Testing from 864 to 868 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6598142979783006 seconds.
#
# ===========================================================
# Testing from 868 to 872 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6369546559872106 seconds.
#
# ===========================================================
# Testing from 872 to 876 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.633858057030011 seconds.
#
# ===========================================================
# Testing from 876 to 880 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.634634824004024 seconds.
#
# ===========================================================
# Testing from 880 to 884 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.734713562007528 seconds.
#
# ===========================================================
# Testing from 884 to 888 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7010620289947838 seconds.
#
# ===========================================================
# Testing from 888 to 892 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.683809269045014 seconds.
#
# ===========================================================
# Testing from 892 to 896 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.648842322989367 seconds.
#
# ===========================================================
# Testing from 896 to 900 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.679081526992377 seconds.
#
# ===========================================================
# Testing from 900 to 904 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.732783010986168 seconds.
#
# ===========================================================
# Testing from 904 to 908 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.72279464796884 seconds.
#
# ===========================================================
# Testing from 908 to 912 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.69623847695766 seconds.
#
# ===========================================================
# Testing from 912 to 916 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.636591160960961 seconds.
#
# ===========================================================
# Testing from 916 to 920 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.646554379025474 seconds.
#
# ===========================================================
# Testing from 920 to 924 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7321565769962035 seconds.
#
# ===========================================================
# Testing from 924 to 928 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.652043927984778 seconds.
#
# ===========================================================
# Testing from 928 to 932 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6903348580235615 seconds.
#
# ===========================================================
# Testing from 932 to 936 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6773481969721615 seconds.
#
# ===========================================================
# Testing from 936 to 940 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.701264389033895 seconds.
#
# ===========================================================
# Testing from 940 to 944 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.771782089024782 seconds.
#
# ===========================================================
# Testing from 944 to 948 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7028411999926902 seconds.
#
# ===========================================================
# Testing from 948 to 952 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6458452600054443 seconds.
#
# ===========================================================
# Testing from 952 to 956 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6319643019814976 seconds.
#
# ===========================================================
# Testing from 956 to 960 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6379783999873325 seconds.
#
# ===========================================================
# Testing from 960 to 964 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.760655279038474 seconds.
#
# ===========================================================
# Testing from 964 to 968 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6953467550338246 seconds.
#
# ===========================================================
# Testing from 968 to 972 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6694232219597325 seconds.
#
# ===========================================================
# Testing from 972 to 976 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7012320469948463 seconds.
#
# ===========================================================
# Testing from 976 to 980 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.676582535961643 seconds.
#
# ===========================================================
# Testing from 980 to 984 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.708363561017904 seconds.
#
# ===========================================================
# Testing from 984 to 988 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.74362474802183 seconds.
#
# ===========================================================
# Testing from 988 to 992 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.722547101031523 seconds.
#
# ===========================================================
# Testing from 992 to 996 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6962391289998777 seconds.
#
# ===========================================================
# Testing from 996 to 1000 of 1000 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.6345764310099185 seconds.
# All done in: 967.75 s.
# Saving mmd to results_leo/particle_features_60/tests/20K/null_hypotheses/MMD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []
ndims = 180

for metric in list(metrics_config[unique_key].values())[1:2]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    print(len(dist_null))

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# 1000
# ThresholdS for metric mmd: [[0.68, [680, 319], 41777569.86425781], [0.95, [950, 50], 1479778373.807495], [0.99, [990, 10], 2758017197.1829834]]
# Computing time for metric mmd: 943.7579201992485
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fc71ca65580>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fc71ca67380>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fc71ca65f80>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fc71ca66020>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fc71ca67420>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 4, 'batch_size_test': 20000, 'batch_...              8
# 1  {'niter': 4, 'batch_size_test': 20000, 'batch_...              2
# 2  {'niter': 4, 'batch_size_test': 20000, 'batch_...            360
# 3  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
# 4  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/20K/nul...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/20K/nul...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/20K/nul...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/20K/nul...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/20K/nul...
#
#                                           thresholds
# 0                                                NaN
# 1  [[0.68, [680, 319], 41777569.86425781], [0.95,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[1:2]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Frequency', fontsize=16)
    ax[0].set_title('PDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 12749707.553012207 +/- 1.4727504198694232e+16
# sigma = 682440162.3407489 +/- 33804798.627549425
# 68%CL = 41777569.86425781, 95%CL = 1479778373.807495, 99%CL = 2758017197.1829834
# mu = 12749707.553012207 +/- 1.4727504198694232e+16
# sigma = 682440162.3407489 +/- 33804798.627549425
# /tmp/ipykernel_573822/190522178.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_573822/190522178.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_573822/190522178.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_573822/190522178.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 2.2178518869914114 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fc71ca65580>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fc71ca67380>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fc71ca65f80>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fc71ca66020>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fc71ca67420>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 4, 'batch_size_test': 20000, 'batch_...              8
# 1  {'niter': 4, 'batch_size_test': 20000, 'batch_...              2
# 2  {'niter': 4, 'batch_size_test': 20000, 'batch_...            360
# 3  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
# 4  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/20K/nul...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/20K/nul...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/20K/nul...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/20K/nul...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/20K/nul...
#
#                                           thresholds  \
# 0                                                NaN
# 1  [[0.68, [680, 319], 41777569.86425781], [0.95,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          null_figure
# 0                                                NaN
# 1  results_leo/particle_features_60/tests/20K/nul...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ### Alternative hypothesis

# %% [markdown]
# #### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100, # this will be adapted to the boostrap size
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}

# %%
file_path = os.path.join(model_dir, "exclusion_limits.json")
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}
    
# Sort the dictionary by keys
existing_data = dict(sorted(existing_data.items()))

# Save the sorted dictionary back to a JSON file
with open(file_path, 'w') as f:
    json.dump(existing_data, f, cls=GMetrics.utils.CustomEncoder, indent=4) # type: ignore

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[1:2]:
    for deformation in deformations:
        eps_max = 2.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection_dataset(dataset = dataset,
                                                             metric_config = metric_config,
                                                             test_kwargs = test_kwargs,
                                                             model_dir = model_dir,
                                                             deformation = deformation,
                                                             seed_dist = 0,
                                                             x_tol = 0.1,
                                                             fn_tol = 0.15,
                                                             bound = bound,
                                                             eps_min = 0.,
                                                             eps_max = eps_max,
                                                             smear = 0.,
                                                             max_iterations = 50,
                                                             save = True,
                                                             filename = "exclusion_limits.json",
                                                             verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Computing upper bounds for mmd with mean deformation.
#
# ======================================================
# =============== mmd - mean ===============
# ======================================================
# niter: 4, nbootstrap: 25
#
# ------------ 1 - 0.95 CL -  upper bound -----------
# eps = 1.0 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8325189959723502 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.749812252994161 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7444865360157564 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7402364279842004 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.637211933964863 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7628742029774003 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.770047196012456 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7723727480042726 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7415987660060637 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.755722362024244 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.87575826398097 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.783569344028365 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7442730360198766 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.725357362010982 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.71150089497678 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.72818280296633 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.78769674297655 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7672430699458346 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7439590460271575 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.753379477013368 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.739332474011462 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.842902373988181 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7818555010017008 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7816279709804803 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.780219740991015 seconds.
# statistic = 16578020606.21291 - next threshold = 1479778373.807495 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.672212903589245
#
# ------------ 2 - 0.95 CL -  upper bound -----------
# eps = 0.5 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7712096920004115 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.784733418026008 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.84623055200791 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7859943770454265 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8145886339480057 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7504845689982176 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7405129880062304 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.89763060194673 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8006138849887066 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.762607138021849 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7531074520084076 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7409111299784854 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.886260066006798 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8677412619581446 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8039570919936523 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.828997274977155 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7961577830137685 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.741278626024723 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.860078377008904 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.857390213990584 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8463438129983842 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7614829360391013 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.76903077197494 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.867613459995482 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8380571199813858 seconds.
# statistic = 3651458381.5965524 - next threshold = 1479778373.807495 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.8464548066319164
#
# ------------ 3 - 0.95 CL -  upper bound -----------
# eps = 0.25 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.80584208201617 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.795704171003308 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7549120720359497 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.812299783981871 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.999005099001806 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.883465716964565 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.876422358036507 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.822783196985256 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7713198109995574 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.798955266014673 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.001347694022115 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.864033007004764 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8272149019758217 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8391433160286397 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.808843287988566 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.806766581023112 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.978480056044646 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.866982249019202 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.829157342959661 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.839727270998992 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8272381420247257 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 4.95172241301043 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8564142659888603 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8292971689952537 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.829975077009294 seconds.
# statistic = 46501846.72610569 - next threshold = 1479778373.807495 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 1.8781302513116542
#
# ------------ 4 - 0.95 CL -  upper bound -----------
# eps = 0.375 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.786558607011102 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7562479180051014 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.013051190006081 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.868555009015836 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8375309070106596 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.811832659994252 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.803591026982758 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7725497120409273 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.002901470987126 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.845261609996669 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.808086541015655 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8585947349783964 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8506068009883165 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.822736254951451 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.074780089023989 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.866325486043934 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.9012090410105884 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8197366949752904 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.781033767038025 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.7778529570205137 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.005448974028695 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.875600470986683 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8977578070480376 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8633139510056935 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8069169190130197 seconds.
# statistic = 1063775307.4002776 - next threshold = 1479778373.807495 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 0.32710382287641276
#
# ------------ 5 - 0.95 CL -  upper bound -----------
# eps = 0.4375 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.799962306045927 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.0130942079704255 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.86037661699811 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.827733594982419 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8107077530003153 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.821329198020976 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8280681769829243 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.065156507014763 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.891022850002628 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.9147562200087123 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.884286446031183 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8238306579878554 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.811291004996747 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.805546216026414 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.098393890017178 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8878888319595717 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.835326255997643 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.828668087022379 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.81733572401572 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 3.8068858130136505 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 5.148565722978674 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# ...
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.332483900012448 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.302407415001653 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.307414764014538 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.254857115040068 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.291607805003878 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.29371550900396 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.29754027898889 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.278298504999839 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.249904826981947 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.271114684001077 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.244578861980699 seconds.
# statistic = -692603305.5010443 - next threshold = 1479778373.807495 at 0.95 CL
# relative_error_eps = 0.6666666666666666
# relative_error_metric = 5.519437204692619
#
# ------------ 3 - 0.95 CL -  upper bound -----------
# eps = 0.75 - deformation = random_uniform
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.229894413030706 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.176152023952454 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.2211541929864325 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.185052668966819 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.201693719020113 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.214458110975102 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.144480517017655 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.147772800002713 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.243569076992571 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.178608232992701 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 21.806779920007102 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.95911007700488 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.769205138960388 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.693418818991631 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.51545146695571 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.434148737986106 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.495816609007306 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.42574150901055 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.447750408027787 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.427715404017363 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.438263837015256 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.407712179992814 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.403950140986126 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.46295958198607 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.4019085059990175 seconds.
# statistic = -251101888.39831662 - next threshold = 1479778373.807495 at 0.95 CL
# relative_error_eps = 0.2857142857142857
# relative_error_metric = 2.8174711289105323
#
# ------------ 4 - 0.95 CL -  upper bound -----------
# eps = 0.875 - deformation = random_uniform
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.467911251005717 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.5049269840237685 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.447701799974311 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .
# Iterating from 2 to 4 out of 4 .
# MMD metric calculation completed in 7.410922258044593 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 4
# batch_size = 20000
# nchunks = 2
# Iterating from 0 to 2 out of 4 .

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd

# %%
results
# Out:
# [['fgd', 'mean', 90, 4, 20000, 'upper', 0.09497, 0.12579, 3185],
#  ['fgd', 'mean', 90, 4, 20000, 'central', 0.07248, 0.10622, 1995],
#  ['fgd', 'mean', 90, 4, 20000, 'lower', 0.03975, 0.08519, 2530],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'upper', 0.09378, 0.11369, 3337],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'central', 0.06284, 0.09005, 2139],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'lower', 0.0358, 0.06854, 3078],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.02887, 0.03966, 3493],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'central', 0.02316, 0.03515, 2017],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.01617, 0.03007, 2423],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'upper', 0.05859, 0.07327, 4420],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'central', 0.03599, 0.04934, 2684],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'lower', 0.01961, 0.03581, 4978],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06534, 0.08171, 4175],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'central', 0.03699, 0.05511, 2697],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'lower', 0.01878, 0.03787, 2431],
#  ['fgd', 'random_normal', 90, 4, 20000, 'upper', 0.22046, 0.25357, 2974],
#  ['fgd', 'random_normal', 90, 4, 20000, 'central', 0.18671, 0.22667, 2163],
#  ['fgd', 'random_normal', 90, 4, 20000, 'lower', 0.14676, 0.19531, 2979],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'upper', 0.39066, 0.44782, 3786],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'central', 0.32909, 0.39263, 2434],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'lower', 0.26571, 0.3428, 2437],
#  ['mmd', 'mean', 90, 4, 20000, 'upper', 0.38566, 0.47565, 2441],
#  ['mmd', 'mean', 90, 4, 20000, 'central', 0.22947, 0.32659, 1654],
#  ['mmd', 'mean', 90, 4, 20000, 'lower', 0.12215, 0.21559, 1874],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'upper', 0.17969, 0.21734, 3476],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'central', 0.11334, 0.15031, 2189],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'lower', 0.06416, 0.09461, 3208],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.21143, 0.27996, 2932],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'central', 0.16131, 0.23825, 2312],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.11084, 0.18291, 1821],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'upper', 0.05414, 0.06147, 2735],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'central', 0.03206, 0.04228, 1756],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'lower', 0.01805, 0.02662, 5319],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06255, 0.07513, 3618],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'central', 0.0336, 0.04991, 2407],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'lower', 0.01711, 0.0303, 2515],
#  ['mmd', 'random_normal', 90, 4, 20000, 'upper', 0.54736, 0.59157, 2782],
#  ['mmd', 'random_normal', 90, 4, 20000, 'central', 0.40194, 0.50268, 5573],
#  ['mmd', 'random_normal', 90, 4, 20000, 'lower', 0.32453, 0.38821, 4008],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'upper', 0.92578, 1.0, 6652],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'central', 0.68726, 0.87417, 3735],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'lower', 0.48549, 0.66939, 5109],
#  ['ks', 'mean', 90, 4, 20000, 'upper', 0.01556, 0.02106, 870],
#  ['ks', 'mean', 90, 4, 20000, 'central', 0.00983, 0.01725, 697],
#  ['ks', 'mean', 90, 4, 20000, 'lower', 0.00216, 0.01212, 907],
#  ['ks', 'cov_diag', 90, 4, 20000, 'upper', 0.03992, 0.05452, 1275],
#  ['ks', 'cov_diag', 90, 4, 20000, 'central', 0.02545, 0.03987, 1038],
#  ['ks', 'cov_diag', 90, 4, 20000, 'lower', 0.00535, 0.02814, 1272],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'upper', 0.05786, 0.07362, 1643],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'central', 0.04069, 0.0569, 1280],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'lower', 0.01406, 0.04636, 1540],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'upper', 0.02649, 0.0377, 2225],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'central', 0.01613, 0.02649, 1668],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'lower', 0.00332, 0.01785, 2094],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'upper', 0.02625, 0.03515, 2699],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'central', 0.01641, 0.02571, 1988],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'lower', 0.00343, 0.01848, 2364],
#  ['ks', 'random_normal', 90, 4, 20000, 'upper', 0.11182, 0.12812, 2605],
#  ['ks', 'random_normal', 90, 4, 20000, 'central', 0.09133, 0.11404, 2153],
#  ['ks', 'random_normal', 90, 4, 20000, 'lower', 0.06526, 0.08927, 2219],
#  ['ks', 'random_uniform', 90, 4, 20000, 'upper', 0.18799, 0.21785, 2787],
#  ['ks', 'random_uniform', 90, 4, 20000, 'central', 0.1553, 0.18609, 2386],
#  ['ks', 'random_uniform', 90, 4, 20000, 'lower', 0.11812, 0.15157, 2508],
#  ['sks', 'mean', 90, 4, 20000, 'upper', 0.03406, 0.04532, 5082],
#  ['sks', 'mean', 90, 4, 20000, 'central', 0.02647, 0.03781, 3461],
#  ['sks', 'mean', 90, 4, 20000, 'lower', 0.01532, 0.03034, 4020],
#  ['sks', 'cov_diag', 90, 4, 20000, 'upper', 0.05493, 0.06906, 5153],
#  ['sks', 'cov_diag', 90, 4, 20000, 'central', 0.04033, 0.05582, 3767],
#  ['sks', 'cov_diag', 90, 4, 20000, 'lower', 0.02605, 0.04593, 4130],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'upper', 0.04724, 0.06382, 5840],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'central', 0.03578, 0.05309, 4064],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'lower', 0.02151, 0.0431, 4766],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'upper', 0.08203, 0.11142, 1146],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'central', 0.06093, 0.08302, 815],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'lower', 0.03502, 0.06202, 856],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'upper', 0.08203, 0.09836, 1348],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'central', 0.05686, 0.0802, 972],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'lower', 0.03133, 0.05424, 1139],
#  ['sks', 'random_normal', 90, 4, 20000, 'upper', 0.12109, 0.13885, 1409],
#  ['sks', 'random_normal', 90, 4, 20000, 'central', 0.10848, 0.13506, 834],
#  ['sks', 'random_normal', 90, 4, 20000, 'lower', 0.08863, 0.11765, 845],
#  ['sks', 'random_uniform', 90, 4, 20000, 'upper', 0.21094, 0.23804, 1257],
#  ['sks', 'random_uniform', 90, 4, 20000, 'central', 0.18597, 0.23153, 901],
#  ['sks', 'random_uniform', 90, 4, 20000, 'lower', 0.15194, 0.20168, 904],
#  ['swd', 'mean', 90, 4, 20000, 'upper', 0.05664, 0.07396, 453],
#  ['swd', 'mean', 90, 4, 20000, 'central', 0.03814, 0.06276, 301],
#  ['swd', 'mean', 90, 4, 20000, 'lower', 0.02059, 0.043, 332],
#  ['swd', 'cov_diag', 90, 4, 20000, 'upper', 0.06445, 0.08147, 443],
#  ['swd', 'cov_diag', 90, 4, 20000, 'central', 0.04455, 0.06532, 304],
#  ['swd', 'cov_diag', 90, 4, 20000, 'lower', 0.02551, 0.04915, 323],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.06055, 0.08458, 481],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'central', 0.04625, 0.0726, 307],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.02836, 0.05878, 284],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'upper', 0.06055, 0.07771, 465],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'central', 0.0425, 0.0535, 294],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'lower', 0.0209, 0.04026, 316],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06055, 0.07771, 455],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'central', 0.04493, 0.05927, 299],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'lower', 0.0213, 0.04622, 321],
#  ['swd', 'random_normal', 90, 4, 20000, 'upper', 0.16406, 0.19031, 357],
#  ['swd', 'random_normal', 90, 4, 20000, 'central', 0.13678, 0.17024, 230],
#  ['swd', 'random_normal', 90, 4, 20000, 'lower', 0.11172, 0.14829, 224],
#  ['swd', 'random_uniform', 90, 4, 20000, 'upper', 0.28906, 0.32861, 284],
#  ['swd', 'random_uniform', 90, 4, 20000, 'central', 0.23619, 0.29395, 228],
#  ['swd', 'random_uniform', 90, 4, 20000, 'lower', 0.19291, 0.25606, 229]]

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_3533038/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 9         ks        mean   90      4                20000
# 23       sks        mean   90      4                20000
# 30       swd        mean   90      4                20000
# 2        fgd        mean   90      4                20000
# 16       mmd        mean   90      4                20000
#
#    $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 9       $0.00983_{-0.0077}^{+0.0057}$      $0.01725_{-0.0051}^{+0.0038}$
# 23       $0.02647_{-0.011}^{+0.0076}$      $0.03781_{-0.0075}^{+0.0075}$
# 30        $0.03814_{-0.018}^{+0.019}$         $0.06276_{-0.02}^{+0.011}$
# 2         $0.07248_{-0.033}^{+0.022}$         $0.10622_{-0.021}^{+0.02}$
# 16          $0.22947_{-0.11}^{+0.16}$          $0.32659_{-0.11}^{+0.15}$
#
#     $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 9            2474  [0.00216, 0.00983, 0.01556]  [0.01212, 0.01725, 0.02106]
# 23          12563  [0.01532, 0.02647, 0.03406]  [0.03034, 0.03781, 0.04532]
# 30           1086  [0.02059, 0.03814, 0.05664]    [0.043, 0.06276, 0.07396]
# 2            7710  [0.03975, 0.07248, 0.09497]  [0.08519, 0.10622, 0.12579]
# 16           5969  [0.12215, 0.22947, 0.38566]  [0.21559, 0.32659, 0.47565]
#
#                   time
# 9      [870, 697, 907]
# 23  [5082, 3461, 4020]
# 30     [453, 301, 332]
# 2   [3185, 1995, 2530]
# 16  [2441, 1654, 1874]
#    Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 9         ks      $0.00983_{-0.0077}^{+0.0057}$
# 23       sks       $0.02647_{-0.011}^{+0.0076}$
# 30       swd        $0.03814_{-0.018}^{+0.019}$
# 2        fgd        $0.07248_{-0.033}^{+0.022}$
# 16       mmd          $0.22947_{-0.11}^{+0.16}$
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 9       $0.01725_{-0.0051}^{+0.0038}$           2474
# 23      $0.03781_{-0.0075}^{+0.0075}$          12563
# 30         $0.06276_{-0.02}^{+0.011}$           1086
# 2          $0.10622_{-0.021}^{+0.02}$           7710
# 16          $0.32659_{-0.11}^{+0.15}$           5969

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_3533038/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 7         ks    cov_diag   90      4                20000
# 21       sks    cov_diag   90      4                20000
# 28       swd    cov_diag   90      4                20000
# 0        fgd    cov_diag   90      4                20000
# 14       mmd    cov_diag   90      4                20000
#
#    $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7                  $0.02545_{-0.02}^{+0.014}$
# 21                $0.04033_{-0.014}^{+0.015}$
# 28                 $0.04455_{-0.019}^{+0.02}$
# 0                 $0.06284_{-0.027}^{+0.031}$
# 14                $0.11334_{-0.049}^{+0.066}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 7                 $0.03987_{-0.012}^{+0.015}$                   3585
# 21               $0.05582_{-0.0099}^{+0.013}$                  13050
# 28                $0.06532_{-0.016}^{+0.016}$                   1070
# 0                 $0.09005_{-0.022}^{+0.024}$                   8554
# 14                $0.15031_{-0.056}^{+0.067}$                   8873
#
#                           95%CL                        99%CL  \
# 7   [0.00535, 0.02545, 0.03992]  [0.02814, 0.03987, 0.05452]
# 21  [0.02605, 0.04033, 0.05493]  [0.04593, 0.05582, 0.06906]
# 28  [0.02551, 0.04455, 0.06445]  [0.04915, 0.06532, 0.08147]
# 0    [0.0358, 0.06284, 0.09378]  [0.06854, 0.09005, 0.11369]
# 14  [0.06416, 0.11334, 0.17969]  [0.09461, 0.15031, 0.21734]
#
#                   time
# 7   [1275, 1038, 1272]
# 21  [5153, 3767, 4130]
# 28     [443, 304, 323]
# 0   [3337, 2139, 3078]
# 14  [3476, 2189, 3208]
#    Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7         ks                 $0.02545_{-0.02}^{+0.014}$
# 21       sks                $0.04033_{-0.014}^{+0.015}$
# 28       swd                 $0.04455_{-0.019}^{+0.02}$
# 0        fgd                $0.06284_{-0.027}^{+0.031}$
# 14       mmd                $0.11334_{-0.049}^{+0.066}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 7                 $0.03987_{-0.012}^{+0.015}$                   3585
# 21               $0.05582_{-0.0099}^{+0.013}$                  13050
# 28                $0.06532_{-0.016}^{+0.016}$                   1070
# 0                 $0.09005_{-0.022}^{+0.024}$                   8554
# 14                $0.15031_{-0.056}^{+0.067}$                   8873

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_3533038/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 1        fgd  cov_off_diag   90      4                20000
# 22       sks  cov_off_diag   90      4                20000
# 8         ks  cov_off_diag   90      4                20000
# 29       swd  cov_off_diag   90      4                20000
# 15       mmd  cov_off_diag   90      4                20000
#
#    $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 1                     $0.02316_{-0.007}^{+0.0057}$
# 22                     $0.03578_{-0.014}^{+0.011}$
# 8                      $0.04069_{-0.027}^{+0.017}$
# 29                     $0.04625_{-0.018}^{+0.014}$
# 15                       $0.16131_{-0.05}^{+0.05}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 1                    $0.03515_{-0.0051}^{+0.0045}$
# 22                      $0.05309_{-0.01}^{+0.011}$
# 8                       $0.0569_{-0.011}^{+0.017}$
# 29                      $0.0726_{-0.014}^{+0.012}$
# 15                     $0.23825_{-0.055}^{+0.042}$
#
#     $t^{\Sigma_{i\neq j}}$ (s)                        95%CL  \
# 1                         7933  [0.01617, 0.02316, 0.02887]
# 22                       14670  [0.02151, 0.03578, 0.04724]
# 8                         4463  [0.01406, 0.04069, 0.05786]
# 29                        1072  [0.02836, 0.04625, 0.06055]
# 15                        7065  [0.11084, 0.16131, 0.21143]
#
#                           99%CL                time
# 1   [0.03007, 0.03515, 0.03966]  [3493, 2017, 2423]
# 22   [0.0431, 0.05309, 0.06382]  [5840, 4064, 4766]
# 8    [0.04636, 0.0569, 0.07362]  [1643, 1280, 1540]
# 29   [0.05878, 0.0726, 0.08458]     [481, 307, 284]
# 15  [0.18291, 0.23825, 0.27996]  [2932, 2312, 1821]
#    Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 1        fgd                    $0.02316_{-0.007}^{+0.0057}$
# 22       sks                     $0.03578_{-0.014}^{+0.011}$
# 8         ks                     $0.04069_{-0.027}^{+0.017}$
# 29       swd                     $0.04625_{-0.018}^{+0.014}$
# 15       mmd                       $0.16131_{-0.05}^{+0.05}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 1                    $0.03515_{-0.0051}^{+0.0045}$                        7933
# 22                      $0.05309_{-0.01}^{+0.011}$                       14670
# 8                       $0.0569_{-0.011}^{+0.017}$                        4463
# 29                      $0.0726_{-0.014}^{+0.012}$                        1072
# 15                     $0.23825_{-0.055}^{+0.042}$                        7065

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_3533038/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 11        ks  power_abs_up   90      4                20000
# 18       mmd  power_abs_up   90      4                20000
# 4        fgd  power_abs_up   90      4                20000
# 32       swd  power_abs_up   90      4                20000
# 25       sks  power_abs_up   90      4                20000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11                  $0.01613_{-0.013}^{+0.01}$
# 18                 $0.03206_{-0.014}^{+0.022}$
# 4                  $0.03599_{-0.016}^{+0.023}$
# 32                  $0.0425_{-0.022}^{+0.018}$
# 25                 $0.06093_{-0.026}^{+0.021}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 11                $0.02649_{-0.0086}^{+0.011}$                    5987
# 18                 $0.04228_{-0.016}^{+0.019}$                    9810
# 4                  $0.04934_{-0.014}^{+0.024}$                   12082
# 32                  $0.0535_{-0.013}^{+0.024}$                    1075
# 25                 $0.08302_{-0.021}^{+0.028}$                    2817
#
#                           95%CL                        99%CL  \
# 11  [0.00332, 0.01613, 0.02649]   [0.01785, 0.02649, 0.0377]
# 18  [0.01805, 0.03206, 0.05414]  [0.02662, 0.04228, 0.06147]
# 4   [0.01961, 0.03599, 0.05859]  [0.03581, 0.04934, 0.07327]
# 32    [0.0209, 0.0425, 0.06055]   [0.04026, 0.0535, 0.07771]
# 25  [0.03502, 0.06093, 0.08203]  [0.06202, 0.08302, 0.11142]
#
#                   time
# 11  [2225, 1668, 2094]
# 18  [2735, 1756, 5319]
# 4   [4420, 2684, 4978]
# 32     [465, 294, 316]
# 25    [1146, 815, 856]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11        ks                  $0.01613_{-0.013}^{+0.01}$
# 18       mmd                 $0.03206_{-0.014}^{+0.022}$
# 4        fgd                 $0.03599_{-0.016}^{+0.023}$
# 32       swd                  $0.0425_{-0.022}^{+0.018}$
# 25       sks                 $0.06093_{-0.026}^{+0.021}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 11                $0.02649_{-0.0086}^{+0.011}$                    5987
# 18                 $0.04228_{-0.016}^{+0.019}$                    9810
# 4                  $0.04934_{-0.014}^{+0.024}$                   12082
# 32                  $0.0535_{-0.013}^{+0.024}$                    1075
# 25                 $0.08302_{-0.021}^{+0.028}$                    2817

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_3533038/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 10        ks  power_abs_down   90      4                20000
# 17       mmd  power_abs_down   90      4                20000
# 3        fgd  power_abs_down   90      4                20000
# 31       swd  power_abs_down   90      4                20000
# 24       sks  power_abs_down   90      4                20000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10                $0.01641_{-0.013}^{+0.0098}$
# 17                  $0.0336_{-0.016}^{+0.029}$
# 3                  $0.03699_{-0.018}^{+0.028}$
# 31                 $0.04493_{-0.024}^{+0.016}$
# 24                 $0.05686_{-0.026}^{+0.025}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 10               $0.02571_{-0.0072}^{+0.0094}$                    7051
# 17                  $0.04991_{-0.02}^{+0.025}$                    8540
# 3                  $0.05511_{-0.017}^{+0.027}$                    9303
# 31                 $0.05927_{-0.013}^{+0.018}$                    1075
# 24                  $0.0802_{-0.026}^{+0.018}$                    3459
#
#                           95%CL                        99%CL  \
# 10  [0.00343, 0.01641, 0.02625]  [0.01848, 0.02571, 0.03515]
# 17   [0.01711, 0.0336, 0.06255]   [0.0303, 0.04991, 0.07513]
# 3   [0.01878, 0.03699, 0.06534]  [0.03787, 0.05511, 0.08171]
# 31   [0.0213, 0.04493, 0.06055]  [0.04622, 0.05927, 0.07771]
# 24  [0.03133, 0.05686, 0.08203]   [0.05424, 0.0802, 0.09836]
#
#                   time
# 10  [2699, 1988, 2364]
# 17  [3618, 2407, 2515]
# 3   [4175, 2697, 2431]
# 31     [455, 299, 321]
# 24   [1348, 972, 1139]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10        ks                $0.01641_{-0.013}^{+0.0098}$
# 17       mmd                  $0.0336_{-0.016}^{+0.029}$
# 3        fgd                 $0.03699_{-0.018}^{+0.028}$
# 31       swd                 $0.04493_{-0.024}^{+0.016}$
# 24       sks                 $0.05686_{-0.026}^{+0.025}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 10               $0.02571_{-0.0072}^{+0.0094}$                    7051
# 17                  $0.04991_{-0.02}^{+0.025}$                    8540
# 3                  $0.05511_{-0.017}^{+0.027}$                    9303
# 31                 $0.05927_{-0.013}^{+0.018}$                    1075
# 24                  $0.0802_{-0.026}^{+0.018}$                    3459

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_3533038/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 12        ks  random_normal   90      4                20000
# 26       sks  random_normal   90      4                20000
# 33       swd  random_normal   90      4                20000
# 5        fgd  random_normal   90      4                20000
# 19       mmd  random_normal   90      4                20000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 12                 $0.09133_{-0.026}^{+0.02}$
# 26                 $0.10848_{-0.02}^{+0.013}$
# 33                $0.13678_{-0.025}^{+0.027}$
# 5                  $0.18671_{-0.04}^{+0.034}$
# 19                 $0.40194_{-0.077}^{+0.15}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 12                $0.11404_{-0.025}^{+0.014}$                   6977
# 26               $0.13506_{-0.017}^{+0.0038}$                   3088
# 33                 $0.17024_{-0.022}^{+0.02}$                    811
# 5                 $0.22667_{-0.031}^{+0.027}$                   8116
# 19                 $0.50268_{-0.11}^{+0.089}$                  12363
#
#                           95%CL                        99%CL  \
# 12  [0.06526, 0.09133, 0.11182]  [0.08927, 0.11404, 0.12812]
# 26  [0.08863, 0.10848, 0.12109]  [0.11765, 0.13506, 0.13885]
# 33  [0.11172, 0.13678, 0.16406]  [0.14829, 0.17024, 0.19031]
# 5   [0.14676, 0.18671, 0.22046]  [0.19531, 0.22667, 0.25357]
# 19  [0.32453, 0.40194, 0.54736]  [0.38821, 0.50268, 0.59157]
#
#                   time
# 12  [2605, 2153, 2219]
# 26    [1409, 834, 845]
# 33     [357, 230, 224]
# 5   [2974, 2163, 2979]
# 19  [2782, 5573, 4008]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 12        ks                 $0.09133_{-0.026}^{+0.02}$
# 26       sks                 $0.10848_{-0.02}^{+0.013}$
# 33       swd                $0.13678_{-0.025}^{+0.027}$
# 5        fgd                 $0.18671_{-0.04}^{+0.034}$
# 19       mmd                 $0.40194_{-0.077}^{+0.15}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 12                $0.11404_{-0.025}^{+0.014}$                   6977
# 26               $0.13506_{-0.017}^{+0.0038}$                   3088
# 33                 $0.17024_{-0.022}^{+0.02}$                    811
# 5                 $0.22667_{-0.031}^{+0.027}$                   8116
# 19                 $0.50268_{-0.11}^{+0.089}$                  12363

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_3533038/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform   90      4                20000
# 13        ks  random_uniform   90      4                20000
# 20       mmd  random_uniform   90      4                20000
# 27       sks  random_uniform   90      4                20000
# 34       swd  random_uniform   90      4                20000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                 $0.32909_{-0.063}^{+0.062}$
# 13                 $0.1553_{-0.037}^{+0.033}$
# 20                   $0.68726_{-0.2}^{+0.24}$
# 27                $0.18597_{-0.034}^{+0.025}$
# 34                $0.23619_{-0.043}^{+0.053}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                  $0.39263_{-0.05}^{+0.055}$                   8657
# 13                $0.18609_{-0.035}^{+0.032}$                   7681
# 20                   $0.87417_{-0.2}^{+0.13}$                  15496
# 27                $0.23153_{-0.03}^{+0.0065}$                   3062
# 34                $0.29395_{-0.038}^{+0.035}$                    741
#
#                           95%CL                        99%CL  \
# 6   [0.26571, 0.32909, 0.39066]   [0.3428, 0.39263, 0.44782]
# 13   [0.11812, 0.1553, 0.18799]  [0.15157, 0.18609, 0.21785]
# 20  [0.48549, 0.68726, 0.92578]      [0.66939, 0.87417, 1.0]
# 27  [0.15194, 0.18597, 0.21094]  [0.20168, 0.23153, 0.23804]
# 34  [0.19291, 0.23619, 0.28906]  [0.25606, 0.29395, 0.32861]
#
#                   time
# 6   [3786, 2434, 2437]
# 13  [2787, 2386, 2508]
# 20  [6652, 3735, 5109]
# 27    [1257, 901, 904]
# 34     [284, 228, 229]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                $0.32909_{-0.063}^{+0.062}$
# 13        ks                 $0.1553_{-0.037}^{+0.033}$
# 20       mmd                   $0.68726_{-0.2}^{+0.24}$
# 27       sks                $0.18597_{-0.034}^{+0.025}$
# 34       swd                $0.23619_{-0.043}^{+0.053}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                  $0.39263_{-0.05}^{+0.055}$                   8657
# 13                $0.18609_{-0.035}^{+0.032}$                   7681
# 20                   $0.87417_{-0.2}^{+0.13}$                  15496
# 27                $0.23153_{-0.03}^{+0.0065}$                   3062
# 34                $0.29395_{-0.038}^{+0.035}$                    741
