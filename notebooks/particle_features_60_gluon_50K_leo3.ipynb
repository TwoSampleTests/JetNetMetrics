# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [3]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more.deformations import deformed_distribution, deform_mean, deform_cov_diag, deform_cov_off_diag, deform_power_abs, deform_random
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection_dataset # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-07-02 11:40:26.297336: Importing os...
# 2024-07-02 11:40:26.297620: Importing sys...
# Visible devices: [3]
# 2024-07-02 11:40:26.297879: Importing timer from timeit...
# 2024-07-02 11:40:26.297947: Setting env variables for tf import (only device(s) [3] will be available)...
# 2024-07-02 11:40:26.298080: Importing numpy...
# 2024-07-02 11:40:26.430977: Importing matplotlib...
# 2024-07-02 11:40:26.888611: Importing h5py...
# 2024-07-02 11:40:26.926773: Importing importlib.util...
# 2024-07-02 11:40:26.926895: Importing json...
# 2024-07-02 11:40:26.926960: Importing pandas...
# 2024-07-02 11:40:27.494380: Importing random...
# 2024-07-02 11:40:27.494532: Importing scipy utils...
# 2024-07-02 11:40:27.931528: Importing subprocess...
# 2024-07-02 11:40:27.931657: Importing textwrap...
# 2024-07-02 11:40:27.931719: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-07-02 11:40:32.424542: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-07-02 11:40:33.873830: Importing timeit...
# 2024-07-02 11:40:33.873940: Importing tqdm...
# 2024-07-02 11:40:33.885323: Importing typing...
# 2024-07-02 11:40:33.885453: Setting tf configs...
# 2024-07-02 11:40:33.960332: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-07-02 11:40:39.825195: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #3, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-07-02 11:40:39.855241: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 60,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 60, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 60, 4)

# %% [markdown]
# # Particle level

# %% [markdown]
# ## Init data

# %%
results_dir = "results_leo/particle_features_60/"
figures_dir = os.path.join(results_dir, "figures/")
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocess_data=(data-means)/stds
    return preprocess_data

def postprocess_data(data,means,stds):
    postprocess_data=data*stds+means
    return postprocess_data

def get_reduced_particle_features(particle_features):
    tmp = particle_features[:, :, :3]
    shape = tmp.shape
    particle_features_reshaped = tf.reshape(tmp, [-1, shape[1] * shape[2]])
    return particle_features_reshaped

particle_features_reduced = get_reduced_particle_features(particle_features)
particle_features_reduced.shape
# Out:
# TensorShape([177252, 180])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests/")
model_dir = os.path.join(tests_dir, '20K/')
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    
dataset = get_reduced_particle_features(particle_features)

# %% [markdown]
# ## 20K

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(model_dir, 'null_hypotheses/')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(model_dir, "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 20_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 20_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 4, nbootstrap: 250
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputsNull.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0      4            20000            1000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  is_symb_1  ndims_1  \
# 0     0    True            False     None     True      False      180
#
#    nsamples_1  is_symb_2  ndims_2  nsamples_2    dtype  ndims  nsamples  \
# 0       80000      False      180       80000  float64    180     80000
#
#    small_sample
# 0         False

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {"verbose": True}, 
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 360,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values())[3:]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng sks with max_vectorize = 800
#
# ===========================================================
# Testing from 0 to 4 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 8.160824928898364 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2195100060198456 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.916281386045739 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.916437198058702 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# WARNING:tensorflow:5 out of the last 5 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fde0c84e340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SKS metric calculation completed in 2.9338421400170773 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# WARNING:tensorflow:6 out of the last 6 calls to <function SKSTest.Test_tf.<locals>.batched_test at 0x7fde0cca53a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SKS metric calculation completed in 3.025182759971358 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4921636159997433 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.909733791020699 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.891840040916577 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.91263033694122 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.91734798590187 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.520819030003622 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.91900206299033 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9483718619449064 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9316704890225083 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.491013583028689 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9764672010205686 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9107657859567553 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.89591798488982 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9153304749634117 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.590962575050071 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.926690281019546 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9669507530052215 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.915110154892318 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.8845959480386227 seconds.
#
# ===========================================================
# Testing from 100 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.750740804011002 seconds.
#
# ===========================================================
# Testing from 104 to 108 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9582757169846445 seconds.
#
# ===========================================================
# Testing from 108 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0222214279929176 seconds.
#
# ===========================================================
# Testing from 112 to 116 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0106947059975937 seconds.
#
# ===========================================================
# Testing from 116 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.903792578028515 seconds.
#
# ===========================================================
# Testing from 120 to 124 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.627572327037342 seconds.
#
# ===========================================================
# Testing from 124 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0449659089790657 seconds.
#
# ===========================================================
# Testing from 128 to 132 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9616122919833288 seconds.
#
# ===========================================================
# Testing from 132 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.8823603549972177 seconds.
#
# ===========================================================
# Testing from 136 to 140 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.96562268701382 seconds.
#
# ===========================================================
# Testing from 140 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.82755907101091 seconds.
#
# ===========================================================
# Testing from 144 to 148 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.07948282698635 seconds.
#
# ===========================================================
# Testing from 148 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0463285780278966 seconds.
#
# ===========================================================
# Testing from 152 to 156 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9577426130417734 seconds.
#
# ===========================================================
# Testing from 156 to 160 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.751675474108197 seconds.
#
# ===========================================================
# Testing from 160 to 164 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0229402399854735 seconds.
#
# ===========================================================
# Testing from 164 to 168 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0213536319788545 seconds.
#
# ===========================================================
# Testing from 168 to 172 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9772816840559244 seconds.
#
# ===========================================================
# Testing from 172 to 176 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9950199259910733 seconds.
#
# ===========================================================
# Testing from 176 to 180 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.8084205279592425 seconds.
#
# ===========================================================
# Testing from 180 to 184 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.055447628023103 seconds.
#
# ===========================================================
# Testing from 184 to 188 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.008260854985565 seconds.
#
# ===========================================================
# Testing from 188 to 192 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9778423690004274 seconds.
#
# ===========================================================
# Testing from 192 to 196 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.972961866063997 seconds.
#
# ===========================================================
# Testing from 196 to 200 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.79281052807346 seconds.
#
# ===========================================================
# Testing from 200 to 204 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9944768249988556 seconds.
#
# ===========================================================
# Testing from 204 to 208 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0522881320212036 seconds.
#
# ===========================================================
# Testing from 208 to 212 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.967566261999309 seconds.
#
# ===========================================================
# Testing from 212 to 216 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.8846903170924634 seconds.
#
# ===========================================================
# Testing from 216 to 220 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.9645658310037106 seconds.
#
# ===========================================================
# Testing from 220 to 224 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0382077919784933 seconds.
#
# ===========================================================
# Testing from 224 to 228 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1023438069969416 seconds.
#
# ===========================================================
# Testing from 228 to 232 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.998010353068821 seconds.
#
# ===========================================================
# Testing from 232 to 236 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.98998788499739 seconds.
#
# ===========================================================
# Testing from 236 to 240 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.9373066420666873 seconds.
#
# ===========================================================
# Testing from 240 to 244 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0385184270562604 seconds.
#
# ===========================================================
# Testing from 244 to 248 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0313293309882283 seconds.
#
# ===========================================================
# Testing from 248 to 252 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0062373030232266 seconds.
#
# ===========================================================
# Testing from 252 to 256 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9791594080161303 seconds.
#
# ===========================================================
# Testing from 256 to 260 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.8571433569304645 seconds.
#
# ===========================================================
# Testing from 260 to 264 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.106791813042946 seconds.
#
# ===========================================================
# Testing from 264 to 268 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.06251836696174 seconds.
#
# ===========================================================
# Testing from 268 to 272 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0078341230982915 seconds.
#
# ===========================================================
# Testing from 272 to 276 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.038278240012005 seconds.
#
# ===========================================================
# Testing from 276 to 280 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9528934620320797 seconds.
#
# ===========================================================
# Testing from 280 to 284 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.934400872909464 seconds.
#
# ===========================================================
# Testing from 284 to 288 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.116929884068668 seconds.
#
# ===========================================================
# Testing from 288 to 292 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0332507039420307 seconds.
#
# ===========================================================
# Testing from 292 to 296 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.973492599907331 seconds.
#
# ===========================================================
# Testing from 296 to 300 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0084736989811063 seconds.
#
# ===========================================================
# Testing from 300 to 304 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.8779293490806594 seconds.
#
# ===========================================================
# Testing from 304 to 308 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1340383099159226 seconds.
#
# ===========================================================
# Testing from 308 to 312 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.064879855955951 seconds.
#
# ===========================================================
# Testing from 312 to 316 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.047508300980553 seconds.
#
# ===========================================================
# Testing from 316 to 320 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.999159269966185 seconds.
#
# ===========================================================
# Testing from 320 to 324 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.916265366016887 seconds.
#
# ===========================================================
# Testing from 324 to 328 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0264544129604474 seconds.
#
# ===========================================================
# Testing from 328 to 332 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0691767799435183 seconds.
#
# ===========================================================
# Testing from 332 to 336 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.011989308986813 seconds.
#
# ===========================================================
# Testing from 336 to 340 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9671211019158363 seconds.
#
# ===========================================================
# Testing from 340 to 344 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.010779556934722 seconds.
#
# ===========================================================
# Testing from 344 to 348 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.062588748987764 seconds.
#
# ===========================================================
# Testing from 348 to 352 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.987071998999454 seconds.
#
# ===========================================================
# Testing from 352 to 356 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0955308369593695 seconds.
#
# ===========================================================
# Testing from 356 to 360 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0297605640953407 seconds.
#
# ===========================================================
# Testing from 360 to 364 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.039805036969483 seconds.
#
# ===========================================================
# Testing from 364 to 368 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1028210879303515 seconds.
#
# ===========================================================
# Testing from 368 to 372 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0600212779827416 seconds.
#
# ===========================================================
# Testing from 372 to 376 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0943603839259595 seconds.
#
# ===========================================================
# Testing from 376 to 380 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.98861952801235 seconds.
#
# ===========================================================
# Testing from 380 to 384 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 2.9718246510019526 seconds.
#
# ===========================================================
# Testing from 384 to 388 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.095044680056162 seconds.
#
# ===========================================================
# Testing from 388 to 392 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.121763499104418 seconds.
#
# ===========================================================
# Testing from 392 to 396 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.03648384695407 seconds.
#
# ===========================================================
# Testing from 396 to 400 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.084758201963268 seconds.
#
# ===========================================================
# Testing from 400 to 404 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.014384686946869 seconds.
#
# ===========================================================
# Testing from 404 to 408 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.967217766912654 seconds.
#
# ===========================================================
# Testing from 408 to 412 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1547436940018088 seconds.
#
# ===========================================================
# Testing from 412 to 416 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0458295959979296 seconds.
#
# ===========================================================
# Testing from 416 to 420 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.061081451945938 seconds.
#
# ===========================================================
# Testing from 420 to 424 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0299448119476438 seconds.
#
# ===========================================================
# Testing from 424 to 428 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.016074264072813 seconds.
#
# ===========================================================
# Testing from 428 to 432 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.193452324019745 seconds.
#
# ===========================================================
# Testing from 432 to 436 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.159735850058496 seconds.
#
# ===========================================================
# Testing from 436 to 440 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.076400930993259 seconds.
#
# ===========================================================
# Testing from 440 to 444 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.221293409005739 seconds.
#
# ===========================================================
# Testing from 444 to 448 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2180539349792525 seconds.
#
# ===========================================================
# Testing from 448 to 452 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.253178227925673 seconds.
#
# ===========================================================
# Testing from 452 to 456 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.234772913972847 seconds.
#
# ===========================================================
# Testing from 456 to 460 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1889311539707705 seconds.
#
# ===========================================================
# Testing from 460 to 464 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2301177619956434 seconds.
#
# ===========================================================
# Testing from 464 to 468 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.266711088945158 seconds.
#
# ===========================================================
# Testing from 468 to 472 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.253590579028241 seconds.
#
# ===========================================================
# Testing from 472 to 476 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3903579460456967 seconds.
#
# ===========================================================
# Testing from 476 to 480 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2091946790460497 seconds.
#
# ===========================================================
# Testing from 480 to 484 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.028831899049692 seconds.
#
# ===========================================================
# Testing from 484 to 488 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3451678979909047 seconds.
#
# ===========================================================
# Testing from 488 to 492 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.295026266016066 seconds.
#
# ===========================================================
# Testing from 492 to 496 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.365255753044039 seconds.
#
# ===========================================================
# Testing from 496 to 500 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2377176249865443 seconds.
#
# ===========================================================
# Testing from 500 to 504 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.177519920980558 seconds.
#
# ===========================================================
# Testing from 504 to 508 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.299037505988963 seconds.
#
# ===========================================================
# Testing from 508 to 512 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2859636819921434 seconds.
#
# ===========================================================
# Testing from 512 to 516 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0045144739560783 seconds.
#
# ===========================================================
# Testing from 516 to 520 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.553384245024063 seconds.
#
# ===========================================================
# Testing from 520 to 524 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.267341393046081 seconds.
#
# ===========================================================
# Testing from 524 to 528 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.272869663895108 seconds.
#
# ===========================================================
# Testing from 528 to 532 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2678262409754097 seconds.
#
# ===========================================================
# Testing from 532 to 536 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.098226221045479 seconds.
#
# ===========================================================
# Testing from 536 to 540 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.36989824695047 seconds.
#
# ===========================================================
# Testing from 540 to 544 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3319902549264953 seconds.
#
# ===========================================================
# Testing from 544 to 548 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1584075409919024 seconds.
#
# ===========================================================
# Testing from 548 to 552 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.362196909962222 seconds.
#
# ===========================================================
# Testing from 552 to 556 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3212158050155267 seconds.
#
# ===========================================================
# Testing from 556 to 560 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.213798515032977 seconds.
#
# ===========================================================
# Testing from 560 to 564 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.462998318020254 seconds.
#
# ===========================================================
# Testing from 564 to 568 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1905510750366375 seconds.
#
# ===========================================================
# Testing from 568 to 572 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.344241042039357 seconds.
#
# ===========================================================
# Testing from 572 to 576 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3138318449491635 seconds.
#
# ===========================================================
# Testing from 576 to 580 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.18509077897761 seconds.
#
# ===========================================================
# Testing from 580 to 584 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2585704990196973 seconds.
#
# ===========================================================
# Testing from 584 to 588 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.422059793956578 seconds.
#
# ===========================================================
# Testing from 588 to 592 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3092436310835183 seconds.
#
# ===========================================================
# Testing from 592 to 596 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2846885069739074 seconds.
#
# ===========================================================
# Testing from 596 to 600 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.0716396720381454 seconds.
#
# ===========================================================
# Testing from 600 to 604 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.371695267036557 seconds.
#
# ===========================================================
# Testing from 604 to 608 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.289515206939541 seconds.
#
# ===========================================================
# Testing from 608 to 612 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.511641293996945 seconds.
#
# ===========================================================
# Testing from 612 to 616 of 1000 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# ...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1252053199568763 seconds.
#
# ===========================================================
# Testing from 792 to 796 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.172704799915664 seconds.
#
# ===========================================================
# Testing from 796 to 800 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1236250039655715 seconds.
#
# ===========================================================
# Testing from 800 to 804 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1398112629540265 seconds.
#
# ===========================================================
# Testing from 804 to 808 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1229352420195937 seconds.
#
# ===========================================================
# Testing from 808 to 812 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1136772880563512 seconds.
#
# ===========================================================
# Testing from 812 to 816 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.08836335898377 seconds.
#
# ===========================================================
# Testing from 816 to 820 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9927352559752762 seconds.
#
# ===========================================================
# Testing from 820 to 824 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1437365100719035 seconds.
#
# ===========================================================
# Testing from 824 to 828 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1187526530120522 seconds.
#
# ===========================================================
# Testing from 828 to 832 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.114010320045054 seconds.
#
# ===========================================================
# Testing from 832 to 836 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0958507279865444 seconds.
#
# ===========================================================
# Testing from 836 to 840 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 2.7556046709651127 seconds.
#
# ===========================================================
# Testing from 840 to 844 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1548264239681885 seconds.
#
# ===========================================================
# Testing from 844 to 848 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.2083276329794899 seconds.
#
# ===========================================================
# Testing from 848 to 852 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.2059971250128 seconds.
#
# ===========================================================
# Testing from 852 to 856 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1279681320302188 seconds.
#
# ===========================================================
# Testing from 856 to 860 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.125753683038056 seconds.
#
# ===========================================================
# Testing from 860 to 864 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1169886549469084 seconds.
#
# ===========================================================
# Testing from 864 to 868 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1511375280097127 seconds.
#
# ===========================================================
# Testing from 868 to 872 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1144599679391831 seconds.
#
# ===========================================================
# Testing from 872 to 876 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0217535929987207 seconds.
#
# ===========================================================
# Testing from 876 to 880 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1121813619975 seconds.
#
# ===========================================================
# Testing from 880 to 884 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1588539719814435 seconds.
#
# ===========================================================
# Testing from 884 to 888 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1313665049383417 seconds.
#
# ===========================================================
# Testing from 888 to 892 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1273697450524196 seconds.
#
# ===========================================================
# Testing from 892 to 896 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.092248504050076 seconds.
#
# ===========================================================
# Testing from 896 to 900 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1284463480114937 seconds.
#
# ===========================================================
# Testing from 900 to 904 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.098469045944512 seconds.
#
# ===========================================================
# Testing from 904 to 908 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9946407999377698 seconds.
#
# ===========================================================
# Testing from 908 to 912 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1051129230763763 seconds.
#
# ===========================================================
# Testing from 912 to 916 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 2.713882612064481 seconds.
#
# ===========================================================
# Testing from 916 to 920 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.2382291599642485 seconds.
#
# ===========================================================
# Testing from 920 to 924 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1650804730597883 seconds.
#
# ===========================================================
# Testing from 924 to 928 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.157050673966296 seconds.
#
# ===========================================================
# Testing from 928 to 932 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0323102020192891 seconds.
#
# ===========================================================
# Testing from 932 to 936 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1434692170005292 seconds.
#
# ===========================================================
# Testing from 936 to 940 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1564549090107903 seconds.
#
# ===========================================================
# Testing from 940 to 944 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1234072420047596 seconds.
#
# ===========================================================
# Testing from 944 to 948 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1407238809624687 seconds.
#
# ===========================================================
# Testing from 948 to 952 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1361824230989441 seconds.
#
# ===========================================================
# Testing from 952 to 956 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1294220590498298 seconds.
#
# ===========================================================
# Testing from 956 to 960 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.105329185957089 seconds.
#
# ===========================================================
# Testing from 960 to 964 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0020371800055727 seconds.
#
# ===========================================================
# Testing from 964 to 968 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.135805896949023 seconds.
#
# ===========================================================
# Testing from 968 to 972 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1319455589400604 seconds.
#
# ===========================================================
# Testing from 972 to 976 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1043041690718383 seconds.
#
# ===========================================================
# Testing from 976 to 980 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.109795773983933 seconds.
#
# ===========================================================
# Testing from 980 to 984 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1282409810228273 seconds.
#
# ===========================================================
# Testing from 984 to 988 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1896353700431064 seconds.
#
# ===========================================================
# Testing from 988 to 992 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 2.367550689028576 seconds.
#
# ===========================================================
# Testing from 992 to 996 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.2958839270286262 seconds.
#
# ===========================================================
# Testing from 996 to 1000 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.2355407100403681 seconds.
# All done in: 1221.18 s.
# Saving swd to results_leo/particle_features_60/tests/20K/null_hypotheses/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []
ndims = 450

for metric in list(metrics_config[unique_key].values())[3:]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    print(len(dist_null))

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# 1000
# ThresholdS for metric sks: [[0.68, [680, 319], 0.892350822687149], [0.95, [950, 50], 1.1198506690561771], [0.99, [990, 10], 1.324150525033474]]
# Computing time for metric sks: 849.1136882300489
# 1000
# ThresholdS for metric swd: [[0.68, [680, 319], 0.6111837879009955], [0.95, [950, 50], 0.8637532523924473], [0.99, [990, 10], 1.076009274642323]]
# Computing time for metric swd: 304.5339633305557
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fdffc934860>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fdffc937600>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fdffc9376a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fdffc934ea0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fdffc936340>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 4, 'batch_size_test': 20000, 'batch_...              8
# 1  {'niter': 4, 'batch_size_test': 20000, 'batch_...              2
# 2  {'niter': 4, 'batch_size_test': 20000, 'batch_...            360
# 3  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
# 4  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/20K/nul...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/20K/nul...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/20K/nul...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/20K/nul...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/20K/nul...
#
#                                           thresholds
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[0.68, [680, 319], 0.892350822687149], [0.95,...
# 4  [[0.68, [680, 319], 0.6111837879009955], [0.95...

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[3:]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Frequency', fontsize=16)
    ax[0].set_title('PDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.8602155718021095 +/- 0.0005491453456555775
# sigma = 0.13177822501278713 +/- 0.004394669982485195
# 68%CL = 0.892350822687149, 95%CL = 1.1198506690561771, 99%CL = 1.324150525033474
# mu = 0.8602155718021095 +/- 0.0005491453456555775
# sigma = 0.13177822501278713 +/- 0.004394669982485195
# /tmp/ipykernel_417600/3538746891.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_417600/3538746891.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_417600/3538746891.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_417600/3538746891.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.6591428390238434 seconds.
# mu = 0.5908799397814728 +/- 0.0006572189452818093
# sigma = 0.1441634068862168 +/- 0.005900331644372758
# 68%CL = 0.6111837879009955, 95%CL = 0.8637532523924473, 99%CL = 1.076009274642323
# mu = 0.5908799397814728 +/- 0.0006572189452818093
# sigma = 0.1441634068862168 +/- 0.005900331644372758
# /tmp/ipykernel_417600/3538746891.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_417600/3538746891.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_417600/3538746891.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_417600/3538746891.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9652976470533758 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fdffc934860>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fdffc937600>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fdffc9376a0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fdffc934ea0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fdffc936340>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 4, 'batch_size_test': 20000, 'batch_...              8
# 1  {'niter': 4, 'batch_size_test': 20000, 'batch_...              2
# 2  {'niter': 4, 'batch_size_test': 20000, 'batch_...            360
# 3  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
# 4  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/20K/nul...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/20K/nul...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/20K/nul...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/20K/nul...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/20K/nul...
#
#                                           thresholds  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[0.68, [680, 319], 0.892350822687149], [0.95,...
# 4  [[0.68, [680, 319], 0.6111837879009955], [0.95...
#
#                                          null_figure
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  results_leo/particle_features_60/tests/20K/nul...
# 4  results_leo/particle_features_60/tests/20K/nul...

# %% [markdown]
# ### Alternative hypothesis

# %% [markdown]
# #### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100, # this will be adapted to the boostrap size
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}

# %%
file_path = os.path.join(model_dir, "exclusion_limits.json")
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}
    
# Sort the dictionary by keys
existing_data = dict(sorted(existing_data.items()))

# Save the sorted dictionary back to a JSON file
with open(file_path, 'w') as f:
    json.dump(existing_data, f, cls=GMetrics.utils.CustomEncoder, indent=4) # type: ignore

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[3:]:
    for deformation in deformations:
        eps_max = 2.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection_dataset(dataset = dataset,
                                                             metric_config = metric_config,
                                                             test_kwargs = test_kwargs,
                                                             model_dir = model_dir,
                                                             deformation = deformation,
                                                             seed_dist = 0,
                                                             x_tol = 0.1,
                                                             fn_tol = 0.15,
                                                             bound = bound,
                                                             eps_min = 0.,
                                                             eps_max = eps_max,
                                                             smear = 0.,
                                                             max_iterations = 50,
                                                             save = True,
                                                             filename = "exclusion_limits.json",
                                                             verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Computing upper bounds for sks with mean deformation.
#
# ======================================================
# =============== sks - mean ===============
# ======================================================
# niter: 4, nbootstrap: 25
#
# ------------ 1 - 0.95 CL -  upper bound -----------
# eps = 1.0 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.396221742965281 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.734079353045672 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.603515376918949 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.0161861759843305 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.782486504991539 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.65166919096373 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5787978400476277 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2057016959879547 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.292709660017863 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1879029750125483 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.20069078495726 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7004041658947244 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4469546349719167 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5747993969125673 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.515845916001126 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.267590348026715 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2096265030559152 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.957817791029811 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7059740510303527 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6371562010608613 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.491229285951704 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4127683381084353 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.1838984119240195 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2691724359756336 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.189645884092897 seconds.
# statistic = 22.560102322312606 - next threshold = 1.1198506690561771 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8108356601105826
#
# ------------ 2 - 0.95 CL -  upper bound -----------
# eps = 0.5 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.1586754189338535 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6170843900181353 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3642044010339305 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.57953379501123 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4056616079760715 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.28564389096573 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2421861219918355 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.434222249081358 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6788636000128463 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.451021510991268 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.486448395997286 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.364694530959241 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.221000468940474 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.270032134023495 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.272292320034467 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.778162950067781 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.692518600029871 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.525836538989097 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3599764119135216 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2955553710926324 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.211619155947119 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.336188317975029 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.654957852093503 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.624070022953674 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3028883839724585 seconds.
# statistic = 12.035806671566975 - next threshold = 1.1198506690561771 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6595074985426361
#
# ------------ 3 - 0.95 CL -  upper bound -----------
# eps = 0.25 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4021000060020015 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.304601041949354 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.259552313014865 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.435324704973027 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7760853950167075 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6623838640516624 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.408589383936487 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4049745809752494 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.334828062914312 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.198330895975232 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3090056420769542 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.326946677058004 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7198752920376137 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6566448860103264 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.493203262099996 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3777421409031376 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.308846976957284 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2218864670721814 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.367780642933212 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6959112039767206 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6426531090401113 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3115625419886783 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4345102220540866 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.318800364038907 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.281409154064022 seconds.
# statistic = 6.228598358227713 - next threshold = 1.1198506690561771 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.390428829322591
#
# ------------ 4 - 0.95 CL -  upper bound -----------
# eps = 0.125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.50391803891398 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7691665379097685 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6313247609650716 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4388356010895222 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5133930100128055 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3514796529198065 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.174406439997256 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.311433592927642 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.365684699965641 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.8049099990166724 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.691830691997893 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5882943579927087 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.431461567990482 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.334244119003415 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.314768327982165 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.263713952037506 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.466389945941046 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7497562509961426 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.539219561032951 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4967372548999265 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4383543439907953 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.353204594925046 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2750026260036975 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.5378186190500855 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.8042976130964234 seconds.
# statistic = 3.26085727831435 - next threshold = 1.1198506690561771 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.9774705983507935
#
# ------------ 5 - 0.95 CL -  upper bound -----------
# eps = 0.0625 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.406471122056246 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5867731811013073 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4396174090215936 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.334898093016818 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.2784290378913283 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.25233822199516 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.647428784985095 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7682748249499127 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6318201809190214 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6288673050003126 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3869010460330173 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4166486680042 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.338237213087268 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.248263482004404 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.66891025507357 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.75454960600473 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.684634563047439 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.399214544915594 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5055682830279693 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.38429563108366 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.35017271398101 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.28159627399873 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.708617207012139 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.8218985199928284 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.527151533984579 seconds.
# statistic = 1.826475550271076 - next threshold = 1.1198506690561771 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.4796650666715687
#
# ------------ 6 - 0.95 CL -  upper bound -----------
# eps = 0.03125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6377209440106526 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4749603120144457 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.332830599974841 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.318069839035161 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.265572992968373 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.645841759978794 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7825758409453556 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.594941374962218 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5480931990314275 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.3250921930884942 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5680954720592126 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.583733416046016 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.445081489975564 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.7669471899280325 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.8111381001072004 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.7065017499262467 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4352879079524428 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.528323400998488 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.547573736985214 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.4798147319816053 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.5813256569672376 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.765706034959294 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.8777066490147263 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.511678038048558 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 3.6718866019509733 seconds.
# ...
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.39988620497752 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.386659890995361 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.399471138021909 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 12.334049425902776 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.687983134062961 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.184897187980823 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.784207368036732 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.964934397954494 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.713958936976269 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.9063725839369 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.7081749479984865 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.864949778071605 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.526659953058697 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.83785974199418 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.707895574043505 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.7383790370076895 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.7770976721076295 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.72602130996529 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.733156709000468 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.714679453056306 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.654613891034387 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.720905002905056 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.561640101950616 seconds.
# statistic = 1.2899812478573902 - next threshold = 1.324150525033474 at 0.99 CL
# relative_error_eps = 0.35944700460829493
# relative_error_metric = 0.026141969988220843
#
# ------------ 3 - 0.99 CL -  lower bound -----------
# eps = 0.051402217453869525 - deformation = cov_diag
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.609415614046156 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.567234843969345 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.644958639983088 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 12.499597372021526 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.64406001905445 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.12829793500714 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.159693954978138 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 5.086084729060531 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.968467039987445 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.971287521999329 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.6969601289602 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.847677364945412 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.595494198962115 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.815806893981062 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.501596692018211 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.783363503986038 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.6082035740837455 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.825572135974653 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.640256935963407 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.723347551072948 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.6544756109360605 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.721442801994272 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.58025042898953 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.7059686339925975 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.500926390988752 seconds.
# statistic = 1.3657351621363267 - next threshold = 1.324150525033474 at 0.99 CL
# relative_error_eps = 0.19746835443037974
# relative_error_metric = 0.030919259730034548
#
# ------------ 4 - 0.99 CL -  lower bound -----------
# eps = 0.04678312418036512 - deformation = cov_diag
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000
# SKS metric calculation completed in 4.634420647984371 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 4
# batch_size = 20000

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_366541/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#   Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 2       sks        mean  450      8                10000
# 9       swd        mean  450      8                10000
#
#   $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 2      $0.01907_{-0.0061}^{+0.0053}$      $0.02864_{-0.0029}^{+0.0043}$
# 9      $0.02298_{-0.0092}^{+0.0073}$      $0.03031_{-0.0052}^{+0.0094}$
#
#    $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 2           2334  [0.01298, 0.01907, 0.02441]   [0.0257, 0.02864, 0.03299]
# 9            894  [0.01374, 0.02298, 0.03027]  [0.02513, 0.03031, 0.03974]
#
#                time
# 2  [1166, 586, 582]
# 9   [438, 237, 219]
#   Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 2       sks      $0.01907_{-0.0061}^{+0.0053}$
# 9       swd      $0.02298_{-0.0092}^{+0.0073}$
#
#   $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 2      $0.02864_{-0.0029}^{+0.0043}$           2334
# 9      $0.03031_{-0.0052}^{+0.0094}$            894

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_366541/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#   Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 7       swd    cov_diag  450      8                10000
# 0       sks    cov_diag  450      8                10000
#
#   $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7                $0.04013_{-0.017}^{+0.017}$
# 0                 $0.0436_{-0.014}^{+0.021}$
#
#   $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 7                $0.05138_{-0.016}^{+0.014}$                    884
# 0                  $0.06547_{-0.02}^{+0.01}$                   2300
#
#                          95%CL                        99%CL              time
# 7  [0.02328, 0.04013, 0.05664]  [0.03558, 0.05138, 0.06585]   [429, 220, 235]
# 0   [0.02967, 0.0436, 0.06445]  [0.04533, 0.06547, 0.07542]  [1064, 615, 621]
#   Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7       swd                $0.04013_{-0.017}^{+0.017}$
# 0       sks                 $0.0436_{-0.014}^{+0.021}$
#
#   $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 7                $0.05138_{-0.016}^{+0.014}$                    884
# 0                  $0.06547_{-0.02}^{+0.01}$                   2300

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_366541/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#   Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 8       swd  cov_off_diag  450      8                10000
# 1       sks  cov_off_diag  450      8                10000
#
#   $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 8                     $0.02913_{-0.012}^{+0.012}$
# 1                     $0.03352_{-0.011}^{+0.011}$
#
#   $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)  \
# 8                    $0.03843_{-0.0066}^{+0.012}$                         914
# 1                   $0.05034_{-0.0086}^{+0.0076}$                        2563
#
#                          95%CL                        99%CL              time
# 8  [0.01741, 0.02913, 0.04102]  [0.03186, 0.03843, 0.05038]   [435, 249, 230]
# 1  [0.02281, 0.03352, 0.04492]  [0.04173, 0.05034, 0.05798]  [1240, 658, 665]
#   Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 8       swd                     $0.02913_{-0.012}^{+0.012}$
# 1       sks                     $0.03352_{-0.011}^{+0.011}$
#
#   $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 8                    $0.03843_{-0.0066}^{+0.012}$                         914
# 1                   $0.05034_{-0.0086}^{+0.0076}$                        2563

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_366541/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 11       swd  power_abs_up  450      8                10000
# 4        sks  power_abs_up  450      8                10000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11                 $0.03145_{-0.013}^{+0.017}$
# 4                  $0.04783_{-0.015}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 11                 $0.04149_{-0.013}^{+0.013}$                     874
# 4                  $0.07182_{-0.022}^{+0.011}$                    2513
#
#                           95%CL                        99%CL              time
# 11   [0.0188, 0.03145, 0.04883]   [0.02873, 0.04149, 0.0544]   [426, 218, 230]
# 4   [0.03254, 0.04783, 0.06445]  [0.04973, 0.07182, 0.08273]  [1167, 669, 677]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11       swd                 $0.03145_{-0.013}^{+0.017}$
# 4        sks                 $0.04783_{-0.015}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 11                 $0.04149_{-0.013}^{+0.013}$                     874
# 4                  $0.07182_{-0.022}^{+0.011}$                    2513

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_366541/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 10       swd  power_abs_down  450      8                10000
# 3        sks  power_abs_down  450      8                10000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10                 $0.03807_{-0.017}^{+0.019}$
# 3                  $0.04783_{-0.017}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 10                 $0.04675_{-0.014}^{+0.019}$                     863
# 3                  $0.06746_{-0.012}^{+0.015}$                    2641
#
#                           95%CL                        99%CL              time
# 10  [0.02119, 0.03807, 0.05664]  [0.03237, 0.04675, 0.06585]   [416, 230, 217]
# 3   [0.03057, 0.04783, 0.06445]  [0.05593, 0.06746, 0.08273]  [1225, 704, 712]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10       swd                 $0.03807_{-0.017}^{+0.019}$
# 3        sks                 $0.04783_{-0.017}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 10                 $0.04675_{-0.014}^{+0.019}$                     863
# 3                  $0.06746_{-0.012}^{+0.015}$                    2641

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_366541/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        sks  random_normal  450      8                10000
# 12       swd  random_normal  450      8                10000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                   $0.132_{-0.014}^{+0.032}$
# 12                 $0.14348_{-0.03}^{+0.021}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 5                 $0.16428_{-0.029}^{+0.019}$                   2195
# 12                $0.15855_{-0.017}^{+0.025}$                    676
#
#                           95%CL                        99%CL              time
# 5     [0.11808, 0.132, 0.16406]  [0.13541, 0.16428, 0.18365]  [1041, 567, 587]
# 12  [0.11395, 0.14348, 0.16406]  [0.14182, 0.15855, 0.18365]   [325, 174, 177]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        sks                  $0.132_{-0.014}^{+0.032}$
# 12       swd                 $0.14348_{-0.03}^{+0.021}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                 $0.16428_{-0.029}^{+0.019}$                   2195
# 12                $0.15855_{-0.017}^{+0.025}$                    676

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_366541/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        sks  random_uniform  450      8                10000
# 13       swd  random_uniform  450      8                10000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                 $0.22101_{-0.023}^{+0.052}$
# 13                $0.25187_{-0.052}^{+0.037}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                 $0.27506_{-0.048}^{+0.032}$                   2180
# 13                $0.27831_{-0.049}^{+0.044}$                    661
#
#                           95%CL                        99%CL             time
# 6    [0.1977, 0.22101, 0.27344]   [0.22671, 0.27506, 0.3075]  [989, 595, 596]
# 13  [0.20004, 0.25187, 0.28906]  [0.22939, 0.27831, 0.32239]  [300, 175, 186]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        sks                $0.22101_{-0.023}^{+0.052}$
# 13       swd                $0.25187_{-0.052}^{+0.037}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                 $0.27506_{-0.048}^{+0.032}$                   2180
# 13                $0.27831_{-0.049}^{+0.044}$                    661
