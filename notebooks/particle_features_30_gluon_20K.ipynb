# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics

# %%
visible_devices = [0]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more import deformations
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection, compute_exclusion_LR_bisection # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-06-15 13:00:51.515854: Importing os...
# 2024-06-15 13:00:51.516008: Importing sys...
# Visible devices: [0]
# 2024-06-15 13:00:51.516261: Importing timer from timeit...
# 2024-06-15 13:00:51.516332: Setting env variables for tf import (only device(s) [0] will be available)...
# 2024-06-15 13:00:51.516464: Importing numpy...
# 2024-06-15 13:00:51.869636: Importing matplotlib...
# 2024-06-15 13:00:52.421521: Importing h5py...
# 2024-06-15 13:00:52.680867: Importing importlib.util...
# 2024-06-15 13:00:52.681031: Importing json...
# 2024-06-15 13:00:52.681099: Importing pandas...
# 2024-06-15 13:00:53.795938: Importing random...
# 2024-06-15 13:00:53.796101: Importing scipy utils...
# 2024-06-15 13:00:54.804687: Importing subprocess...
# 2024-06-15 13:00:54.804856: Importing textwrap...
# 2024-06-15 13:00:54.804931: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-06-15 13:01:04.697250: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-06-15 13:01:06.281177: Importing timeit...
# 2024-06-15 13:01:06.281276: Importing tqdm...
# 2024-06-15 13:01:06.293479: Importing typing...
# 2024-06-15 13:01:06.293614: Setting tf configs...
# 2024-06-15 13:01:07.468486: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-06-15 13:01:16.751813: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #0, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-06-15 13:01:16.769543: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 30,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 30, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 30, 4)

# %% [markdown]
# # Particle level

# %% [markdown]
# ## Init data

# %%
results_dir = "results_leo/particle_features/"
figures_dir = results_dir + "figures/"
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocess_data=(data-means)/stds
    return preprocess_data

def postprocess_data(data,means,stds):
    postprocess_data=data*stds+means
    return postprocess_data

def get_reduced_particle_features(particle_features):
    tmp = particle_features[:, :, :3]
    shape = tmp.shape
    particle_features_reshaped = tf.reshape(tmp, [-1, shape[1] * shape[2]])
    return particle_features_reshaped

particle_features_reduced = get_reduced_particle_features(particle_features)
particle_features_reduced.shape
# Out:
# TensorShape([177252, 90])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests")
if not os.path.exists(tests_dir):
    os.makedirs(tests_dir)
    
dataset = get_reduced_particle_features(particle_features)

# %% [markdown]
# ## 20K

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(tests_dir, '20K', 'null_hypotheses')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(tests_dir, '20K', "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 20_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 20_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 4, nbootstrap: 250
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "max_vectorize": 360, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False},
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "max_vectorize": 360, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {},
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "max_vectorize": 720,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "max_vectorize": 400,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0},
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "max_vectorize": 400,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values()):
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng fgd with max_vectorize = 360
#
# ===========================================================
# Testing from 0 to 4 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 9.343117462936789 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.725571987219155 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.745821163058281 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.729580673389137 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# WARNING:tensorflow:5 out of the last 5 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f659302f100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# FGD metric calculation completed in 5.763507877010852 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# WARNING:tensorflow:6 out of the last 6 calls to <function FGDMetric.Test_tf.<locals>.batched_test_sub at 0x7f642d2bf1a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# FGD metric calculation completed in 5.754798896610737 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.713044472038746 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.192847655154765 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.722619270905852 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.757650183048099 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.766273953020573 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.728592148981988 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7497713207267225 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.726210821885616 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.761006338056177 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.736011005006731 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.2740801139734685 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.742885590065271 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.744444765150547 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.726999009028077 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.753101330716163 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7221664492972195 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.747650817967951 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.739471988286823 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.721699759364128 seconds.
#
# ===========================================================
# Testing from 100 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.730803888756782 seconds.
#
# ===========================================================
# Testing from 104 to 108 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.3321005161851645 seconds.
#
# ===========================================================
# Testing from 108 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.785196053329855 seconds.
#
# ===========================================================
# Testing from 112 to 116 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.708257558289915 seconds.
#
# ===========================================================
# Testing from 116 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.768797911237925 seconds.
#
# ===========================================================
# Testing from 120 to 124 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.729192595928907 seconds.
#
# ===========================================================
# Testing from 124 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.770725084003061 seconds.
#
# ===========================================================
# Testing from 128 to 132 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.751403380185366 seconds.
#
# ===========================================================
# Testing from 132 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.742747035808861 seconds.
#
# ===========================================================
# Testing from 136 to 140 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.759741861838847 seconds.
#
# ===========================================================
# Testing from 140 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.323964173905551 seconds.
#
# ===========================================================
# Testing from 144 to 148 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.77261383831501 seconds.
#
# ===========================================================
# Testing from 148 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.779307761695236 seconds.
#
# ===========================================================
# Testing from 152 to 156 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7285222271457314 seconds.
#
# ===========================================================
# Testing from 156 to 160 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.740830629132688 seconds.
#
# ===========================================================
# Testing from 160 to 164 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7553626373410225 seconds.
#
# ===========================================================
# Testing from 164 to 168 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.75341028207913 seconds.
#
# ===========================================================
# Testing from 168 to 172 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.746375608257949 seconds.
#
# ===========================================================
# Testing from 172 to 176 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.735059018712491 seconds.
#
# ===========================================================
# Testing from 176 to 180 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.744752025231719 seconds.
#
# ===========================================================
# Testing from 180 to 184 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.360829882323742 seconds.
#
# ===========================================================
# Testing from 184 to 188 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7586428839713335 seconds.
#
# ===========================================================
# Testing from 188 to 192 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.75339172128588 seconds.
#
# ===========================================================
# Testing from 192 to 196 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7508629080839455 seconds.
#
# ===========================================================
# Testing from 196 to 200 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.756177046801895 seconds.
#
# ===========================================================
# Testing from 200 to 204 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.728762601036578 seconds.
#
# ===========================================================
# Testing from 204 to 208 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.731297406367958 seconds.
#
# ===========================================================
# Testing from 208 to 212 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.751602895092219 seconds.
#
# ===========================================================
# Testing from 212 to 216 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.767438629176468 seconds.
#
# ===========================================================
# Testing from 216 to 220 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.338278497103602 seconds.
#
# ===========================================================
# Testing from 220 to 224 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.950335227884352 seconds.
#
# ===========================================================
# Testing from 224 to 228 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.826329743955284 seconds.
#
# ===========================================================
# Testing from 228 to 232 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.746751009020954 seconds.
#
# ===========================================================
# Testing from 232 to 236 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.745695060119033 seconds.
#
# ===========================================================
# Testing from 236 to 240 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.74354829126969 seconds.
#
# ===========================================================
# Testing from 240 to 244 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.730132639873773 seconds.
#
# ===========================================================
# Testing from 244 to 248 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.763899565674365 seconds.
#
# ===========================================================
# Testing from 248 to 252 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.730702652595937 seconds.
#
# ===========================================================
# Testing from 252 to 256 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.3807012951001525 seconds.
#
# ===========================================================
# Testing from 256 to 260 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.780066464096308 seconds.
#
# ===========================================================
# Testing from 260 to 264 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.759251952636987 seconds.
#
# ===========================================================
# Testing from 264 to 268 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.753858674317598 seconds.
#
# ===========================================================
# Testing from 268 to 272 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.749401175882667 seconds.
#
# ===========================================================
# Testing from 272 to 276 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.773060971871018 seconds.
#
# ===========================================================
# Testing from 276 to 280 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.751069208607078 seconds.
#
# ===========================================================
# Testing from 280 to 284 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7704310291446745 seconds.
#
# ===========================================================
# Testing from 284 to 288 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.746362010017037 seconds.
#
# ===========================================================
# Testing from 288 to 292 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.766353283077478 seconds.
#
# ===========================================================
# Testing from 292 to 296 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.393513978924602 seconds.
#
# ===========================================================
# Testing from 296 to 300 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.768876776099205 seconds.
#
# ===========================================================
# Testing from 300 to 304 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.890806850045919 seconds.
#
# ===========================================================
# Testing from 304 to 308 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.956452808342874 seconds.
#
# ===========================================================
# Testing from 308 to 312 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.915016940329224 seconds.
#
# ===========================================================
# Testing from 312 to 316 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.791293988004327 seconds.
#
# ===========================================================
# Testing from 316 to 320 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.760083883069456 seconds.
#
# ===========================================================
# Testing from 320 to 324 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.760444507934153 seconds.
#
# ===========================================================
# Testing from 324 to 328 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.749618540983647 seconds.
#
# ===========================================================
# Testing from 328 to 332 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.420934623107314 seconds.
#
# ===========================================================
# Testing from 332 to 336 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.801060184836388 seconds.
#
# ===========================================================
# Testing from 336 to 340 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.764527626801282 seconds.
#
# ===========================================================
# Testing from 340 to 344 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.778682126197964 seconds.
#
# ===========================================================
# Testing from 344 to 348 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.777427073102444 seconds.
#
# ===========================================================
# Testing from 348 to 352 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.763397796079516 seconds.
#
# ===========================================================
# Testing from 352 to 356 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.777033844962716 seconds.
#
# ===========================================================
# Testing from 356 to 360 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.746861350722611 seconds.
#
# ===========================================================
# Testing from 360 to 364 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.743909643962979 seconds.
#
# ===========================================================
# Testing from 364 to 368 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.747658018022776 seconds.
#
# ===========================================================
# Testing from 368 to 372 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.39015653077513 seconds.
#
# ===========================================================
# Testing from 372 to 376 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.764825398568064 seconds.
#
# ===========================================================
# Testing from 376 to 380 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.757024483755231 seconds.
#
# ===========================================================
# Testing from 380 to 384 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.762745387386531 seconds.
#
# ===========================================================
# Testing from 384 to 388 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.756087005138397 seconds.
#
# ===========================================================
# Testing from 388 to 392 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.734273824375123 seconds.
#
# ===========================================================
# Testing from 392 to 396 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7424197611398995 seconds.
#
# ===========================================================
# Testing from 396 to 400 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.728226359002292 seconds.
#
# ===========================================================
# Testing from 400 to 404 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.744603483937681 seconds.
#
# ===========================================================
# Testing from 404 to 408 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.411980990786105 seconds.
#
# ===========================================================
# Testing from 408 to 412 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.782087677158415 seconds.
#
# ===========================================================
# Testing from 412 to 416 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.740172062069178 seconds.
#
# ===========================================================
# Testing from 416 to 420 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.749181624967605 seconds.
#
# ===========================================================
# Testing from 420 to 424 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.730015262961388 seconds.
#
# ===========================================================
# Testing from 424 to 428 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7548533282242715 seconds.
#
# ===========================================================
# Testing from 428 to 432 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.754999812692404 seconds.
#
# ===========================================================
# Testing from 432 to 436 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.729434673208743 seconds.
#
# ===========================================================
# Testing from 436 to 440 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.733902050647885 seconds.
#
# ===========================================================
# Testing from 440 to 444 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.752426216378808 seconds.
#
# ===========================================================
# Testing from 444 to 448 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.388383308891207 seconds.
#
# ===========================================================
# Testing from 448 to 452 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.765679960139096 seconds.
#
# ===========================================================
# Testing from 452 to 456 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.767324992921203 seconds.
#
# ===========================================================
# Testing from 456 to 460 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.780675899237394 seconds.
#
# ===========================================================
# Testing from 460 to 464 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.759163836017251 seconds.
#
# ===========================================================
# Testing from 464 to 468 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.759297099895775 seconds.
#
# ===========================================================
# Testing from 468 to 472 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.730900709051639 seconds.
#
# ===========================================================
# Testing from 472 to 476 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.729255723301321 seconds.
#
# ===========================================================
# Testing from 476 to 480 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.732971068006009 seconds.
#
# ===========================================================
# Testing from 480 to 484 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.422457986976951 seconds.
#
# ===========================================================
# Testing from 484 to 488 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.783926208037883 seconds.
#
# ===========================================================
# Testing from 488 to 492 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7841603038832545 seconds.
#
# ===========================================================
# Testing from 492 to 496 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.775618189945817 seconds.
#
# ===========================================================
# Testing from 496 to 500 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7852318421937525 seconds.
#
# ===========================================================
# Testing from 500 to 504 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.730099825654179 seconds.
#
# ===========================================================
# Testing from 504 to 508 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.746942555066198 seconds.
#
# ===========================================================
# Testing from 508 to 512 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.779054075013846 seconds.
#
# ===========================================================
# Testing from 512 to 516 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.732780310790986 seconds.
#
# ===========================================================
# Testing from 516 to 520 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.385018861852586 seconds.
#
# ===========================================================
# Testing from 520 to 524 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.807016441132873 seconds.
#
# ===========================================================
# Testing from 524 to 528 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.764419361948967 seconds.
#
# ===========================================================
# Testing from 528 to 532 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7654685000889 seconds.
#
# ===========================================================
# Testing from 532 to 536 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.744793274905533 seconds.
#
# ===========================================================
# Testing from 536 to 540 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.760012099053711 seconds.
#
# ===========================================================
# Testing from 540 to 544 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7596730859950185 seconds.
#
# ===========================================================
# Testing from 544 to 548 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.778961040079594 seconds.
#
# ===========================================================
# Testing from 548 to 552 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.744458906818181 seconds.
#
# ===========================================================
# Testing from 552 to 556 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.742772838100791 seconds.
#
# ===========================================================
# Testing from 556 to 560 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.409660165663809 seconds.
#
# ===========================================================
# Testing from 560 to 564 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.805779593065381 seconds.
#
# ===========================================================
# Testing from 564 to 568 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.782487493939698 seconds.
#
# ===========================================================
# Testing from 568 to 572 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7831646632403135 seconds.
#
# ===========================================================
# Testing from 572 to 576 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.750208554789424 seconds.
#
# ===========================================================
# Testing from 576 to 580 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.742494651116431 seconds.
#
# ===========================================================
# Testing from 580 to 584 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.743321951944381 seconds.
#
# ===========================================================
# Testing from 584 to 588 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.753683955874294 seconds.
#
# ===========================================================
# Testing from 588 to 592 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.756671912968159 seconds.
#
# ===========================================================
# Testing from 592 to 596 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 6.3795343530364335 seconds.
#
# ===========================================================
# Testing from 596 to 600 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7816974790766835 seconds.
#
# ===========================================================
# Testing from 600 to 604 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.802242020145059 seconds.
#
# ===========================================================
# Testing from 604 to 608 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.7810004549100995 seconds.
#
# ===========================================================
# Testing from 608 to 612 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# FGD metric calculation completed in 5.783440775703639 seconds.
#
# ===========================================================
# Testing from 612 to 616 of 1000 samples.
#
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 4
# batch_size = 20000
# ...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.070217730011791 seconds.
#
# ===========================================================
# Testing from 792 to 796 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0688873156905174 seconds.
#
# ===========================================================
# Testing from 796 to 800 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0664850929751992 seconds.
#
# ===========================================================
# Testing from 800 to 804 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0870350352488458 seconds.
#
# ===========================================================
# Testing from 804 to 808 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0640989830717444 seconds.
#
# ===========================================================
# Testing from 808 to 812 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0570775619708002 seconds.
#
# ===========================================================
# Testing from 812 to 816 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0519010787829757 seconds.
#
# ===========================================================
# Testing from 816 to 820 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 3.822626039851457 seconds.
#
# ===========================================================
# Testing from 820 to 824 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.5470031150616705 seconds.
#
# ===========================================================
# Testing from 824 to 828 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.289110411889851 seconds.
#
# ===========================================================
# Testing from 828 to 832 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.2191855171695352 seconds.
#
# ===========================================================
# Testing from 832 to 836 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1740010711364448 seconds.
#
# ===========================================================
# Testing from 836 to 840 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1524500767700374 seconds.
#
# ===========================================================
# Testing from 840 to 844 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1555242580361664 seconds.
#
# ===========================================================
# Testing from 844 to 848 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1315206307917833 seconds.
#
# ===========================================================
# Testing from 848 to 852 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1256311857141554 seconds.
#
# ===========================================================
# Testing from 852 to 856 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1222773981280625 seconds.
#
# ===========================================================
# Testing from 856 to 860 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.120120958890766 seconds.
#
# ===========================================================
# Testing from 860 to 864 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1190206571482122 seconds.
#
# ===========================================================
# Testing from 864 to 868 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1170763513073325 seconds.
#
# ===========================================================
# Testing from 868 to 872 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1022017197683454 seconds.
#
# ===========================================================
# Testing from 872 to 876 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1129817985929549 seconds.
#
# ===========================================================
# Testing from 876 to 880 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0966775347478688 seconds.
#
# ===========================================================
# Testing from 880 to 884 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1090824832208455 seconds.
#
# ===========================================================
# Testing from 884 to 888 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1083036712370813 seconds.
#
# ===========================================================
# Testing from 888 to 892 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0916698910295963 seconds.
#
# ===========================================================
# Testing from 892 to 896 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.096209698356688 seconds.
#
# ===========================================================
# Testing from 896 to 900 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0804408257827163 seconds.
#
# ===========================================================
# Testing from 900 to 904 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0861339219845831 seconds.
#
# ===========================================================
# Testing from 904 to 908 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.083641449920833 seconds.
#
# ===========================================================
# Testing from 908 to 912 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.101143351290375 seconds.
#
# ===========================================================
# Testing from 912 to 916 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0729566980153322 seconds.
#
# ===========================================================
# Testing from 916 to 920 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0663621327839792 seconds.
#
# ===========================================================
# Testing from 920 to 924 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0809312900528312 seconds.
#
# ===========================================================
# Testing from 924 to 928 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0649990160018206 seconds.
#
# ===========================================================
# Testing from 928 to 932 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0710595878772438 seconds.
#
# ===========================================================
# Testing from 932 to 936 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0836935229599476 seconds.
#
# ===========================================================
# Testing from 936 to 940 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.055095061659813 seconds.
#
# ===========================================================
# Testing from 940 to 944 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 4.028153780382127 seconds.
#
# ===========================================================
# Testing from 944 to 948 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.44209223985672 seconds.
#
# ===========================================================
# Testing from 948 to 952 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.28949835896492 seconds.
#
# ===========================================================
# Testing from 952 to 956 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1932726483792067 seconds.
#
# ===========================================================
# Testing from 956 to 960 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1816448499448597 seconds.
#
# ===========================================================
# Testing from 960 to 964 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1500425743870437 seconds.
#
# ===========================================================
# Testing from 964 to 968 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1435667467303574 seconds.
#
# ===========================================================
# Testing from 968 to 972 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1443865657784045 seconds.
#
# ===========================================================
# Testing from 972 to 976 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1360732321627438 seconds.
#
# ===========================================================
# Testing from 976 to 980 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1274568191729486 seconds.
#
# ===========================================================
# Testing from 980 to 984 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.123340768739581 seconds.
#
# ===========================================================
# Testing from 984 to 988 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1195094170980155 seconds.
#
# ===========================================================
# Testing from 988 to 992 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1260754591785371 seconds.
#
# ===========================================================
# Testing from 992 to 996 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.130913011264056 seconds.
#
# ===========================================================
# Testing from 996 to 1000 of 1000 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.1009427369572222 seconds.
# All done in: 4191.68 s.
# Saving swd to results_leo/particle_features/tests/20K/null_hypotheses/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []
ndims = 90

for metric in list(metrics_config[unique_key].values()):
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# ThresholdS for metric fgd: [[0.68, [680, 319], 0.4474645788726467], [0.95, [950, 50], 14.101784526405465], [0.99, [990, 10], 29.25695820419948]]
# Computing time for metric fgd: 1462.3055652272888
# ThresholdS for metric mmd: [[0.68, [680, 319], 560764596.0126953], [0.95, [950, 50], 23636964354.731445], [0.99, [990, 10], 44119727854.39746]]
# Computing time for metric mmd: 943.6238622502424
# ThresholdS for metric ks: [[0.68, [680, 319], 0.9026117208931181], [0.95, [950, 50], 1.0436674041880503], [0.99, [990, 10], 1.1533337334791818]]
# Computing time for metric ks: 386.23408247111365
# ThresholdS for metric sks: [[0.68, [680, 319], 0.8942003361880779], [0.95, [950, 50], 1.1402010917663574], [0.99, [990, 10], 1.3346505351364613]]
# Computing time for metric sks: 958.3402614588849
# ThresholdS for metric swd: [[0.68, [680, 319], 1.9255338374559303], [0.95, [950, 50], 2.726426769584323], [0.99, [990, 10], 3.402446569660933]]
# Computing time for metric swd: 303.38321568630636
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...      metric_list
# 2                                                 {}  statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}     metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f659302cfe0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f659302dda0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f659302e160>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f659302d9e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f659302e2a0>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#    max_vectorize               latex  \
# 0            360  $d_{\mathrm{FGD}}$
# 1            360  $d_{\mathrm{MMD}}$
# 2            720      $\overline{D}$
# 3            400     $\widetilde{D}$
# 4            400     $\widetilde{W}$
#
#                                            null_file  \
# 0  results_leo/particle_features/tests/20K/null_h...
# 1  results_leo/particle_features/tests/20K/null_h...
# 2  results_leo/particle_features/tests/20K/null_h...
# 3  results_leo/particle_features/tests/20K/null_h...
# 4  results_leo/particle_features/tests/20K/null_h...
#
#                                           thresholds
# 0  [[0.68, [680, 319], 0.4474645788726467], [0.95...
# 1  [[0.68, [680, 319], 560764596.0126953], [0.95,...
# 2  [[0.68, [680, 319], 0.9026117208931181], [0.95...
# 3  [[0.68, [680, 319], 0.8942003361880779], [0.95...
# 4  [[0.68, [680, 319], 1.9255338374559303], [0.95...

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values()):
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Number of pseudo-experiments', fontsize=16)
    ax[0].set_title('PDF for EW_Likelihood null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for EW_Likelihood null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 2.529404675853822 +/- 1.1176891231599932
# sigma = 5.945118455659257 +/- 0.37734606242328705
# 68%CL = 0.4474645788726467, 95%CL = 14.101784526405465, 99%CL = 29.25695820419948
# mu = 2.529404675853822 +/- 1.1176891231599932
# sigma = 5.945118455659257 +/- 0.37734606242328705
# /tmp/ipykernel_807532/4088019264.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_807532/4088019264.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_807532/4088019264.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.5047201197594404 seconds.
# mu = 172079482.35933936 +/- 3.760845884869599e+18
# sigma = 10905429347.37524 +/- 541869690.9003949
# 68%CL = 560764596.0126953, 95%CL = 23636964354.731445, 99%CL = 44119727854.39746
# mu = 172079482.35933936 +/- 3.760845884869599e+18
# sigma = 10905429347.37524 +/- 541869690.9003949
# /tmp/ipykernel_807532/4088019264.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_807532/4088019264.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_807532/4088019264.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_807532/4088019264.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.0688238060101867 seconds.
# mu = 0.864218190178896 +/- 0.00030038651497468847
# sigma = 0.09746309895136167 +/- 0.002521487760393997
# 68%CL = 0.9026117208931181, 95%CL = 1.0436674041880503, 99%CL = 1.1533337334791818
# mu = 0.864218190178896 +/- 0.00030038651497468847
# sigma = 0.09746309895136167 +/- 0.002521487760393997
# /tmp/ipykernel_807532/4088019264.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_807532/4088019264.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_807532/4088019264.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_807532/4088019264.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.32069331407547 seconds.
# mu = 0.8600483770482242 +/- 0.0006332002999230701
# sigma = 0.1415045993195501 +/- 0.004762824239575719
# 68%CL = 0.8942003361880779, 95%CL = 1.1402010917663574, 99%CL = 1.3346505351364613
# mu = 0.8600483770482242 +/- 0.0006332002999230701
# sigma = 0.1415045993195501 +/- 0.004762824239575719
# /tmp/ipykernel_807532/4088019264.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_807532/4088019264.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_807532/4088019264.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_807532/4088019264.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.3176046358421445 seconds.
# mu = 1.8493566142424966 +/- 0.006983928962529012
# sigma = 0.4699481092462062 +/- 0.019320736856606496
# 68%CL = 1.9255338374559303, 95%CL = 2.726426769584323, 99%CL = 3.402446569660933
# mu = 1.8493566142424966 +/- 0.006983928962529012
# sigma = 0.4699481092462062 +/- 0.019320736856606496
# /tmp/ipykernel_807532/4088019264.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_807532/4088019264.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_807532/4088019264.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_807532/4088019264.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 0.9989524018019438 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...      metric_list
# 2                                                 {}  statistic_means
# 3                {'nslices': 100, 'seed_slicing': 0}     metric_means
# 4                {'nslices': 100, 'seed_slicing': 0}     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f659302cfe0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f659302dda0>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f659302e160>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f659302d9e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f659302e2a0>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#    max_vectorize               latex  \
# 0            360  $d_{\mathrm{FGD}}$
# 1            360  $d_{\mathrm{MMD}}$
# 2            720      $\overline{D}$
# 3            400     $\widetilde{D}$
# 4            400     $\widetilde{W}$
#
#                                            null_file  \
# 0  results_leo/particle_features/tests/20K/null_h...
# 1  results_leo/particle_features/tests/20K/null_h...
# 2  results_leo/particle_features/tests/20K/null_h...
# 3  results_leo/particle_features/tests/20K/null_h...
# 4  results_leo/particle_features/tests/20K/null_h...
#
#                                           thresholds  \
# 0  [[0.68, [680, 319], 0.4474645788726467], [0.95...
# 1  [[0.68, [680, 319], 560764596.0126953], [0.95,...
# 2  [[0.68, [680, 319], 0.9026117208931181], [0.95...
# 3  [[0.68, [680, 319], 0.8942003361880779], [0.95...
# 4  [[0.68, [680, 319], 1.9255338374559303], [0.95...
#
#                                          null_figure
# 0  results_leo/particle_features/tests/20K/null_h...
# 1  results_leo/particle_features/tests/20K/null_h...
# 2  results_leo/particle_features/tests/20K/null_h...
# 3  results_leo/particle_features/tests/20K/null_h...
# 4  results_leo/particle_features/tests/20K/null_h...

# %% [markdown]
# ### Alternative hypothesis

# %%
#l = len(dataset) // 2
l = 1_000_000
dstmp = tf.random.shuffle(dataset, seed = 0)
dist_1_alt = tf.cast(dstmp[:l], tf.float64)
del(dstmp)
print(f"Available {len(dist_1_alt)} samples for dist_1_alt.")
# Out:
# Available 1000000 samples for dist_1_alt.

# %%
print("i=0")
dist_2_alt = postprocess_data(NFObject.nf_dist.sample(100_000, seed = 0).numpy(),means,stds)
for i in range(1,10):
    print(f"i={i}")
    dist_2_alt = np.concatenate((dist_2_alt,postprocess_data(NFObject.nf_dist.sample(100_000, seed = 1000 * i + i).numpy(),means,stds)),axis=0)
dist_2_alt = tf.cast(dist_2_alt, tf.float64)
# Out:
# i=0
# i=1
# i=2
# i=3
# i=4
# i=5
# i=6
# i=7
# i=8
# i=9

# %%
niter_alt = 100

TwoSampleTestInputsAlt = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_alt[:niter_alt*batch_size_test],
                                                      dist_2_input = dist_2_alt[:niter_alt*batch_size_test],
                                                      niter = niter_alt,
                                                      batch_size_test = batch_size_test,
                                                      small_sample_threshold = 1e7,
                                                      dtype_input = tf.float64,
                                                      seed_input = 0,
                                                      use_tf = True,
                                                      mirror_strategy = False,
                                                      verbose = True)

FGDMetricAlt = GMetrics.FGDMetric(TwoSampleTestInputsAlt,
                                  progress_bar = True,
                                  verbose = True,
                                  num_batches = 20, # to be included in metric kwargs
                                  num_points = 10, # to be included in metric kwargs
                                  normalise = False) # to be included in metric kwargs
MMDMetricAlt = GMetrics.MMDMetric(TwoSampleTestInputsAlt,
                                  progress_bar = True,
                                  verbose = True,
                                  degree = 4, # to be included in metric kwargs
                                  block_size = 10_000, # to be included in metric kwargs
                                  normalise = False) # to be included in metric kwargs
KSTestAlt = GMetrics.KSTest(TwoSampleTestInputsAlt,
                            progress_bar = True,
                            verbose = True)
SKSTestAlt = GMetrics.SKSTest(TwoSampleTestInputsAlt,
                              nslices = 100, # to be included in metric kwargs
                              seed_slicing = 0, # to be included in metric kwargs
                              progress_bar = True,
                              verbose = True)
SWDMetricAlt = GMetrics.SWDMetric(TwoSampleTestInputsAlt,
                                  nslices = 100, # to be included in metric kwargs
                                  seed_slicing = 0, # to be included in metric kwargs
                                  progress_bar = True,
                                  verbose = True)
# Out:
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
for metric in list(metrics_config[unique_key].values()):
    file = metric["null_file"]
    name = metric["name"]
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"].replace("Null","Alt"))
    obj.Test_tf(max_vectorize = max_vectorize)
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_alt  = np.array(obj.Results[-1].result_value[result_key]) * scale_func(ns, ndims)
    print(f"Thresholds for metric {name}: {metric['thresholds']}")
    print(f"Value of the test-statistic for the alternative hypothesis: {np.mean(dist_alt)}")
# Out:
# ------------------------------------------
# Starting FGD metric calculation...
# Running TF FGD calculation...
# niter = 100
# batch_size = 10000
# FGD metric calculation completed in 29.26061704941094 seconds.
# Thresholds for metric fgd: [[0.68, [408, 191], 4.4577638779739245e-05], [0.95, [570, 30], 7.448543633039335e-05], [0.99, [594, 6], 0.00011959992550350216]]
# Value of the test-statistic for the alternative hypothesis: 4.769454026330981e-05
#
# ------------------------------------------
# Starting MMD metric calculation...
# Running TF MMD calculation...
# niter = 100
# batch_size = 10000
# nchunks = 20
# Iterating from 0 to 5 out of 100 .
# Iterating from 5 to 10 out of 100 .
# Iterating from 10 to 15 out of 100 .
# Iterating from 15 to 20 out of 100 .
# Iterating from 20 to 25 out of 100 .
# Iterating from 25 to 30 out of 100 .
# Iterating from 30 to 35 out of 100 .
# Iterating from 35 to 40 out of 100 .
# Iterating from 40 to 45 out of 100 .
# Iterating from 45 to 50 out of 100 .
# Iterating from 50 to 55 out of 100 .
# Iterating from 55 to 60 out of 100 .
# Iterating from 60 to 65 out of 100 .
# Iterating from 65 to 70 out of 100 .
# Iterating from 70 to 75 out of 100 .
# Iterating from 75 to 80 out of 100 .
# Iterating from 80 to 85 out of 100 .
# Iterating from 85 to 90 out of 100 .
# Iterating from 90 to 95 out of 100 .
# Iterating from 95 to 100 out of 100 .
# MMD metric calculation completed in 26.254005106166005 seconds.
# Thresholds for metric mmd: [[0.68, [408, 191], 2746.20703125], [0.95, [570, 30], 72365.234375], [0.99, [594, 6], 129499.375]]
# Value of the test-statistic for the alternative hypothesis: 4429.12591796875
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 100
# batch_size = 10000
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7f4b88403520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# KS tests calculation completed in 5.030375241301954 seconds.
# Thresholds for metric ks: [[0.68, [408, 191], 0.896965621184943], [0.95, [570, 30], 0.9819947807132462], [0.99, [594, 6], 1.0392703985478076]]
# Value of the test-statistic for the alternative hypothesis: 1.026958062132224
#
# ------------------------------------------
# Starting SKS metric calculation...
# Running TF SKS calculation...
# niter = 100
# batch_size = 10000
# SKS metric calculation completed in 11.924437906593084 seconds.
# Thresholds for metric sks: [[0.68, [408, 191], 0.9108953390102558], [0.95, [570, 30], 1.0818030487732582], [0.99, [594, 6], 1.2206786268323748]]
# Value of the test-statistic for the alternative hypothesis: 0.8993284663672394
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 100
# batch_size = 10000
# SWD metric calculation completed in 6.559205180965364 seconds.
# Thresholds for metric swd: [[0.68, [408, 191], 0.015897704081644884], [0.95, [570, 30], 0.020952556527507812], [0.99, [594, 6], 0.024422429300298917]]
# Value of the test-statistic for the alternative hypothesis: 0.01573983413328476
