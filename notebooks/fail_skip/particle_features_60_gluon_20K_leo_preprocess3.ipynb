# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [0]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more.deformations import deformed_distribution, deform_mean, deform_cov_diag, deform_cov_off_diag, deform_power_abs, deform_random
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection_dataset # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-07-03 10:48:19.752948: Importing os...
# 2024-07-03 10:48:19.753240: Importing sys...
# Visible devices: [0]
# 2024-07-03 10:48:19.753474: Importing timer from timeit...
# 2024-07-03 10:48:19.753543: Setting env variables for tf import (only device(s) [0] will be available)...
# 2024-07-03 10:48:19.753666: Importing numpy...
# 2024-07-03 10:48:19.861382: Importing matplotlib...
# 2024-07-03 10:48:20.223117: Importing h5py...
# 2024-07-03 10:48:20.246458: Importing importlib.util...
# 2024-07-03 10:48:20.246562: Importing json...
# 2024-07-03 10:48:20.246626: Importing pandas...
# 2024-07-03 10:48:20.687486: Importing random...
# 2024-07-03 10:48:20.687634: Importing scipy utils...
# 2024-07-03 10:48:21.072182: Importing subprocess...
# 2024-07-03 10:48:21.072317: Importing textwrap...
# 2024-07-03 10:48:21.072380: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-07-03 10:48:24.558144: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-07-03 10:48:25.610969: Importing timeit...
# 2024-07-03 10:48:25.611060: Importing tqdm...
# 2024-07-03 10:48:25.619250: Importing typing...
# 2024-07-03 10:48:25.619354: Setting tf configs...
# 2024-07-03 10:48:25.683247: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-07-03 10:48:30.105996: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #0, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-07-03 10:48:30.121829: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 60,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 60, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 60, 4)

# %% [markdown]
# # Particle level

# %% [markdown]
# ## Init data

# %%
results_dir = "results_leo/particle_features_60/"
figures_dir = os.path.join(results_dir, "figures/")
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocess_data=(data-means)/stds
    return preprocess_data

def postprocess_data(data,means,stds):
    postprocess_data=data*stds+means
    return postprocess_data

def get_reduced_particle_features(particle_features):
    tmp = particle_features[:, :, :3]
    shape = tmp.shape
    particle_features_reshaped = tf.reshape(tmp, [-1, shape[1] * shape[2]])
    return particle_features_reshaped

particle_features_reduced = get_reduced_particle_features(particle_features)
particle_features_reduced.shape
# Out:
# TensorShape([177252, 180])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests/")
model_dir = os.path.join(tests_dir, '20K_preprocessed/')
if not os.path.exists(model_dir):
    os.makedirs(model_dir, exist_ok = True)

particle_features_reduced = get_reduced_particle_features(particle_features)

mean = tf.reduce_mean(particle_features_reduced, axis=0)
std = tf.math.reduce_std(particle_features_reduced, axis=0)
    
dataset = preprocess_data(particle_features_reduced, mean, std)

# %% [markdown]
# ## 20K

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(model_dir, 'null_hypotheses/')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(model_dir, "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 20_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 20_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 4, nbootstrap: 250
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputsNull.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0      4            20000            1000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  is_symb_1  ndims_1  \
# 0     0    True            False     None     True      False      180
#
#    nsamples_1  is_symb_2  ndims_2  nsamples_2    dtype  ndims  nsamples  \
# 0       80000      False      180       80000  float64    180     80000
#
#    small_sample
# 0         False

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 20_000, 
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 2, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {"verbose": True}, 
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 360,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values())[3:]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Loading sks from results_leo/particle_features_60/tests/20K_preprocessed/null_hypotheses/SKS.json
# Loading swd from results_leo/particle_features_60/tests/20K_preprocessed/null_hypotheses/SWD.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []
ndims = 180

for metric in list(metrics_config[unique_key].values())[3:]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    print(len(dist_null))

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# 1000
# ThresholdS for metric sks: [[0.68, [680, 319], 0.8857004344463348], [0.95, [950, 50], 0.9962502866983414], [0.99, [990, 10], 1.1002001352608204]]
# Computing time for metric sks: 870.7678263993002
# 1000
# ThresholdS for metric swd: [[0.68, [680, 319], 0.09611304936433983], [0.95, [950, 50], 0.11484337267116299], [0.99, [990, 10], 0.1304459681370961]]
# Computing time for metric swd: 306.9467780861305
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f1078a31580>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f1078a31760>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f1078a33240>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f1078a332e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f1078a33380>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 4, 'batch_size_test': 20000, 'batch_...              8
# 1  {'niter': 4, 'batch_size_test': 20000, 'batch_...              2
# 2  {'niter': 4, 'batch_size_test': 20000, 'batch_...            360
# 3  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
# 4  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/20K_pre...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/20K_pre...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/20K_pre...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/20K_pre...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/20K_pre...
#
#                                           thresholds
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[0.68, [680, 319], 0.8857004344463348], [0.95...
# 4  [[0.68, [680, 319], 0.09611304936433983], [0.9...

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[3:]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Frequency', fontsize=16)
    ax[0].set_title('PDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.8646757141686976 +/- 0.0001618238800228097
# sigma = 0.07153544860262633 +/- 0.00207367135240614
# 68%CL = 0.8857004344463348, 95%CL = 0.9962502866983414, 99%CL = 1.1002001352608204
# mu = 0.8646757141686976 +/- 0.0001618238800228097
# sigma = 0.07153544860262633 +/- 0.00207367135240614
# /tmp/ipykernel_793176/3538746891.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_793176/3538746891.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_793176/3538746891.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_793176/3538746891.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.4512195317074656 seconds.
# mu = 0.0935778664941532 +/- 3.830746864011376e-06
# sigma = 0.011006309658474657 +/- 0.00035584087970000247
# 68%CL = 0.09611304936433983, 95%CL = 0.11484337267116299, 99%CL = 0.1304459681370961
# mu = 0.0935778664941532 +/- 3.830746864011376e-06
# sigma = 0.011006309658474657 +/- 0.00035584087970000247
# /tmp/ipykernel_793176/3538746891.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_793176/3538746891.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_793176/3538746891.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_793176/3538746891.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.1012935172766447 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 20000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7f1078a31580>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7f1078a31760>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7f1078a33240>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7f1078a332e0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7f1078a33380>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 4, 'batch_size_test': 20000, 'batch_...              8
# 1  {'niter': 4, 'batch_size_test': 20000, 'batch_...              2
# 2  {'niter': 4, 'batch_size_test': 20000, 'batch_...            360
# 3  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
# 4  {'niter': 4, 'batch_size_test': 20000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/20K_pre...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/20K_pre...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/20K_pre...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/20K_pre...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/20K_pre...
#
#                                           thresholds  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [[0.68, [680, 319], 0.8857004344463348], [0.95...
# 4  [[0.68, [680, 319], 0.09611304936433983], [0.9...
#
#                                          null_figure
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  results_leo/particle_features_60/tests/20K_pre...
# 4  results_leo/particle_features_60/tests/20K_pre...

# %% [markdown]
# ### Alternative hypothesis

# %% [markdown]
# #### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100, # this will be adapted to the boostrap size
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}

# %%
file_path = os.path.join(model_dir, "exclusion_limits.json")
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}
    
# Sort the dictionary by keys
existing_data = dict(sorted(existing_data.items()))

# Save the sorted dictionary back to a JSON file
with open(file_path, 'w') as f:
    json.dump(existing_data, f, cls=GMetrics.utils.CustomEncoder, indent=4) # type: ignore

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[3:]:
    for deformation in deformations:
        eps_max = 2.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection_dataset(dataset = dataset,
                                                             metric_config = metric_config,
                                                             test_kwargs = test_kwargs,
                                                             model_dir = model_dir,
                                                             deformation = deformation,
                                                             seed_dist = 0,
                                                             x_tol = 0.1,
                                                             fn_tol = 0.15,
                                                             bound = bound,
                                                             eps_min = 0.,
                                                             eps_max = eps_max,
                                                             smear = 0.,
                                                             max_iterations = 50,
                                                             save = True,
                                                             filename = "exclusion_limits.json",
                                                             verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Upper bounds for sks with mean deformation already loaded.
# Central bounds for sks with mean deformation already loaded.
# Lower bounds for sks with mean deformation already loaded.
# Upper bounds for sks with cov_diag deformation already loaded.
# Central bounds for sks with cov_diag deformation already loaded.
# Lower bounds for sks with cov_diag deformation already loaded.
# Upper bounds for sks with cov_off_diag deformation already loaded.
# Central bounds for sks with cov_off_diag deformation already loaded.
# Lower bounds for sks with cov_off_diag deformation already loaded.
# Upper bounds for sks with power_abs_up deformation already loaded.
# Central bounds for sks with power_abs_up deformation already loaded.
# Lower bounds for sks with power_abs_up deformation already loaded.
# Upper bounds for sks with power_abs_down deformation already loaded.
# Central bounds for sks with power_abs_down deformation already loaded.
# Lower bounds for sks with power_abs_down deformation already loaded.
# Upper bounds for sks with random_normal deformation already loaded.
# Central bounds for sks with random_normal deformation already loaded.
# Lower bounds for sks with random_normal deformation already loaded.
# Upper bounds for sks with random_uniform deformation already loaded.
# Central bounds for sks with random_uniform deformation already loaded.
# Lower bounds for sks with random_uniform deformation already loaded.
# Upper bounds for swd with mean deformation already loaded.
# Computing central bounds for swd with mean deformation.
#
# ======================================================
# =============== swd - mean ===============
# ======================================================
# niter: 4, nbootstrap: 25
#
# ------------ 1 - 0.95 CL -  central bound -----------
# eps = 1.0 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 3.5463955611921847 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9439145773649216 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9347548368386924 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9605845347978175 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# WARNING:tensorflow:5 out of the last 5 calls to <function SWDMetric.Test_tf.<locals>.batched_test_sub at 0x7f0f009f2c00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SWD metric calculation completed in 0.952213800046593 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# WARNING:tensorflow:6 out of the last 6 calls to <function SWDMetric.Test_tf.<locals>.batched_test_sub at 0x7f0f01354400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# SWD metric calculation completed in 1.0090823280625045 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9445087001658976 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.2995652481913567 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9357761540450156 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.94506252463907 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9657845846377313 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9381579770706594 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9738840060308576 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9356088428758085 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9566524438560009 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9349181330762804 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9355566031299531 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0405107703991234 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.937762517016381 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9599291430786252 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.4087777771055698 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0173673299141228 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9353154092095792 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9641102203167975 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9361837077885866 seconds.
# statistic = 3.413670035001788 - next threshold = 0.11484337267116299 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.8698110400584795
#
# ------------ 2 - 0.95 CL -  central bound -----------
# eps = 0.5 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9541232539340854 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9336259406991303 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9372050473466516 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9817160707898438 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9778324877843261 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9358310531824827 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9270752989687026 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9584556319750845 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.5258526913821697 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9411394009366632 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9641199372708797 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9328843546099961 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9386946181766689 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0775944357737899 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9327791407704353 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9613503301516175 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9263500398956239 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9380192663520575 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0729797249659896 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9340479569509625 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9576033032499254 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.431746853981167 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.06146605219692 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9424354317598045 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9416264430619776 seconds.
# statistic = 1.7100710393870526 - next threshold = 0.11484337267116299 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7482766930606068
#
# ------------ 3 - 0.95 CL -  central bound -----------
# eps = 0.25 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.935570536646992 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9638247028924525 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9290448538959026 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9336433177813888 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0649279952049255 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9431857219897211 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9533382095396519 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9476920808665454 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9561426378786564 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.4232464591041207 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9692920288071036 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9813155648298562 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9436207306571305 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9668846959248185 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9360909066163003 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9386876779608428 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.089955735951662 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9332030150108039 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9849679698236287 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9370542080141604 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9332603709772229 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0724269980564713 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.4237648518756032 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9653233499266207 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9525229041464627 seconds.
# statistic = 0.861675216026637 - next threshold = 0.11484337267116299 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5295803930396938
#
# ------------ 4 - 0.95 CL -  central bound -----------
# eps = 0.125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0892618061043322 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9388382458128035 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.938871162943542 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9572754707187414 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9712122669443488 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0257566068321466 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9410753082484007 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9398858854547143 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9681288707070053 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9739983500912786 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.450529407709837 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9624120802618563 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.09530691197142 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9433165458030999 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9401629697531462 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9447706970386207 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0253336378373206 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9376778062433004 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9598071360960603 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9374831109307706 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9426195700652897 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0318324211984873 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.4080668548122048 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9424611092545092 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0714952130801976 seconds.
# statistic = 0.44295722369898965 - next threshold = 0.11484337267116299 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.1764557197070207
#
# ------------ 5 - 0.95 CL -  central bound -----------
# eps = 0.0625 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9531515324488282 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9557848549447954 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9399827499873936 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9430086431093514 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.048933775164187 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9391588708385825 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9698176248930395 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.949415619019419 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9547262210398912 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9497060901485384 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.4485315820202231 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.080247510690242 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9494612351991236 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9752480331808329 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9790513948537409 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9426800236105919 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9392727250233293 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9455788237974048 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0289925658144057 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9418235472403467 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9766444670967758 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9431878682225943 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9476115312427282 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.447538903914392 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9474537754431367 seconds.
# statistic = 0.24007740691280322 - next threshold = 0.11484337267116299 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.7057013364415464
#
# ------------ 6 - 0.95 CL -  central bound -----------
# eps = 0.03125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.947574321180582 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0541940568946302 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9413394061848521 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9647045042365789 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.943196589127183 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9473776491358876 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.050225450657308 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9543752670288086 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9622718510217965 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9389942614361644 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.5782720423303545 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9491555509157479 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9590651406906545 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0291175050660968 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9377511451020837 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0129572739824653 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9681548504158854 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9694345151074231 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9918088680133224 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9538982720114291 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0381495477631688 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9619522849097848 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9510641479864717 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0760402572341263 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9536066986620426 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.938422457780689 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.6470168950036168 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9815770545974374 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9790492760948837 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0098141827620566 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.963238078635186 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.045051452703774 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9719410948455334 seconds.
# statistic = 0.1299767424787168 - next threshold = 0.1304459681370961 at 0.99 CL
# relative_error_eps = 0.15126050420168066
# relative_error_metric = 0.0036035694219582522
#
# ------------ 3 - 0.99 CL -  lower bound -----------
# eps = 0.2610532436519861 - deformation = random_uniform
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9513924848288298 seconds.
#
# ===========================================================
# Testing from 4 to 8 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9992597820237279 seconds.
#
# ===========================================================
# Testing from 8 to 12 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9517381680198014 seconds.
#
# ===========================================================
# Testing from 12 to 16 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9439947442151606 seconds.
#
# ===========================================================
# Testing from 16 to 20 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.976554305292666 seconds.
#
# ===========================================================
# Testing from 20 to 24 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9510668618604541 seconds.
#
# ===========================================================
# Testing from 24 to 28 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.6217643287964165 seconds.
#
# ===========================================================
# Testing from 28 to 32 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0257556228898466 seconds.
#
# ===========================================================
# Testing from 32 to 36 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9708841410465539 seconds.
#
# ===========================================================
# Testing from 36 to 40 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.118644508998841 seconds.
#
# ===========================================================
# Testing from 40 to 44 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9756042580120265 seconds.
#
# ===========================================================
# Testing from 44 to 48 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9560617157258093 seconds.
#
# ===========================================================
# Testing from 48 to 52 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.955481898970902 seconds.
#
# ===========================================================
# Testing from 52 to 56 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9558117277920246 seconds.
#
# ===========================================================
# Testing from 56 to 60 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9523052773438394 seconds.
#
# ===========================================================
# Testing from 60 to 64 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9523016889579594 seconds.
#
# ===========================================================
# Testing from 64 to 68 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9556009941734374 seconds.
#
# ===========================================================
# Testing from 68 to 72 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9404978039674461 seconds.
#
# ===========================================================
# Testing from 72 to 76 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9449197240173817 seconds.
#
# ===========================================================
# Testing from 76 to 80 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.6217284193262458 seconds.
#
# ===========================================================
# Testing from 80 to 84 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 1.0284844217821956 seconds.
#
# ===========================================================
# Testing from 84 to 88 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.981859290972352 seconds.
#
# ===========================================================
# Testing from 88 to 92 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9688681038096547 seconds.
#
# ===========================================================
# Testing from 92 to 96 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9736397950910032 seconds.
#
# ===========================================================
# Testing from 96 to 100 of 100 samples.
#
# ------------------------------------------
# Starting SWD metric calculation...
# Running TF SWD calculation...
# niter = 4
# batch_size = 20000
# SWD metric calculation completed in 0.9639405538327992 seconds.
# statistic = 0.1325566394363037 - next threshold = 0.1304459681370961 at 0.99 CL
# relative_error_eps = 0.07860262008733625
# relative_error_metric = 0.016050573176302287
# =======> statistic within required accuracy at 0.99 CL in 85.09420395735651 seconds
#
# ======================================================
# New threshold. Resetting eps_min and eps_max.
# Time elapsed: 198.62975936289877 seconds.
# Saving results in the file results_leo/particle_features_60/tests/20K_preprocessed/exclusion_limits.json
# dict_keys(['sks_mean_upper_2024-07-02T11:53:20.529989', 'sks_mean_central_2024-07-02T12:29:10.693692', 'sks_mean_lower_2024-07-02T12:42:04.481237', 'sks_cov_diag_upper_2024-07-02T12:58:56.646628', 'sks_cov_diag_central_2024-07-02T13:37:01.812132', 'sks_cov_diag_lower_2024-07-02T13:51:40.651595', 'sks_cov_off_diag_upper_2024-07-02T14:11:01.448911', 'sks_cov_off_diag_central_2024-07-02T14:55:56.268212', 'sks_cov_off_diag_lower_2024-07-02T15:17:15.530314', 'sks_power_abs_up_upper_2024-07-02T15:38:55.573655', 'sks_power_abs_up_central_2024-07-02T16:25:58.030121', 'sks_power_abs_up_lower_2024-07-02T16:43:47.073959', 'sks_power_abs_down_upper_2024-07-02T17:07:13.276194', 'sks_power_abs_down_central_2024-07-02T17:58:17.994149', 'sks_power_abs_down_lower_2024-07-02T18:20:37.123004', 'sks_random_normal_upper_2024-07-02T18:46:04.360316', 'sks_random_normal_central_2024-07-02T19:29:59.740922', 'sks_random_normal_lower_2024-07-02T19:51:08.053391', 'sks_random_uniform_upper_2024-07-02T20:15:39.991869', 'sks_random_uniform_central_2024-07-02T20:59:00.784988', 'sks_random_uniform_lower_2024-07-02T21:21:00.821410', 'swd_mean_upper_2024-07-02T21:43:58.009119', 'swd_mean_central_2024-07-03T10:48:42.830045', 'swd_mean_lower_2024-07-03T10:58:57.293604', 'swd_cov_diag_upper_2024-07-03T11:03:08.839494', 'swd_cov_diag_central_2024-07-03T11:12:33.896248', 'swd_cov_diag_lower_2024-07-03T11:16:19.831766', 'swd_cov_off_diag_upper_2024-07-03T11:20:34.306311', 'swd_cov_off_diag_central_2024-07-03T11:30:43.171223', 'swd_cov_off_diag_lower_2024-07-03T11:34:06.363777', 'swd_power_abs_up_upper_2024-07-03T11:38:26.917295', 'swd_power_abs_up_central_2024-07-03T11:47:51.562722', 'swd_power_abs_up_lower_2024-07-03T11:51:36.912677', 'swd_power_abs_down_upper_2024-07-03T11:55:50.926077', 'swd_power_abs_down_central_2024-07-03T12:04:45.972209', 'swd_power_abs_down_lower_2024-07-03T12:08:31.839425', 'swd_random_normal_upper_2024-07-03T12:12:45.317309', 'swd_random_normal_central_2024-07-03T12:19:50.300607', 'swd_random_normal_lower_2024-07-03T12:23:07.817356', 'swd_random_uniform_upper_2024-07-03T12:26:21.561408', 'swd_random_uniform_central_2024-07-03T12:32:50.815849', 'swd_random_uniform_lower_2024-07-03T12:36:05.667980'])

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 34
#      32     #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
#      33 results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
# ---> 34 results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
#      35     "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
#      36     "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
#      37     "t (s)": lambda x: x.tolist()
#      38 }).reset_index()
#      39 results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
#      40 results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)
#     421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/apply.py:1608, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1603     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1605 with com.temp_setattr(
#    1606     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607 ):
# -> 1608     result_index, result_data = self.compute_dict_like(
#    1609         op_name, selected_obj, selection, kwargs
#    1610     )
#    1611 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1612 return result
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/apply.py:496, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     493         results += key_data
#     494 else:
#     495     # key used for column selection and output
# --> 496     results = [
#     497         getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     498         for key, how in func.items()
#     499     ]
#     500     keys = list(func.keys())
#     502 return keys, results
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/apply.py:497, in <listcomp>(.0)
#     493         results += key_data
#     494 else:
#     495     # key used for column selection and output
#     496     results = [
# --> 497         getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     498         for key, how in func.items()
#     499     ]
#     500     keys = list(func.keys())
#     502 return keys, results
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/groupby/generic.py:291, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     283     return self.obj._constructor(
#     284         [],
#     285         name=self.obj.name,
#     286         index=self._grouper.result_index,
#     287         dtype=obj.dtype,
#     288     )
#     290 if self._grouper.nkeys > 1:
# --> 291     return self._python_agg_general(func, *args, **kwargs)
#     293 try:
#     294     return self._python_agg_general(func, *args, **kwargs)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/groupby/generic.py:327, in SeriesGroupBy._python_agg_general(self, func, *args, **kwargs)
#     324 f = lambda x: func(x, *args, **kwargs)
#     326 obj = self._obj_with_exclusions
# --> 327 result = self._grouper.agg_series(obj, f)
#     328 res = obj._constructor(result, name=obj.name)
#     329 return self._wrap_aggregated_output(res)
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     857 if not isinstance(obj._values, np.ndarray):
#     858     # we can preserve a little bit more aggressively with EA dtype
#     859     #  because maybe_cast_pointwise_result will do a try/except
#     860     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     861     #  is sufficiently strict that it casts appropriately.
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     867 if preserve_dtype:
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     882 splitter = self._get_splitter(obj, axis=0)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#     888     if not initialized:
#     889         # We only do this validation on the first iteration
#
# File ~/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/pandas/core/groupby/generic.py:324, in SeriesGroupBy._python_agg_general.<locals>.<lambda>(x)
#     322     alias = com._builtin_table_alias[func]
#     323     warn_alias_replacement(self, orig_func, alias)
# --> 324 f = lambda x: func(x, *args, **kwargs)
#     326 obj = self._obj_with_exclusions
#     327 result = self._grouper.agg_series(obj, f)
#
# Cell In[19], line 35, in <lambda>(x)
#      32     #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
#      33 results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
#      34 results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
# ---> 35     "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
#      36     "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
#      37     "t (s)": lambda x: x.tolist()
#      38 }).reset_index()
#      39 results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
#      40 results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_366541/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#   Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 2       sks        mean  450      8                10000
# 9       swd        mean  450      8                10000
#
#   $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 2      $0.01907_{-0.0061}^{+0.0053}$      $0.02864_{-0.0029}^{+0.0043}$
# 9      $0.02298_{-0.0092}^{+0.0073}$      $0.03031_{-0.0052}^{+0.0094}$
#
#    $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 2           2334  [0.01298, 0.01907, 0.02441]   [0.0257, 0.02864, 0.03299]
# 9            894  [0.01374, 0.02298, 0.03027]  [0.02513, 0.03031, 0.03974]
#
#                time
# 2  [1166, 586, 582]
# 9   [438, 237, 219]
#   Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 2       sks      $0.01907_{-0.0061}^{+0.0053}$
# 9       swd      $0.02298_{-0.0092}^{+0.0073}$
#
#   $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 2      $0.02864_{-0.0029}^{+0.0043}$           2334
# 9      $0.03031_{-0.0052}^{+0.0094}$            894

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_366541/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#   Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 7       swd    cov_diag  450      8                10000
# 0       sks    cov_diag  450      8                10000
#
#   $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7                $0.04013_{-0.017}^{+0.017}$
# 0                 $0.0436_{-0.014}^{+0.021}$
#
#   $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 7                $0.05138_{-0.016}^{+0.014}$                    884
# 0                  $0.06547_{-0.02}^{+0.01}$                   2300
#
#                          95%CL                        99%CL              time
# 7  [0.02328, 0.04013, 0.05664]  [0.03558, 0.05138, 0.06585]   [429, 220, 235]
# 0   [0.02967, 0.0436, 0.06445]  [0.04533, 0.06547, 0.07542]  [1064, 615, 621]
#   Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7       swd                $0.04013_{-0.017}^{+0.017}$
# 0       sks                 $0.0436_{-0.014}^{+0.021}$
#
#   $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 7                $0.05138_{-0.016}^{+0.014}$                    884
# 0                  $0.06547_{-0.02}^{+0.01}$                   2300

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_366541/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#   Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 8       swd  cov_off_diag  450      8                10000
# 1       sks  cov_off_diag  450      8                10000
#
#   $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 8                     $0.02913_{-0.012}^{+0.012}$
# 1                     $0.03352_{-0.011}^{+0.011}$
#
#   $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)  \
# 8                    $0.03843_{-0.0066}^{+0.012}$                         914
# 1                   $0.05034_{-0.0086}^{+0.0076}$                        2563
#
#                          95%CL                        99%CL              time
# 8  [0.01741, 0.02913, 0.04102]  [0.03186, 0.03843, 0.05038]   [435, 249, 230]
# 1  [0.02281, 0.03352, 0.04492]  [0.04173, 0.05034, 0.05798]  [1240, 658, 665]
#   Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 8       swd                     $0.02913_{-0.012}^{+0.012}$
# 1       sks                     $0.03352_{-0.011}^{+0.011}$
#
#   $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 8                    $0.03843_{-0.0066}^{+0.012}$                         914
# 1                   $0.05034_{-0.0086}^{+0.0076}$                        2563

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_366541/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 11       swd  power_abs_up  450      8                10000
# 4        sks  power_abs_up  450      8                10000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11                 $0.03145_{-0.013}^{+0.017}$
# 4                  $0.04783_{-0.015}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 11                 $0.04149_{-0.013}^{+0.013}$                     874
# 4                  $0.07182_{-0.022}^{+0.011}$                    2513
#
#                           95%CL                        99%CL              time
# 11   [0.0188, 0.03145, 0.04883]   [0.02873, 0.04149, 0.0544]   [426, 218, 230]
# 4   [0.03254, 0.04783, 0.06445]  [0.04973, 0.07182, 0.08273]  [1167, 669, 677]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11       swd                 $0.03145_{-0.013}^{+0.017}$
# 4        sks                 $0.04783_{-0.015}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 11                 $0.04149_{-0.013}^{+0.013}$                     874
# 4                  $0.07182_{-0.022}^{+0.011}$                    2513

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_366541/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 10       swd  power_abs_down  450      8                10000
# 3        sks  power_abs_down  450      8                10000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10                 $0.03807_{-0.017}^{+0.019}$
# 3                  $0.04783_{-0.017}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 10                 $0.04675_{-0.014}^{+0.019}$                     863
# 3                  $0.06746_{-0.012}^{+0.015}$                    2641
#
#                           95%CL                        99%CL              time
# 10  [0.02119, 0.03807, 0.05664]  [0.03237, 0.04675, 0.06585]   [416, 230, 217]
# 3   [0.03057, 0.04783, 0.06445]  [0.05593, 0.06746, 0.08273]  [1225, 704, 712]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10       swd                 $0.03807_{-0.017}^{+0.019}$
# 3        sks                 $0.04783_{-0.017}^{+0.017}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 10                 $0.04675_{-0.014}^{+0.019}$                     863
# 3                  $0.06746_{-0.012}^{+0.015}$                    2641

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_366541/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 5        sks  random_normal  450      8                10000
# 12       swd  random_normal  450      8                10000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5                   $0.132_{-0.014}^{+0.032}$
# 12                 $0.14348_{-0.03}^{+0.021}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 5                 $0.16428_{-0.029}^{+0.019}$                   2195
# 12                $0.15855_{-0.017}^{+0.025}$                    676
#
#                           95%CL                        99%CL              time
# 5     [0.11808, 0.132, 0.16406]  [0.13541, 0.16428, 0.18365]  [1041, 567, 587]
# 12  [0.11395, 0.14348, 0.16406]  [0.14182, 0.15855, 0.18365]   [325, 174, 177]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 5        sks                  $0.132_{-0.014}^{+0.032}$
# 12       swd                 $0.14348_{-0.03}^{+0.021}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 5                 $0.16428_{-0.029}^{+0.019}$                   2195
# 12                $0.15855_{-0.017}^{+0.025}$                    676

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_366541/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        sks  random_uniform  450      8                10000
# 13       swd  random_uniform  450      8                10000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                 $0.22101_{-0.023}^{+0.052}$
# 13                $0.25187_{-0.052}^{+0.037}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                 $0.27506_{-0.048}^{+0.032}$                   2180
# 13                $0.27831_{-0.049}^{+0.044}$                    661
#
#                           95%CL                        99%CL             time
# 6    [0.1977, 0.22101, 0.27344]   [0.22671, 0.27506, 0.3075]  [989, 595, 596]
# 13  [0.20004, 0.25187, 0.28906]  [0.22939, 0.27831, 0.32239]  [300, 175, 186]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        sks                $0.22101_{-0.023}^{+0.052}$
# 13       swd                $0.25187_{-0.052}^{+0.037}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                 $0.27506_{-0.048}^{+0.032}$                   2180
# 13                $0.27831_{-0.049}^{+0.044}$                    661
