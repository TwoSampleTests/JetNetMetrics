# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more.deformations import deformed_distribution, deform_mean, deform_cov_diag, deform_cov_off_diag, deform_power_abs, deform_random
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection_dataset # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-07-02 14:35:20.082876: Importing os...
# 2024-07-02 14:35:20.083189: Importing sys...
# Visible devices: [2]
# 2024-07-02 14:35:20.083430: Importing timer from timeit...
# 2024-07-02 14:35:20.083497: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-07-02 14:35:20.083630: Importing numpy...
# 2024-07-02 14:35:20.205835: Importing matplotlib...
# 2024-07-02 14:35:20.595278: Importing h5py...
# 2024-07-02 14:35:20.637460: Importing importlib.util...
# 2024-07-02 14:35:20.637618: Importing json...
# 2024-07-02 14:35:20.637692: Importing pandas...
# 2024-07-02 14:35:21.207365: Importing random...
# 2024-07-02 14:35:21.207533: Importing scipy utils...
# 2024-07-02 14:35:21.673345: Importing subprocess...
# 2024-07-02 14:35:21.673504: Importing textwrap...
# 2024-07-02 14:35:21.673567: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-07-02 14:35:25.679580: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-07-02 14:35:26.853737: Importing timeit...
# 2024-07-02 14:35:26.853838: Importing tqdm...
# 2024-07-02 14:35:26.862410: Importing typing...
# 2024-07-02 14:35:26.862530: Setting tf configs...
# 2024-07-02 14:35:26.958146: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-07-02 14:35:32.235589: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-07-02 14:35:32.264660: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 60,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 60, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 60, 4)

# %% [markdown]
# # Particle level

# %% [markdown]
# ## Init data

# %%
results_dir = "results_leo/particle_features_60/"
figures_dir = os.path.join(results_dir, "figures/")
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocessed_data=(data-means)/stds
    return preprocessed_data

def postprocess_data(data,means,stds):
    postprocessed_data=data*stds+means
    return postprocessed_data

def get_reduced_particle_features(particle_features):
    tmp = particle_features[:, :, :3]
    shape = tmp.shape
    particle_features_reshaped = tf.reshape(tmp, [-1, shape[1] * shape[2]])
    return particle_features_reshaped

particle_features_reduced = get_reduced_particle_features(particle_features)
particle_features_reduced.shape
# Out:
# TensorShape([177252, 180])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests/")
model_dir = os.path.join(tests_dir, '50K_preprocessed/')
if not os.path.exists(model_dir):
    os.makedirs(model_dir, exist_ok = True)

particle_features_reduced = get_reduced_particle_features(particle_features)

mean = tf.reduce_mean(particle_features_reduced, axis=0)
std = tf.math.reduce_std(particle_features_reduced, axis=0)
    
dataset = preprocess_data(particle_features_reduced, mean, std)

# %% [markdown]
# ## 50K

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(model_dir, 'null_hypotheses/')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(model_dir, "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 50_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 25_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 1, nbootstrap: 1000
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputsNull.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0      1            50000            1000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  is_symb_1  ndims_1  \
# 0     0    True            False     None     True      False      180
#
#    nsamples_1  is_symb_2  ndims_2  nsamples_2    dtype  ndims  nsamples  \
# 0       50000      False      180       50000  float64    180     50000
#
#    small_sample
# 0          True

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 25_000, 
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 1, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {"verbose": True}, 
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 360,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values())[2:3]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng ks with max_vectorize = 360
#
# ===========================================================
# Testing from 0 to 1 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.831666993908584 seconds.
#
# ===========================================================
# Testing from 1 to 2 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0418104473501444 seconds.
#
# ===========================================================
# Testing from 2 to 3 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.191148530691862 seconds.
#
# ===========================================================
# Testing from 3 to 4 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1947500742971897 seconds.
#
# ===========================================================
# Testing from 4 to 5 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7fb3ce3bcd60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# KS tests calculation completed in 1.08232038654387 seconds.
#
# ===========================================================
# Testing from 5 to 6 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7fb3d0d59da0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# KS tests calculation completed in 1.0640034871175885 seconds.
#
# ===========================================================
# Testing from 6 to 7 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0745148938149214 seconds.
#
# ===========================================================
# Testing from 7 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.07319709751755 seconds.
#
# ===========================================================
# Testing from 8 to 9 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.4614028688520193 seconds.
#
# ===========================================================
# Testing from 9 to 10 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1085972925648093 seconds.
#
# ===========================================================
# Testing from 10 to 11 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1121689407154918 seconds.
#
# ===========================================================
# Testing from 11 to 12 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1439054002985358 seconds.
#
# ===========================================================
# Testing from 12 to 13 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2375060394406319 seconds.
#
# ===========================================================
# Testing from 13 to 14 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1240459037944674 seconds.
#
# ===========================================================
# Testing from 14 to 15 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0948385372757912 seconds.
#
# ===========================================================
# Testing from 15 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0896574696525931 seconds.
#
# ===========================================================
# Testing from 16 to 17 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0902230041101575 seconds.
#
# ===========================================================
# Testing from 17 to 18 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.094637505710125 seconds.
#
# ===========================================================
# Testing from 18 to 19 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1446595331653953 seconds.
#
# ===========================================================
# Testing from 19 to 20 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.097928186878562 seconds.
#
# ===========================================================
# Testing from 20 to 21 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0626128567382693 seconds.
#
# ===========================================================
# Testing from 21 to 22 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1854114355519414 seconds.
#
# ===========================================================
# Testing from 22 to 23 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9166704481467605 seconds.
#
# ===========================================================
# Testing from 23 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1073583029210567 seconds.
#
# ===========================================================
# Testing from 24 to 25 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1009791707620025 seconds.
#
# ===========================================================
# Testing from 25 to 26 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.095565790310502 seconds.
#
# ===========================================================
# Testing from 26 to 27 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1110166143625975 seconds.
#
# ===========================================================
# Testing from 27 to 28 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1107663279399276 seconds.
#
# ===========================================================
# Testing from 28 to 29 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0909743094816804 seconds.
#
# ===========================================================
# Testing from 29 to 30 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0789698511362076 seconds.
#
# ===========================================================
# Testing from 30 to 31 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1859979731962085 seconds.
#
# ===========================================================
# Testing from 31 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.245051502250135 seconds.
#
# ===========================================================
# Testing from 32 to 33 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1067077089101076 seconds.
#
# ===========================================================
# Testing from 33 to 34 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.104393302462995 seconds.
#
# ===========================================================
# Testing from 34 to 35 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.104814681224525 seconds.
#
# ===========================================================
# Testing from 35 to 36 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1120807956904173 seconds.
#
# ===========================================================
# Testing from 36 to 37 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.119638603180647 seconds.
#
# ===========================================================
# Testing from 37 to 38 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1168214613571763 seconds.
#
# ===========================================================
# Testing from 38 to 39 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.6937152985483408 seconds.
#
# ===========================================================
# Testing from 39 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1128283282741904 seconds.
#
# ===========================================================
# Testing from 40 to 41 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.3186132162809372 seconds.
#
# ===========================================================
# Testing from 41 to 42 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2131769275292754 seconds.
#
# ===========================================================
# Testing from 42 to 43 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1447472758591175 seconds.
#
# ===========================================================
# Testing from 43 to 44 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1404479490593076 seconds.
#
# ===========================================================
# Testing from 44 to 45 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1427116794511676 seconds.
#
# ===========================================================
# Testing from 45 to 46 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.130476277321577 seconds.
#
# ===========================================================
# Testing from 46 to 47 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1166898123919964 seconds.
#
# ===========================================================
# Testing from 47 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1297098575159907 seconds.
#
# ===========================================================
# Testing from 48 to 49 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1096957623958588 seconds.
#
# ===========================================================
# Testing from 49 to 50 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.169201917015016 seconds.
#
# ===========================================================
# Testing from 50 to 51 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2524384846910834 seconds.
#
# ===========================================================
# Testing from 51 to 52 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.116125245578587 seconds.
#
# ===========================================================
# Testing from 52 to 53 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1281263791024685 seconds.
#
# ===========================================================
# Testing from 53 to 54 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7279722997918725 seconds.
#
# ===========================================================
# Testing from 54 to 55 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1470193797722459 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1285193227231503 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1170572834089398 seconds.
#
# ===========================================================
# Testing from 57 to 58 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1117428606376052 seconds.
#
# ===========================================================
# Testing from 58 to 59 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.200253545306623 seconds.
#
# ===========================================================
# Testing from 59 to 60 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2634586095809937 seconds.
#
# ===========================================================
# Testing from 60 to 61 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1369643546640873 seconds.
#
# ===========================================================
# Testing from 61 to 62 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1186398519203067 seconds.
#
# ===========================================================
# Testing from 62 to 63 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1287209438160062 seconds.
#
# ===========================================================
# Testing from 63 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1217242693528533 seconds.
#
# ===========================================================
# Testing from 64 to 65 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1276417206972837 seconds.
#
# ===========================================================
# Testing from 65 to 66 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1168051455169916 seconds.
#
# ===========================================================
# Testing from 66 to 67 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1103446744382381 seconds.
#
# ===========================================================
# Testing from 67 to 68 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.0907506411895156 seconds.
#
# ===========================================================
# Testing from 68 to 69 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.238734700717032 seconds.
#
# ===========================================================
# Testing from 69 to 70 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9856395367532969 seconds.
#
# ===========================================================
# Testing from 70 to 71 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.139883833937347 seconds.
#
# ===========================================================
# Testing from 71 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.147584461607039 seconds.
#
# ===========================================================
# Testing from 72 to 73 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1520762592554092 seconds.
#
# ===========================================================
# Testing from 73 to 74 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1509111942723393 seconds.
#
# ===========================================================
# Testing from 74 to 75 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.161801534704864 seconds.
#
# ===========================================================
# Testing from 75 to 76 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1525972923263907 seconds.
#
# ===========================================================
# Testing from 76 to 77 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.130967234261334 seconds.
#
# ===========================================================
# Testing from 77 to 78 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2754523577168584 seconds.
#
# ===========================================================
# Testing from 78 to 79 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2387470500543714 seconds.
#
# ===========================================================
# Testing from 79 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1503883711993694 seconds.
#
# ===========================================================
# Testing from 80 to 81 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1302745519205928 seconds.
#
# ===========================================================
# Testing from 81 to 82 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.146016487851739 seconds.
#
# ===========================================================
# Testing from 82 to 83 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1241067852824926 seconds.
#
# ===========================================================
# Testing from 83 to 84 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1382123455405235 seconds.
#
# ===========================================================
# Testing from 84 to 85 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1399056389927864 seconds.
#
# ===========================================================
# Testing from 85 to 86 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8088477244600654 seconds.
#
# ===========================================================
# Testing from 86 to 87 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.3555018696933985 seconds.
#
# ===========================================================
# Testing from 87 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.206072298809886 seconds.
#
# ===========================================================
# Testing from 88 to 89 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.169906278140843 seconds.
#
# ===========================================================
# Testing from 89 to 90 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.16360305249691 seconds.
#
# ===========================================================
# Testing from 90 to 91 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1807661512866616 seconds.
#
# ===========================================================
# Testing from 91 to 92 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.157280944287777 seconds.
#
# ===========================================================
# Testing from 92 to 93 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1648790733888745 seconds.
#
# ===========================================================
# Testing from 93 to 94 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1520640850067139 seconds.
#
# ===========================================================
# Testing from 94 to 95 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1117484765127301 seconds.
#
# ===========================================================
# Testing from 95 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.3001746824011207 seconds.
#
# ===========================================================
# Testing from 96 to 97 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.212545926682651 seconds.
#
# ===========================================================
# Testing from 97 to 98 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1604175232350826 seconds.
#
# ===========================================================
# Testing from 98 to 99 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1450063893571496 seconds.
#
# ===========================================================
# Testing from 99 to 100 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1251819226890802 seconds.
#
# ===========================================================
# Testing from 100 to 101 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.146429712884128 seconds.
#
# ===========================================================
# Testing from 101 to 102 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1323353396728635 seconds.
#
# ===========================================================
# Testing from 102 to 103 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8709174562245607 seconds.
#
# ===========================================================
# Testing from 103 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1924101384356618 seconds.
#
# ===========================================================
# Testing from 104 to 105 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.3300550058484077 seconds.
#
# ===========================================================
# Testing from 105 to 106 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2313284613192081 seconds.
#
# ===========================================================
# Testing from 106 to 107 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.188296351581812 seconds.
#
# ===========================================================
# Testing from 107 to 108 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.155381920747459 seconds.
#
# ===========================================================
# Testing from 108 to 109 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1875371970236301 seconds.
#
# ===========================================================
# Testing from 109 to 110 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1624680925160646 seconds.
#
# ===========================================================
# Testing from 110 to 111 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.173239273019135 seconds.
#
# ===========================================================
# Testing from 111 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1899136118590832 seconds.
#
# ===========================================================
# Testing from 112 to 113 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1352253314107656 seconds.
#
# ===========================================================
# Testing from 113 to 114 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.298609608784318 seconds.
#
# ===========================================================
# Testing from 114 to 115 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2530851075425744 seconds.
#
# ===========================================================
# Testing from 115 to 116 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1663680132478476 seconds.
#
# ===========================================================
# Testing from 116 to 117 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1633533844724298 seconds.
#
# ===========================================================
# Testing from 117 to 118 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1820350363850594 seconds.
#
# ===========================================================
# Testing from 118 to 119 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1555189276114106 seconds.
#
# ===========================================================
# Testing from 119 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9298345781862736 seconds.
#
# ===========================================================
# Testing from 120 to 121 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1878263661637902 seconds.
#
# ===========================================================
# Testing from 121 to 122 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2534610265865922 seconds.
#
# ===========================================================
# Testing from 122 to 123 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.3734523225575686 seconds.
#
# ===========================================================
# Testing from 123 to 124 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1913063591346145 seconds.
#
# ===========================================================
# Testing from 124 to 125 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2016331972554326 seconds.
#
# ===========================================================
# Testing from 125 to 126 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1932446714490652 seconds.
#
# ===========================================================
# Testing from 126 to 127 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1823742743581533 seconds.
#
# ===========================================================
# Testing from 127 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1793250208720565 seconds.
#
# ===========================================================
# Testing from 128 to 129 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1774433702230453 seconds.
#
# ===========================================================
# Testing from 129 to 130 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1817081458866596 seconds.
#
# ===========================================================
# Testing from 130 to 131 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1974947238340974 seconds.
#
# ===========================================================
# Testing from 131 to 132 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.3224851861596107 seconds.
#
# ===========================================================
# Testing from 132 to 133 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1890524979680777 seconds.
#
# ===========================================================
# Testing from 133 to 134 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.173709848895669 seconds.
#
# ===========================================================
# Testing from 134 to 135 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1805863315239549 seconds.
#
# ===========================================================
# Testing from 135 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1624287609010935 seconds.
#
# ===========================================================
# Testing from 136 to 137 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2068151226267219 seconds.
#
# ===========================================================
# Testing from 137 to 138 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9842745466157794 seconds.
#
# ===========================================================
# Testing from 138 to 139 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2039891825988889 seconds.
#
# ===========================================================
# Testing from 139 to 140 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.3538399133831263 seconds.
#
# ===========================================================
# Testing from 140 to 141 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.286574819125235 seconds.
#
# ===========================================================
# Testing from 141 to 142 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1906164605170488 seconds.
#
# ===========================================================
# Testing from 142 to 143 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1950204158201814 seconds.
#
# ===========================================================
# Testing from 143 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2081523453816772 seconds.
#
# ===========================================================
# Testing from 144 to 145 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1928093386813998 seconds.
#
# ===========================================================
# Testing from 145 to 146 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.220160131342709 seconds.
#
# ===========================================================
# Testing from 146 to 147 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1929023377597332 seconds.
#
# ===========================================================
# Testing from 147 to 148 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1515937466174364 seconds.
#
# ===========================================================
# Testing from 148 to 149 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.224298633635044 seconds.
#
# ===========================================================
# Testing from 149 to 150 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.3509016297757626 seconds.
#
# ===========================================================
# Testing from 150 to 151 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2046326752752066 seconds.
#
# ===========================================================
# Testing from 151 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.186701717786491 seconds.
#
# ===========================================================
# Testing from 152 to 153 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1778618739917874 seconds.
#
# ===========================================================
# Testing from 153 to 154 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1847716365009546 seconds.
#
# ===========================================================
# Testing from 154 to 155 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.1717912340536714 seconds.
#
# ===========================================================
# Testing from 155 to 156 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.076593577861786 seconds.
#
# ===========================================================
# Testing from 156 to 157 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2095844121649861 seconds.
#
# ===========================================================
# Testing from 157 to 158 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.4353950386866927 seconds.
#
# ===========================================================
# Testing from 158 to 159 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.2623787010088563 seconds.
#
# ===========================================================
# Testing from 159 to 160 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# ...
# KS tests calculation completed in 1.9423952689394355 seconds.
#
# ===========================================================
# Testing from 946 to 947 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7482161670923233 seconds.
#
# ===========================================================
# Testing from 947 to 948 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7379852822050452 seconds.
#
# ===========================================================
# Testing from 948 to 949 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7589210709556937 seconds.
#
# ===========================================================
# Testing from 949 to 950 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7525441581383348 seconds.
#
# ===========================================================
# Testing from 950 to 951 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.696451360359788 seconds.
#
# ===========================================================
# Testing from 951 to 952 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9231469444930553 seconds.
#
# ===========================================================
# Testing from 952 to 953 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8023790065199137 seconds.
#
# ===========================================================
# Testing from 953 to 954 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.744058328680694 seconds.
#
# ===========================================================
# Testing from 954 to 955 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7588973389938474 seconds.
#
# ===========================================================
# Testing from 955 to 956 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7331130178645253 seconds.
#
# ===========================================================
# Testing from 956 to 957 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7172557618469 seconds.
#
# ===========================================================
# Testing from 957 to 958 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8041708590462804 seconds.
#
# ===========================================================
# Testing from 958 to 959 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.850646018050611 seconds.
#
# ===========================================================
# Testing from 959 to 960 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7193477023392916 seconds.
#
# ===========================================================
# Testing from 960 to 961 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7330351192504168 seconds.
#
# ===========================================================
# Testing from 961 to 962 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.725868091918528 seconds.
#
# ===========================================================
# Testing from 962 to 963 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.710871258750558 seconds.
#
# ===========================================================
# Testing from 963 to 964 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.6698958100751042 seconds.
#
# ===========================================================
# Testing from 964 to 965 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8982333485037088 seconds.
#
# ===========================================================
# Testing from 965 to 966 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.6937950383871794 seconds.
#
# ===========================================================
# Testing from 966 to 967 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7174147181212902 seconds.
#
# ===========================================================
# Testing from 967 to 968 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.6975384829565883 seconds.
#
# ===========================================================
# Testing from 968 to 969 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7062200298532844 seconds.
#
# ===========================================================
# Testing from 969 to 970 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.680164858698845 seconds.
#
# ===========================================================
# Testing from 970 to 971 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7831482896581292 seconds.
#
# ===========================================================
# Testing from 971 to 972 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.773543680086732 seconds.
#
# ===========================================================
# Testing from 972 to 973 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7296389769762754 seconds.
#
# ===========================================================
# Testing from 973 to 974 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7036492340266705 seconds.
#
# ===========================================================
# Testing from 974 to 975 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7115569971501827 seconds.
#
# ===========================================================
# Testing from 975 to 976 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7240128125995398 seconds.
#
# ===========================================================
# Testing from 976 to 977 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.703750622458756 seconds.
#
# ===========================================================
# Testing from 977 to 978 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.78754570428282 seconds.
#
# ===========================================================
# Testing from 978 to 979 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.141403028741479 seconds.
#
# ===========================================================
# Testing from 979 to 980 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9497361108660698 seconds.
#
# ===========================================================
# Testing from 980 to 981 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8152006547898054 seconds.
#
# ===========================================================
# Testing from 981 to 982 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9886912163347006 seconds.
#
# ===========================================================
# Testing from 982 to 983 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8524991553276777 seconds.
#
# ===========================================================
# Testing from 983 to 984 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7893080553039908 seconds.
#
# ===========================================================
# Testing from 984 to 985 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.807230963371694 seconds.
#
# ===========================================================
# Testing from 985 to 986 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7939005037769675 seconds.
#
# ===========================================================
# Testing from 986 to 987 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7428414383903146 seconds.
#
# ===========================================================
# Testing from 987 to 988 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.913706679828465 seconds.
#
# ===========================================================
# Testing from 988 to 989 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8673026394098997 seconds.
#
# ===========================================================
# Testing from 989 to 990 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.767424768768251 seconds.
#
# ===========================================================
# Testing from 990 to 991 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7946938332170248 seconds.
#
# ===========================================================
# Testing from 991 to 992 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7972793746739626 seconds.
#
# ===========================================================
# Testing from 992 to 993 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7866420960053802 seconds.
#
# ===========================================================
# Testing from 993 to 994 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8413300877436996 seconds.
#
# ===========================================================
# Testing from 994 to 995 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9079818595200777 seconds.
#
# ===========================================================
# Testing from 995 to 996 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7991294097155333 seconds.
#
# ===========================================================
# Testing from 996 to 997 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7651110850274563 seconds.
#
# ===========================================================
# Testing from 997 to 998 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.769822172820568 seconds.
#
# ===========================================================
# Testing from 998 to 999 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7770477533340454 seconds.
#
# ===========================================================
# Testing from 999 to 1000 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.761961368843913 seconds.
# All done in: 1637.11 s.
# Saving ks to results_leo/particle_features_60/tests/50K_preprocessed/null_hypotheses/KS.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []
ndims = 180

for metric in list(metrics_config[unique_key].values())[2:3]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    print(len(dist_null))

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# 1000
# ThresholdS for metric ks: [[0.68, [680, 319], 0.9014081952287704], [0.95, [950, 50], 1.044571111304352], [0.99, [990, 10], 1.1555677534629605]]
# Computing time for metric ks: 1528.7581710144877
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 25000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fb5bc855760>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fb5bc854360>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fb5bc857420>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fb5bc8574c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fb5bc857560>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 1, 'batch_size_test': 50000, 'batch_...              8
# 1  {'niter': 1, 'batch_size_test': 50000, 'batch_...              1
# 2  {'niter': 1, 'batch_size_test': 50000, 'batch_...            360
# 3  {'niter': 1, 'batch_size_test': 50000, 'batch_...            800
# 4  {'niter': 1, 'batch_size_test': 50000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/50K_pre...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/50K_pre...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/50K_pre...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/50K_pre...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/50K_pre...
#
#                                           thresholds
# 0                                                NaN
# 1                                                NaN
# 2  [[0.68, [680, 319], 0.9014081952287704], [0.95...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[2:3]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Frequency', fontsize=16)
    ax[0].set_title('PDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.8613733505524943 +/- 0.0003289534177353389
# sigma = 0.101992256771801 +/- 0.002531593142256417
# 68%CL = 0.9014081952287704, 95%CL = 1.044571111304352, 99%CL = 1.1555677534629605
# mu = 0.8613733505524943 +/- 0.0003289534177353389
# sigma = 0.101992256771801 +/- 0.002531593142256417
# /tmp/ipykernel_1590281/3463214430.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1590281/3463214430.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1590281/3463214430.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1590281/3463214430.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 1.7808696795254946 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 25000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fb5bc855760>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fb5bc854360>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fb5bc857420>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fb5bc8574c0>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fb5bc857560>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 1, 'batch_size_test': 50000, 'batch_...              8
# 1  {'niter': 1, 'batch_size_test': 50000, 'batch_...              1
# 2  {'niter': 1, 'batch_size_test': 50000, 'batch_...            360
# 3  {'niter': 1, 'batch_size_test': 50000, 'batch_...            800
# 4  {'niter': 1, 'batch_size_test': 50000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/50K_pre...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/50K_pre...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/50K_pre...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/50K_pre...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/50K_pre...
#
#                                           thresholds  \
# 0                                                NaN
# 1                                                NaN
# 2  [[0.68, [680, 319], 0.9014081952287704], [0.95...
# 3                                                NaN
# 4                                                NaN
#
#                                          null_figure
# 0                                                NaN
# 1                                                NaN
# 2  results_leo/particle_features_60/tests/50K_pre...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ### Alternative hypothesis

# %% [markdown]
# #### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100, # this will be adapted to the boostrap size
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}

# %%
file_path = os.path.join(model_dir, "exclusion_limits.json")
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}
    
# Sort the dictionary by keys
existing_data = dict(sorted(existing_data.items()))

# Save the sorted dictionary back to a JSON file
with open(file_path, 'w') as f:
    json.dump(existing_data, f, cls=GMetrics.utils.CustomEncoder, indent=4) # type: ignore

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[2:3]:
    for deformation in deformations:
        eps_max = 1e-12
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection_dataset(dataset = dataset,
                                                             metric_config = metric_config,
                                                             test_kwargs = test_kwargs,
                                                             model_dir = model_dir,
                                                             deformation = deformation,
                                                             seed_dist = 0,
                                                             x_tol = 0.1,
                                                             fn_tol = 0.15,
                                                             bound = bound,
                                                             eps_min = 0.,
                                                             eps_max = eps_max,
                                                             smear = 0.,
                                                             max_iterations = 50,
                                                             save = True,
                                                             filename = "exclusion_limits.json",
                                                             verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Computing upper bounds for ks with mean deformation.
#
# ======================================================
# =============== ks - mean ===============
# ======================================================
# niter: 1, nbootstrap: 100
#
# ------------ 1 - 0.95 CL -  upper bound -----------
# eps = 5e-13 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8159558456391096 seconds.
#
# ===========================================================
# Testing from 1 to 2 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7900214893743396 seconds.
#
# ===========================================================
# Testing from 2 to 3 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8055569985881448 seconds.
#
# ===========================================================
# Testing from 3 to 4 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7816805923357606 seconds.
#
# ===========================================================
# Testing from 4 to 5 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.717541340738535 seconds.
#
# ===========================================================
# Testing from 5 to 6 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9501974815502763 seconds.
#
# ===========================================================
# Testing from 6 to 7 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.800158285535872 seconds.
#
# ===========================================================
# Testing from 7 to 8 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.795010513626039 seconds.
#
# ===========================================================
# Testing from 8 to 9 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7774678422138095 seconds.
#
# ===========================================================
# Testing from 9 to 10 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7941755158826709 seconds.
#
# ===========================================================
# Testing from 10 to 11 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7349079875275493 seconds.
#
# ===========================================================
# Testing from 11 to 12 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8991170907393098 seconds.
#
# ===========================================================
# Testing from 12 to 13 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8160427566617727 seconds.
#
# ===========================================================
# Testing from 13 to 14 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7921607419848442 seconds.
#
# ===========================================================
# Testing from 14 to 15 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.486844386905432 seconds.
#
# ===========================================================
# Testing from 15 to 16 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.177185418084264 seconds.
#
# ===========================================================
# Testing from 16 to 17 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.1588726099580526 seconds.
#
# ===========================================================
# Testing from 17 to 18 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.961314451880753 seconds.
#
# ===========================================================
# Testing from 18 to 19 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8916564332321286 seconds.
#
# ===========================================================
# Testing from 19 to 20 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8877966227009892 seconds.
#
# ===========================================================
# Testing from 20 to 21 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8531952435150743 seconds.
#
# ===========================================================
# Testing from 21 to 22 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9751264080405235 seconds.
#
# ===========================================================
# Testing from 22 to 23 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9330561943352222 seconds.
#
# ===========================================================
# Testing from 23 to 24 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8642711425200105 seconds.
#
# ===========================================================
# Testing from 24 to 25 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8567793127149343 seconds.
#
# ===========================================================
# Testing from 25 to 26 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8905010782182217 seconds.
#
# ===========================================================
# Testing from 26 to 27 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.819665726274252 seconds.
#
# ===========================================================
# Testing from 27 to 28 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0029411651194096 seconds.
#
# ===========================================================
# Testing from 28 to 29 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9075813591480255 seconds.
#
# ===========================================================
# Testing from 29 to 30 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8432829594239593 seconds.
#
# ===========================================================
# Testing from 30 to 31 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8790681716054678 seconds.
#
# ===========================================================
# Testing from 31 to 32 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.84806511644274 seconds.
#
# ===========================================================
# Testing from 32 to 33 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8065492352470756 seconds.
#
# ===========================================================
# Testing from 33 to 34 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9675119630992413 seconds.
#
# ===========================================================
# Testing from 34 to 35 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8693805458024144 seconds.
#
# ===========================================================
# Testing from 35 to 36 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8531272178515792 seconds.
#
# ===========================================================
# Testing from 36 to 37 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8329367386177182 seconds.
#
# ===========================================================
# Testing from 37 to 38 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8468597726896405 seconds.
#
# ===========================================================
# Testing from 38 to 39 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7777810469269753 seconds.
#
# ===========================================================
# Testing from 39 to 40 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9511060090735555 seconds.
#
# ===========================================================
# Testing from 40 to 41 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8563532587140799 seconds.
#
# ===========================================================
# Testing from 41 to 42 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8213548995554447 seconds.
#
# ===========================================================
# Testing from 42 to 43 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8195321587845683 seconds.
#
# ===========================================================
# Testing from 43 to 44 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8267177063971758 seconds.
#
# ===========================================================
# Testing from 44 to 45 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7787863435223699 seconds.
#
# ===========================================================
# Testing from 45 to 46 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9038861095905304 seconds.
#
# ===========================================================
# Testing from 46 to 47 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8850608794018626 seconds.
#
# ===========================================================
# Testing from 47 to 48 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8145136591047049 seconds.
#
# ===========================================================
# Testing from 48 to 49 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8000306189060211 seconds.
#
# ===========================================================
# Testing from 49 to 50 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8299937257543206 seconds.
#
# ===========================================================
# Testing from 50 to 51 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7884256886318326 seconds.
#
# ===========================================================
# Testing from 51 to 52 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8902431260794401 seconds.
#
# ===========================================================
# Testing from 52 to 53 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9034252669662237 seconds.
#
# ===========================================================
# Testing from 53 to 54 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8115068785846233 seconds.
#
# ===========================================================
# Testing from 54 to 55 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8261926220729947 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8163391463458538 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.803320126608014 seconds.
#
# ===========================================================
# Testing from 57 to 58 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 5.359406495466828 seconds.
#
# ===========================================================
# Testing from 58 to 59 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.218351465649903 seconds.
#
# ===========================================================
# Testing from 59 to 60 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0699080917984247 seconds.
#
# ===========================================================
# Testing from 60 to 61 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9229794731363654 seconds.
#
# ===========================================================
# Testing from 61 to 62 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0870416928082705 seconds.
#
# ===========================================================
# Testing from 62 to 63 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9713427145034075 seconds.
#
# ===========================================================
# Testing from 63 to 64 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8997801458463073 seconds.
#
# ===========================================================
# Testing from 64 to 65 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8981095207855105 seconds.
#
# ===========================================================
# Testing from 65 to 66 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8899087086319923 seconds.
#
# ===========================================================
# Testing from 66 to 67 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8499814188107848 seconds.
#
# ===========================================================
# Testing from 67 to 68 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9980345712974668 seconds.
#
# ===========================================================
# Testing from 68 to 69 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9356366768479347 seconds.
#
# ===========================================================
# Testing from 69 to 70 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9005976701155305 seconds.
#
# ===========================================================
# Testing from 70 to 71 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8723442675545812 seconds.
#
# ===========================================================
# Testing from 71 to 72 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9052706751972437 seconds.
#
# ===========================================================
# Testing from 72 to 73 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8234244426712394 seconds.
#
# ===========================================================
# Testing from 73 to 74 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9976303605362773 seconds.
#
# ===========================================================
# Testing from 74 to 75 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9248217213898897 seconds.
#
# ===========================================================
# Testing from 75 to 76 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8800209891051054 seconds.
#
# ===========================================================
# Testing from 76 to 77 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9052503379061818 seconds.
#
# ===========================================================
# Testing from 77 to 78 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8699843809008598 seconds.
#
# ===========================================================
# Testing from 78 to 79 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8250594940036535 seconds.
#
# ===========================================================
# Testing from 79 to 80 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9917579675093293 seconds.
#
# ===========================================================
# Testing from 80 to 81 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.897382534109056 seconds.
#
# ===========================================================
# Testing from 81 to 82 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8619931945577264 seconds.
#
# ===========================================================
# Testing from 82 to 83 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8461241722106934 seconds.
#
# ===========================================================
# Testing from 83 to 84 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.842753586359322 seconds.
#
# ===========================================================
# Testing from 84 to 85 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.803911380469799 seconds.
#
# ===========================================================
# Testing from 85 to 86 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.992427395656705 seconds.
#
# ===========================================================
# Testing from 86 to 87 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.884825563058257 seconds.
#
# ===========================================================
# Testing from 87 to 88 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8418925665318966 seconds.
#
# ===========================================================
# Testing from 88 to 89 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8486404083669186 seconds.
#
# ===========================================================
# Testing from 89 to 90 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.849673641845584 seconds.
#
# ===========================================================
# Testing from 90 to 91 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7898854352533817 seconds.
#
# ===========================================================
# Testing from 91 to 92 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9667987180873752 seconds.
#
# ===========================================================
# Testing from 92 to 93 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8695821268483996 seconds.
#
# ===========================================================
# Testing from 93 to 94 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8350214576348662 seconds.
#
# ===========================================================
# Testing from 94 to 95 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8394371159374714 seconds.
#
# ===========================================================
# Testing from 95 to 96 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8511798763647676 seconds.
#
# ===========================================================
# Testing from 96 to 97 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.7805738234892488 seconds.
#
# ===========================================================
# Testing from 97 to 98 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9822081178426743 seconds.
#
# ===========================================================
# Testing from 98 to 99 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8675259500741959 seconds.
#
# ===========================================================
# Testing from 99 to 100 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.842534645460546 seconds.
# statistic = 10.12098107331619 - next threshold = 1.044571111304352 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6257879255651515
#
# ------------ 2 - 0.95 CL -  upper bound -----------
# eps = 2.5e-13 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8508491050451994 seconds.
#
# ===========================================================
# Testing from 1 to 2 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 5.055722065269947 seconds.
#
# ===========================================================
# Testing from 2 to 3 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.3399967113509774 seconds.
#
# ===========================================================
# Testing from 3 to 4 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.1851090816780925 seconds.
#
# ===========================================================
# Testing from 4 to 5 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.017303816974163 seconds.
#
# ===========================================================
# Testing from 5 to 6 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9818471791222692 seconds.
#
# ===========================================================
# Testing from 6 to 7 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9681450184434652 seconds.
#
# ===========================================================
# Testing from 7 to 8 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0440623573958874 seconds.
#
# ===========================================================
# Testing from 8 to 9 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9510683752596378 seconds.
#
# ===========================================================
# Testing from 9 to 10 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9105940461158752 seconds.
#
# ===========================================================
# Testing from 10 to 11 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9408703614026308 seconds.
#
# ===========================================================
# Testing from 11 to 12 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8984081838279963 seconds.
#
# ===========================================================
# Testing from 12 to 13 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0063309259712696 seconds.
#
# ===========================================================
# Testing from 13 to 14 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9747010134160519 seconds.
#
# ===========================================================
# Testing from 14 to 15 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8966317418962717 seconds.
#
# ===========================================================
# Testing from 15 to 16 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.927132016979158 seconds.
#
# ===========================================================
# Testing from 16 to 17 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.947759823873639 seconds.
#
# ===========================================================
# Testing from 17 to 18 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8521491410210729 seconds.
#
# ===========================================================
# Testing from 18 to 19 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0845070956274867 seconds.
#
# ===========================================================
# Testing from 19 to 20 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.949773257598281 seconds.
#
# ===========================================================
# Testing from 20 to 21 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9155390113592148 seconds.
#
# ===========================================================
# Testing from 21 to 22 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.927771432325244 seconds.
#
# ===========================================================
# Testing from 22 to 23 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9129797322675586 seconds.
#
# ===========================================================
# Testing from 23 to 24 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8536473689600825 seconds.
#
# ===========================================================
# Testing from 24 to 25 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0725402291864157 seconds.
#
# ===========================================================
# Testing from 25 to 26 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9089557053521276 seconds.
#
# ===========================================================
# Testing from 26 to 27 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.887221397832036 seconds.
#
# ===========================================================
# Testing from 27 to 28 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8685397831723094 seconds.
#
# ===========================================================
# Testing from 28 to 29 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.903917022049427 seconds.
#
# ===========================================================
# Testing from 29 to 30 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.819821291603148 seconds.
#
# ===========================================================
# Testing from 30 to 31 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.029845641925931 seconds.
#
# ===========================================================
# Testing from 31 to 32 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8956457618623972 seconds.
#
# ===========================================================
# Testing from 32 to 33 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8869913667440414 seconds.
#
# ===========================================================
# Testing from 33 to 34 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.876920921728015 seconds.
#
# ===========================================================
# Testing from 34 to 35 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8898571329191327 seconds.
#
# ===========================================================
# Testing from 35 to 36 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8151310300454497 seconds.
#
# ===========================================================
# Testing from 36 to 37 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.032020757906139 seconds.
#
# ===========================================================
# Testing from 37 to 38 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8635642873123288 seconds.
#
# ===========================================================
# Testing from 38 to 39 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8704071016982198 seconds.
#
# ===========================================================
# Testing from 39 to 40 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.865085401572287 seconds.
#
# ===========================================================
# Testing from 40 to 41 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8752716174349189 seconds.
#
# ===========================================================
# Testing from 41 to 42 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8259949032217264 seconds.
#
# ===========================================================
# Testing from 42 to 43 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9979748036712408 seconds.
#
# ===========================================================
# Testing from 43 to 44 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8806951688602567 seconds.
#
# ===========================================================
# Testing from 44 to 45 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.865166064351797 seconds.
#
# ===========================================================
# Testing from 45 to 46 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.8598386701196432 seconds.
#
# ===========================================================
# Testing from 46 to 47 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.880621712654829 seconds.
#
# ===========================================================
# Testing from 47 to 48 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 5.284126542508602 seconds.
#
# ===========================================================
# Testing from 48 to 49 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.3204889809712768 seconds.
#
# ===========================================================
# Testing from 49 to 50 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.1673223888501525 seconds.
#
# ===========================================================
# Testing from 50 to 51 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0598900308832526 seconds.
#
# ===========================================================
# Testing from 51 to 52 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.1241300301626325 seconds.
#
# ===========================================================
# Testing from 52 to 53 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.0763723673298955 seconds.
#
# ===========================================================
# Testing from 53 to 54 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9690883243456483 seconds.
#
# ===========================================================
# Testing from 54 to 55 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9674962256103754 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9368742825463414 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.900529384613037 seconds.
#
# ===========================================================
# Testing from 57 to 58 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 2.092929445207119 seconds.
#
# ===========================================================
# Testing from 58 to 59 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.952812978066504 seconds.
#
# ===========================================================
# Testing from 59 to 60 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.967992352321744 seconds.
#
# ===========================================================
# Testing from 60 to 61 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.9538172697648406 seconds.
#
# ===========================================================
# Testing from 61 to 62 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 1.936559485271573 seconds.
#
# ===========================================================
# Testing from 62 to 63 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# ...
# Testing from 54 to 55 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.799883044324815 seconds.
#
# ===========================================================
# Testing from 55 to 56 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.790047354996204 seconds.
#
# ===========================================================
# Testing from 56 to 57 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.8244754346087575 seconds.
#
# ===========================================================
# Testing from 57 to 58 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.694058608263731 seconds.
#
# ===========================================================
# Testing from 58 to 59 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.691134641878307 seconds.
#
# ===========================================================
# Testing from 59 to 60 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.7878789603710175 seconds.
#
# ===========================================================
# Testing from 60 to 61 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.690530641004443 seconds.
#
# ===========================================================
# Testing from 61 to 62 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.86812577303499 seconds.
#
# ===========================================================
# Testing from 62 to 63 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.731958561576903 seconds.
#
# ===========================================================
# Testing from 63 to 64 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.669695190154016 seconds.
#
# ===========================================================
# Testing from 64 to 65 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.839905055239797 seconds.
#
# ===========================================================
# Testing from 65 to 66 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.708640933036804 seconds.
#
# ===========================================================
# Testing from 66 to 67 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.804824943654239 seconds.
#
# ===========================================================
# Testing from 67 to 68 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.7457959009334445 seconds.
#
# ===========================================================
# Testing from 68 to 69 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.742045063525438 seconds.
#
# ===========================================================
# Testing from 69 to 70 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.789884313009679 seconds.
#
# ===========================================================
# Testing from 70 to 71 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.686687651090324 seconds.
#
# ===========================================================
# Testing from 71 to 72 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.766178973950446 seconds.
#
# ===========================================================
# Testing from 72 to 73 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.702320987358689 seconds.
#
# ===========================================================
# Testing from 73 to 74 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.779402825050056 seconds.
#
# ===========================================================
# Testing from 74 to 75 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.737442422658205 seconds.
#
# ===========================================================
# Testing from 75 to 76 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.6657502530142665 seconds.
#
# ===========================================================
# Testing from 76 to 77 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.7548018749803305 seconds.
#
# ===========================================================
# Testing from 77 to 78 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.714680905453861 seconds.
#
# ===========================================================
# Testing from 78 to 79 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.816963380202651 seconds.
#
# ===========================================================
# Testing from 79 to 80 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.718185659497976 seconds.
#
# ===========================================================
# Testing from 80 to 81 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.653905577026308 seconds.
#
# ===========================================================
# Testing from 81 to 82 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.774844999425113 seconds.
#
# ===========================================================
# Testing from 82 to 83 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.706407385878265 seconds.
#
# ===========================================================
# Testing from 83 to 84 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.831311323679984 seconds.
#
# ===========================================================
# Testing from 84 to 85 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.742658590897918 seconds.
#
# ===========================================================
# Testing from 85 to 86 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.666996139101684 seconds.
#
# ===========================================================
# Testing from 86 to 87 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.812959739007056 seconds.
#
# ===========================================================
# Testing from 87 to 88 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.692077803425491 seconds.
#
# ===========================================================
# Testing from 88 to 89 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.840062789618969 seconds.
#
# ===========================================================
# Testing from 89 to 90 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.685844023711979 seconds.
#
# ===========================================================
# Testing from 90 to 91 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.687286052852869 seconds.
#
# ===========================================================
# Testing from 91 to 92 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.813918922096491 seconds.
#
# ===========================================================
# Testing from 92 to 93 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.714260629378259 seconds.
#
# ===========================================================
# Testing from 93 to 94 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.766274267807603 seconds.
#
# ===========================================================
# Testing from 94 to 95 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.720443251542747 seconds.
#
# ===========================================================
# Testing from 95 to 96 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.765642239712179 seconds.
#
# ===========================================================
# Testing from 96 to 97 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.787834961898625 seconds.
#
# ===========================================================
# Testing from 97 to 98 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.692637969739735 seconds.
#
# ===========================================================
# Testing from 98 to 99 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.7664492428302765 seconds.
#
# ===========================================================
# Testing from 99 to 100 of 100 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 1
# batch_size = 50000
# KS tests calculation completed in 4.680274186655879 seconds.
# statistic = 1.9446751260806225 - next threshold = 1.044571111304352 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 0.6022280824638196
# Time elapsed: 17855.55634849053 seconds.
# Saving results in the file results_leo/particle_features_60/tests/50K_preprocessed/exclusion_limits.json
# Computing central bounds for ks with mean deformation.
#
# ======================================================
# =============== ks - mean ===============
# ======================================================
# niter: 1, nbootstrap: 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 15
#      13 if result == {}:
#      14     print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
# ---> 15     result = compute_exclusion_bisection_dataset(dataset = dataset,
#      16                                                  metric_config = metric_config,
#      17                                                  test_kwargs = test_kwargs,
#      18                                                  model_dir = model_dir,
#      19                                                  deformation = deformation,
#      20                                                  seed_dist = 0,
#      21                                                  x_tol = 0.1,
#      22                                                  fn_tol = 0.15,
#      23                                                  bound = bound,
#      24                                                  eps_min = 0.,
#      25                                                  eps_max = eps_max,
#      26                                                  smear = 0.,
#      27                                                  max_iterations = 50,
#      28                                                  save = True,
#      29                                                  filename = "exclusion_limits.json",
#      30                                                  verbose = True)
#      31     eps_max = list(result.values())[0]["exclusion_list"][-1][3]
#      32 else:
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics/GMetrics/more/optimizers_deformations.py:299, in compute_exclusion_bisection_dataset(dataset, metric_config, test_kwargs, model_dir, deformation, seed_dist, x_tol, fn_tol, bound, eps_min, eps_max, smear, max_iterations, save, filename, verbose)
#     297 eps_min_start = eps_min
#     298 eps_max_start = eps_max
# --> 299 eps = (eps_max + eps_min) / 2.
#     300 eps_min, eps_max = eps_min_start, eps_max_start # Initialize the bounds
#     301 sigma_factor = smear
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'float'

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd

# %%
results
# Out:
# [['fgd', 'mean', 90, 4, 20000, 'upper', 0.09497, 0.12579, 3185],
#  ['fgd', 'mean', 90, 4, 20000, 'central', 0.07248, 0.10622, 1995],
#  ['fgd', 'mean', 90, 4, 20000, 'lower', 0.03975, 0.08519, 2530],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'upper', 0.09378, 0.11369, 3337],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'central', 0.06284, 0.09005, 2139],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'lower', 0.0358, 0.06854, 3078],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.02887, 0.03966, 3493],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'central', 0.02316, 0.03515, 2017],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.01617, 0.03007, 2423],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'upper', 0.05859, 0.07327, 4420],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'central', 0.03599, 0.04934, 2684],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'lower', 0.01961, 0.03581, 4978],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06534, 0.08171, 4175],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'central', 0.03699, 0.05511, 2697],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'lower', 0.01878, 0.03787, 2431],
#  ['fgd', 'random_normal', 90, 4, 20000, 'upper', 0.22046, 0.25357, 2974],
#  ['fgd', 'random_normal', 90, 4, 20000, 'central', 0.18671, 0.22667, 2163],
#  ['fgd', 'random_normal', 90, 4, 20000, 'lower', 0.14676, 0.19531, 2979],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'upper', 0.39066, 0.44782, 3786],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'central', 0.32909, 0.39263, 2434],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'lower', 0.26571, 0.3428, 2437],
#  ['mmd', 'mean', 90, 4, 20000, 'upper', 0.38566, 0.47565, 2441],
#  ['mmd', 'mean', 90, 4, 20000, 'central', 0.22947, 0.32659, 1654],
#  ['mmd', 'mean', 90, 4, 20000, 'lower', 0.12215, 0.21559, 1874],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'upper', 0.17969, 0.21734, 3476],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'central', 0.11334, 0.15031, 2189],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'lower', 0.06416, 0.09461, 3208],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.21143, 0.27996, 2932],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'central', 0.16131, 0.23825, 2312],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.11084, 0.18291, 1821],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'upper', 0.05414, 0.06147, 2735],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'central', 0.03206, 0.04228, 1756],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'lower', 0.01805, 0.02662, 5319],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06255, 0.07513, 3618],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'central', 0.0336, 0.04991, 2407],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'lower', 0.01711, 0.0303, 2515],
#  ['mmd', 'random_normal', 90, 4, 20000, 'upper', 0.54736, 0.59157, 2782],
#  ['mmd', 'random_normal', 90, 4, 20000, 'central', 0.40194, 0.50268, 5573],
#  ['mmd', 'random_normal', 90, 4, 20000, 'lower', 0.32453, 0.38821, 4008],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'upper', 0.92578, 1.0, 6652],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'central', 0.68726, 0.87417, 3735],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'lower', 0.48549, 0.66939, 5109],
#  ['ks', 'mean', 90, 4, 20000, 'upper', 0.01556, 0.02106, 870],
#  ['ks', 'mean', 90, 4, 20000, 'central', 0.00983, 0.01725, 697],
#  ['ks', 'mean', 90, 4, 20000, 'lower', 0.00216, 0.01212, 907],
#  ['ks', 'cov_diag', 90, 4, 20000, 'upper', 0.03992, 0.05452, 1275],
#  ['ks', 'cov_diag', 90, 4, 20000, 'central', 0.02545, 0.03987, 1038],
#  ['ks', 'cov_diag', 90, 4, 20000, 'lower', 0.00535, 0.02814, 1272],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'upper', 0.05786, 0.07362, 1643],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'central', 0.04069, 0.0569, 1280],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'lower', 0.01406, 0.04636, 1540],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'upper', 0.02649, 0.0377, 2225],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'central', 0.01613, 0.02649, 1668],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'lower', 0.00332, 0.01785, 2094],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'upper', 0.02625, 0.03515, 2699],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'central', 0.01641, 0.02571, 1988],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'lower', 0.00343, 0.01848, 2364],
#  ['ks', 'random_normal', 90, 4, 20000, 'upper', 0.11182, 0.12812, 2605],
#  ['ks', 'random_normal', 90, 4, 20000, 'central', 0.09133, 0.11404, 2153],
#  ['ks', 'random_normal', 90, 4, 20000, 'lower', 0.06526, 0.08927, 2219],
#  ['ks', 'random_uniform', 90, 4, 20000, 'upper', 0.18799, 0.21785, 2787],
#  ['ks', 'random_uniform', 90, 4, 20000, 'central', 0.1553, 0.18609, 2386],
#  ['ks', 'random_uniform', 90, 4, 20000, 'lower', 0.11812, 0.15157, 2508],
#  ['sks', 'mean', 90, 4, 20000, 'upper', 0.03406, 0.04532, 5082],
#  ['sks', 'mean', 90, 4, 20000, 'central', 0.02647, 0.03781, 3461],
#  ['sks', 'mean', 90, 4, 20000, 'lower', 0.01532, 0.03034, 4020],
#  ['sks', 'cov_diag', 90, 4, 20000, 'upper', 0.05493, 0.06906, 5153],
#  ['sks', 'cov_diag', 90, 4, 20000, 'central', 0.04033, 0.05582, 3767],
#  ['sks', 'cov_diag', 90, 4, 20000, 'lower', 0.02605, 0.04593, 4130],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'upper', 0.04724, 0.06382, 5840],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'central', 0.03578, 0.05309, 4064],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'lower', 0.02151, 0.0431, 4766],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'upper', 0.08203, 0.11142, 1146],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'central', 0.06093, 0.08302, 815],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'lower', 0.03502, 0.06202, 856],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'upper', 0.08203, 0.09836, 1348],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'central', 0.05686, 0.0802, 972],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'lower', 0.03133, 0.05424, 1139],
#  ['sks', 'random_normal', 90, 4, 20000, 'upper', 0.12109, 0.13885, 1409],
#  ['sks', 'random_normal', 90, 4, 20000, 'central', 0.10848, 0.13506, 834],
#  ['sks', 'random_normal', 90, 4, 20000, 'lower', 0.08863, 0.11765, 845],
#  ['sks', 'random_uniform', 90, 4, 20000, 'upper', 0.21094, 0.23804, 1257],
#  ['sks', 'random_uniform', 90, 4, 20000, 'central', 0.18597, 0.23153, 901],
#  ['sks', 'random_uniform', 90, 4, 20000, 'lower', 0.15194, 0.20168, 904],
#  ['swd', 'mean', 90, 4, 20000, 'upper', 0.05664, 0.07396, 453],
#  ['swd', 'mean', 90, 4, 20000, 'central', 0.03814, 0.06276, 301],
#  ['swd', 'mean', 90, 4, 20000, 'lower', 0.02059, 0.043, 332],
#  ['swd', 'cov_diag', 90, 4, 20000, 'upper', 0.06445, 0.08147, 443],
#  ['swd', 'cov_diag', 90, 4, 20000, 'central', 0.04455, 0.06532, 304],
#  ['swd', 'cov_diag', 90, 4, 20000, 'lower', 0.02551, 0.04915, 323],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.06055, 0.08458, 481],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'central', 0.04625, 0.0726, 307],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.02836, 0.05878, 284],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'upper', 0.06055, 0.07771, 465],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'central', 0.0425, 0.0535, 294],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'lower', 0.0209, 0.04026, 316],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06055, 0.07771, 455],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'central', 0.04493, 0.05927, 299],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'lower', 0.0213, 0.04622, 321],
#  ['swd', 'random_normal', 90, 4, 20000, 'upper', 0.16406, 0.19031, 357],
#  ['swd', 'random_normal', 90, 4, 20000, 'central', 0.13678, 0.17024, 230],
#  ['swd', 'random_normal', 90, 4, 20000, 'lower', 0.11172, 0.14829, 224],
#  ['swd', 'random_uniform', 90, 4, 20000, 'upper', 0.28906, 0.32861, 284],
#  ['swd', 'random_uniform', 90, 4, 20000, 'central', 0.23619, 0.29395, 228],
#  ['swd', 'random_uniform', 90, 4, 20000, 'lower', 0.19291, 0.25606, 229]]

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_3533038/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 9         ks        mean   90      4                20000
# 23       sks        mean   90      4                20000
# 30       swd        mean   90      4                20000
# 2        fgd        mean   90      4                20000
# 16       mmd        mean   90      4                20000
#
#    $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 9       $0.00983_{-0.0077}^{+0.0057}$      $0.01725_{-0.0051}^{+0.0038}$
# 23       $0.02647_{-0.011}^{+0.0076}$      $0.03781_{-0.0075}^{+0.0075}$
# 30        $0.03814_{-0.018}^{+0.019}$         $0.06276_{-0.02}^{+0.011}$
# 2         $0.07248_{-0.033}^{+0.022}$         $0.10622_{-0.021}^{+0.02}$
# 16          $0.22947_{-0.11}^{+0.16}$          $0.32659_{-0.11}^{+0.15}$
#
#     $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 9            2474  [0.00216, 0.00983, 0.01556]  [0.01212, 0.01725, 0.02106]
# 23          12563  [0.01532, 0.02647, 0.03406]  [0.03034, 0.03781, 0.04532]
# 30           1086  [0.02059, 0.03814, 0.05664]    [0.043, 0.06276, 0.07396]
# 2            7710  [0.03975, 0.07248, 0.09497]  [0.08519, 0.10622, 0.12579]
# 16           5969  [0.12215, 0.22947, 0.38566]  [0.21559, 0.32659, 0.47565]
#
#                   time
# 9      [870, 697, 907]
# 23  [5082, 3461, 4020]
# 30     [453, 301, 332]
# 2   [3185, 1995, 2530]
# 16  [2441, 1654, 1874]
#    Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 9         ks      $0.00983_{-0.0077}^{+0.0057}$
# 23       sks       $0.02647_{-0.011}^{+0.0076}$
# 30       swd        $0.03814_{-0.018}^{+0.019}$
# 2        fgd        $0.07248_{-0.033}^{+0.022}$
# 16       mmd          $0.22947_{-0.11}^{+0.16}$
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 9       $0.01725_{-0.0051}^{+0.0038}$           2474
# 23      $0.03781_{-0.0075}^{+0.0075}$          12563
# 30         $0.06276_{-0.02}^{+0.011}$           1086
# 2          $0.10622_{-0.021}^{+0.02}$           7710
# 16          $0.32659_{-0.11}^{+0.15}$           5969

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_3533038/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 7         ks    cov_diag   90      4                20000
# 21       sks    cov_diag   90      4                20000
# 28       swd    cov_diag   90      4                20000
# 0        fgd    cov_diag   90      4                20000
# 14       mmd    cov_diag   90      4                20000
#
#    $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7                  $0.02545_{-0.02}^{+0.014}$
# 21                $0.04033_{-0.014}^{+0.015}$
# 28                 $0.04455_{-0.019}^{+0.02}$
# 0                 $0.06284_{-0.027}^{+0.031}$
# 14                $0.11334_{-0.049}^{+0.066}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 7                 $0.03987_{-0.012}^{+0.015}$                   3585
# 21               $0.05582_{-0.0099}^{+0.013}$                  13050
# 28                $0.06532_{-0.016}^{+0.016}$                   1070
# 0                 $0.09005_{-0.022}^{+0.024}$                   8554
# 14                $0.15031_{-0.056}^{+0.067}$                   8873
#
#                           95%CL                        99%CL  \
# 7   [0.00535, 0.02545, 0.03992]  [0.02814, 0.03987, 0.05452]
# 21  [0.02605, 0.04033, 0.05493]  [0.04593, 0.05582, 0.06906]
# 28  [0.02551, 0.04455, 0.06445]  [0.04915, 0.06532, 0.08147]
# 0    [0.0358, 0.06284, 0.09378]  [0.06854, 0.09005, 0.11369]
# 14  [0.06416, 0.11334, 0.17969]  [0.09461, 0.15031, 0.21734]
#
#                   time
# 7   [1275, 1038, 1272]
# 21  [5153, 3767, 4130]
# 28     [443, 304, 323]
# 0   [3337, 2139, 3078]
# 14  [3476, 2189, 3208]
#    Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7         ks                 $0.02545_{-0.02}^{+0.014}$
# 21       sks                $0.04033_{-0.014}^{+0.015}$
# 28       swd                 $0.04455_{-0.019}^{+0.02}$
# 0        fgd                $0.06284_{-0.027}^{+0.031}$
# 14       mmd                $0.11334_{-0.049}^{+0.066}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 7                 $0.03987_{-0.012}^{+0.015}$                   3585
# 21               $0.05582_{-0.0099}^{+0.013}$                  13050
# 28                $0.06532_{-0.016}^{+0.016}$                   1070
# 0                 $0.09005_{-0.022}^{+0.024}$                   8554
# 14                $0.15031_{-0.056}^{+0.067}$                   8873

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_3533038/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 1        fgd  cov_off_diag   90      4                20000
# 22       sks  cov_off_diag   90      4                20000
# 8         ks  cov_off_diag   90      4                20000
# 29       swd  cov_off_diag   90      4                20000
# 15       mmd  cov_off_diag   90      4                20000
#
#    $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 1                     $0.02316_{-0.007}^{+0.0057}$
# 22                     $0.03578_{-0.014}^{+0.011}$
# 8                      $0.04069_{-0.027}^{+0.017}$
# 29                     $0.04625_{-0.018}^{+0.014}$
# 15                       $0.16131_{-0.05}^{+0.05}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 1                    $0.03515_{-0.0051}^{+0.0045}$
# 22                      $0.05309_{-0.01}^{+0.011}$
# 8                       $0.0569_{-0.011}^{+0.017}$
# 29                      $0.0726_{-0.014}^{+0.012}$
# 15                     $0.23825_{-0.055}^{+0.042}$
#
#     $t^{\Sigma_{i\neq j}}$ (s)                        95%CL  \
# 1                         7933  [0.01617, 0.02316, 0.02887]
# 22                       14670  [0.02151, 0.03578, 0.04724]
# 8                         4463  [0.01406, 0.04069, 0.05786]
# 29                        1072  [0.02836, 0.04625, 0.06055]
# 15                        7065  [0.11084, 0.16131, 0.21143]
#
#                           99%CL                time
# 1   [0.03007, 0.03515, 0.03966]  [3493, 2017, 2423]
# 22   [0.0431, 0.05309, 0.06382]  [5840, 4064, 4766]
# 8    [0.04636, 0.0569, 0.07362]  [1643, 1280, 1540]
# 29   [0.05878, 0.0726, 0.08458]     [481, 307, 284]
# 15  [0.18291, 0.23825, 0.27996]  [2932, 2312, 1821]
#    Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 1        fgd                    $0.02316_{-0.007}^{+0.0057}$
# 22       sks                     $0.03578_{-0.014}^{+0.011}$
# 8         ks                     $0.04069_{-0.027}^{+0.017}$
# 29       swd                     $0.04625_{-0.018}^{+0.014}$
# 15       mmd                       $0.16131_{-0.05}^{+0.05}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 1                    $0.03515_{-0.0051}^{+0.0045}$                        7933
# 22                      $0.05309_{-0.01}^{+0.011}$                       14670
# 8                       $0.0569_{-0.011}^{+0.017}$                        4463
# 29                      $0.0726_{-0.014}^{+0.012}$                        1072
# 15                     $0.23825_{-0.055}^{+0.042}$                        7065

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_3533038/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 11        ks  power_abs_up   90      4                20000
# 18       mmd  power_abs_up   90      4                20000
# 4        fgd  power_abs_up   90      4                20000
# 32       swd  power_abs_up   90      4                20000
# 25       sks  power_abs_up   90      4                20000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11                  $0.01613_{-0.013}^{+0.01}$
# 18                 $0.03206_{-0.014}^{+0.022}$
# 4                  $0.03599_{-0.016}^{+0.023}$
# 32                  $0.0425_{-0.022}^{+0.018}$
# 25                 $0.06093_{-0.026}^{+0.021}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 11                $0.02649_{-0.0086}^{+0.011}$                    5987
# 18                 $0.04228_{-0.016}^{+0.019}$                    9810
# 4                  $0.04934_{-0.014}^{+0.024}$                   12082
# 32                  $0.0535_{-0.013}^{+0.024}$                    1075
# 25                 $0.08302_{-0.021}^{+0.028}$                    2817
#
#                           95%CL                        99%CL  \
# 11  [0.00332, 0.01613, 0.02649]   [0.01785, 0.02649, 0.0377]
# 18  [0.01805, 0.03206, 0.05414]  [0.02662, 0.04228, 0.06147]
# 4   [0.01961, 0.03599, 0.05859]  [0.03581, 0.04934, 0.07327]
# 32    [0.0209, 0.0425, 0.06055]   [0.04026, 0.0535, 0.07771]
# 25  [0.03502, 0.06093, 0.08203]  [0.06202, 0.08302, 0.11142]
#
#                   time
# 11  [2225, 1668, 2094]
# 18  [2735, 1756, 5319]
# 4   [4420, 2684, 4978]
# 32     [465, 294, 316]
# 25    [1146, 815, 856]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11        ks                  $0.01613_{-0.013}^{+0.01}$
# 18       mmd                 $0.03206_{-0.014}^{+0.022}$
# 4        fgd                 $0.03599_{-0.016}^{+0.023}$
# 32       swd                  $0.0425_{-0.022}^{+0.018}$
# 25       sks                 $0.06093_{-0.026}^{+0.021}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 11                $0.02649_{-0.0086}^{+0.011}$                    5987
# 18                 $0.04228_{-0.016}^{+0.019}$                    9810
# 4                  $0.04934_{-0.014}^{+0.024}$                   12082
# 32                  $0.0535_{-0.013}^{+0.024}$                    1075
# 25                 $0.08302_{-0.021}^{+0.028}$                    2817

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_3533038/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 10        ks  power_abs_down   90      4                20000
# 17       mmd  power_abs_down   90      4                20000
# 3        fgd  power_abs_down   90      4                20000
# 31       swd  power_abs_down   90      4                20000
# 24       sks  power_abs_down   90      4                20000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10                $0.01641_{-0.013}^{+0.0098}$
# 17                  $0.0336_{-0.016}^{+0.029}$
# 3                  $0.03699_{-0.018}^{+0.028}$
# 31                 $0.04493_{-0.024}^{+0.016}$
# 24                 $0.05686_{-0.026}^{+0.025}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 10               $0.02571_{-0.0072}^{+0.0094}$                    7051
# 17                  $0.04991_{-0.02}^{+0.025}$                    8540
# 3                  $0.05511_{-0.017}^{+0.027}$                    9303
# 31                 $0.05927_{-0.013}^{+0.018}$                    1075
# 24                  $0.0802_{-0.026}^{+0.018}$                    3459
#
#                           95%CL                        99%CL  \
# 10  [0.00343, 0.01641, 0.02625]  [0.01848, 0.02571, 0.03515]
# 17   [0.01711, 0.0336, 0.06255]   [0.0303, 0.04991, 0.07513]
# 3   [0.01878, 0.03699, 0.06534]  [0.03787, 0.05511, 0.08171]
# 31   [0.0213, 0.04493, 0.06055]  [0.04622, 0.05927, 0.07771]
# 24  [0.03133, 0.05686, 0.08203]   [0.05424, 0.0802, 0.09836]
#
#                   time
# 10  [2699, 1988, 2364]
# 17  [3618, 2407, 2515]
# 3   [4175, 2697, 2431]
# 31     [455, 299, 321]
# 24   [1348, 972, 1139]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10        ks                $0.01641_{-0.013}^{+0.0098}$
# 17       mmd                  $0.0336_{-0.016}^{+0.029}$
# 3        fgd                 $0.03699_{-0.018}^{+0.028}$
# 31       swd                 $0.04493_{-0.024}^{+0.016}$
# 24       sks                 $0.05686_{-0.026}^{+0.025}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 10               $0.02571_{-0.0072}^{+0.0094}$                    7051
# 17                  $0.04991_{-0.02}^{+0.025}$                    8540
# 3                  $0.05511_{-0.017}^{+0.027}$                    9303
# 31                 $0.05927_{-0.013}^{+0.018}$                    1075
# 24                  $0.0802_{-0.026}^{+0.018}$                    3459

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_3533038/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 12        ks  random_normal   90      4                20000
# 26       sks  random_normal   90      4                20000
# 33       swd  random_normal   90      4                20000
# 5        fgd  random_normal   90      4                20000
# 19       mmd  random_normal   90      4                20000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 12                 $0.09133_{-0.026}^{+0.02}$
# 26                 $0.10848_{-0.02}^{+0.013}$
# 33                $0.13678_{-0.025}^{+0.027}$
# 5                  $0.18671_{-0.04}^{+0.034}$
# 19                 $0.40194_{-0.077}^{+0.15}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 12                $0.11404_{-0.025}^{+0.014}$                   6977
# 26               $0.13506_{-0.017}^{+0.0038}$                   3088
# 33                 $0.17024_{-0.022}^{+0.02}$                    811
# 5                 $0.22667_{-0.031}^{+0.027}$                   8116
# 19                 $0.50268_{-0.11}^{+0.089}$                  12363
#
#                           95%CL                        99%CL  \
# 12  [0.06526, 0.09133, 0.11182]  [0.08927, 0.11404, 0.12812]
# 26  [0.08863, 0.10848, 0.12109]  [0.11765, 0.13506, 0.13885]
# 33  [0.11172, 0.13678, 0.16406]  [0.14829, 0.17024, 0.19031]
# 5   [0.14676, 0.18671, 0.22046]  [0.19531, 0.22667, 0.25357]
# 19  [0.32453, 0.40194, 0.54736]  [0.38821, 0.50268, 0.59157]
#
#                   time
# 12  [2605, 2153, 2219]
# 26    [1409, 834, 845]
# 33     [357, 230, 224]
# 5   [2974, 2163, 2979]
# 19  [2782, 5573, 4008]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 12        ks                 $0.09133_{-0.026}^{+0.02}$
# 26       sks                 $0.10848_{-0.02}^{+0.013}$
# 33       swd                $0.13678_{-0.025}^{+0.027}$
# 5        fgd                 $0.18671_{-0.04}^{+0.034}$
# 19       mmd                 $0.40194_{-0.077}^{+0.15}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 12                $0.11404_{-0.025}^{+0.014}$                   6977
# 26               $0.13506_{-0.017}^{+0.0038}$                   3088
# 33                 $0.17024_{-0.022}^{+0.02}$                    811
# 5                 $0.22667_{-0.031}^{+0.027}$                   8116
# 19                 $0.50268_{-0.11}^{+0.089}$                  12363

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_3533038/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform   90      4                20000
# 13        ks  random_uniform   90      4                20000
# 20       mmd  random_uniform   90      4                20000
# 27       sks  random_uniform   90      4                20000
# 34       swd  random_uniform   90      4                20000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                 $0.32909_{-0.063}^{+0.062}$
# 13                 $0.1553_{-0.037}^{+0.033}$
# 20                   $0.68726_{-0.2}^{+0.24}$
# 27                $0.18597_{-0.034}^{+0.025}$
# 34                $0.23619_{-0.043}^{+0.053}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                  $0.39263_{-0.05}^{+0.055}$                   8657
# 13                $0.18609_{-0.035}^{+0.032}$                   7681
# 20                   $0.87417_{-0.2}^{+0.13}$                  15496
# 27                $0.23153_{-0.03}^{+0.0065}$                   3062
# 34                $0.29395_{-0.038}^{+0.035}$                    741
#
#                           95%CL                        99%CL  \
# 6   [0.26571, 0.32909, 0.39066]   [0.3428, 0.39263, 0.44782]
# 13   [0.11812, 0.1553, 0.18799]  [0.15157, 0.18609, 0.21785]
# 20  [0.48549, 0.68726, 0.92578]      [0.66939, 0.87417, 1.0]
# 27  [0.15194, 0.18597, 0.21094]  [0.20168, 0.23153, 0.23804]
# 34  [0.19291, 0.23619, 0.28906]  [0.25606, 0.29395, 0.32861]
#
#                   time
# 6   [3786, 2434, 2437]
# 13  [2787, 2386, 2508]
# 20  [6652, 3735, 5109]
# 27    [1257, 901, 904]
# 34     [284, 228, 229]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                $0.32909_{-0.063}^{+0.062}$
# 13        ks                 $0.1553_{-0.037}^{+0.033}$
# 20       mmd                   $0.68726_{-0.2}^{+0.24}$
# 27       sks                $0.18597_{-0.034}^{+0.025}$
# 34       swd                $0.23619_{-0.043}^{+0.053}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                  $0.39263_{-0.05}^{+0.055}$                   8657
# 13                $0.18609_{-0.035}^{+0.032}$                   7681
# 20                   $0.87417_{-0.2}^{+0.13}$                  15496
# 27                $0.23153_{-0.03}^{+0.0065}$                   3062
# 34                $0.29395_{-0.038}^{+0.035}$                    741
