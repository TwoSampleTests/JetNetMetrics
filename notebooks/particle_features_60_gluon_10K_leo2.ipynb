# %% [markdown]
# # Initialize

# %%
# %cd "/leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics"
# Out:
# /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
visible_devices = [2]
from datetime import datetime
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing os...")
import os
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing sys...")
import sys
if not any("ipykernel" in arg for arg in sys.argv):
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing and initializing argparse...")
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("-v", "--visible_devices", help="Set visible devices", nargs='*', type=list, default=visible_devices)
    args = parser.parse_args()
    visible_devices = args.visible_devices if args.visible_devices else visible_devices
    if not isinstance(visible_devices, list):
        raise ValueError("Visible devices must be a list of integers")
    for i in visible_devices:
        if not isinstance(i, int):
            raise ValueError("Visible devices must be a list of integers")
print("Visible devices:", visible_devices)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timer from timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting env variables for tf import (only device(s)", visible_devices, "will be available)...")
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join([str(i) for i in visible_devices]) # type: ignore
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
#os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=2'
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing numpy...")
import numpy as np # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing matplotlib...")
from matplotlib import pyplot as plt
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing h5py...")
import h5py # type: ignore
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing importlib.util...")
import importlib.util
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing json...")
import json
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing pandas...")
import pandas as pd
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing random...")
import random
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing scipy utils...")
from scipy.stats import norm, lognorm, chi2, kstwo, kstwobign, ks_2samp, moment
from scipy.special import kolmogorov
from scipy.optimize import minimize, curve_fit, root, bisect
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing subprocess...")
import subprocess
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing textwrap...")
import textwrap
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow...")
import tensorflow as tf # type: ignore
print("Tensorflow version:", tf.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tensorflow_probability...")
import tensorflow_probability as tfp # type: ignore
tfd = tfp.distributions
print("Tensorflow probability version:", tfp.__version__)
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing timeit...")
from timeit import default_timer as timer
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing tqdm...")
from tqdm import tqdm
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing typing...")
from typing import List, Tuple, Dict, Callable, Union, Optional, Any, Type
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Setting tf configs...")
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu_device in gpu_devices:
    tf.config.experimental.set_memory_growth(gpu_device, True)

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing GMetrics module...")

import GMetrics # type: ignore
from GMetrics.plotters import plot_corners, cornerplotter, plot_corr_matrix, plot_corr_matrix_side_by_side # type: ignore
from GMetrics.more.deformations import deformed_distribution, deform_mean, deform_cov_diag, deform_cov_off_diag, deform_power_abs, deform_random
from GMetrics.more.optimizers_deformations import compute_exclusion_bisection_dataset # type: ignore
from GMetrics.utils import se_mean, se_std

print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "Importing jetnet.evaluation.gen_metrics module...")
import jetnet

def get_gpu_info():
    try:
        gpu_info = subprocess.check_output(["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"]).decode('utf-8')
        return gpu_info.strip().split('\n')
    except Exception as e:
        print(e)
        return None
training_devices = []
gpu_models = get_gpu_info()
for i in visible_devices:
    if gpu_models:
        training_devices.append(gpu_models[i])
        print(f"Successfully loaded GPU #{i}, model: {gpu_models[i]}")
    else:
        training_devices.append('undetermined')
        print(f"Failed to load GPU {i} model. Defaulting to 'undetermined'.")
print(f"Loaded {len(training_devices)} GPUs: {training_devices}")
        
print(datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")+":", "All done.")
# Out:
# 2024-07-02 11:09:57.367543: Importing os...
# 2024-07-02 11:09:57.367662: Importing sys...
# Visible devices: [2]
# 2024-07-02 11:09:57.367893: Importing timer from timeit...
# 2024-07-02 11:09:57.367960: Setting env variables for tf import (only device(s) [2] will be available)...
# 2024-07-02 11:09:57.368087: Importing numpy...
# 2024-07-02 11:09:57.525169: Importing matplotlib...
# 2024-07-02 11:09:57.935889: Importing h5py...
# 2024-07-02 11:09:57.963554: Importing importlib.util...
# 2024-07-02 11:09:57.963674: Importing json...
# 2024-07-02 11:09:57.963738: Importing pandas...
# 2024-07-02 11:09:58.479429: Importing random...
# 2024-07-02 11:09:58.479590: Importing scipy utils...
# 2024-07-02 11:09:58.922152: Importing subprocess...
# 2024-07-02 11:09:58.922295: Importing textwrap...
# 2024-07-02 11:09:58.922357: Importing tensorflow...
# Tensorflow version: 2.16.1
# 2024-07-02 11:10:02.613070: Importing tensorflow_probability...
# Tensorflow probability version: 0.24.0
# 2024-07-02 11:10:03.818803: Importing timeit...
# 2024-07-02 11:10:03.818923: Importing tqdm...
# 2024-07-02 11:10:03.828925: Importing typing...
# 2024-07-02 11:10:03.829059: Setting tf configs...
# 2024-07-02 11:10:03.932085: Importing GMetrics module...
# /leonardo/home/userexternal/rtorre00/fast/rtorre00/envs/tf2_custom/lib/python3.11/site-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-07-02 11:10:09.179239: Importing jetnet.evaluation.gen_metrics module...
# Successfully loaded GPU #2, model: NVIDIA A100-SXM-64GB
# Loaded 1 GPUs: ['NVIDIA A100-SXM-64GB']
# 2024-07-02 11:10:09.208143: All done.

# %% [markdown]
# # Load data

# %%
data = jetnet.datasets.JetNet.getData(jet_type = "g",
                                      data_dir = "data/g",
                                      particle_features = "all",
                                      jet_features = "all",
                                      num_particles = 60,
                                      split = "all",
                                      split_fraction = None,
                                      seed = 42,
                                      download = False,
                                     )

# %%
def get_particle_features(relative_features,
                          jet_features):
    eta_rel = relative_features[:, :, 0]
    phi_rel = relative_features[:, :, 1]
    pt_rel = relative_features[:, :, 2]
    mask = relative_features[:, :, 3]
    eta_jet = jet_features[:, 2]
    pt_jet = jet_features[:, 1]
    eta_particle = eta_jet[:, None] + eta_rel
    phi_paericle = phi_rel
    pt_particle = pt_jet[:, None] * pt_rel
    particle_features = tf.stack([eta_particle, phi_paericle, pt_particle, mask], axis = 2)
    return particle_features

# %%
relative_features = tf.cast(data[0], tf.float64)                            #    ``["etarel", "phirel", "ptrel", "mask"]``.
jet_features = tf.cast(data[1], tf.float64)                                 #    ``["type", "pt", "eta", "mass", "num_particles"]``.
particle_features = get_particle_features(relative_features, jet_features)  #    ``["eta", "phi", "pt", "mask"]``.
print(f"relative_features.shape: {relative_features.shape}")
print(f"jet_features.shape: {jet_features.shape}")
print(f"particle_features.shape: {particle_features.shape}")
# Out:
# relative_features.shape: (177252, 60, 4)
# jet_features.shape: (177252, 5)
# particle_features.shape: (177252, 60, 4)

# %% [markdown]
# # Particle level

# %% [markdown]
# ## Init data

# %%
results_dir = "results_leo/particle_features_60/"
figures_dir = os.path.join(results_dir, "figures/")
if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)
    print("Results directories waere created")

# %%
def preprocess_data(data,means,stds):
    preprocessed_data=(data-means)/stds
    return preprocessed_data

def postprocess_data(data,means,stds):
    postprocessed_data=data*stds+means
    return postprocessed_data

def get_reduced_particle_features(particle_features):
    tmp = particle_features[:, :, :3]
    shape = tmp.shape
    particle_features_reshaped = tf.reshape(tmp, [-1, shape[1] * shape[2]])
    return particle_features_reshaped

particle_features_reduced = get_reduced_particle_features(particle_features)
particle_features_reduced.shape
# Out:
# TensorShape([177252, 180])

# %% [markdown]
# ## TwoSample Test

# %%
tests_dir = os.path.join(results_dir, "tests/")
model_dir = os.path.join(tests_dir, '10K/')
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    
dataset = get_reduced_particle_features(particle_features)

# %% [markdown]
# ## 10K

# %% [markdown]
# ### Bootstrapping Null Hypothesis

# %%
null_hypotheses_dir = os.path.join(model_dir, 'null_hypotheses/')
if not os.path.exists(null_hypotheses_dir):
    os.makedirs(null_hypotheses_dir)
metrics_config_file = os.path.join(model_dir, "metrics_config.json")

# %%
niter_tot = 1_000
batch_size_test = 10_000
namples = len(dataset) // 2
niter = namples // batch_size_test
nbootstrap = niter_tot // niter
niter_tot = niter * nbootstrap
print(f"niter: {niter}, nbootstrap: {nbootstrap}")

def shuffle_dataset(seed):
    return tf.random.shuffle(dataset, seed=seed)

start = timer()
l = len(dataset) // 2
dstmp = shuffle_dataset(seed = 0)
dist_1_null = tf.cast(dstmp[:l], tf.float64)
dist_2_null = tf.cast(dstmp[l:], tf.float64)
del(dstmp)

TwoSampleTestInputsNull = GMetrics.TwoSampleTestInputs(dist_1_input = dist_1_null[:niter*batch_size_test],
                                                       dist_2_input = dist_2_null[:niter*batch_size_test],
                                                       niter = niter,
                                                       batch_size_test = batch_size_test,
                                                       small_sample_threshold = 1e7,
                                                       dtype_input = tf.float64,
                                                       seed_input = 0,
                                                       use_tf = True,
                                                       mirror_strategy = False,
                                                       verbose = True)
FGDMetricNull = GMetrics.FGDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   num_batches = 20, # to be included in metric kwargs
                                   num_points = 10, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
MMDMetricNull = GMetrics.MMDMetric(TwoSampleTestInputsNull,
                                   progress_bar = True,
                                   verbose = True,
                                   degree = 4, # to be included in metric kwargs
                                   block_size = 10_000, # to be included in metric kwargs
                                   normalise = False) # to be included in metric kwargs
KSTestNull = GMetrics.KSTest(TwoSampleTestInputsNull,
                             progress_bar = True,
                             verbose = True)
SKSTestNull = GMetrics.SKSTest(TwoSampleTestInputsNull,
                               nslices = 100, # to be included in metric kwargs
                               seed_slicing = 0, # to be included in metric kwargs
                               progress_bar = True,
                               verbose = True)
SWDMetricNull = GMetrics.SWDMetric(TwoSampleTestInputsNull,
                                   nslices = 100, # to be included in metric kwargs
                                   seed_slicing = 0, # to be included in metric kwargs
                                   progress_bar = True,
                                   verbose = True)
# Out:
# niter: 8, nbootstrap: 125
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
# Generating random directions based on nslices, ndims, and seed_slicing.
# Generating random directions based on nslices, ndims, and seed_slicing.

# %%
test_config_null = {}
test_config_tmp = dict(TwoSampleTestInputsNull.__dict__)
keys_to_remove = ["_dist_1_input", "_dist_2_input", "_dist_1_num", "_dist_2_num", "_dist_1_symb", "_dist_2_symb", "_seed_generator"]
for key in keys_to_remove:
    test_config_tmp.pop(key, None)
for key, value in test_config_tmp.items():
    new_key = key.lstrip('_')
    
    if isinstance(value, tf.Tensor):
        new_value = value.numpy() # type: ignore
    elif isinstance(value, np.ndarray):
        new_value = value.tolist()
    elif isinstance(value, np.generic):
        new_value = value.item() # Convert NumPy scalars to Python scalars
    elif isinstance(value, tf.DType):
        new_value = value.name
    elif isinstance(value, np.dtype):
        new_value = np.dtype(value).name
    else:
        new_value = value
    
    test_config_null[new_key] = new_value

pd.DataFrame([test_config_null])
# Out:
#    niter  batch_size_test  batch_size_gen  small_sample_threshold dtype_input  \
# 0      8            10000            1000                10000000     float64
#
#    seed  use_tf  mirror_strategy strategy  verbose  is_symb_1  ndims_1  \
# 0     0    True            False     None     True      False      180
#
#    nsamples_1  is_symb_2  ndims_2  nsamples_2    dtype  ndims  nsamples  \
# 0       80000      False      180       80000  float64    180     80000
#
#    small_sample
# 0         False

# %%
unique_key = "config_flavor_nsamples_"+str(TwoSampleTestInputsNull.batch_size_test)+"_niter_"+str(niter_tot)
metrics_config = {unique_key: {"fgd": {"name": "fgd",
                                       "object_name": "FGDMetricNull",
                                       "class_name": "GMetrics.FGDMetric",
                                       "kwargs": {"num_batches": 20,
                                                  "num_points": 10,
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{FGD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"FGD.json")},
                               "mmd": {"name": "mmd",
                                       "object_name": "MMDMetricNull" ,
                                       "class_name": "GMetrics.MMDMetric",
                                       "kwargs": {"degree": 4, 
                                                  "block_size": 10_000, 
                                                  "normalise": False,
                                                  "verbose": True}, 
                                       "result_key": "metric_list", 
                                       "scale_func": lambda ns, ndims: 1,
                                       "scale_func_string": "lambda ns, ndims: 1",
                                       "test_config": test_config_null,
                                       "max_vectorize": 8, # optimized for 5D
                                       "latex": "$d_{\mathrm{MMD}}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"MMD.json")},
                               "ks":  {"name": "ks",
                                       "object_name": "KSTestNull",
                                       "class_name": "GMetrics.KSTest", 
                                       "kwargs": {"verbose": True}, 
                                       "result_key": "statistic_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 360,
                                       "latex": "$\overline{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"KS.json")},
                               "sks": {"name": "sks",
                                       "object_name": "SKSTestNull",
                                       "class_name": "GMetrics.SKSTest", 
                                       "kwargs": {"nslices": 100, 
                                                  "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, _ : np.sqrt(ns),
                                       "scale_func_string": "lambda ns, _: np.sqrt(ns)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{D}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SKS.json")},
                               "swd": {"name": "swd",
                                      "object_name": "SWDMetricNull",
                                      "class_name": "GMetrics.SWDMetric", 
                                      "kwargs": {"nslices": 100, 
                                                 "seed_slicing": 0,
                                                  "verbose": True}, 
                                       "result_key": "metric_means", 
                                       "scale_func": lambda ns, ndims: np.sqrt(ns/ndims),
                                       "scale_func_string": "lambda ns, ndims: np.sqrt(ns/ndims)",
                                       "test_config": test_config_null,
                                       "max_vectorize": 800,
                                       "latex": "$\widetilde{W}$",
                                       "null_file": os.path.join(null_hypotheses_dir,"SWD.json")}}}

# %%
for metric in list(metrics_config[unique_key].values())[2:3]:
    file = metric["null_file"]
    name = metric["name"]
    max_vectorize = metric["max_vectorize"]
    obj = eval(metric["object_name"])
    if os.path.exists(file):
        print(f"Loading {name} from {file}")
        obj.Results.load_from_json(file)
    else:
        print(f"Computing and savng {name} with max_vectorize = {max_vectorize}")
        print("\n===========================================================")
        print(f"Testing from 0 to {niter} of {niter * nbootstrap} samples.")
        obj.Test_tf(max_vectorize = max_vectorize)
        for i in range(1, nbootstrap):
            l = len(dataset) // 2
            dstmp = shuffle_dataset(seed = 1000 * i + i)
            dist_1_null = tf.cast(dstmp[:l], tf.float64)
            dist_2_null = tf.cast(dstmp[l:], tf.float64)
            #KSTestNull.Inputs.dist_1_input = dist_1 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_1_num = dist_1_null[:niter*batch_size_test] # Overwriting the _dist_1_num attribute. Less consistent, but         faster
            #KSTestNull.Inputs.dist_2_input = dist_2 # This is the consistent way, but slower
            TwoSampleTestInputsNull._dist_2_num = dist_2_null[:niter*batch_size_test] # Overwriting the _dist_2_num attribute. Less consistent, but         faster
            print("\n===========================================================")
            print(f"Testing from {i * niter} to {(i+1) * niter} of {niter * nbootstrap} samples.")
            obj.Test_tf(max_vectorize = max_vectorize)
            del(dstmp)
        end = timer()
        print(f"All done in: {end-start:.2f} s.")
        print(f"Saving {name} to {file}")
        obj.Results.save_to_json(file)
# Out:
# Computing and savng ks with max_vectorize = 360
#
# ===========================================================
# Testing from 0 to 8 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 6.591927816043608 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# WARNING:tensorflow:5 out of the last 5 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7fa307480180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 2 to 4 out of 8 .
# WARNING:tensorflow:6 out of the last 6 calls to <function KSTest.Test_tf.<locals>.batched_test at 0x7fa307480180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.6790415269788355 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.788237885106355 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.7850718040717766 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.656273772008717 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.783943368936889 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.21428387099877 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.901467645075172 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0354056330397725 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8109203460626304 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8130311149870977 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.7474022869719192 seconds.
#
# ===========================================================
# Testing from 96 to 104 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.687200568965636 seconds.
#
# ===========================================================
# Testing from 104 to 112 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.7782080940669402 seconds.
#
# ===========================================================
# Testing from 112 to 120 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.69493848294951 seconds.
#
# ===========================================================
# Testing from 120 to 128 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.867736244923435 seconds.
#
# ===========================================================
# Testing from 128 to 136 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.989892620011233 seconds.
#
# ===========================================================
# Testing from 136 to 144 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.649674489046447 seconds.
#
# ===========================================================
# Testing from 144 to 152 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.7751424190355465 seconds.
#
# ===========================================================
# Testing from 152 to 160 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9774996269261464 seconds.
#
# ===========================================================
# Testing from 160 to 168 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1006541119422764 seconds.
#
# ===========================================================
# Testing from 168 to 176 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.047750992933288 seconds.
#
# ===========================================================
# Testing from 176 to 184 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.835969311068766 seconds.
#
# ===========================================================
# Testing from 184 to 192 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0126363820163533 seconds.
#
# ===========================================================
# Testing from 192 to 200 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.875563557026908 seconds.
#
# ===========================================================
# Testing from 200 to 208 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0879719129297882 seconds.
#
# ===========================================================
# Testing from 208 to 216 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.083097205031663 seconds.
#
# ===========================================================
# Testing from 216 to 224 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.854690053034574 seconds.
#
# ===========================================================
# Testing from 224 to 232 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.116169608081691 seconds.
#
# ===========================================================
# Testing from 232 to 240 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8201027689501643 seconds.
#
# ===========================================================
# Testing from 240 to 248 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0911032379372045 seconds.
#
# ===========================================================
# Testing from 248 to 256 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.212108134990558 seconds.
#
# ===========================================================
# Testing from 256 to 264 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.337444860022515 seconds.
#
# ===========================================================
# Testing from 264 to 272 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.313606728101149 seconds.
#
# ===========================================================
# Testing from 272 to 280 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1176399290561676 seconds.
#
# ===========================================================
# Testing from 280 to 288 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.239217913011089 seconds.
#
# ===========================================================
# Testing from 288 to 296 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.945092251058668 seconds.
#
# ===========================================================
# Testing from 296 to 304 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2235302100889385 seconds.
#
# ===========================================================
# Testing from 304 to 312 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.973321928991936 seconds.
#
# ===========================================================
# Testing from 312 to 320 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.128351571969688 seconds.
#
# ===========================================================
# Testing from 320 to 328 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1321727570611984 seconds.
#
# ===========================================================
# Testing from 328 to 336 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.827644467004575 seconds.
#
# ===========================================================
# Testing from 336 to 344 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9738072970649227 seconds.
#
# ===========================================================
# Testing from 344 to 352 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9174042779486626 seconds.
#
# ===========================================================
# Testing from 352 to 360 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.705502438941039 seconds.
#
# ===========================================================
# Testing from 360 to 368 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2864847580203786 seconds.
#
# ===========================================================
# Testing from 368 to 376 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.548259641043842 seconds.
#
# ===========================================================
# Testing from 376 to 384 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3305692749563605 seconds.
#
# ===========================================================
# Testing from 384 to 392 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.219292049994692 seconds.
#
# ===========================================================
# Testing from 392 to 400 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3151595840463415 seconds.
#
# ===========================================================
# Testing from 400 to 408 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.028615117073059 seconds.
#
# ===========================================================
# Testing from 408 to 416 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2214307370595634 seconds.
#
# ===========================================================
# Testing from 416 to 424 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9157008440233767 seconds.
#
# ===========================================================
# Testing from 424 to 432 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.183506375993602 seconds.
#
# ===========================================================
# Testing from 432 to 440 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1008277300279588 seconds.
#
# ===========================================================
# Testing from 440 to 448 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9059572640107945 seconds.
#
# ===========================================================
# Testing from 448 to 456 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.116287112934515 seconds.
#
# ===========================================================
# Testing from 456 to 464 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.49971532006748 seconds.
#
# ===========================================================
# Testing from 464 to 472 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.8637845469638705 seconds.
#
# ===========================================================
# Testing from 472 to 480 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3481142170494422 seconds.
#
# ===========================================================
# Testing from 480 to 488 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.558555886032991 seconds.
#
# ===========================================================
# Testing from 488 to 496 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1488102459115908 seconds.
#
# ===========================================================
# Testing from 496 to 504 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.535437381011434 seconds.
#
# ===========================================================
# Testing from 504 to 512 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9947641199687496 seconds.
#
# ===========================================================
# Testing from 512 to 520 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3946395399980247 seconds.
#
# ===========================================================
# Testing from 520 to 528 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1761490020435303 seconds.
#
# ===========================================================
# Testing from 528 to 536 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9042941329535097 seconds.
#
# ===========================================================
# Testing from 536 to 544 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1568023920990527 seconds.
#
# ===========================================================
# Testing from 544 to 552 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.825640336959623 seconds.
#
# ===========================================================
# Testing from 552 to 560 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.856043340987526 seconds.
#
# ===========================================================
# Testing from 560 to 568 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.6865172610851005 seconds.
#
# ===========================================================
# Testing from 568 to 576 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.8206974109634757 seconds.
#
# ===========================================================
# Testing from 576 to 584 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3656013149302453 seconds.
#
# ===========================================================
# Testing from 584 to 592 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.5927830130094662 seconds.
#
# ===========================================================
# Testing from 592 to 600 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.374156540958211 seconds.
#
# ===========================================================
# Testing from 600 to 608 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.286400652024895 seconds.
#
# ===========================================================
# Testing from 608 to 616 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4343093710485846 seconds.
#
# ===========================================================
# Testing from 616 to 624 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0202397539978847 seconds.
#
# ===========================================================
# Testing from 624 to 632 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2214858180377632 seconds.
#
# ===========================================================
# Testing from 632 to 640 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9670739689609036 seconds.
#
# ===========================================================
# Testing from 640 to 648 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.193544932990335 seconds.
#
# ===========================================================
# Testing from 648 to 656 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.902257781010121 seconds.
#
# ===========================================================
# Testing from 656 to 664 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.7360492119332775 seconds.
#
# ===========================================================
# Testing from 664 to 672 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.858591264928691 seconds.
#
# ===========================================================
# Testing from 672 to 680 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.7121458519250154 seconds.
#
# ===========================================================
# Testing from 680 to 688 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.075387272052467 seconds.
#
# ===========================================================
# Testing from 688 to 696 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.432145089027472 seconds.
#
# ===========================================================
# Testing from 696 to 704 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.73832065903116 seconds.
#
# ===========================================================
# Testing from 704 to 712 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.002022000029683 seconds.
#
# ===========================================================
# Testing from 712 to 720 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.552644673967734 seconds.
#
# ===========================================================
# Testing from 720 to 728 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.192413385026157 seconds.
#
# ===========================================================
# Testing from 728 to 736 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2352611100068316 seconds.
#
# ===========================================================
# Testing from 736 to 744 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1286329950671643 seconds.
#
# ===========================================================
# Testing from 744 to 752 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.77711702499073 seconds.
#
# ===========================================================
# Testing from 752 to 760 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8732897270238027 seconds.
#
# ===========================================================
# Testing from 760 to 768 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.790172416018322 seconds.
#
# ===========================================================
# Testing from 768 to 776 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.794878210988827 seconds.
#
# ===========================================================
# Testing from 776 to 784 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8622263650177047 seconds.
#
# ===========================================================
# Testing from 784 to 792 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 5.013936470029876 seconds.
#
# ===========================================================
# Testing from 792 to 800 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.864406412001699 seconds.
#
# ===========================================================
# Testing from 800 to 808 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.521267308969982 seconds.
#
# ===========================================================
# Testing from 808 to 816 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.690798677969724 seconds.
#
# ===========================================================
# Testing from 816 to 824 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.396110073896125 seconds.
#
# ===========================================================
# Testing from 824 to 832 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.538617286947556 seconds.
#
# ===========================================================
# Testing from 832 to 840 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.163585138041526 seconds.
#
# ===========================================================
# Testing from 840 to 848 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3122280170209706 seconds.
#
# ===========================================================
# Testing from 848 to 856 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9208230660296977 seconds.
#
# ===========================================================
# Testing from 856 to 864 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0706447060219944 seconds.
#
# ===========================================================
# Testing from 864 to 872 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.949328816961497 seconds.
#
# ===========================================================
# Testing from 872 to 880 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.7190699339844286 seconds.
#
# ===========================================================
# Testing from 880 to 888 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9994613010203466 seconds.
#
# ===========================================================
# Testing from 888 to 896 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8887093999655917 seconds.
#
# ===========================================================
# Testing from 896 to 904 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 5.704494990990497 seconds.
#
# ===========================================================
# Testing from 904 to 912 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.558063320000656 seconds.
#
# ===========================================================
# Testing from 912 to 920 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.00253799604252 seconds.
#
# ===========================================================
# Testing from 920 to 928 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3458624159684405 seconds.
#
# ===========================================================
# Testing from 928 to 936 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.7752619119128212 seconds.
#
# ===========================================================
# Testing from 936 to 944 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2384555409662426 seconds.
#
# ===========================================================
# Testing from 944 to 952 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.520167149952613 seconds.
#
# ===========================================================
# Testing from 952 to 960 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1980419689789414 seconds.
#
# ===========================================================
# Testing from 960 to 968 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.285922630922869 seconds.
#
# ===========================================================
# Testing from 968 to 976 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1460836539044976 seconds.
#
# ===========================================================
# Testing from 976 to 984 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.959773209062405 seconds.
#
# ===========================================================
# Testing from 984 to 992 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.066345048020594 seconds.
#
# ===========================================================
# Testing from 992 to 1000 of 1000 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.857625183998607 seconds.
# All done in: 424.79 s.
# Saving ks to results_leo/particle_features_60/tests/10K/null_hypotheses/KS.json

# %%
cl_list = [0.68, 0.95, 0.99]
null_times = []
ndims = 180

for metric in list(metrics_config[unique_key].values())[2:3]:
    name = metric["name"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    
    nsamples = obj.Inputs.batch_size_test
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    print(len(dist_null))

    metric_thresholds = [[cl, 
                          [int(cl*len(dist_null)), 
                           int((1-cl)*len(dist_null))], 
                          np.sort(dist_null)[int(len(dist_null)*cl)]] for cl in cl_list]
    
    print(f"ThresholdS for metric {metric['name']}: {metric_thresholds}")
    null_time = obj.Results[0].__dict__['computing_time']
    for i in range(1,len(obj.Results)):
        null_time += obj.Results[i].__dict__['computing_time']
    null_times.append([name, int(null_time)])
    print(f"Computing time for metric {metric['name']}: {null_time}")
    
    metric.update({"thresholds": metric_thresholds})
    
GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# 1000
# ThresholdS for metric ks: [[0.68, [680, 319], 0.8885194717687009], [0.95, [950, 50], 1.0343795758063465], [0.99, [990, 10], 1.1210396076377789]]
# Computing time for metric ks: 406.9686811793363
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fa4e2f9c9a0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fa4e2f9f560>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fa4e2f9c7c0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fa4e2f9f380>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fa4e2f9f420>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 8, 'batch_size_test': 10000, 'batch_...              8
# 1  {'niter': 8, 'batch_size_test': 10000, 'batch_...              8
# 2  {'niter': 8, 'batch_size_test': 10000, 'batch_...            360
# 3  {'niter': 8, 'batch_size_test': 10000, 'batch_...            800
# 4  {'niter': 8, 'batch_size_test': 10000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/10K/nul...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/10K/nul...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/10K/nul...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/10K/nul...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/10K/nul...
#
#                                           thresholds
# 0                                                NaN
# 1                                                NaN
# 2  [[0.68, [680, 319], 0.8885194717687009], [0.95...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# #### Plots of null-distributions

# %%
for metric in list(metrics_config[unique_key].values())[2:3]:
    name = metric["name"]
    name_cap = name.upper()
    latex = metric["latex"]
    obj = eval(metric["object_name"])
    result_key = metric["result_key"]
    scale_func = metric["scale_func"]
    figure_file = metric["null_file"].replace("json","pdf")
    thresholds = metric["thresholds"]

    start = timer()
    
    nsamples = obj.Inputs.batch_size_test
    niter = obj.Inputs.niter
    ns = nsamples**2 /(2*nsamples)
    dist_null  = np.array(obj.Results[0].result_value[result_key])
    for i in range(1,len(obj.Results)):
        dist_null = np.concatenate((dist_null, np.array(obj.Results[i].result_value[result_key])))
    dist_null = dist_null * scale_func(ns, ndims)
    
    scale = 'log'
    num_bins = 50  # number of bins|
    
    mu, deltamu, sigma, deltasigma = (np.mean(dist_null), se_mean(dist_null), np.std(dist_null), se_std(dist_null))
    sigma_68, sigma_95, sigma_99 = [np.sort(dist_null)[int(len(dist_null)*cl)] for cl in [0.68, 0.95, 0.99]]
    print(f"mu = {mu} +/- {deltamu}")
    print(f"sigma = {sigma} +/- {deltasigma}")
    print(f"68%CL = {sigma_68}, 95%CL = {sigma_95}, 99%CL = {sigma_99}")
    
    print("mu =", mu, "+/-", deltamu)
    print("sigma =", sigma, "+/-", deltasigma)
    
    min_x, max_x = min(dist_null), max(dist_null) # lower and upper limit of the binning
    x = np.linspace(min_x, max_x, num_bins + 1)
    counts, bin_edges = np.histogram(dist_null, bins=x, density=True)
    cum_counts = np.cumsum(counts)/np.sum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Only if metric is KS-derived plot the theoretical distribution
    if "ks" in name:
        # Calculate the theoretical PDF and CDF of the KS distribution for each x value
        theoretical_pdf_ks = kstwobign.pdf(x)
        theoretical_cdf_ks = kstwobign.cdf(x)

        # Empirical SKS Normal
        empirical_pdf_norm = norm.pdf(x, loc=kstwobign.mean(), scale=kstwobign.std())
        empirical_cdf_norm = norm.cdf(x, loc=kstwobign.mean(), scale=kstwobign.std())

    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    
    dash_styles = ['-', '--', '-.']
    colors = ["royalblue", "darkorange", "mediumseagreen"]
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = counts[:-1]  # assuming counts is one element longer than step_edges

    ax[0].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    current_ylim0 = ax[0].get_ylim()
    if "ks" in name:
        ax[0].plot(x, theoretical_pdf_ks, label="Kolmogorov PDF")
    ax[0].set_yscale(scale)
    ax[0].set_xlabel(r"%s"%latex, fontsize=16)
    ax[0].set_ylabel('Frequency', fontsize=16)
    ax[0].set_title('PDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[0].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[0].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[0].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[0].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)

    ax[0].set_ylim(current_ylim0)  
    legend0 = ax[0].legend(loc='upper right', fontsize=15)
    for handle in legend0.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    # Create step plot
    step_edges = np.convolve(bin_centers, [0.5, 0.5], 'valid')
    step_counts = cum_counts[:-1]  # assuming counts is one element longer than step_edges
    
    ax[1].step(step_edges, step_counts, where='mid', linestyle='-', color = "tomato", label = "Null distribution")
    #ax[1].plot(bin_centers, cum_counts, linestyle = '-', color = "tomato", label = "Null distribution", drawstyle='steps-mid')
    current_ylim1 = ax[1].get_ylim()
    if "ks" in name:
        ax[1].plot(x, theoretical_cdf_ks, label="Kolmogorov CDF")
    #for i, threshold in enumerate(thresholds):
    #    confidence_level, _, threshold_value = threshold
    #    ax[1].axhline(y=confidence_level, color=colors[i], linestyle=dash_styles[i], linewidth=0.5, alpha=1)
    ax[1].set_yscale(scale)
    ax[1].set_xlabel(r"%s"%latex, fontsize=16)
    ax[1].set_title('CDF for particle_features_150 null with $N = '+str(ndims)+'$, $n=m='+str(int(nsamples/1000))+'$K, $n_{\mathrm{iter}} = '+str(int(niter_tot/1000))+'$K', fontsize=15)
    ax[1].tick_params(axis='x', labelsize=15)  # Set x-axis tick label size
    ax[1].tick_params(axis='y', labelsize=15)  # Set y-axis tick label size
    
    for i, threshold in enumerate(thresholds):
        confidence_level, _, threshold_value = threshold
        start_index = np.searchsorted(step_edges, threshold_value, side="right") - 1
        start_index = max(start_index, 0)
        fill_x_range = np.concatenate([[threshold_value], step_edges[start_index+1:]])
        fill_y_values = step_counts[start_index:]
        if len(fill_x_range) > 1 and len(fill_y_values) > 0:
            ax[1].fill_between(fill_x_range, 0, fill_y_values, color=colors[i], alpha=0.1, step='mid', label=f"{int(confidence_level * 100)}% CL ($x>{format(threshold_value, '.2f')}   $)")
        ax[1].axvline(x=threshold_value, linestyle=dash_styles[i], color=colors[i], linewidth=1)
    
    ax[1].set_ylim(current_ylim1)  
    #for i, threshold in enumerate(thresholds):
    #    confidence, _, value = threshold
    #    ax[1].axvline(x=value, color=colors[i], linestyle=dash_styles[i], alpha=1, label=f"{int(confidence_level * 100)} CL% ($x>{format(threshold_value,'.2f')}$)")
    
    legend1 = ax[1].legend(loc='upper right', fontsize=15)
    for handle in legend1.legendHandles[-3:]:
        handle.set_alpha(0.5)  # Set to desired alpha value
    
    plt.subplots_adjust(wspace=0.1)  # Adjust this value to your liking
    plt.tight_layout()
    plt.savefig(figure_file)
    plt.show()
    plt.close()
    
    metric.update({"null_figure": figure_file})

    end = timer()
    print("Time elapsed:", end-start, "seconds.")

GMetrics.utils.save_update_metrics_config(metrics_config = metrics_config, metrics_config_file = metrics_config_file) # type: ignore
# Out:
# mu = 0.8532179518070878 +/- 0.00029726424761712775
# sigma = 0.09695525201898061 +/- 0.0025123297658635694
# 68%CL = 0.8885194717687009, 95%CL = 1.0343795758063465, 99%CL = 1.1210396076377789
# mu = 0.8532179518070878 +/- 0.00029726424761712775
# sigma = 0.09695525201898061 +/- 0.0025123297658635694
# /tmp/ipykernel_1264009/3463214430.py:79: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[0].set_ylim(current_ylim0)
# /tmp/ipykernel_1264009/3463214430.py:81: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend0.legendHandles[-3:]:
# /tmp/ipykernel_1264009/3463214430.py:112: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax[1].set_ylim(current_ylim1)
# /tmp/ipykernel_1264009/3463214430.py:118: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend1.legendHandles[-3:]:
# Time elapsed: 2.88766862207558 seconds.
#   name    object_name          class_name  \
# 0  fgd  FGDMetricNull  GMetrics.FGDMetric
# 1  mmd  MMDMetricNull  GMetrics.MMDMetric
# 2   ks     KSTestNull     GMetrics.KSTest
# 3  sks    SKSTestNull    GMetrics.SKSTest
# 4  swd  SWDMetricNull  GMetrics.SWDMetric
#
#                                               kwargs       result_key  \
# 0  {'num_batches': 20, 'num_points': 10, 'normali...      metric_list
# 1  {'degree': 4, 'block_size': 10000, 'normalise'...      metric_list
# 2                                  {'verbose': True}  statistic_means
# 3  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
# 4  {'nslices': 100, 'seed_slicing': 0, 'verbose':...     metric_means
#
#                               scale_func                    scale_func_string  \
# 0  <function <lambda> at 0x7fa4e2f9c9a0>                  lambda ns, ndims: 1
# 1  <function <lambda> at 0x7fa4e2f9f560>                  lambda ns, ndims: 1
# 2  <function <lambda> at 0x7fa4e2f9c7c0>            lambda ns, _: np.sqrt(ns)
# 3  <function <lambda> at 0x7fa4e2f9f380>            lambda ns, _: np.sqrt(ns)
# 4  <function <lambda> at 0x7fa4e2f9f420>  lambda ns, ndims: np.sqrt(ns/ndims)
#
#                                          test_config  max_vectorize  \
# 0  {'niter': 8, 'batch_size_test': 10000, 'batch_...              8
# 1  {'niter': 8, 'batch_size_test': 10000, 'batch_...              8
# 2  {'niter': 8, 'batch_size_test': 10000, 'batch_...            360
# 3  {'niter': 8, 'batch_size_test': 10000, 'batch_...            800
# 4  {'niter': 8, 'batch_size_test': 10000, 'batch_...            800
#
#                 latex                                          null_file  \
# 0  $d_{\mathrm{FGD}}$  results_leo/particle_features_60/tests/10K/nul...
# 1  $d_{\mathrm{MMD}}$  results_leo/particle_features_60/tests/10K/nul...
# 2      $\overline{D}$  results_leo/particle_features_60/tests/10K/nul...
# 3     $\widetilde{D}$  results_leo/particle_features_60/tests/10K/nul...
# 4     $\widetilde{W}$  results_leo/particle_features_60/tests/10K/nul...
#
#                                           thresholds  \
# 0                                                NaN
# 1                                                NaN
# 2  [[0.68, [680, 319], 0.8885194717687009], [0.95...
# 3                                                NaN
# 4                                                NaN
#
#                                          null_figure
# 0                                                NaN
# 1                                                NaN
# 2  results_leo/particle_features_60/tests/10K/nul...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ### Alternative hypothesis

# %% [markdown]
# #### Scan and exclusion limits (bisection method)

# %%
if test_config_null["use_tf"]:
    dtype = getattr(tf, test_config_null["dtype_input"])
else:
    dtype = np.dtype(test_config_null["dtype_input"])
test_kwargs = {"niter_null": niter,
               "niter_alt": 100, # this will be adapted to the boostrap size
               "batch_size_test": test_config_null["batch_size_test"],
               "batch_size_gen": test_config_null["batch_size_gen"],
               "small_sample_threshold": test_config_null["small_sample_threshold"],
               "dtype_input": dtype,
               "seed_input": test_config_null["seed"],
               "use_tf": test_config_null["use_tf"],
               "mirror_strategy": test_config_null["mirror_strategy"],
               "verbose": True}

# %%
file_path = os.path.join(model_dir, "exclusion_limits.json")
if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            existing_data = json.load(file)
    except json.JSONDecodeError:
        existing_data = {}
else:
    existing_data = {}
    
# Sort the dictionary by keys
existing_data = dict(sorted(existing_data.items()))

# Save the sorted dictionary back to a JSON file
with open(file_path, 'w') as f:
    json.dump(existing_data, f, cls=GMetrics.utils.CustomEncoder, indent=4) # type: ignore

# %%
deformations = ["mean", "cov_diag", "cov_off_diag", "power_abs_up", "power_abs_down", "random_normal", "random_uniform"]
bounds = ["upper", "central", "lower"]
global_results = {}

for metric_config in list(metrics_config[unique_key].values())[2:3]:
    for deformation in deformations:
        eps_max = 2.
        for bound in bounds:
            try:
                result = {k: v for k, v in {k: v for k, v in existing_data.items() if v["null_config"]["name"] == metric_config["name"] and v["deformation"] == deformation and v["bound"] == bound}.items() if v["exclusion_list"] != []}
            except:
                result = {}
            if result == {}:
                print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
                result = compute_exclusion_bisection_dataset(dataset = dataset,
                                                             metric_config = metric_config,
                                                             test_kwargs = test_kwargs,
                                                             model_dir = model_dir,
                                                             deformation = deformation,
                                                             seed_dist = 0,
                                                             x_tol = 0.1,
                                                             fn_tol = 0.15,
                                                             bound = bound,
                                                             eps_min = 0.,
                                                             eps_max = eps_max,
                                                             smear = 0.,
                                                             max_iterations = 50,
                                                             save = True,
                                                             filename = "exclusion_limits.json",
                                                             verbose = True)
                eps_max = list(result.values())[0]["exclusion_list"][-1][3]
            else:
                print(f"{bound.capitalize()} bounds for {metric_config['name']} with {deformation} deformation already loaded.")
            global_results.update(result)
print(global_results.keys())
# Out:
# Computing upper bounds for ks with mean deformation.
#
# ======================================================
# =============== ks - mean ===============
# ======================================================
# niter: 8, nbootstrap: 12
#
# ------------ 1 - 0.95 CL -  upper bound -----------
# eps = 1.0 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.893406715011224 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.025755731971003 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3328894010046497 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.738044157042168 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.323088235105388 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.318084391998127 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3414318370632827 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9342697910033166 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1325420700013638 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8764614140382037 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1410517579643056 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0688272960251197 seconds.
# statistic = 18.453262648003747 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.7876850233749595
#
# ------------ 2 - 0.95 CL -  upper bound -----------
# eps = 0.5 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0005086199380457 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.987293960992247 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 5.218435241957195 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.107305387966335 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.919605072005652 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.5986834700452164 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.7057480859803036 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4886898470576853 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3647314469562843 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4642993739107624 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.133124373969622 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.264379685977474 seconds.
# statistic = 11.704464992441507 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.6752045853877253
#
# ------------ 3 - 0.95 CL -  upper bound -----------
# eps = 0.25 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.869955098023638 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2315700729377568 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.122658240958117 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0211860690033063 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2022020340664312 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8750038080615923 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 5.9776828091125935 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.335245985072106 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.716700832010247 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.8410105939256027 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.492523042950779 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.655789265059866 seconds.
# statistic = 8.049465204993211 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.5445190441859133
#
# ------------ 4 - 0.95 CL -  upper bound -----------
# eps = 0.125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3846737999701872 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.460651988047175 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3852269529597834 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.115567928995006 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.363238034886308 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9204523289809003 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.188957766047679 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9755755790974945 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9902020969893783 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1644060550024733 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8683659080415964 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 6.260970977018587 seconds.
# statistic = 6.235210358890798 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.4308457092638258
#
# ------------ 5 - 0.95 CL -  upper bound -----------
# eps = 0.0625 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.098458403954282 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.603898141067475 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.8830012490507215 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4710189239121974 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.63131706090644 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.472440959070809 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4719364769989625 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4305882380576804 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.202766629983671 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4101831609150395 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.005598446005024 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3485058109508827 seconds.
# statistic = 5.417754243554757 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3587364399030575
#
# ------------ 6 - 0.95 CL -  upper bound -----------
# eps = 0.03125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.935065058991313 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2356550300028175 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1286321779480204 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 6.913553409045562 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.803020865074359 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.141764648025855 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.6227460629306734 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.9320978289470077 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3889295218978077 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.7841170880710706 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2520883919205517 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.5040699370438233 seconds.
# statistic = 5.036649101783621 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.3184815089906856
#
# ------------ 7 - 0.95 CL -  upper bound -----------
# eps = 0.015625 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.0188585920259356 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3489623110508546 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.02046370098833 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8049459899775684 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.979133722023107 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.8328356930287555 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.865715500083752 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.787727254093625 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.772035431000404 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.837966541061178 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.248076535994187 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.462168373982422 seconds.
# statistic = 4.8799340261147455 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.300422909282079
#
# ------------ 8 - 0.95 CL -  upper bound -----------
# eps = 0.0078125 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.9624902210198343 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.254583404981531 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.759794692043215 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2702313190093264 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.5581600790610537 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3189406599849463 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2571861199103296 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2488371590152383 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.972372005926445 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2071094519924372 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 2.9223231789655983 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.214741231990047 seconds.
# statistic = 4.807864236895507 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2917929419121734
#
# ------------ 9 - 0.95 CL -  upper bound -----------
# eps = 0.00390625 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 5.967026410973631 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.987636741017923 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.5083585740067065 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.7330588890472427 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.9877555560087785 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.6242328319931403 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# ...
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2694772030226886 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.5149749430129305 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.312080947915092 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.188736766926013 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.3205438719596714 seconds.
# statistic = 4.75691044520884 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.285561888938158
#
# ------------ 49 - 0.95 CL -  upper bound -----------
# eps = 3.552713678800501e-15 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1448023670818657 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.2491361279971898 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.1275875450810418 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 9.244242061045952 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 5.695621015038341 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 5.3436530319741 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.333128966973163 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.530043461942114 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.433687168988399 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.053974775946699 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.3153198580257595 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.6813403599662706 seconds.
# statistic = 4.767102440599496 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.2868170078740195
#
# ------------ 50 - 0.95 CL -  upper bound -----------
# eps = 1.7763568394002505e-15 - deformation = mean
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Parsing input distribution...
# Input distribution is a numeric numpy array or tf.Tensor.
# Checking and setting numerical distributions.
# Returning dist_num.
# Returning dist_num.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.214653293020092 seconds.
#
# ===========================================================
# Testing from 8 to 16 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.631973829935305 seconds.
#
# ===========================================================
# Testing from 16 to 24 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 4.0705051390687 seconds.
#
# ===========================================================
# Testing from 24 to 32 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4850424299947917 seconds.
#
# ===========================================================
# Testing from 32 to 40 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.966453926055692 seconds.
#
# ===========================================================
# Testing from 40 to 48 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.512467461056076 seconds.
#
# ===========================================================
# Testing from 48 to 56 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.7767436819849536 seconds.
#
# ===========================================================
# Testing from 56 to 64 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.4307689560810104 seconds.
#
# ===========================================================
# Testing from 64 to 72 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.6457098469836637 seconds.
#
# ===========================================================
# Testing from 72 to 80 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.456666963058524 seconds.
#
# ===========================================================
# Testing from 80 to 88 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.5956664989935234 seconds.
#
# ===========================================================
# Testing from 88 to 96 of 96 samples.
#
# ------------------------------------------
# Starting KS tests calculation...
# Running TF KS tests...
# niter = 8
# batch_size = 10000
# nchunks = 4
# Iterating from 0 to 2 out of 8 .
# Iterating from 2 to 4 out of 8 .
# Iterating from 4 to 6 out of 8 .
# Iterating from 6 to 8 out of 8 .
# KS tests calculation completed in 3.5373540950240567 seconds.
# statistic = 4.748036013985011 - next threshold = 1.0343795758063465 at 0.95 CL
# relative_error_eps = 2.0
# relative_error_metric = 1.284465421245401
# Time elapsed: 2394.4666615340393 seconds.
# Saving results in the file results_leo/particle_features_60/tests/10K/exclusion_limits.json
# Computing central bounds for ks with mean deformation.
#
# ======================================================
# =============== ks - mean ===============
# ======================================================
# niter: 8, nbootstrap: 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 15
#      13 if result == {}:
#      14     print(f"Computing {bound} bounds for {metric_config['name']} with {deformation} deformation.")
# ---> 15     result = compute_exclusion_bisection_dataset(dataset = dataset,
#      16                                                  metric_config = metric_config,
#      17                                                  test_kwargs = test_kwargs,
#      18                                                  model_dir = model_dir,
#      19                                                  deformation = deformation,
#      20                                                  seed_dist = 0,
#      21                                                  x_tol = 0.1,
#      22                                                  fn_tol = 0.15,
#      23                                                  bound = bound,
#      24                                                  eps_min = 0.,
#      25                                                  eps_max = eps_max,
#      26                                                  smear = 0.,
#      27                                                  max_iterations = 50,
#      28                                                  save = True,
#      29                                                  filename = "exclusion_limits.json",
#      30                                                  verbose = True)
#      31     eps_max = list(result.values())[0]["exclusion_list"][-1][3]
#      32 else:
#
# File /leonardo_scratch/fast/INF24_pmlhep_1/rtorre00/projects/JetNetMetrics/GMetrics/more/optimizers_deformations.py:299, in compute_exclusion_bisection_dataset(dataset, metric_config, test_kwargs, model_dir, deformation, seed_dist, x_tol, fn_tol, bound, eps_min, eps_max, smear, max_iterations, save, filename, verbose)
#     297 eps_min_start = eps_min
#     298 eps_max_start = eps_max
# --> 299 eps = (eps_max + eps_min) / 2.
#     300 eps_min, eps_max = eps_min_start, eps_max_start # Initialize the bounds
#     301 sigma_factor = smear
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'float'

# %% [markdown]
# ### Show and save results

# %%
# Function to format bounds
def format_bounds(bounds):
    lower, central, upper = bounds
    return f"${central}_{{-{central-lower:.2g}}}^{{+{upper-central:.2g}}}$"

def format_times(times):
    return sum(times)

global_results_list = [x for x in global_results.values()]
results = []
for global_result in global_results_list:
    pippo = global_result
    name = global_result["null_config"]["name"]
    print(f"Metric: {name}")
    deformation = global_result["deformation"]
    bound = global_result["bound"]
    ndims = global_result["null_config"]["test_config"]["ndims"]
    niter = global_result["null_config"]["test_config"]["niter"]
    nsamples = global_result["null_config"]["test_config"]["batch_size_test"]
    try:
        exclusion_95 = eval(format(global_result["exclusion_list"][1][3], ".5f"))
    except:
        exclusion_95 = "N/A"
    try:
        exclusion_99 = eval(format(global_result["exclusion_list"][2][3], ".5f"))
    except:
        exclusion_99 = "N/A"
    time_elapsed = global_result["time_elapsed"]
    #print(exclusion_95)
    #print(round_to_n_significant_digits(exclusion_95, 3))
    results.append([name, deformation, ndims, niter, nsamples, bound, exclusion_95, exclusion_99, int(time_elapsed)])
    #results.append([name, deformation, ndims, niter, nsamples, round_to_n_significant_digits(exclusion_95, 3), round_to_n_significant_digits(exclusion_99, 3), int(time_elapsed)])
results_df = pd.DataFrame(results, columns=["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$", "Bound", "$\\epsilon_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$", "t (s)"])
results_df = results_df.groupby(["Statistic", "Deformation", "$N$", "$n=m$", "$n_{\\mathrm{iter}}$"]).agg({
    "$\\epsilon_{95\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "$\\epsilon_{99\\%\\mathrm{CL}}$": lambda x: sorted(x.tolist()),
    "t (s)": lambda x: x.tolist()
}).reset_index()
results_df["95%CL"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"]
results_df["99%CL"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"]
results_df["time"] = results_df["t (s)"]
results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{95\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"] = results_df["$\\epsilon_{99\\%\\mathrm{CL}}$"].apply(format_bounds)
results_df["t (s)"] = results_df["t (s)"].apply(format_times)
times_df = pd.DataFrame(null_times+[["lr", "-"]], columns=["Statistic", "$t^{\\mathrm{null}}$ (s)"])
# Out:
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: fgd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: mmd
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: ks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: sks
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd
# Metric: swd

# %%
results
# Out:
# [['fgd', 'mean', 90, 4, 20000, 'upper', 0.09497, 0.12579, 3185],
#  ['fgd', 'mean', 90, 4, 20000, 'central', 0.07248, 0.10622, 1995],
#  ['fgd', 'mean', 90, 4, 20000, 'lower', 0.03975, 0.08519, 2530],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'upper', 0.09378, 0.11369, 3337],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'central', 0.06284, 0.09005, 2139],
#  ['fgd', 'cov_diag', 90, 4, 20000, 'lower', 0.0358, 0.06854, 3078],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.02887, 0.03966, 3493],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'central', 0.02316, 0.03515, 2017],
#  ['fgd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.01617, 0.03007, 2423],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'upper', 0.05859, 0.07327, 4420],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'central', 0.03599, 0.04934, 2684],
#  ['fgd', 'power_abs_up', 90, 4, 20000, 'lower', 0.01961, 0.03581, 4978],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06534, 0.08171, 4175],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'central', 0.03699, 0.05511, 2697],
#  ['fgd', 'power_abs_down', 90, 4, 20000, 'lower', 0.01878, 0.03787, 2431],
#  ['fgd', 'random_normal', 90, 4, 20000, 'upper', 0.22046, 0.25357, 2974],
#  ['fgd', 'random_normal', 90, 4, 20000, 'central', 0.18671, 0.22667, 2163],
#  ['fgd', 'random_normal', 90, 4, 20000, 'lower', 0.14676, 0.19531, 2979],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'upper', 0.39066, 0.44782, 3786],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'central', 0.32909, 0.39263, 2434],
#  ['fgd', 'random_uniform', 90, 4, 20000, 'lower', 0.26571, 0.3428, 2437],
#  ['mmd', 'mean', 90, 4, 20000, 'upper', 0.38566, 0.47565, 2441],
#  ['mmd', 'mean', 90, 4, 20000, 'central', 0.22947, 0.32659, 1654],
#  ['mmd', 'mean', 90, 4, 20000, 'lower', 0.12215, 0.21559, 1874],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'upper', 0.17969, 0.21734, 3476],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'central', 0.11334, 0.15031, 2189],
#  ['mmd', 'cov_diag', 90, 4, 20000, 'lower', 0.06416, 0.09461, 3208],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.21143, 0.27996, 2932],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'central', 0.16131, 0.23825, 2312],
#  ['mmd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.11084, 0.18291, 1821],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'upper', 0.05414, 0.06147, 2735],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'central', 0.03206, 0.04228, 1756],
#  ['mmd', 'power_abs_up', 90, 4, 20000, 'lower', 0.01805, 0.02662, 5319],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06255, 0.07513, 3618],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'central', 0.0336, 0.04991, 2407],
#  ['mmd', 'power_abs_down', 90, 4, 20000, 'lower', 0.01711, 0.0303, 2515],
#  ['mmd', 'random_normal', 90, 4, 20000, 'upper', 0.54736, 0.59157, 2782],
#  ['mmd', 'random_normal', 90, 4, 20000, 'central', 0.40194, 0.50268, 5573],
#  ['mmd', 'random_normal', 90, 4, 20000, 'lower', 0.32453, 0.38821, 4008],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'upper', 0.92578, 1.0, 6652],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'central', 0.68726, 0.87417, 3735],
#  ['mmd', 'random_uniform', 90, 4, 20000, 'lower', 0.48549, 0.66939, 5109],
#  ['ks', 'mean', 90, 4, 20000, 'upper', 0.01556, 0.02106, 870],
#  ['ks', 'mean', 90, 4, 20000, 'central', 0.00983, 0.01725, 697],
#  ['ks', 'mean', 90, 4, 20000, 'lower', 0.00216, 0.01212, 907],
#  ['ks', 'cov_diag', 90, 4, 20000, 'upper', 0.03992, 0.05452, 1275],
#  ['ks', 'cov_diag', 90, 4, 20000, 'central', 0.02545, 0.03987, 1038],
#  ['ks', 'cov_diag', 90, 4, 20000, 'lower', 0.00535, 0.02814, 1272],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'upper', 0.05786, 0.07362, 1643],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'central', 0.04069, 0.0569, 1280],
#  ['ks', 'cov_off_diag', 90, 4, 20000, 'lower', 0.01406, 0.04636, 1540],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'upper', 0.02649, 0.0377, 2225],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'central', 0.01613, 0.02649, 1668],
#  ['ks', 'power_abs_up', 90, 4, 20000, 'lower', 0.00332, 0.01785, 2094],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'upper', 0.02625, 0.03515, 2699],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'central', 0.01641, 0.02571, 1988],
#  ['ks', 'power_abs_down', 90, 4, 20000, 'lower', 0.00343, 0.01848, 2364],
#  ['ks', 'random_normal', 90, 4, 20000, 'upper', 0.11182, 0.12812, 2605],
#  ['ks', 'random_normal', 90, 4, 20000, 'central', 0.09133, 0.11404, 2153],
#  ['ks', 'random_normal', 90, 4, 20000, 'lower', 0.06526, 0.08927, 2219],
#  ['ks', 'random_uniform', 90, 4, 20000, 'upper', 0.18799, 0.21785, 2787],
#  ['ks', 'random_uniform', 90, 4, 20000, 'central', 0.1553, 0.18609, 2386],
#  ['ks', 'random_uniform', 90, 4, 20000, 'lower', 0.11812, 0.15157, 2508],
#  ['sks', 'mean', 90, 4, 20000, 'upper', 0.03406, 0.04532, 5082],
#  ['sks', 'mean', 90, 4, 20000, 'central', 0.02647, 0.03781, 3461],
#  ['sks', 'mean', 90, 4, 20000, 'lower', 0.01532, 0.03034, 4020],
#  ['sks', 'cov_diag', 90, 4, 20000, 'upper', 0.05493, 0.06906, 5153],
#  ['sks', 'cov_diag', 90, 4, 20000, 'central', 0.04033, 0.05582, 3767],
#  ['sks', 'cov_diag', 90, 4, 20000, 'lower', 0.02605, 0.04593, 4130],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'upper', 0.04724, 0.06382, 5840],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'central', 0.03578, 0.05309, 4064],
#  ['sks', 'cov_off_diag', 90, 4, 20000, 'lower', 0.02151, 0.0431, 4766],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'upper', 0.08203, 0.11142, 1146],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'central', 0.06093, 0.08302, 815],
#  ['sks', 'power_abs_up', 90, 4, 20000, 'lower', 0.03502, 0.06202, 856],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'upper', 0.08203, 0.09836, 1348],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'central', 0.05686, 0.0802, 972],
#  ['sks', 'power_abs_down', 90, 4, 20000, 'lower', 0.03133, 0.05424, 1139],
#  ['sks', 'random_normal', 90, 4, 20000, 'upper', 0.12109, 0.13885, 1409],
#  ['sks', 'random_normal', 90, 4, 20000, 'central', 0.10848, 0.13506, 834],
#  ['sks', 'random_normal', 90, 4, 20000, 'lower', 0.08863, 0.11765, 845],
#  ['sks', 'random_uniform', 90, 4, 20000, 'upper', 0.21094, 0.23804, 1257],
#  ['sks', 'random_uniform', 90, 4, 20000, 'central', 0.18597, 0.23153, 901],
#  ['sks', 'random_uniform', 90, 4, 20000, 'lower', 0.15194, 0.20168, 904],
#  ['swd', 'mean', 90, 4, 20000, 'upper', 0.05664, 0.07396, 453],
#  ['swd', 'mean', 90, 4, 20000, 'central', 0.03814, 0.06276, 301],
#  ['swd', 'mean', 90, 4, 20000, 'lower', 0.02059, 0.043, 332],
#  ['swd', 'cov_diag', 90, 4, 20000, 'upper', 0.06445, 0.08147, 443],
#  ['swd', 'cov_diag', 90, 4, 20000, 'central', 0.04455, 0.06532, 304],
#  ['swd', 'cov_diag', 90, 4, 20000, 'lower', 0.02551, 0.04915, 323],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'upper', 0.06055, 0.08458, 481],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'central', 0.04625, 0.0726, 307],
#  ['swd', 'cov_off_diag', 90, 4, 20000, 'lower', 0.02836, 0.05878, 284],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'upper', 0.06055, 0.07771, 465],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'central', 0.0425, 0.0535, 294],
#  ['swd', 'power_abs_up', 90, 4, 20000, 'lower', 0.0209, 0.04026, 316],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'upper', 0.06055, 0.07771, 455],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'central', 0.04493, 0.05927, 299],
#  ['swd', 'power_abs_down', 90, 4, 20000, 'lower', 0.0213, 0.04622, 321],
#  ['swd', 'random_normal', 90, 4, 20000, 'upper', 0.16406, 0.19031, 357],
#  ['swd', 'random_normal', 90, 4, 20000, 'central', 0.13678, 0.17024, 230],
#  ['swd', 'random_normal', 90, 4, 20000, 'lower', 0.11172, 0.14829, 224],
#  ['swd', 'random_uniform', 90, 4, 20000, 'upper', 0.28906, 0.32861, 284],
#  ['swd', 'random_uniform', 90, 4, 20000, 'central', 0.23619, 0.29395, 228],
#  ['swd', 'random_uniform', 90, 4, 20000, 'lower', 0.19291, 0.25606, 229]]

# %%
results_df_mean = results_df[results_df["Deformation"] == "mean"]
results_df_cov_diag = results_df[results_df["Deformation"] == "cov_diag"]
results_df_cov_off_diag = results_df[results_df["Deformation"] == "cov_off_diag"]
results_df_power_abs_up = results_df[results_df["Deformation"] == "power_abs_up"]
results_df_power_abs_down = results_df[results_df["Deformation"] == "power_abs_down"]
results_df_random_normal = results_df[results_df["Deformation"] == "random_normal"]
results_df_random_uniform = results_df[results_df["Deformation"] == "random_uniform"]

# %%
results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
sorted_df_mean = results_df_mean.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_mean.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mu}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mu}$ (s)"}, inplace=True)
display(sorted_df_mean)
sorted_df_mean.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_mean)
# Out:
# /tmp/ipykernel_3533038/2349835371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_mean["sort_key"] = results_df_mean["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 9         ks        mean   90      4                20000
# 23       sks        mean   90      4                20000
# 30       swd        mean   90      4                20000
# 2        fgd        mean   90      4                20000
# 16       mmd        mean   90      4                20000
#
#    $\epsilon^{\mu}_{95\%\mathrm{CL}}$ $\epsilon^{\mu}_{99\%\mathrm{CL}}$  \
# 9       $0.00983_{-0.0077}^{+0.0057}$      $0.01725_{-0.0051}^{+0.0038}$
# 23       $0.02647_{-0.011}^{+0.0076}$      $0.03781_{-0.0075}^{+0.0075}$
# 30        $0.03814_{-0.018}^{+0.019}$         $0.06276_{-0.02}^{+0.011}$
# 2         $0.07248_{-0.033}^{+0.022}$         $0.10622_{-0.021}^{+0.02}$
# 16          $0.22947_{-0.11}^{+0.16}$          $0.32659_{-0.11}^{+0.15}$
#
#     $t^{\mu}$ (s)                        95%CL                        99%CL  \
# 9            2474  [0.00216, 0.00983, 0.01556]  [0.01212, 0.01725, 0.02106]
# 23          12563  [0.01532, 0.02647, 0.03406]  [0.03034, 0.03781, 0.04532]
# 30           1086  [0.02059, 0.03814, 0.05664]    [0.043, 0.06276, 0.07396]
# 2            7710  [0.03975, 0.07248, 0.09497]  [0.08519, 0.10622, 0.12579]
# 16           5969  [0.12215, 0.22947, 0.38566]  [0.21559, 0.32659, 0.47565]
#
#                   time
# 9      [870, 697, 907]
# 23  [5082, 3461, 4020]
# 30     [453, 301, 332]
# 2   [3185, 1995, 2530]
# 16  [2441, 1654, 1874]
#    Statistic $\epsilon^{\mu}_{95\%\mathrm{CL}}$  \
# 9         ks      $0.00983_{-0.0077}^{+0.0057}$
# 23       sks       $0.02647_{-0.011}^{+0.0076}$
# 30       swd        $0.03814_{-0.018}^{+0.019}$
# 2        fgd        $0.07248_{-0.033}^{+0.022}$
# 16       mmd          $0.22947_{-0.11}^{+0.16}$
#
#    $\epsilon^{\mu}_{99\%\mathrm{CL}}$  $t^{\mu}$ (s)
# 9       $0.01725_{-0.0051}^{+0.0038}$           2474
# 23      $0.03781_{-0.0075}^{+0.0075}$          12563
# 30         $0.06276_{-0.02}^{+0.011}$           1086
# 2          $0.10622_{-0.021}^{+0.02}$           7710
# 16          $0.32659_{-0.11}^{+0.15}$           5969

# %%
results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_diag = results_df_cov_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{ii}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{ii}}$ (s)"}, inplace=True)
display(sorted_df_cov_diag)
sorted_df_cov_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_diag)
# Out:
# /tmp/ipykernel_3533038/2882134307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_diag["sort_key"] = results_df_cov_diag["95%CL"].apply(lambda x: x[1])
#    Statistic Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 7         ks    cov_diag   90      4                20000
# 21       sks    cov_diag   90      4                20000
# 28       swd    cov_diag   90      4                20000
# 0        fgd    cov_diag   90      4                20000
# 14       mmd    cov_diag   90      4                20000
#
#    $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7                  $0.02545_{-0.02}^{+0.014}$
# 21                $0.04033_{-0.014}^{+0.015}$
# 28                 $0.04455_{-0.019}^{+0.02}$
# 0                 $0.06284_{-0.027}^{+0.031}$
# 14                $0.11334_{-0.049}^{+0.066}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)  \
# 7                 $0.03987_{-0.012}^{+0.015}$                   3585
# 21               $0.05582_{-0.0099}^{+0.013}$                  13050
# 28                $0.06532_{-0.016}^{+0.016}$                   1070
# 0                 $0.09005_{-0.022}^{+0.024}$                   8554
# 14                $0.15031_{-0.056}^{+0.067}$                   8873
#
#                           95%CL                        99%CL  \
# 7   [0.00535, 0.02545, 0.03992]  [0.02814, 0.03987, 0.05452]
# 21  [0.02605, 0.04033, 0.05493]  [0.04593, 0.05582, 0.06906]
# 28  [0.02551, 0.04455, 0.06445]  [0.04915, 0.06532, 0.08147]
# 0    [0.0358, 0.06284, 0.09378]  [0.06854, 0.09005, 0.11369]
# 14  [0.06416, 0.11334, 0.17969]  [0.09461, 0.15031, 0.21734]
#
#                   time
# 7   [1275, 1038, 1272]
# 21  [5153, 3767, 4130]
# 28     [443, 304, 323]
# 0   [3337, 2139, 3078]
# 14  [3476, 2189, 3208]
#    Statistic $\epsilon^{\Sigma_{ii}}_{95\%\mathrm{CL}}$  \
# 7         ks                 $0.02545_{-0.02}^{+0.014}$
# 21       sks                $0.04033_{-0.014}^{+0.015}$
# 28       swd                 $0.04455_{-0.019}^{+0.02}$
# 0        fgd                $0.06284_{-0.027}^{+0.031}$
# 14       mmd                $0.11334_{-0.049}^{+0.066}$
#
#    $\epsilon^{\Sigma_{ii}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{ii}}$ (s)
# 7                 $0.03987_{-0.012}^{+0.015}$                   3585
# 21               $0.05582_{-0.0099}^{+0.013}$                  13050
# 28                $0.06532_{-0.016}^{+0.016}$                   1070
# 0                 $0.09005_{-0.022}^{+0.024}$                   8554
# 14                $0.15031_{-0.056}^{+0.067}$                   8873

# %%
results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
sorted_df_cov_off_diag = results_df_cov_off_diag.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_cov_off_diag.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\Sigma_{i\\neq j}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\Sigma_{i\\neq j}}$ (s)"}, inplace=True)
display(sorted_df_cov_off_diag)
sorted_df_cov_off_diag.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_cov_off_diag)
# Out:
# /tmp/ipykernel_3533038/3376285218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_cov_off_diag["sort_key"] = results_df_cov_off_diag["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 1        fgd  cov_off_diag   90      4                20000
# 22       sks  cov_off_diag   90      4                20000
# 8         ks  cov_off_diag   90      4                20000
# 29       swd  cov_off_diag   90      4                20000
# 15       mmd  cov_off_diag   90      4                20000
#
#    $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 1                     $0.02316_{-0.007}^{+0.0057}$
# 22                     $0.03578_{-0.014}^{+0.011}$
# 8                      $0.04069_{-0.027}^{+0.017}$
# 29                     $0.04625_{-0.018}^{+0.014}$
# 15                       $0.16131_{-0.05}^{+0.05}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  \
# 1                    $0.03515_{-0.0051}^{+0.0045}$
# 22                      $0.05309_{-0.01}^{+0.011}$
# 8                       $0.0569_{-0.011}^{+0.017}$
# 29                      $0.0726_{-0.014}^{+0.012}$
# 15                     $0.23825_{-0.055}^{+0.042}$
#
#     $t^{\Sigma_{i\neq j}}$ (s)                        95%CL  \
# 1                         7933  [0.01617, 0.02316, 0.02887]
# 22                       14670  [0.02151, 0.03578, 0.04724]
# 8                         4463  [0.01406, 0.04069, 0.05786]
# 29                        1072  [0.02836, 0.04625, 0.06055]
# 15                        7065  [0.11084, 0.16131, 0.21143]
#
#                           99%CL                time
# 1   [0.03007, 0.03515, 0.03966]  [3493, 2017, 2423]
# 22   [0.0431, 0.05309, 0.06382]  [5840, 4064, 4766]
# 8    [0.04636, 0.0569, 0.07362]  [1643, 1280, 1540]
# 29   [0.05878, 0.0726, 0.08458]     [481, 307, 284]
# 15  [0.18291, 0.23825, 0.27996]  [2932, 2312, 1821]
#    Statistic $\epsilon^{\Sigma_{i\neq j}}_{95\%\mathrm{CL}}$  \
# 1        fgd                    $0.02316_{-0.007}^{+0.0057}$
# 22       sks                     $0.03578_{-0.014}^{+0.011}$
# 8         ks                     $0.04069_{-0.027}^{+0.017}$
# 29       swd                     $0.04625_{-0.018}^{+0.014}$
# 15       mmd                       $0.16131_{-0.05}^{+0.05}$
#
#    $\epsilon^{\Sigma_{i\neq j}}_{99\%\mathrm{CL}}$  $t^{\Sigma_{i\neq j}}$ (s)
# 1                    $0.03515_{-0.0051}^{+0.0045}$                        7933
# 22                      $0.05309_{-0.01}^{+0.011}$                       14670
# 8                       $0.0569_{-0.011}^{+0.017}$                        4463
# 29                      $0.0726_{-0.014}^{+0.012}$                        1072
# 15                     $0.23825_{-0.055}^{+0.042}$                        7065

# %%
results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_up = results_df_power_abs_up.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_up.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{+}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{+}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_up)
sorted_df_power_abs_up.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_up)
# Out:
# /tmp/ipykernel_3533038/2976661110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_up["sort_key"] = results_df_power_abs_up["95%CL"].apply(lambda x: x[1])
#    Statistic   Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 11        ks  power_abs_up   90      4                20000
# 18       mmd  power_abs_up   90      4                20000
# 4        fgd  power_abs_up   90      4                20000
# 32       swd  power_abs_up   90      4                20000
# 25       sks  power_abs_up   90      4                20000
#
#    $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11                  $0.01613_{-0.013}^{+0.01}$
# 18                 $0.03206_{-0.014}^{+0.022}$
# 4                  $0.03599_{-0.016}^{+0.023}$
# 32                  $0.0425_{-0.022}^{+0.018}$
# 25                 $0.06093_{-0.026}^{+0.021}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)  \
# 11                $0.02649_{-0.0086}^{+0.011}$                    5987
# 18                 $0.04228_{-0.016}^{+0.019}$                    9810
# 4                  $0.04934_{-0.014}^{+0.024}$                   12082
# 32                  $0.0535_{-0.013}^{+0.024}$                    1075
# 25                 $0.08302_{-0.021}^{+0.028}$                    2817
#
#                           95%CL                        99%CL  \
# 11  [0.00332, 0.01613, 0.02649]   [0.01785, 0.02649, 0.0377]
# 18  [0.01805, 0.03206, 0.05414]  [0.02662, 0.04228, 0.06147]
# 4   [0.01961, 0.03599, 0.05859]  [0.03581, 0.04934, 0.07327]
# 32    [0.0209, 0.0425, 0.06055]   [0.04026, 0.0535, 0.07771]
# 25  [0.03502, 0.06093, 0.08203]  [0.06202, 0.08302, 0.11142]
#
#                   time
# 11  [2225, 1668, 2094]
# 18  [2735, 1756, 5319]
# 4   [4420, 2684, 4978]
# 32     [465, 294, 316]
# 25    [1146, 815, 856]
#    Statistic $\epsilon^{\rm{pow}_{+}}_{95\%\mathrm{CL}}$  \
# 11        ks                  $0.01613_{-0.013}^{+0.01}$
# 18       mmd                 $0.03206_{-0.014}^{+0.022}$
# 4        fgd                 $0.03599_{-0.016}^{+0.023}$
# 32       swd                  $0.0425_{-0.022}^{+0.018}$
# 25       sks                 $0.06093_{-0.026}^{+0.021}$
#
#    $\epsilon^{\rm{pow}_{+}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{+}}$ (s)
# 11                $0.02649_{-0.0086}^{+0.011}$                    5987
# 18                 $0.04228_{-0.016}^{+0.019}$                    9810
# 4                  $0.04934_{-0.014}^{+0.024}$                   12082
# 32                  $0.0535_{-0.013}^{+0.024}$                    1075
# 25                 $0.08302_{-0.021}^{+0.028}$                    2817

# %%
results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
sorted_df_power_abs_down = results_df_power_abs_down.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_power_abs_down.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\rm{pow}_{-}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\rm{pow}_{-}}$ (s)"}, inplace=True)
display(sorted_df_power_abs_down)
sorted_df_power_abs_down.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_power_abs_down)
# Out:
# /tmp/ipykernel_3533038/1061777215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_power_abs_down["sort_key"] = results_df_power_abs_down["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 10        ks  power_abs_down   90      4                20000
# 17       mmd  power_abs_down   90      4                20000
# 3        fgd  power_abs_down   90      4                20000
# 31       swd  power_abs_down   90      4                20000
# 24       sks  power_abs_down   90      4                20000
#
#    $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10                $0.01641_{-0.013}^{+0.0098}$
# 17                  $0.0336_{-0.016}^{+0.029}$
# 3                  $0.03699_{-0.018}^{+0.028}$
# 31                 $0.04493_{-0.024}^{+0.016}$
# 24                 $0.05686_{-0.026}^{+0.025}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)  \
# 10               $0.02571_{-0.0072}^{+0.0094}$                    7051
# 17                  $0.04991_{-0.02}^{+0.025}$                    8540
# 3                  $0.05511_{-0.017}^{+0.027}$                    9303
# 31                 $0.05927_{-0.013}^{+0.018}$                    1075
# 24                  $0.0802_{-0.026}^{+0.018}$                    3459
#
#                           95%CL                        99%CL  \
# 10  [0.00343, 0.01641, 0.02625]  [0.01848, 0.02571, 0.03515]
# 17   [0.01711, 0.0336, 0.06255]   [0.0303, 0.04991, 0.07513]
# 3   [0.01878, 0.03699, 0.06534]  [0.03787, 0.05511, 0.08171]
# 31   [0.0213, 0.04493, 0.06055]  [0.04622, 0.05927, 0.07771]
# 24  [0.03133, 0.05686, 0.08203]   [0.05424, 0.0802, 0.09836]
#
#                   time
# 10  [2699, 1988, 2364]
# 17  [3618, 2407, 2515]
# 3   [4175, 2697, 2431]
# 31     [455, 299, 321]
# 24   [1348, 972, 1139]
#    Statistic $\epsilon^{\rm{pow}_{-}}_{95\%\mathrm{CL}}$  \
# 10        ks                $0.01641_{-0.013}^{+0.0098}$
# 17       mmd                  $0.0336_{-0.016}^{+0.029}$
# 3        fgd                 $0.03699_{-0.018}^{+0.028}$
# 31       swd                 $0.04493_{-0.024}^{+0.016}$
# 24       sks                 $0.05686_{-0.026}^{+0.025}$
#
#    $\epsilon^{\rm{pow}_{-}}_{99\%\mathrm{CL}}$  $t^{\rm{pow}_{-}}$ (s)
# 10               $0.02571_{-0.0072}^{+0.0094}$                    7051
# 17                  $0.04991_{-0.02}^{+0.025}$                    8540
# 3                  $0.05511_{-0.017}^{+0.027}$                    9303
# 31                 $0.05927_{-0.013}^{+0.018}$                    1075
# 24                  $0.0802_{-0.026}^{+0.018}$                    3459

# %%
results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_normal = results_df_random_normal.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_normal.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{N}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{N}}$ (s)"}, inplace=True)
display(sorted_df_random_normal)
sorted_df_random_normal.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_normal)
# Out:
# /tmp/ipykernel_3533038/3420336598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_normal["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic    Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 12        ks  random_normal   90      4                20000
# 26       sks  random_normal   90      4                20000
# 33       swd  random_normal   90      4                20000
# 5        fgd  random_normal   90      4                20000
# 19       mmd  random_normal   90      4                20000
#
#    $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 12                 $0.09133_{-0.026}^{+0.02}$
# 26                 $0.10848_{-0.02}^{+0.013}$
# 33                $0.13678_{-0.025}^{+0.027}$
# 5                  $0.18671_{-0.04}^{+0.034}$
# 19                 $0.40194_{-0.077}^{+0.15}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)  \
# 12                $0.11404_{-0.025}^{+0.014}$                   6977
# 26               $0.13506_{-0.017}^{+0.0038}$                   3088
# 33                 $0.17024_{-0.022}^{+0.02}$                    811
# 5                 $0.22667_{-0.031}^{+0.027}$                   8116
# 19                 $0.50268_{-0.11}^{+0.089}$                  12363
#
#                           95%CL                        99%CL  \
# 12  [0.06526, 0.09133, 0.11182]  [0.08927, 0.11404, 0.12812]
# 26  [0.08863, 0.10848, 0.12109]  [0.11765, 0.13506, 0.13885]
# 33  [0.11172, 0.13678, 0.16406]  [0.14829, 0.17024, 0.19031]
# 5   [0.14676, 0.18671, 0.22046]  [0.19531, 0.22667, 0.25357]
# 19  [0.32453, 0.40194, 0.54736]  [0.38821, 0.50268, 0.59157]
#
#                   time
# 12  [2605, 2153, 2219]
# 26    [1409, 834, 845]
# 33     [357, 230, 224]
# 5   [2974, 2163, 2979]
# 19  [2782, 5573, 4008]
#    Statistic $\epsilon^{\mathcal{N}}_{95\%\mathrm{CL}}$  \
# 12        ks                 $0.09133_{-0.026}^{+0.02}$
# 26       sks                 $0.10848_{-0.02}^{+0.013}$
# 33       swd                $0.13678_{-0.025}^{+0.027}$
# 5        fgd                 $0.18671_{-0.04}^{+0.034}$
# 19       mmd                 $0.40194_{-0.077}^{+0.15}$
#
#    $\epsilon^{\mathcal{N}}_{99\%\mathrm{CL}}$  $t^{\mathcal{N}}$ (s)
# 12                $0.11404_{-0.025}^{+0.014}$                   6977
# 26               $0.13506_{-0.017}^{+0.0038}$                   3088
# 33                 $0.17024_{-0.022}^{+0.02}$                    811
# 5                 $0.22667_{-0.031}^{+0.027}$                   8116
# 19                 $0.50268_{-0.11}^{+0.089}$                  12363

# %%
results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
sorted_df_random_uniform = results_df_random_uniform.sort_values(by="sort_key", ascending=True).drop(columns=["sort_key"])
sorted_df_random_uniform.rename(columns={"$\\epsilon_{95\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{95\\%\\mathrm{CL}}$", "$\\epsilon_{99\\%\\mathrm{CL}}$": "$\\epsilon^{\\mathcal{U}}_{99\\%\\mathrm{CL}}$", "t (s)": "$t^{\\mathcal{U}}$ (s)"}, inplace=True)
display(sorted_df_random_uniform)
sorted_df_random_uniform.drop(columns=["Deformation","$N$","$n=m$","$n_{\\mathrm{iter}}$", "95%CL", "99%CL", "time"], inplace=True)
display(sorted_df_random_uniform)
# Out:
# /tmp/ipykernel_3533038/3647480920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df_random_uniform["sort_key"] = results_df_random_normal["95%CL"].apply(lambda x: x[1])
#    Statistic     Deformation  $N$  $n=m$  $n_{\mathrm{iter}}$  \
# 6        fgd  random_uniform   90      4                20000
# 13        ks  random_uniform   90      4                20000
# 20       mmd  random_uniform   90      4                20000
# 27       sks  random_uniform   90      4                20000
# 34       swd  random_uniform   90      4                20000
#
#    $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6                 $0.32909_{-0.063}^{+0.062}$
# 13                 $0.1553_{-0.037}^{+0.033}$
# 20                   $0.68726_{-0.2}^{+0.24}$
# 27                $0.18597_{-0.034}^{+0.025}$
# 34                $0.23619_{-0.043}^{+0.053}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)  \
# 6                  $0.39263_{-0.05}^{+0.055}$                   8657
# 13                $0.18609_{-0.035}^{+0.032}$                   7681
# 20                   $0.87417_{-0.2}^{+0.13}$                  15496
# 27                $0.23153_{-0.03}^{+0.0065}$                   3062
# 34                $0.29395_{-0.038}^{+0.035}$                    741
#
#                           95%CL                        99%CL  \
# 6   [0.26571, 0.32909, 0.39066]   [0.3428, 0.39263, 0.44782]
# 13   [0.11812, 0.1553, 0.18799]  [0.15157, 0.18609, 0.21785]
# 20  [0.48549, 0.68726, 0.92578]      [0.66939, 0.87417, 1.0]
# 27  [0.15194, 0.18597, 0.21094]  [0.20168, 0.23153, 0.23804]
# 34  [0.19291, 0.23619, 0.28906]  [0.25606, 0.29395, 0.32861]
#
#                   time
# 6   [3786, 2434, 2437]
# 13  [2787, 2386, 2508]
# 20  [6652, 3735, 5109]
# 27    [1257, 901, 904]
# 34     [284, 228, 229]
#    Statistic $\epsilon^{\mathcal{U}}_{95\%\mathrm{CL}}$  \
# 6        fgd                $0.32909_{-0.063}^{+0.062}$
# 13        ks                 $0.1553_{-0.037}^{+0.033}$
# 20       mmd                   $0.68726_{-0.2}^{+0.24}$
# 27       sks                $0.18597_{-0.034}^{+0.025}$
# 34       swd                $0.23619_{-0.043}^{+0.053}$
#
#    $\epsilon^{\mathcal{U}}_{99\%\mathrm{CL}}$  $t^{\mathcal{U}}$ (s)
# 6                  $0.39263_{-0.05}^{+0.055}$                   8657
# 13                $0.18609_{-0.035}^{+0.032}$                   7681
# 20                   $0.87417_{-0.2}^{+0.13}$                  15496
# 27                $0.23153_{-0.03}^{+0.0065}$                   3062
# 34                $0.29395_{-0.038}^{+0.035}$                    741
